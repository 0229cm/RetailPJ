# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
pd.set_option('display.max_rows', 2800)

# %%
df = pd.read_csv(base_path + 'df1007-1.csv')

# %%
df
# Out:
#          month      GDS_NM  SALE_AMT  day
# 0            9   의성햇사과8입1봉      9960    3
# 1            9     쌈배추벌크1통      1980    3
# 2            9  성주꿀참외특6입1봉      9800    3
# 3            9     대패삼겹살수입     13060    3
# 4            9        거봉포도      6420    3
# ...        ...         ...       ...  ...
# 2079019      4          찹쌀     49500    4
# 2079020      7          찹쌀     49500    2
# 2079021     11         늘보리      7300    6
# 2079022      3         늘보리      7300    3
# 2079023      6         늘보리      7300    4
#
# [2079024 rows x 4 columns]

# %%
df['GDS_NM'].nunique()
# Out:
# 2667

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                          69350
# 백오이                         45710
# 깻잎                          42013
# 흙당근                         39918
# 적상추                         32551
# 감자                          30366
# 청양고추소                       29863
# 인큐애호박2개행사                   29190
# 느타리버섯1팩                     27791
# 인큐애호박                       24443
# 부추                          22604
# 팽이버섯1봉                      21808
# 시금치                         21602
# 양파중1망                       20830
# 새송이버섯1봉                     19871
# 청상추1봉                       19475
# 파프리카                        19352
# 쌈배추알배기1통                    18446
# 가지5입봉                       18322
# 새송이버섯2봉1인2봉한정               18111
# 국내산돈앞다리살                    17692
# 부사사과6개                      16908
# 백오이3개                       16698
# 추부깻잎1봉                      16638
# 무우봉투명비닐                     16446
# 야채                          14441
# 양파특대1망                      14141
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2개행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1팩", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1봉", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1망", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2봉1인2봉한정", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("6개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1송이", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("k", "kg")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("kgg", "kg")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("구입시행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10개", "")

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                          69350
# 백오이                         62408
# 인큐애호박                       53633
# 깻잎                          42013
# 새송이버섯                       40855
# 흙당근                         39918
# 적상추                         32551
# 감자                          30366
# 청양고추소                       29863
# 느타리버섯                       29574
# 파프리카                        28053
# 부추                          22604
# 팽이버섯                        22170
# 시금치                         21602
# 청상추                         21258
# 양파중                         20830
# 추부깻잎                        18739
# 쌈배추알배기1통                    18446
# 가지5입봉                       18322
# 부사사과                        17744
# 국내산돈앞다리살                    17692
# 무우봉투명비닐                     16446
# 일반애호박                       15645
# 야채                          14441
# 양파특대                        14141
# 포기상추                        14140
# 빨강대추방울토마토                   13328
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1통", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2팩", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3팩전단", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2송이", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2팩", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3팩행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("8개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("6입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2팩구입시", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10입행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5개벌크행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("특1", "")

# %%
df['GDS_NM'].value_counts()
# Out:
# 백오이                      70088
# 대파                       69350
# 인큐애호박                    53633
# 깻잎                       42013
# 새송이버섯                    41361
# 흙당근                      39918
# 느타리버섯                    37596
# 적상추                      33023
# 감자                       30366
# 청양고추소                    29863
# 파프리카                     28053
# 부추                       22604
# 팽이버섯                     22170
# 시금치                      21602
# 청상추                      21358
# 양파중                      20830
# 양배추                      20447
# 빨강대추방울토마토                19792
# 추부깻잎                     18739
# 쌈배추알배기                   18446
# 가지5입봉                    18322
# 부사사과                     17745
# 국내산돈앞다리살                 17692
# 무우봉투명비닐                  16446
# 일반애호박                    15645
# 야채                       14441
# 포기상추                     14229
# 양파특대                     14141
# 국내산돈삼겹살                  13264
# 아삭이고추                    13077
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1줄행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4개전단", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2단어플행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("구입시", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("행사", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("벌크1", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10단", "")

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     39918
# 적상추                     33023
# 감자                      30366
# 청양고추소                   29863
# 파프리카                    28313
# 시금치                     24670
# 부추                      22604
# 팽이버섯                    22171
# 청상추                     21358
# 양파중                     20830
# 양배추                     20447
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지5입봉                   18322
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 포기상추                    14229
# 양파특대                    14141
# 국내산돈삼겹살                 13264
# 아삭이고추                   13077
# ...

# %%
df['GDS_NM'].nunique()
# Out:
# 2523

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10kg이상라벨", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("SB", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("101입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("59kg이상", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4kg박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2L5kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1묶음", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("상35", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("7입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1판", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10kg라벨부착", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("M5kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1다발", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10kg이상", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1포", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4봉", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5kgL2L", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1kg봉", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("7kg이상", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5입", "")

# %%
df['GDS_NM'].nunique()
# Out:
# 2482

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     39918
# 적상추                     33023
# 감자                      30366
# 청양고추소                   29863
# 파프리카                    28313
# 시금치                     24670
# 부추                      22604
# 팽이버섯                    22171
# 청상추                     21358
# 양파중                     20830
# 양배추                     20447
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 청양고추                    17614
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 포기상추                    14229
# 양파특대                    14141
# 국내산돈삼겹살                 13264
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("500g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2입봉", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("180g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("350g이내국산", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("15kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2kg박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("500g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("15kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("18kg국산", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("200g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("L5kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2입묶음", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("750g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("15kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("15kg박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("35", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4입", "")

# %%
df['GDS_NM'].nunique()
# Out:
# 2438

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     39918
# 파프리카                    38262
# 감자                      34202
# 적상추                     33067
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22604
# 팽이버섯                    22171
# 청상추                     21358
# 양파중                     20830
# 양배추                     20447
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14364
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2봉", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("S", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("45", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2S", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1번들", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2통", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("양파장아찌용1", "양파장아찌용")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1214수", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3구", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("햇양파쇼리1", "햇양파쇼리")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2봉전단한정", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1상자", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("20kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3구", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("짭짤이토마토2", "짭짤이토마토")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("800g", "")

# %%
df['GDS_NM'].nunique()
# Out:
# 2422

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     39918
# 파프리카                    38262
# 감자                      34202
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22604
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14364
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("8입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2단", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2s", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1다라", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("0kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1뭉치", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2다라_", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3단", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4단", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("팩딸기특34", "딸기")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5ML", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("호올스자몽B", "호올스자몽")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("100g특품", "")

# %%
df['GDS_NM'].nunique()
# Out:
# 2397

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14364
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("감귤L", "감귤")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("141박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("짱아찌마늘태안박상식문석훈외", "짱아찌마늘")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("56수팩", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("9kg이상", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3K", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("100g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4kg13내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("특품100g", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10내4kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4T", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("172", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("141516과", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("양파1", "양파")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1Kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4kg", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("7개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4송이", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("곱들락감귤2", "감귤")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("감귤곱들락5KG", "감귤")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("의성자두2번", "의성자두")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("일천배세트10내", "일천배")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("육쪽마늘태안이주희이병문송일춘김영웅외", "육쪽마늘")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("한우치마살1", "한우치마살")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("한우채끝등심1", "한우채끝등심")

# %%
df['GDS_NM'].nunique()
# Out:
# 2374

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("16내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("B파", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("한우꽃등심1", "한우꽃등심")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("5K", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("기획", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("약30개", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("16내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("15내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1113과", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1번", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("중10KG", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("111", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("14과", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("안동청송의성4번", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("밤고구마상", "밤고구마")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("배사랑일천배세트12내", "일천배")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("매실특대10KG", "매실")

# %%
df['GDS_NM'].nunique()
# Out:
# 2361

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42013
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1419입", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("M", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("13내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1417내박스", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("4수", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("3팩", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10입봉", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1315과", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("하10KG", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("9깻잎", "깻잎")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("10내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("13내", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("1617과", "")

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace("2과", "")

# %%
df['GDS_NM'].nunique()
# Out:
# 2346

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
df.to_csv('df1007-2.csv', index=False)

# %%
df
# Out:
#          month   GDS_NM  SALE_AMT  day
# 0            9    의성햇사과      9960    3
# 1            9    쌈배추벌크      1980    3
# 2            9   성주꿀참외특      9800    3
# 3            9  대패삼겹살수입     13060    3
# 4            9     거봉포도      6420    3
# ...        ...      ...       ...  ...
# 2079019      4       찹쌀     49500    4
# 2079020      7       찹쌀     49500    2
# 2079021     11      늘보리      7300    6
# 2079022      3      늘보리      7300    3
# 2079023      6      늘보리      7300    4
#
# [2079024 rows x 4 columns]
