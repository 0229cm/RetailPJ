# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# 제품목록 gds_list_0, gds_list_1
gds_0 = pd.read_csv(base_path + 'gds_list_0.csv')
gds_1 = pd.read_csv(base_path + 'gds_list_1.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
gdsclss_0 = pd.read_csv(base_path + 'gdsclss_list_0.csv')
gdsclss_1 = pd.read_csv(base_path + 'gdsclss_list_1.csv')

# 매장 목록: str_list
str_list = pd.read_csv(base_path + 'str_list.csv')

# 매출 데이터 마스터(장바구니 단위): tr_list_0, tr_list_1
tr_list_0 = pd.read_csv(base_path + 'tr_list_0_convert.csv')
tr_list_1 = pd.read_csv(base_path + 'tr_list_1_convert.csv')

# 매출 제품 데이터 상세: tr_dtl_list_0, tr_dtl_list_1
tr_dtl_list_0 = pd.read_csv(base_path + 'tr_dtl_list_0.csv')
tr_dtl_list_1 = pd.read_csv(base_path + 'tr_dtl_list_1.csv')
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
idx = gds_0[gds_0['STR_CD'] == 72005].index
gds_a = gds_0.drop(idx)
gds_a
# Out:
#          CO_CD  STR_CD         PLU_CD          GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0      1001294   12018              1             배송비       999999       배송료
# 1      1001294   12018              2          사은행사쿠폰       999999       배송료
# 2      1001294   12018          91770          코지유리물병        93331        일반
# 3      1001294   12018          91770            크지물병        91701        일반
# 4      1001294   12018       50390427           POM석류        12579        일반
# ...        ...     ...            ...             ...          ...       ...
# 72142  1001294   12018  9999999914157  맥 원형후라이 대(240)        93330        일반
# 72143  1001294   12018  9999999914171         맥웰빙원후/8        93330        일반
# 72144  1001294   12018  9999999914393           절구 소소        91701        일반
# 72145  1001294   12018  9999999915079          알뜰Y투라인        91701        일반
# 72146  1001294   12018  9999999915833        맥 웰빙원후 7        91701        일반
#
#        VEN_CD
# 0           0
# ...

# %%
gds_a.to_csv('gds_a.csv', index = False)

# %%
gds_a
# Out:
#          CO_CD  STR_CD         PLU_CD          GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0      1001294   12018              1             배송비       999999       배송료
# 1      1001294   12018              2          사은행사쿠폰       999999       배송료
# 2      1001294   12018          91770          코지유리물병        93331        일반
# 3      1001294   12018          91770            크지물병        91701        일반
# 4      1001294   12018       50390427           POM석류        12579        일반
# ...        ...     ...            ...             ...          ...       ...
# 72142  1001294   12018  9999999914157  맥 원형후라이 대(240)        93330        일반
# 72143  1001294   12018  9999999914171         맥웰빙원후/8        93330        일반
# 72144  1001294   12018  9999999914393           절구 소소        91701        일반
# 72145  1001294   12018  9999999915079          알뜰Y투라인        91701        일반
# 72146  1001294   12018  9999999915833        맥 웰빙원후 7        91701        일반
#
#        VEN_CD
# 0           0
# ...

# %%
idx = gds_0[gds_0['STR_CD'] == 12018].index
gds_b = gds_0.drop(idx)
gds_b
# Out:
#           CO_CD  STR_CD         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 72147   1001739   72005              1              배송비       999999
# 72148   1001739   72005              2           사은행사쿠폰       999999
# 72149   1001739   72005        1801828         버드와이저(캔)        10702
# 72150   1001739   72005        1801859         버드와이저(캔)        10702
# 72151   1001739   72005       40122731   퀴네발사믹코드레싱250ML       140101
# ...         ...     ...            ...              ...          ...
# 102668  1001739   72005  9901234001249           그린매실주통        20301
# 102669  1001739   72005  9901345698772          담배케이스스틸        20301
# 102670  1001739   72005  9902345678771  9902345678771등록        70202
# 102671  1001739   72005         990891        ok캐쉬백 포인트        70101
# 102672  1001739   72005         990942             맥주공병        10801
#
#        GDS_TP_NM  VEN_CD
# 72147        배송료       0
# 72148        배송료       0
# 72149         일반       3
# 72150         일반       3
# ...

# %%
gds_b
# Out:
#           CO_CD  STR_CD         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 72147   1001739   72005              1              배송비       999999
# 72148   1001739   72005              2           사은행사쿠폰       999999
# 72149   1001739   72005        1801828         버드와이저(캔)        10702
# 72150   1001739   72005        1801859         버드와이저(캔)        10702
# 72151   1001739   72005       40122731   퀴네발사믹코드레싱250ML       140101
# ...         ...     ...            ...              ...          ...
# 102668  1001739   72005  9901234001249           그린매실주통        20301
# 102669  1001739   72005  9901345698772          담배케이스스틸        20301
# 102670  1001739   72005  9902345678771  9902345678771등록        70202
# 102671  1001739   72005         990891        ok캐쉬백 포인트        70101
# 102672  1001739   72005         990942             맥주공병        10801
#
#        GDS_TP_NM  VEN_CD
# 72147        배송료       0
# 72148        배송료       0
# 72149         일반       3
# 72150         일반       3
# ...

# %%
gds_b.to_csv('gds_b.csv', index = False)

# %%
idx = gds_1[gds_1['STR_CD'] == 168009].index
gds_c = gds_1.drop(idx)
gds_c
# Out:
#          CO_CD  STR_CD         PLU_CD    GDS_NM  GDS_CLSS_CD GDS_TP_NM  VEN_CD
# 0      1001993  142011              0    종랑제75ㄴ       999999        일반       0
# 1      1001993  142011              1       배송비       999999       배송료       0
# 2      1001993  142011              2    사은행사쿠폰       999999       배송료       0
# 3      1001993  142011          12003       얼음물       999999        일반       0
# 4      1001993  142011          22002   써니텐=사이다       999999        일반       0
# ...        ...     ...            ...       ...          ...       ...     ...
# 48669  1001993  142011       97059582      약초갱이       999999        일반    9999
# 48670  1001993  142011       97059585      약초갱이       999999        일반    9999
# 48671  1001993  142011       97159490      약초갱이       999999        일반    9999
# 48672  1001993  142011       97159599  약초갱이(3발)       999999        일반    9999
# 48673  1001993  142011  9788087049099  쿨토시(국방색)        20101        일반    9094
#
# ...

# %%
gds_c
# Out:
#          CO_CD  STR_CD         PLU_CD    GDS_NM  GDS_CLSS_CD GDS_TP_NM  VEN_CD
# 0      1001993  142011              0    종랑제75ㄴ       999999        일반       0
# 1      1001993  142011              1       배송비       999999       배송료       0
# 2      1001993  142011              2    사은행사쿠폰       999999       배송료       0
# 3      1001993  142011          12003       얼음물       999999        일반       0
# 4      1001993  142011          22002   써니텐=사이다       999999        일반       0
# ...        ...     ...            ...       ...          ...       ...     ...
# 48669  1001993  142011       97059582      약초갱이       999999        일반    9999
# 48670  1001993  142011       97059585      약초갱이       999999        일반    9999
# 48671  1001993  142011       97159490      약초갱이       999999        일반    9999
# 48672  1001993  142011       97159599  약초갱이(3발)       999999        일반    9999
# 48673  1001993  142011  9788087049099  쿨토시(국방색)        20101        일반    9094
#
# ...

# %%
gds_c.to_csv('gds_c.csv', index = False)

# %%
idx = gds_1[gds_1['STR_CD'] == 142011].index
gds_d = gds_1.drop(idx)
gds_d
# Out:
#          CO_CD  STR_CD         PLU_CD     GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 48674  1002056  168009              0         동태       898989        일반
# 48675  1002056  168009              0       간고등어       898989        일반
# 48676  1002056  168009              1        배송비       999999       배송료
# 48677  1002056  168009              2     사은행사쿠폰       999999       배송료
# 48678  1002056  168009     9800800056      누델라엔고       997979        일반
# ...        ...     ...            ...        ...          ...       ...
# 70057  1002056  168009  9805817760205        포카칩       898989        일반
# 70058  1002056  168009  9808205106111  매입에서등록한상품       997979        일반
# 70059  1002056  168009  9808862878406        월드콘       898989        일반
# 70060  1002056  168009  9880913160015  매입에서등록한상품       997979        일반
# 70061  1002056  168009       99889906     버디 토스트       898989        일반
#
#        VEN_CD
# 48674       1
# 48675       1
# 48676       0
# 48677       0
# 48678      53
# ...

# %%
gds_c
# Out:
#          CO_CD  STR_CD         PLU_CD    GDS_NM  GDS_CLSS_CD GDS_TP_NM  VEN_CD
# 0      1001993  142011              0    종랑제75ㄴ       999999        일반       0
# 1      1001993  142011              1       배송비       999999       배송료       0
# 2      1001993  142011              2    사은행사쿠폰       999999       배송료       0
# 3      1001993  142011          12003       얼음물       999999        일반       0
# 4      1001993  142011          22002   써니텐=사이다       999999        일반       0
# ...        ...     ...            ...       ...          ...       ...     ...
# 48669  1001993  142011       97059582      약초갱이       999999        일반    9999
# 48670  1001993  142011       97059585      약초갱이       999999        일반    9999
# 48671  1001993  142011       97159490      약초갱이       999999        일반    9999
# 48672  1001993  142011       97159599  약초갱이(3발)       999999        일반    9999
# 48673  1001993  142011  9788087049099  쿨토시(국방색)        20101        일반    9094
#
# ...

# %%
gds_d.to_csv('gds_d.csv', index = False)

# %%
idx = tr_list_0[tr_list_0['STR_CD'] == 72005].index
tr_list_a = tr_list_0.drop(idx)

# %%
tr_list_a
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 0        20210901   12018     01        1            영업개시             1
# 1        20210901   12018     01        2             준비금             1
# 2        20210901   12018     01        3              매출             1
# 3        20210901   12018     01        4            전체취소             1
# 4        20210901   12018     01        5              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 1095545  20220901   12018     R1        3              매출             1
# 1095546  20220901   12018     R1        4              매출             1
# 1095547  20220901   12018     R1        5              매출             1
# 1095548  20220901   12018     R1        6              매출             1
# 1095549  20220901   12018     R1        7              매출             1
#
#          REAL_SAL_DT  REAL_SAL_TTM    PAY_AMT       MSHP_ID  ORN_SAL_DT  \
# ...

# %%
tr_list_a.to_csv('tr_list_a.csv', index = False)

# %%
idx = tr_list_0[tr_list_0['STR_CD'] == 12018].index
tr_list_b = tr_list_0.drop(idx)

# %%
tr_list_b
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 1095550  20210901   72005     01        1            영업개시             1
# 1095551  20210901   72005     01        2             준비금             1
# 1095552  20210901   72005     01        3              매출             1
# 1095553  20210901   72005     01        4              매출             1
# 1095554  20210901   72005     01        5              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 1395629  20220901   72005     03      334            캐셔정산             1
# 1395630  20220901   72005     03      335           POS정산             1
# 1395631  20220901   72005     03      336            영업종료             1
# 1395632  20220901   72005     03      337            로그오프             1
# 1395633  20220901   72005     03      338             로그인             1
#
#          REAL_SAL_DT  REAL_SAL_TTM  PAY_AMT   MSHP_ID  ORN_SAL_DT ORN_POS_NO  \
# ...

# %%
tr_list_b.to_csv('tr_list_b.csv', index = False)

# %%
idx = tr_list_1[tr_list_1['STR_CD'] == 168009].index
tr_list_c = tr_list_1.drop(idx)

# %%
tr_list_c
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 0      20210901  142011       1        1            영업개시             1
# 1      20210901  142011       1        2              매출             1
# 2      20210901  142011       1        3              매출             1
# 3      20210901  142011       1        4              매출             1
# 4      20210901  142011       1        5              매출             1
# ...         ...     ...     ...      ...             ...           ...
# 38415  20220901  142011       1      120            캐셔정산             1
# 38416  20220901  142011       1      121           POS정산             1
# 38417  20220901  142011       1      122            영업종료             1
# 38418  20220901  142011       1      123            로그오프             1
# 38419  20220901  142011       1      124             로그인             1
#
#        REAL_SAL_DT  REAL_SAL_TTM  PAY_AMT  MSHP_ID  ORN_SAL_DT  ORN_POS_NO  \
# ...

# %%
tr_list_c.to_csv('tr_list_c.csv', index = False)

# %%
idx = tr_list_1[tr_list_1['STR_CD'] == 142011].index
tr_list_d = tr_list_1.drop(idx)

# %%
tr_list_d
# Out:
#           SAL_DT  STR_CD  POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 38420   20210902  168009       1        1            영업개시             1
# 38421   20210902  168009       1        2             준비금             1
# 38422   20210902  168009       1        3             로그인             1
# 38423   20210902  168009       1        4              매출             1
# 38424   20210902  168009       1        5              매출             1
# ...          ...     ...     ...      ...             ...           ...
# 155870  20220901  168009       1      284              매출             1
# 155871  20220901  168009       1      285            캐셔정산             1
# 155872  20220901  168009       1      286           POS정산             1
# 155873  20220901  168009       1      287            영업종료             1
# 155874  20220901  168009       1      288             로그인             1
#
#         REAL_SAL_DT  REAL_SAL_TTM  PAY_AMT  MSHP_ID  ORN_SAL_DT  ORN_POS_NO  \
# ...

# %%
tr_list_d.to_csv('tr_list_d.csv', index = False)

# %%
idx = tr_dtl_list_0[tr_dtl_list_0['STR_CD'] == 72005].index
tr_dtl_list_a = tr_dtl_list_0.drop(idx)

# %%
tr_dtl_list_a
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 5166594  20220901   12018     R1        7       9            정상판매
# 5166595  20220901   12018     R1        7      10            정상판매
# 5166596  20220901   12018     R1        7      11            정상판매
# 5166597  20220901   12018     R1        7      12            정상판매
# 5166598  20220901   12018     R1        7      13            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
tr_dtl_list_a.to_csv('tr_dtl_list_a.csv', index = False)

# %%
idx = tr_dtl_list_0[tr_dtl_list_0['STR_CD'] == 12018].index
tr_dtl_list_b = tr_dtl_list_0.drop(idx)

# %%
tr_dtl_list_b
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 5166599  20210901   72005     01        3       1            정상판매
# 5166600  20210901   72005     01        4       1            정상판매
# 5166601  20210901   72005     01        5       1            정상판매
# 5166602  20210901   72005     01        5       2            정상판매
# 5166603  20210901   72005     01        5       3            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 6149885  20220901   72005     03      333       2            정상판매
# 6149886  20220901   72005     03      333       3            정상판매
# 6149887  20220901   72005     03      333       4            정상판매
# 6149888  20220901   72005     03      333       5            정상판매
# 6149889  20220901   72005     03      333       6            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 5166599             1  8806006507770     999999.0       1.0    6700.0
# ...

# %%
tr_dtl_list_b.to_csv('tr_dtl_list_b.csv', index = False)

# %%
idx = tr_dtl_list_1[tr_dtl_list_1['STR_CD'] == 168009].index
tr_dtl_list_c = tr_dtl_list_1.drop(idx)

# %%
tr_dtl_list_c
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0      20210901  142011       1        2       1            정상판매
# 1      20210901  142011       1        2       2            정상판매
# 2      20210901  142011       1        2       3            정상판매
# 3      20210901  142011       1        3       1            정상판매
# 4      20210901  142011       1        3       2            정상판매
# ...         ...     ...     ...      ...     ...             ...
# 91807  20220901  142011       1      118       5            정상판매
# 91808  20220901  142011       1      119       1            정상판매
# 91809  20220901  142011       1      119       2            정상판매
# 91810  20220901  142011       1      119       3            정상판매
# 91811  20220901  142011       1      119       4            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0                 1  8801097250048     999999.0       1.0    1500.0    1500.0
# ...

# %%
tr_dtl_list_c.to_csv('tr_dtl_list_c.csv', index = False)

# %%
idx = tr_dtl_list_1[tr_dtl_list_1['STR_CD'] == 142011].index
tr_dtl_list_d = tr_dtl_list_1.drop(idx)

# %%
tr_dtl_list_d
# Out:
#           SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 91812   20210902  168009       1        4       1            정상판매
# 91813   20210902  168009       1        5       1            정상판매
# 91814   20210902  168009       1        5       2            정상판매
# 91815   20210902  168009       1        5       3            정상판매
# 91816   20210902  168009       1        5       4            정상판매
# ...          ...     ...     ...      ...     ...             ...
# 372020  20220901  168009       1      282       4            정상판매
# 372021  20220901  168009       1      282       5            정상판매
# 372022  20220901  168009       1      283       1            정상판매
# 372023  20220901  168009       1      284       1            정상판매
# 372024  20220901  168009       1      284       2            정상판매
#
#         SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 91812              1  8809604270008     997979.0       1.0    1300.0
# ...

# %%
tr_dtl_list_d.to_csv('tr_dtl_list_d.csv', index = False)
