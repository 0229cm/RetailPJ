# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''
pd.set_option('display.max_row', 100)

# %%
# 제품목록 gds_list_0, gds_list_1
gds_0 = pd.read_csv(base_path + 'gds_list_0.csv')
gds_1 = pd.read_csv(base_path + 'gds_list_1.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
gdsclss_0 = pd.read_csv(base_path + 'gdsclss_list_0.csv')
gdsclss_1 = pd.read_csv(base_path + 'gdsclss_list_1.csv')

# 매장 목록: str_list
str_list = pd.read_csv(base_path + 'str_list.csv')

# 매출 데이터 마스터(장바구니 단위): tr_list_0, tr_list_1
tr_list_0 = pd.read_csv(base_path + 'tr_list_0_convert.csv')
tr_list_1 = pd.read_csv(base_path + 'tr_list_1_convert.csv')

# 매출 제품 데이터 상세: tr_dtl_list_0, tr_dtl_list_1
tr_dtl_list_0 = pd.read_csv(base_path + 'tr_dtl_list_0.csv')
tr_dtl_list_1 = pd.read_csv(base_path + 'tr_dtl_list_1.csv')
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## 제품 목록: gds_list_0, gds_list_1
# * CO_CD: 회사 코드
# * STR_CD: 매장 코드
# * PLU_CD: 제품 코드로 880으로 시작하는 바코드도 있지만 매장에서 직접 생성하여 등록한 코드가 혼재
# * GDS_NM: 제품 명
# * GDS_CLSS_CD: 제품 카테고리 코드(자세한 코드 구조는 제품 카테고리 데이터 참조)
# * GDS_TP_NM: 제품 구분으로 [일반/저울상품/사이드상품/원타임/공병/배송료]로 구분
# * VEN_CD: 제품 공급사 코드로 매장에서 관리하는 번호기 때문에 다른 매장 간 같은 코드로 중복되더라도 다른 제품 공급사일 수 있음

# %%
gds_0
# Out:
#           CO_CD  STR_CD         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0       1001294   12018              1              배송비       999999
# 1       1001294   12018              2           사은행사쿠폰       999999
# 2       1001294   12018          91770           코지유리물병        93331
# 3       1001294   12018          91770             크지물병        91701
# 4       1001294   12018       50390427            POM석류        12579
# ...         ...     ...            ...              ...          ...
# 102668  1001739   72005  9901234001249           그린매실주통        20301
# 102669  1001739   72005  9901345698772          담배케이스스틸        20301
# 102670  1001739   72005  9902345678771  9902345678771등록        70202
# 102671  1001739   72005         990891        ok캐쉬백 포인트        70101
# 102672  1001739   72005         990942             맥주공병        10801
#
#        GDS_TP_NM  VEN_CD
# 0            배송료       0
# 1            배송료       0
# 2             일반       0
# 3             일반       0
# 4             일반       0
# ...          ...     ...
# 102668        일반      30
# 102669        일반      30
# 102670        일반      30
# 102671        일반      37
# 102672        일반       3
#
# [102673 rows x 7 columns]

# %%
gds_0['GDS_NM'].unique()
# Out:
# array(['배송비', '사은행사쿠폰', '코지유리물병', ..., '담배케이스스틸', '9902345678771등록',
#        'ok캐쉬백 포인트'], dtype=object)

# %%
gds_0['GDS_NM'].value_counts()
# Out:
# 악세사리             121
# 모닝다이어리            34
# 현대)멀티             34
# 황태포               28
# 하기스매직팬티           27
#                 ...
# 피마자잎               1
# 죤슨 베이비오일           1
# 오뚜기 열라면 멀티         1
# 매일 마이리틀딸기블루베리      1
# 리본 거실화             1
# Name: GDS_NM, Length: 86014, dtype: int64

# %%
gds_0[gds_0.GDS_NM.str.contains(r'(케이스)')]
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#           CO_CD  STR_CD         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2707    1001294   12018         223143       복숭아(케이스)2팩        40205
# 3595    1001294   12018   290300000719              케이스        95501
# 3623    1001294   12018   290300000869          리더벨트케이스        95501
# 5681    1001294   12018  3304567123071          점보롤 케이스        99999
# 7330    1001294   12018  4955959123019            두부케이스        91301
# ...         ...     ...            ...              ...          ...
# 98756   1001739   72005  8809089309842    뽀로로/이지수저케이스세트        20302
# 98757   1001739   72005  8809089309859     패티/이지수저케이스세트        20302
# 99571   1001739   72005  8809183002359        문서보존케이스A4        20301
# 101306  1001739   72005  8809358470204  후토스 수저케이스셋트*에스유        20301
# 102669  1001739   72005  9901345698772          담배케이스스틸        20301
#
#        GDS_TP_NM  VEN_CD
# 2707        저울상품      81
# 3595          일반       0
# 3623          일반       0
# 5681          일반      13
# 7330          일반       0
# ...          ...     ...
# 98756         일반      30
# 98757         일반      30
# 99571         일반      30
# 101306        일반      37
# 102669        일반      30
#
# [183 rows x 7 columns]

# %%
gds_0[gds_0.GDS_NM.str.contains(r'(포인트)')] # 포인트
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#           CO_CD  STR_CD         PLU_CD            GDS_NM  GDS_CLSS_CD  \
# 19378   1001294   12018  8801046895450          포인트녹차머드폼        21001
# 19379   1001294   12018  8801046895467           뉴포인트녹차폼        21001
# 39495   1001294   12018  8801237639450            루미포인트자        90301
# 41633   1001294   12018  8801237726877           컬러포인트수첩        90301
# 45180   1001294   12018  8802088301640        포인트훅행거(사각)        91701
# 45181   1001294   12018  8802088301664           포인트원형행가        99999
# 45182   1001294   12018  8802088301671  우일.포인트하트행가(P-04)        91701
# 45367   1001294   12018  8802240002514           데코포인트시트        91701
# 45389   1001294   12018  8802240014210         포인트스티커(소)        91701
# 51662   1001294   12018  8806329301246            포인트욕실화        91401
# 51821   1001294   12018  8806365028367         마이멜포인트S/F        91701
# 52809   1001294   12018  8807511000244             타일포인트        91701
# 53821   1001294   12018  8809003240886         포인트세이커550        91701
# 55291   1001294   12018  8809026682755          포인트사각휴지통        91701
# 55304   1001294   12018  8809026685114     대일 포인트사각휴지통5호        91701
# 55305   1001294   12018  8809026685121          포인트사각휴지통        91701
# 55306   1001294   12018  8809026685138            포인트휴지통        91701
# 55318   1001294   12018  8809026687415          포인트사각휴지통        91701
# 55332   1001294   12018  8809026688252          포인트사각휴지통        91701
# 56262   1001294   12018  8809043826194             포인트 인        90301
# 56264   1001294   12018  8809043826217             포인트 인        90301
# 56270   1001294   12018  8809043826279        1100 포인트 인        90301
# 56271   1001294   12018  8809043826286          포인트 인 2호        90301
# 56272   1001294   12018  8809043826293             포인트 인        90301
# 56273   1001294   12018  8809043826408            포인트수정액        90301
# 59873   1001294   12018  8809158524695            포인트실내화        91701
# 64559   1001294   12018  8809296550440         인테리어포인트시트        91701
# 64561   1001294   12018  8809296550495           포인트점착시트        91701
# 68211   1001294   12018  8809435945540            레이져포인트        90301
# 94391   1001739   72005  8802088301688           포인트주방걸이        20301
# 100420  1001739   72005  8809245940001              포인트폴        80101
# 102671  1001739   72005         990891         ok캐쉬백 포인트        70101
#
#        GDS_TP_NM  VEN_CD
# 19378         일반       0
# 19379         일반       0
# 39495         일반       0
# 41633         일반       0
# 45180         일반       0
# 45181         일반      13
# 45182         일반       0
# 45367         일반       0
# 45389         일반       0
# 51662         일반       0
# 51821         일반       0
# 52809         일반       0
# 53821         일반       0
# 55291         일반       0
# 55304         일반       0
# 55305         일반       0
# 55306         일반       0
# 55318         일반       0
# 55332         일반       0
# 56262         일반       0
# 56264         일반       0
# 56270         일반       0
# 56271         일반       0
# 56272         일반       0
# 56273         일반       0
# 59873         일반       0
# 64559         일반       0
# 64561         일반       0
# 68211         일반       0
# 94391         일반      30
# 100420        일반      37
# 102671        일반      37

# %%
gds_0[gds_0.GDS_NM.str.contains(r'(등록)')] # outlier
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#           CO_CD  STR_CD         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 8       1001294   12018       35000000   000035000000등록        20901
# 3414    1001294   12018  2902000034154  2902000034154등록        91701
# 3427    1001294   12018  2902000039319  2902000039319등록        95501
# 3735    1001294   12018  2903000010834  2903000010834등록        91701
# 3767    1001294   12018  2903000025746  2903000025746등록        91701
# 3823    1001294   12018  2903000026699  2903000026699등록       999999
# 60399   1001294   12018  8809172924488  8809172924488등록        91701
# 72355   1001739   72005     1047605592    01047605592등록        70202
# 72519   1001739   72005        7120013       07120013등록        70202
# 72621   1001739   72005        8480644       08480644등록        70202
# 74802   1001739   72005  2072100029609  2072100029609등록        40601
# 75420   1001739   72005  2216680025006  2216680025006등록        70202
# 75424   1001739   72005  2216740040000  2216740040000등록        70202
# 75523   1001739   72005   305212752007   305212752007등록        20105
# 75574   1001739   72005  3848117895907  3848117895907등록        70202
# 76535   1001739   72005  6802242161150  6802242161150등록        70202
# 76795   1001739   72005  7809534610210  7809534610210등록        20405
# 85070   1001739   72005  8801055772803  8801055772803등록        70202
# 90962   1001739   72005  8801117474010  8801117474010등록        70202
# 96277   1001739   72005  8805803068204  8805803068204등록        70202
# 98480   1001739   72005  8809063718899  8809063718899등록        20302
# 100899  1001739   72005  8809297361069  8809297361069등록       100104
# 102670  1001739   72005  9902345678771  9902345678771등록        70202
#
#        GDS_TP_NM  VEN_CD
# 8             일반       0
# 3414          일반       0
# 3427          일반       0
# 3735          일반       0
# 3767          일반       0
# 3823          일반       0
# 60399         일반       0
# 72355         일반      37
# 72519         일반      37
# 72621         일반      37
# 74802         일반       5
# 75420         일반       0
# 75424         일반       0
# 75523         일반      37
# 75574         일반       0
# 76535         일반       0
# 76795         일반       0
# 85070         일반      37
# 90962         일반       0
# 96277         일반      37
# 98480         일반      37
# 100899        일반       7
# 102670        일반      30

# %%
gds_0['GDS_NM'].nunique()
# Out:
# 86014

# %%
gds_0[gds_0['GDS_NM']=='악세사리']
# Out:
#           CO_CD  STR_CD         PLU_CD GDS_NM  GDS_CLSS_CD GDS_TP_NM  VEN_CD
# 2370    1001294   12018       22000736   악세사리        95501        일반       0
# 2376    1001294   12018       22000835   악세사리        95501        일반       0
# 2377    1001294   12018       22000873   악세사리        95501        일반       0
# 2378    1001294   12018       22000880   악세사리        95501        일반       0
# 2379    1001294   12018       22000897   악세사리        95501        일반       0
# ...         ...     ...            ...    ...          ...       ...     ...
# 3953    1001294   12018   290409140635   악세사리        95501        일반       0
# 14723   1001294   12018  8801038123905   악세사리        95501        일반       0
# 56251   1001294   12018  8809043460107   악세사리        95501        일반       0
# 61697   1001294   12018  8809207588753   악세사리        95501        일반       0
# 101852  1001739   72005  8809477191967   악세사리       130101        일반      56
#
# [121 rows x 7 columns]

# %%
len(gds_0['GDS_NM'].value_counts().index)
# Out:
# 86014

# %% [markdown]
# ## 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
#
# * CO_CD: 회사 코드
# * STR_CD: B/C/D마트는 000000으로 표기되고 A마트만 A마트의 매장코드가 표시됨(A마트는 다점포회사 소속으로 매장마다 카테고리 구분하여 관리)
# * GDS_CLSS_CD: 제품 카테고리 코드로 2자리, 4자리, 6자리로 구성, 6자리 코드의 앞 4자리와 4자리 코드의 앞 2자리는 각 상위 카테고리의 코드
# * GDS_CLSS_NM: 제품 카테고리 명
# * GDS_CLSS_LVL_TP: 카테고리 Level로 1/2/3으로 표시 ???
# * UP_GDS_CLSS_CD: 상위 카테고리 코드
# * GDS_CLSS_GRP_TP: 카테고리 구분으로 1은 공산품, 2는 식자재, 3은 신선식품(실수로 연결을 못해서 코드 그대로 표시)

# %%
gdsclss_0['STR_CD'].value_counts()
# Out:
# 12018    607
# 0        165
# Name: STR_CD, dtype: int64

# %%
gdsclss_1
# Out:
#        CO_CD  STR_CD  GDS_CLSS_CD GDS_CLSS_NM  GDS_CLSS_LVL_TP  \
# 0    1001993       0            1       식 품 류                1
# 1    1001993       0          101        가공식품                2
# 2    1001993       0        10101        가공식품                3
# 3    1001993       0        10199     기타-가공식품                3
# 4    1001993       0          102       식 용 유                2
# ..       ...     ...          ...         ...              ...
# 362  1002056       0           99         미등록                1
# 363  1002056       0         9979   임시핸디매입등록용                2
# 364  1002056       0       997979   임시핸디매입등록용                3
# 365  1002056       0         9999         미등록                2
# 366  1002056       0       999999         미등록                3
#
#      UP_GDS_CLSS_CD  GDS_CLSS_GRP_TP
# 0                 0                1
# 1                 1                1
# 2               101                1
# 3               101                1
# 4                 1                1
# ..              ...              ...
# 362               0                1
# 363              99                1
# 364            9979                1
# 365              99                1
# 366            9999                1
#
# [367 rows x 7 columns]

# %% [markdown]
# ## 매장 목록: str_list
# * CO_CD: 회사 코드
# * STR_CD: 매장 코드
# * STR_NM: (마스킹 된) 매장 명
# * CM_ITM_NM: 매장 크기 구분, 30평/50평/100평/300평/500평/1000평 총 6종류
# * POS_QTY: 포스 대수(토마토 솔루션 가입 당시)
# * OPN_DT: 매장 오픈 일자

# %%
str_list
# Out:
#      CO_CD  STR_CD STR_NM CM_ITM_NM  POS_QTY    OPN_DT
# 0  1001294   12018    A마트     100평대        9  20201220
# 1  1001739   72005    B마트     100평대        3  20210526
# 2  1001993  142011    C마트      30평대        1  20210805
# 3  1002056  168009    D마트     100평대        2  20210831

# %% [markdown]
# ## 매출 데이터 마스터(장바구니 단위): tr_list_0, tr_list_1
# * SAL_DT: 매출 등록 일자
# * STR_CD: 매장 코드
# * POS_NO: 포스 번호
# * TRAN_NO: 포스 거래 순번 -- **위의 4개 항목을 합쳐 하나의 장바구니**
# * SALE_KIND_TP_NM: 매출 구분으로 매출/전체취소/배달입금/배달착불만 대상으로 처리하면 됩니다. 나머지는 기능적이거나 오프라인 외 매출 등 입니다.
# * SALE_RTN_SGN: 금액에 대한 부호로 1과 -1로 구분, -1은 반품
# * REAL_SAL_DT: 실제 판매 일자
# * *REAL_SAL_TTM: 실제 판매 시각*
# * PAY_AMT: 지불 금액
# * **MSHP_ID: (마스킹 된) 회원 번호**
# * ORN_SAL_DT: 원 매출 등록 일자(반품 시 반품 대상이 되는 매출을 특정하기 위함)
# * ORN_POS_NO: 원 매출 포스 번호(반품 시 반품 대상이 되는 매출을 특정하기 위함)
# * ORN_TRAN_NO: 원 매출 포스 거래 순번(반품 시 반품 대상이 되는 매출을 특정하기 위함)

# %%
tr_list_0
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 0        20210901   12018     01        1            영업개시             1
# 1        20210901   12018     01        2             준비금             1
# 2        20210901   12018     01        3              매출             1
# 3        20210901   12018     01        4            전체취소             1
# 4        20210901   12018     01        5              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 1395629  20220901   72005     03      334            캐셔정산             1
# 1395630  20220901   72005     03      335           POS정산             1
# 1395631  20220901   72005     03      336            영업종료             1
# 1395632  20220901   72005     03      337            로그오프             1
# 1395633  20220901   72005     03      338             로그인             1
#
#          REAL_SAL_DT  REAL_SAL_TTM    PAY_AMT   MSHP_ID  ORN_SAL_DT  \
# 0           20210901         65745        0.0       NaN         NaN
# 1           20210901         65758        0.0       NaN         NaN
# 2           20210901         71138  9000000.0       NaN         NaN
# 3           20210901         85353        0.0       NaN         NaN
# 4           20210901         91245     3650.0  012018_0         NaN
# ...              ...           ...        ...       ...         ...
# 1395629     20220901        215155        0.0       NaN         NaN
# 1395630     20220901        215201        0.0       NaN         NaN
# 1395631     20220901        215202        0.0       NaN         NaN
# 1395632     20220901        215210        0.0       NaN         NaN
# 1395633     20220903        155106        0.0       NaN         NaN
#
#         ORN_POS_NO  ORN_TRAN_NO
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 1395629        NaN          NaN
# 1395630        NaN          NaN
# 1395631        NaN          NaN
# 1395632        NaN          NaN
# 1395633        NaN          NaN
#
# [1395634 rows x 13 columns]

# %%
tr_list_0[tr_list_0.duplicated(subset='MSHP_ID') & tr_list_0['MSHP_ID'].notna()]
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 32       20210901   12018     01       33              매출             1
# 39       20210901   12018     01       40           거래후적립             1
# 90       20210901   12018     01       91           거래후적립             1
# 116      20210901   12018     01      117              매출             1
# 121      20210901   12018     01      122              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 1395619  20220901   72005     03      324              매출             1
# 1395622  20220901   72005     03      327              매출             1
# 1395623  20220901   72005     03      328              매출             1
# 1395624  20220901   72005     03      329              매출             1
# 1395628  20220901   72005     03      333              매출             1
#
#          REAL_SAL_DT  REAL_SAL_TTM   PAY_AMT      MSHP_ID  ORN_SAL_DT  \
# 32          20210901         95632    4380.0     012018_1         NaN
# 39          20210901        100155       0.0    012018_26  20210901.0
# 90          20210901        103147       0.0    012018_67  20210901.0
# 116         20210901        104715    1980.0    012018_75         NaN
# 121         20210901        104955    1980.0    012018_80         NaN
# ...              ...           ...       ...          ...         ...
# 1395619     20220901        213618    2980.0   072005_544         NaN
# 1395622     20220901        214425  134830.0  072005_2653         NaN
# 1395623     20220901        214500    7980.0  072005_5652         NaN
# 1395624     20220901        214612    5100.0   072005_435         NaN
# 1395628     20220901        215001   14090.0  072005_1699         NaN
#
#         ORN_POS_NO  ORN_TRAN_NO
# 32             NaN          NaN
# 39               1         39.0
# 90               1         89.0
# 116            NaN          NaN
# 121            NaN          NaN
# ...            ...          ...
# 1395619        NaN          NaN
# 1395622        NaN          NaN
# 1395623        NaN          NaN
# 1395624        NaN          NaN
# 1395628        NaN          NaN
#
# [993445 rows x 13 columns]

# %%
tr_list_0['MSHP_ID'].notna().mean() # 회원번호가 73%로 존재
# Out:
# 0.7327838100820129

# %%
tr_list_0['REAL_SAL_TTM'].value_counts()
# Out:
# 170249    71
# 181318    69
# 170542    69
# 172502    67
# 180315    66
#           ..
# 73045      1
# 220444     1
# 62825      1
# 54637      1
# 71715      1
# Name: REAL_SAL_TTM, Length: 59389, dtype: int64

# %%
tr_list_0['MSHP_ID'].value_counts()
# Out:
# 012018_398      793
# 012018_135      718
# 012018_945      715
# 012018_2207     682
# 012018_52       669
#                ...
# 012018_13219      1
# 012018_8392       1
# 012018_19720      1
# 072005_5862       1
# 012018_16562      1
# Name: MSHP_ID, Length: 29253, dtype: int64

# %%
tr_list_0[tr_list_0['MSHP_ID'] == '012018_398']
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 526      20210901   12018     01      527              매출             1
# 1505     20210901   12018     03       64              매출             1
# 3793     20210902   12018     01      452              매출             1
# 4736     20210902   12018     03       55              매출             1
# 5177     20210902   12018     04      278              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 1093328  20220901   12018     02      220              매출             1
# 1093966  20220901   12018     03      397              매출             1
# 1094826  20220901   12018     07       18              매출             1
# 1094846  20220901   12018     07       38              매출             1
# 1095527  20220901   12018     08       22              매출             1
#
#          REAL_SAL_DT  REAL_SAL_TTM   PAY_AMT     MSHP_ID  ORN_SAL_DT  \
# 526         20210901        161704   64130.0  012018_398         NaN
# 1505        20210901         93351    5590.0  012018_398         NaN
# 3793        20210902        151824    7410.0  012018_398         NaN
# 4736        20210902        142808   49600.0  012018_398         NaN
# 5177        20210902        143711   45000.0  012018_398         NaN
# ...              ...           ...       ...         ...         ...
# 1093328     20220901        172402   13720.0  012018_398         NaN
# 1093966     20220901        183814    3100.0  012018_398         NaN
# 1094826     20220901         92853    2000.0  012018_398         NaN
# 1094846     20220901        100324  102430.0  012018_398         NaN
# 1095527     20220901        190658    3100.0  012018_398         NaN
#
#         ORN_POS_NO  ORN_TRAN_NO
# 526            NaN          NaN
# 1505           NaN          NaN
# 3793           NaN          NaN
# 4736           NaN          NaN
# 5177           NaN          NaN
# ...            ...          ...
# 1093328        NaN          NaN
# 1093966        NaN          NaN
# 1094826        NaN          NaN
# 1094846        NaN          NaN
# 1095527        NaN          NaN
#
# [793 rows x 13 columns]

# %% [markdown]
# ## 매출 제품 데이터 상세: tr_dtl_list_0, tr_dtl_list_1
# * SAL_DT: 매출 등록 일자
# * STR_CD: 매장 코드
# * POS_NO: 포스 번호
# * TRAN_NO: 포스 거래 순번 -- 위의 4개 항목을 합쳐 하나의 장바구니
# * SEQ_NO: 매출 별 상품 순번
# * DESI_CNCL_TP_NM: 취소 구분으로 정상판매/지정취소/전체취소 총 3종류이며 지정취소와 전체취소는 거래 후 환불이 아닌 바코드 찍을 당시 삭제한 것을 기록한 것으로 정상판매만 사용해도 무방
# * SALE_RTN_SGN: 금액에 대한 부호로 1과 -1로 구분, -1은 반품
# * PLU_CD: 제품 코드
# * GDS_CLSS_CD: 제품 카테고리 코드로 (예상하기로는) 거래 당시 등록되어있던 카테고리를 기록하는 목적인 것으로 판단(무시해도 좋을 것 같습니다.)
# * SALE_QTY: 수량
# * SALE_PRC: 단가
# * SALE_AMT: 총 금액(수량X단가) - 전체 할인 금액
# * SGDS_DC_TP_NM: 단품 할인 구분이라는 항목으로 정상/단품할인/고객지정가할인/할인특매 총 4개로 구분되나 매장마다 사용하는 용도가 다른 것으로 보입니다.
# * SGDS_DC_PRC: 단품 할인 단가
# * SUBTOT_DC_AMT: 할인 소계(제품에 적용된 할인 총액)
# * EVT_DC_AMT: 행사 할인 금액
# * CPON_DC_AMT: 쿠폰 할인 금액
# * SCALES_GDS_TP_NM: 저울 상품 구분, 일반/일반저울/중량저울, 저울상품이란 저울로 측정된 무게로 가격을 책정하는 경우로 주로 신선(야채, 육류) 등을 구분하는데 사용됨
# * GDS_CPON_DC_AMT: 상품 쿠폰 할인 금액
# * BASKET_CPON_DC_AMT: 장바구니 쿠폰 할인 금액

# %%
tr_dtl_list_0
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 6149885  20220901   72005     03      333       2            정상판매
# 6149886  20220901   72005     03      333       3            정상판매
# 6149887  20220901   72005     03      333       4            정상판매
# 6149888  20220901   72005     03      333       5            정상판매
# 6149889  20220901   72005     03      333       6            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 6149885             1       22000422     110101.0       1.0     490.0
# 6149886             1  8801094012403      10203.0       1.0    3200.0
# 6149887             1  8801019605505      10101.0       1.0    2500.0
# 6149888             1  8801117694807      10101.0       1.0    2100.0
# 6149889             1  8801062381937      10101.0       1.0    1300.0
#
#           SALE_AMT SGDS_DC_TP_NM  SGDS_DC_PRC  SUBTOT_DC_AMT  EVT_DC_AMT  \
# 0         540000.0          할인특매          0.0            0.0         0.0
# 1         360000.0          할인특매          0.0            0.0         0.0
# 2         360000.0          할인특매          0.0            0.0         0.0
# 3         486000.0          할인특매          0.0            0.0         0.0
# 4        1710000.0          할인특매          0.0            0.0         0.0
# ...            ...           ...          ...            ...         ...
# 6149885      490.0            정상          0.0            0.0         0.0
# 6149886     3200.0            정상          0.0            0.0         0.0
# 6149887     2500.0            정상          0.0            0.0         0.0
# 6149888     2100.0            정상          0.0            0.0         0.0
# 6149889     1300.0            정상          0.0            0.0         0.0
#
#          CPON_DC_AMT SCALES_GDS_TP_NM  GDS_CPON_DC_AMT  BASKET_CPON_DC_AMT
# 0                0.0               일반              0.0                 0.0
# 1                0.0               일반              0.0                 0.0
# 2                0.0               일반              0.0                 0.0
# 3                0.0               일반              0.0                 0.0
# 4                0.0               일반              0.0                 0.0
# ...              ...              ...              ...                 ...
# 6149885          0.0               일반              0.0                 0.0
# 6149886          0.0               일반              0.0                 0.0
# 6149887          0.0               일반              0.0                 0.0
# 6149888          0.0               일반              0.0                 0.0
# 6149889          0.0               일반              0.0                 0.0
#
# [6149890 rows x 20 columns]

# %%
tr_dtl_list_0.DESI_CNCL_TP_NM.value_counts()
# Out:
# 정상판매    6093260
# 지정취소      41521
# 전체취소      15109
# Name: DESI_CNCL_TP_NM, dtype: int64

# %%
tr_dtl_list_0.isnull().sum().sort_values(ascending = False)
# Out:
# GDS_CLSS_CD           117423
# BASKET_CPON_DC_AMT         0
# GDS_CPON_DC_AMT            0
# STR_CD                     0
# POS_NO                     0
# TRAN_NO                    0
# SEQ_NO                     0
# DESI_CNCL_TP_NM            0
# SALE_RTN_SGN               0
# PLU_CD                     0
# SALE_QTY                   0
# SALE_PRC                   0
# SALE_AMT                   0
# SGDS_DC_TP_NM              0
# SGDS_DC_PRC                0
# SUBTOT_DC_AMT              0
# EVT_DC_AMT                 0
# CPON_DC_AMT                0
# SCALES_GDS_TP_NM           0
# SAL_DT                     0
# dtype: int64

# %%
cond = tr_dtl_list_0['SALE_AMT'] == max(tr_dtl_list_0['SALE_AMT'])

# %%
tr_dtl_list_0[cond]
# Out:
#           SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 632975  20211010   12018     05      184       4            지정취소
#
#         SALE_RTN_SGN  PLU_CD  GDS_CLSS_CD  SALE_QTY     SALE_PRC     SALE_AMT  \
# 632975             1  351030      52399.0       1.0  351028000.0  351028000.0
#
#        SGDS_DC_TP_NM  SGDS_DC_PRC  SUBTOT_DC_AMT  EVT_DC_AMT  CPON_DC_AMT  \
# 632975            정상          0.0            0.0         0.0          0.0
#
#        SCALES_GDS_TP_NM  GDS_CPON_DC_AMT  BASKET_CPON_DC_AMT
# 632975               일반              0.0                 0.0

# %%
sns.kdeplot(x=tr_dtl_list_0['SALE_AMT'])
# Out:
# <AxesSubplot:xlabel='SALE_AMT', ylabel='Density'>
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
gdsclss_0['STR_CD'].value_counts() # 마트 분류
# Out:
# 12018    607
# 0        165
# Name: STR_CD, dtype: int64

# %%
gdsclss_1 # 장바구니 분류
# Out:
#        CO_CD  STR_CD  GDS_CLSS_CD GDS_CLSS_NM  GDS_CLSS_LVL_TP  \
# 0    1001993       0            1       식 품 류                1
# 1    1001993       0          101        가공식품                2
# 2    1001993       0        10101        가공식품                3
# 3    1001993       0        10199     기타-가공식품                3
# 4    1001993       0          102       식 용 유                2
# ..       ...     ...          ...         ...              ...
# 362  1002056       0           99         미등록                1
# 363  1002056       0         9979   임시핸디매입등록용                2
# 364  1002056       0       997979   임시핸디매입등록용                3
# 365  1002056       0         9999         미등록                2
# 366  1002056       0       999999         미등록                3
#
#      UP_GDS_CLSS_CD  GDS_CLSS_GRP_TP
# 0                 0                1
# 1                 1                1
# 2               101                1
# 3               101                1
# 4                 1                1
# ..              ...              ...
# 362               0                1
# 363              99                1
# 364            9979                1
# 365              99                1
# 366            9999                1
#
# [367 rows x 7 columns]

# %%
gdsclss_1['GDS_CLSS_NM'].value_counts().head(100) # 장바구니 분류
# Out:
# 액세서리         5
# 아이스크림        4
# 위생용품         4
# 공    병       3
# 종량봉투         3
# 청    과       3
# 쇼핑봉투         3
# 미등록          3
# 담    배       3
# 수    산       3
# 임의코드         3
# 야    채       3
# 세 트 류        3
# 양    곡       3
# 의약외품         3
# 정    육       3
# 베이커리         3
# 냉장/냉동        2
# 기타주류         2
# 전기           2
# 기타공    병     2
# 통 조 림        2
# 차류           2
# 카메라/필름       2
# 기타베이커리       2
# 유제품          2
# 식 용 유        2
# 면/가루류        2
# 분유-면세        2
# 도서/잡지        2
# 문구/완구        2
# 주방세제         2
# 기타쇼핑봉투       2
# 주방잡화         2
# 패    드       2
# 분유-과세        2
# 기타식 품 류      2
# POS등록용소분류    2
# 빵    류       2
# 치약치솔         2
# 일회용품         2
# 기타청    과     2
# 안주류          2
# 일반음료         2
# 기타양    곡     2
# 제과/제빵        2
# 냉동식품         2
# 기타미 분 류      2
# 유아용품         2
# 의약품          2
# 제지류          2
# 욕실잡화         2
# 국산주류         2
# 과 자 류        2
# 제 분 류        2
# 국산담배         2
# 기타임의코드       2
# 냉장식품         2
# 화 장 지        2
# 계    란       2
# 건 어 물        2
# 기타건 어 물      2
# 가공식품         2
# 애완용품         2
# 양    주       2
# 축산물          2
# 조미장류         2
# 헤어용품         2
# 간편조리         2
# 기타야    채     2
# 기초의류         2
# 커피/차         2
# 세탁세제         2
# 신문           2
# 일반잡화         2
# 양념소스         2
# 잡화           2
# 방향/방습/방충     2
# 샴푸린스         2
# 건강엑기스        2
# 수입주류         2
# 기타면    세     2
# 기호식품         2
# 기타분    유     2
# 기타주    류     2
# 씨 리 얼        2
# 기타액세서리       2
# 통조림          2
# 애견용품         2
# 기타의약외품       2
# 방향방충         2
# 화장품          2
# 임시핸디매입등록용    2
# 1차식품         2
# 공 박 스        2
# 즉석식품         2
# 유 제 품        2
# 기타종량봉투       2
# 기타-세 트 류     2
# 면    류       2
# Name: GDS_CLSS_NM, dtype: int64

# %%
gdsclss_0['GDS_CLSS_NM'].value_counts().head(100) # 장바구니 분류
# Out:
# 기타         16
# 식품         14
# 쓰레기봉투       7
# 건어물         6
# 비식품         6
# 야채          6
# 수산          6
# 계란          6
# 양곡          5
# 모기약         5
# 화장품         5
# 부자재         5
# 담배          5
# 수입류         5
# 방향제         4
# 욕실용품        4
# 주류          4
# 세트          4
# 염색약         4
# 콩나물         4
# 식자재         4
# 청과          4
# 잡곡          4
# 치약칫솔        4
# 샴푸린스        4
# 반찬          4
# 문구류         3
# 소주          3
# 아울렛         3
# 매입대분류       3
# 음료수류        3
# 과채류         3
# 팬시          3
# 포인트현금화      3
# 기타잡화        3
# 신상품         3
# 수수료         3
# 사내소비        3
# 정육          3
# 아울렛기타잡화     3
# 화장품류        3
# 공병          3
# 스프류         3
# 미등록         3
# 일회용품        3
# 생선          3
# 분유          3
# 통일상사        3
# 면도기         3
# 건전지         3
# 유아용품        3
# 시집가는청국장     2
# 아기용품        2
# 제이제이코리아     2
# 계절용품        2
# 수입소         2
# 건전지류        2
# 김장채소류       2
# 수예품         2
# 밀폐용기        2
# 통조림류        2
# 깨           2
# 청소용품        2
# 야채식자재       2
# 아이스크림       2
# 후추          2
# 이불/원예외      2
# 양념/나물류      2
# 동아펫         2
# 냉동          2
# 맘스케익        2
# 막걸리         2
# 웰라          2
# 계육          2
# 냉동식품        2
# 생리대         2
# 한돈          2
# 맥주          2
# 레토르트식품      2
# 돼지          2
# 견과류         2
# 인과류         2
# 양념장         2
# 유제품         2
# 디핀다트코리아     2
# 두유          2
# 열대과일        2
# 기타청과        2
# 에센스         2
# 핵과류         2
# 세제류         2
# 오이피클        2
# 수입돼지        2
# 가루          2
# 자동차용품       2
# 화장비누        2
# 묵류          2
# 기저귀         2
# 땅콩          2
# 냉장          2
# Name: GDS_CLSS_NM, dtype: int64

# %% [markdown]
# - tr_list와 dtl_list가 장바구니 코드로 mapping되는 지 확인

# %%
tr_list_0[
    (tr_list_0.SAL_DT == 20210901) &
    (tr_list_0.STR_CD == 12018) &
    (tr_list_0.POS_NO == "01") &
    (tr_list_0.TRAN_NO == 5)
]
# Out:
#      SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 4  20210901   12018     01        5              매출             1
#
#    REAL_SAL_DT  REAL_SAL_TTM  PAY_AMT   MSHP_ID  ORN_SAL_DT ORN_POS_NO  \
# 4     20210901         91245   3650.0  012018_0         NaN        NaN
#
#    ORN_TRAN_NO
# 4          NaN

# %%
tr_dtl_list_0[
    (tr_dtl_list_0.SAL_DT == 20210901) &
    (tr_dtl_list_0.STR_CD == 12018) &
    (tr_dtl_list_0.POS_NO == "01") &
    (tr_dtl_list_0.TRAN_NO == 5)
]
# Out:
#       SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  SALE_RTN_SGN  \
# 17  20210901   12018     01        5       1            정상판매             1
# 18  20210901   12018     01        5       2            정상판매             1
#
#            PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT SGDS_DC_TP_NM  \
# 17  8801056190019      12202.0       1.0    2650.0    2650.0            정상
# 18  8801056177355      12215.0       1.0    1000.0    1000.0          할인특매
#
#     SGDS_DC_PRC  SUBTOT_DC_AMT  EVT_DC_AMT  CPON_DC_AMT SCALES_GDS_TP_NM  \
# 17          0.0            0.0         0.0          0.0               일반
# 18          0.0            0.0         0.0          0.0               일반
#
#     GDS_CPON_DC_AMT  BASKET_CPON_DC_AMT
# 17              0.0                 0.0
# 18              0.0                 0.0

# %% [markdown]
# - tr_dtl이 거래 세부 내역이고 tr_listr가 장바구니 ID로 기준으로 한 해당 일시 총 거래 내역

# %%
 gds_0[gds_0.GDS_NM.str.contains(r'(배추)')].head(100)
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#          CO_CD  STR_CD         PLU_CD            GDS_NM  GDS_CLSS_CD  \
# 765    1001294   12018         201162               양배추        30102
# 772    1001294   12018         201169           알배기/쌈배추        30101
# 773    1001294   12018         201170               통배추        39999
# 774    1001294   12018         201171                배추        30899
# 776    1001294   12018         201173               망배추        39999
# 777    1001294   12018         201174          절임배추 1박스        30899
# 2390   1001294   12018       22001054           양배추(반통)        39999
# 2414   1001294   12018       22001344               양배추        39999
# 2419   1001294   12018       22001399               쌈배추        39999
# 2430   1001294   12018       22001498              절임배추        39999
# 2434   1001294   12018       22001535                배추        39999
# 2473   1001294   12018       22001894             양배추3통        39999
# 2572   1001294   12018       22002891              배추행사        39999
# 2827   1001294   12018         224191                배추        30899
# 2828   1001294   12018         224193                배추        39999
# 2830   1001294   12018         224195               양배추        30199
# 2864   1001294   12018         224247               쌈배추        30101
# 3130   1001294   12018         225512                배추        39999
# 3139   1001294   12018         225521             양배추4입        39999
# 4061   1001294   12018   290899000124      배추(아이보리색끈)1망        30899
# 4129   1001294   12018  2908990003293           *양배추 1망        30499
# 4165   1001294   12018  2908990003620            *배추 1망        30899
# 4166   1001294   12018  2908990003637         쌈배추(봉지)1통        30101
# 4168   1001294   12018  2908990003651       *양배추(4*5)1망        30499
# 4250   1001294   12018  2908990004443         쌈배추(벌크)1통        30101
# 4320   1001294   12018  2908990005174        양배추(수입)1박스        30499
# 4339   1001294   12018  2908990005365          배추(특)/1망        30899
# 4399   1001294   12018  2908990005969            배추 1박스        30899
# 4423   1001294   12018  2908990006201            *배추 1통        30899
# 4458   1001294   12018  2908990006553         *미니양배추 1팩        30102
# 4463   1001294   12018  2908990006607           *양배추 1통        30102
# 4531   1001294   12018  2908990007284     양배추 1통/1인1통한정        30102
# 4576   1001294   12018  2908990007734     배추(행사)1망/베이지끈        30899
# 4695   1001294   12018  2908990008922         *절임배추 1박스        30899
# 4751   1001294   12018  2908990042254     *꼬깔양배추 1통(행사)        30102
# 4823   1001294   12018  2908990043190             배추우거지        30701
# 4845   1001294   12018  2908990043480           양배추 1박스        30499
# 4948   1001294   12018  2909441429037      *쌈배추(알배기) 1통        30101
# 4975   1001294   12018  2909441429310            정육 양배추       510499
# 5247   1001294   12018  2999000003143         *꼬마양배추 1통        30102
# 5316   1001294   12018  2999000033836   **쌈배추(특/비닐포장)1봉        30101
# 5356   1001294   12018  2999000034253  *쌈배추(알배기) 1통 추가시        30101
# 6203   1001294   12018  4562353730240           일)양배추칼P        93334
# 6204   1001294   12018  4562353730257           일제양배추칼G        91701
# 7591   1001294   12018  4991203138217              양배추칼        91201
# 7596   1001294   12018  4991203147301              양배추칼        91301
# 10012  1001294   12018  8801007070162            썰은배추김치        10152
# 10951  1001294   12018  8801007280417         비비고썰은배추김치        12001
# 10952  1001294   12018  8801007280431         CJ 썰은배추김치        10152
# 11054  1001294   12018  8801007316000           비비고썰은배추        10152
# 11112  1001294   12018  8801007335070           비비고썰은배추        10152
# 11244  1001294   12018  8801007369563           비비고썰은배추        10152
# 11394  1001294   12018  8801007423456            궁중배추김치        10152
# 11404  1001294   12018  8801007424583         CJ비비고포기배추        10152
# 11508  1001294   12018  8801007448275         비비고궁중배추김치        10152
# 11590  1001294   12018  8801007529066        비비고/포기배추김치        10152
# 11591  1001294   12018  8801007529080        비비고/포기배추김치        10152
# 11592  1001294   12018  8801007529127        비비고/포기배추김치        12001
# 11593  1001294   12018  8801007529158      CJ비비고/썰은배추김치        10152
# 11594  1001294   12018  8801007529202        비비고/썰은배추김치        10152
# 11595  1001294   12018  8801007529226           비비고썰은배추        10152
# 11596  1001294   12018  8801007529264        비비고/썰은배추김치        10152
# 11597  1001294   12018  8801007529301        비비고/썰은배추김치        10152
# 11598  1001294   12018  8801007529387           비비고썰은배추        10152
# 11614  1001294   12018  8801007531137           비비고썰은배추        10152
# 11625  1001294   12018  8801007532639           비비고썰은배추        10152
# 11628  1001294   12018  8801007533605          비비고포기배추통        10152
# 11633  1001294   12018  8801007534176           비비고썰은배추        10152
# 11634  1001294   12018  8801007534213           비비고썰은배추        10152
# 11635  1001294   12018  8801007534237           비비고썰은배추        10152
# 11636  1001294   12018  8801007534251           비비고포기배추        10152
# 11652  1001294   12018  8801007539119           비비고썰은배추        10152
# 11653  1001294   12018  8801007539133           비비고썰은배추        10152
# 11654  1001294   12018  8801007539188           비비고썰은배추        10152
# 11655  1001294   12018  8801007539201           비비고썰은배추        10152
# 12529  1001294   12018  8801007989556        비비고)썰은배추김치        10152
# 12530  1001294   12018  8801007989570        비비고)포기배추김치        10152
# 13938  1001294   12018  8801024956654      종가집어린이한입배추김치        10152
# 14847  1001294   12018  8801039003480        해표 배추겉절이양념        11171
# 18309  1001294   12018  8801045891033          엣날국밥배추된장        12101
# 18312  1001294   12018  8801045891071            배추된장국밥        12101
# 25994  1001294   12018  8801056177430         롯데 사과양배추즙        12212
# 36789  1001294   12018  8801156177430         롯데 사과양배추즙        12212
# 54610  1001294   12018  8809016634498           양배추슬라이서        91701
# 55346  1001294   12018  8809026850185              양배추칼        91701
# 62137  1001294   12018  8809217138368               양배추       140101
# 63671  1001294   12018  8809263421179              배추봉투        99999
# 66088  1001294   12018  8809342242138              배추김치        39999
# 72736  1001739   72005         200079              해남배추        40601
# 72806  1001739   72005         200147               배추         40601
# 72809  1001739   72005         200149             배추시래기        40601
# 72850  1001739   72005         200190              솎음배추        40601
# 72868  1001739   72005         200208               쌈배추        40601
# 72892  1001739   72005         200229               양배추        40601
# 73094  1001739   72005         200425           해남절임배추         40601
# 73095  1001739   72005         200426           괴산절임배추         40601
# 74791  1001739   72005         207200              배추김치        50101
# 75292  1001739   72005       22001184              양배추         40601
# 75293  1001739   72005       22001191              양배추         40601
# 75305  1001739   72005       22001313               쌈배추        40601
#
#       GDS_TP_NM  VEN_CD
# 765        저울상품      80
# 772        저울상품      80
# 773        저울상품      80
# 774        저울상품      80
# 776        저울상품      80
# 777        저울상품      80
# 2390         일반      80
# 2414         일반      80
# 2419         일반      80
# 2430         일반      80
# 2434         일반      80
# 2473         일반      80
# 2572         일반      80
# 2827       저울상품      80
# 2828       저울상품      80
# 2830       저울상품      80
# 2864       저울상품      80
# 3130       저울상품      80
# 3139       저울상품      80
# 4061         일반      80
# 4129         일반      80
# 4165         일반      80
# 4166         일반      80
# 4168         일반      80
# 4250         일반      80
# 4320         일반      80
# 4339         일반      80
# 4399         일반      80
# 4423         일반      80
# 4458         일반      80
# 4463         일반      80
# 4531         일반      80
# 4576         일반      80
# 4695         일반      80
# 4751         일반      80
# 4823         일반      80
# 4845         일반      80
# 4948         일반      80
# 4975         일반       0
# 5247         일반      80
# 5316         일반      80
# 5356         일반      80
# 6203         일반       0
# 6204         일반       0
# 7591         일반       0
# 7596         일반       0
# 10012        일반       0
# 10951        일반       0
# 10952        일반       0
# 11054        일반       0
# 11112        일반       0
# 11244        일반       0
# 11394        일반       0
# 11404        일반       0
# 11508        일반       0
# 11590        일반      60
# 11591        일반      60
# 11592        일반      60
# 11593        일반      60
# 11594        일반      60
# 11595        일반       0
# 11596        일반      60
# 11597        일반      60
# 11598        일반       0
# 11614        일반       0
# 11625        일반       0
# 11628        일반       0
# 11633        일반       0
# 11634        일반       0
# 11635        일반       0
# 11636        일반       0
# 11652        일반       0
# 11653        일반       0
# 11654        일반       0
# 11655        일반       0
# 12529        일반      60
# 12530        일반      60
# 13938        일반       0
# 14847        일반       0
# 18309        일반       0
# 18312        일반       0
# 25994        일반      20
# 36789        일반       0
# 54610        일반       0
# 55346        일반       0
# 62137        일반       0
# 63671        일반      13
# 66088        일반      80
# 72736      저울상품       5
# 72806      저울상품       5
# 72809      저울상품       5
# 72850      저울상품       5
# 72868      저울상품       5
# 72892      저울상품       5
# 73094      저울상품       5
# 73095      저울상품       5
# 74791      저울상품      57
# 75292        일반       5
# 75293        일반       5
# 75305        일반       5
