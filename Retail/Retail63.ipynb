# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df21011_4_1.csv')
df
# Out:
#         GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0          청량초  2021-11-13         5      3000      5000
# 1          청량초  2021-11-14         3      2000      3000
# 2          청량초  2021-11-18         3      2000      3000
# 3          청량초  2022-03-20         3      1000      3000
# 4          청량초  2022-07-04         3      2000      3000
# ...        ...         ...       ...       ...       ...
# 608934  히츠퍼플라벨  2022-07-26         4      9000     18000
# 608935  히츠퍼플라벨  2022-07-30         4      9000     18000
# 608936  히츠퍼플라벨  2022-08-09         4      9000     18000
# 608937  히츠퍼플라벨  2022-08-23         4      9000     18000
# 608938  히츠퍼플라벨  2022-08-26         3      9000     13500
#
# [608939 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608939 entries, 0 to 608938
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   GDS_NM    608938 non-null  object
#  1   SAL_DT    608939 non-null  object
#  2   SALE_QTY  608939 non-null  int64
#  3   SALE_PRC  608939 non-null  int64
#  4   SALE_AMT  608939 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 23.2+ MB

# %%
df.SAL_DT = pd.to_datetime(df.SAL_DT)
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0          청량초 2021-11-13         5      3000      5000
# 1          청량초 2021-11-14         3      2000      3000
# 2          청량초 2021-11-18         3      2000      3000
# 3          청량초 2022-03-20         3      1000      3000
# 4          청량초 2022-07-04         3      2000      3000
# ...        ...        ...       ...       ...       ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500
#
# [608939 rows x 5 columns]

# %%
df['year'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.year
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year
# 0          청량초 2021-11-13         5      3000      5000  2021
# 1          청량초 2021-11-14         3      2000      3000  2021
# 2          청량초 2021-11-18         3      2000      3000  2021
# 3          청량초 2022-03-20         3      1000      3000  2022
# 4          청량초 2022-07-04         3      2000      3000  2022
# ...        ...        ...       ...       ...       ...   ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022
#
# [608939 rows x 6 columns]

# %%
df['month'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.month
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month
# 0          청량초 2021-11-13         5      3000      5000  2021     11
# 1          청량초 2021-11-14         3      2000      3000  2021     11
# 2          청량초 2021-11-18         3      2000      3000  2021     11
# 3          청량초 2022-03-20         3      1000      3000  2022      3
# 4          청량초 2022-07-04         3      2000      3000  2022      7
# ...        ...        ...       ...       ...       ...   ...    ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022      7
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022      8
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022      8
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022      8
#
# [608939 rows x 7 columns]

# %%
df['day'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.day
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day
# 0          청량초 2021-11-13         5      3000      5000  2021     11   13
# 1          청량초 2021-11-14         3      2000      3000  2021     11   14
# 2          청량초 2021-11-18         3      2000      3000  2021     11   18
# 3          청량초 2022-03-20         3      1000      3000  2022      3   20
# 4          청량초 2022-07-04         3      2000      3000  2022      7    4
# ...        ...        ...       ...       ...       ...   ...    ...  ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022      7   30
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022      8    9
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022      8   23
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022      8   26
#
# [608939 rows x 8 columns]

# %%
df['weekday'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.weekday
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# 0          청량초 2021-11-13         5      3000      5000  2021     11   13
# 1          청량초 2021-11-14         3      2000      3000  2021     11   14
# 2          청량초 2021-11-18         3      2000      3000  2021     11   18
# 3          청량초 2022-03-20         3      1000      3000  2022      3   20
# 4          청량초 2022-07-04         3      2000      3000  2022      7    4
# ...        ...        ...       ...       ...       ...   ...    ...  ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022      7   30
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022      8    9
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022      8   23
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022      8   26
#
#         weekday
# 0             5
# 1             6
# 2             3
# ...

# %%
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# 0          청량초 2021-11-13         5      3000      5000  2021     11   13
# 1          청량초 2021-11-14         3      2000      3000  2021     11   14
# 2          청량초 2021-11-18         3      2000      3000  2021     11   18
# 3          청량초 2022-03-20         3      1000      3000  2022      3   20
# 4          청량초 2022-07-04         3      2000      3000  2022      7    4
# ...        ...        ...       ...       ...       ...   ...    ...  ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022      7   30
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022      8    9
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022      8   23
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022      8   26
#
#         weekday
# 0             5
# 1             6
# 2             3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608939 entries, 0 to 608938
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   GDS_NM    608938 non-null  object
#  1   SAL_DT    608939 non-null  datetime64[ns]
#  2   SALE_QTY  608939 non-null  int64
#  3   SALE_PRC  608939 non-null  int64
#  4   SALE_AMT  608939 non-null  int64
#  5   year      608939 non-null  int64
#  6   month     608939 non-null  int64
#  7   day       608939 non-null  int64
#  8   weekday   608939 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 41.8+ MB

# %%
df1 = df.groupby('GDS_NM').sum()
df1
# Out:
#            SALE_QTY  SALE_PRC  SALE_AMT   year  month  day  weekday
# GDS_NM
# ABC초코            97    121320    210700  44480    131  306       75
# ABC초코렛            7     18000     31500   4043     14    4        3
# ABC초코쿠키         167    259300    316100  84912    235  649      107
# ABC초코쿠키민트         6      4000      6000   4042     18   34        8
# ABC쿠키앤크림          4      1800      3600   2021      9   28        1
# ...             ...       ...       ...    ...    ...  ...      ...
# 히츠썸머브리즈          10     22500     45000   6064     26   25        4
# 히츠앰버             39     40500    175500  12128     51  110       19
# 히츠엠버            109    211500    490500  60650    192  449       92
# 히츠퍼플             32    270000    346500  16172     54  132       30
# 히츠퍼플라벨          105    225000    472500  50540    186  431       85
#
# [16785 rows x 7 columns]

# %%
df1_1 = df.groupby(['GDS_NM', 'SAL_DT']).sum()
df1_1
# Out:
#                    SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  weekday
# GDS_NM SAL_DT
# ABC초코  2021-11-01         5      2180     10900  2021     11    1        0
#        2021-12-12         5     10920     10920  2021     12   12        6
#        2021-12-20        15      4360     32700  2021     12   20        0
#        2021-12-23         5      2180     10900  2021     12   23        3
#        2022-01-09         3      6540      6540  2022      1    9        6
# ...                     ...       ...       ...   ...    ...  ...      ...
# 히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26        1
#        2022-07-30         4      9000     18000  2022      7   30        5
#        2022-08-09         4      9000     18000  2022      8    9        1
#        2022-08-23         4      9000     18000  2022      8   23        1
#        2022-08-26         3      9000     13500  2022      8   26        4
#
# [600712 rows x 7 columns]

# %%
df1_2 = df.groupby(['GDS_NM', 'SAL_DT' ,'year']).sum()
df1_2
# Out:
#                         SALE_QTY  SALE_PRC  SALE_AMT  month  day  weekday
# GDS_NM SAL_DT     year
# ABC초코  2021-11-01 2021         5      2180     10900     11    1        0
#        2021-12-12 2021         5     10920     10920     12   12        6
#        2021-12-20 2021        15      4360     32700     12   20        0
#        2021-12-23 2021         5      2180     10900     12   23        3
#        2022-01-09 2022         3      6540      6540      1    9        6
# ...                          ...       ...       ...    ...  ...      ...
# 히츠퍼플라벨 2022-07-26 2022         4      9000     18000      7   26        1
#        2022-07-30 2022         4      9000     18000      7   30        5
#        2022-08-09 2022         4      9000     18000      8    9        1
#        2022-08-23 2022         4      9000     18000      8   23        1
#        2022-08-26 2022         3      9000     13500      8   26        4
#
# [600712 rows x 6 columns]

# %%
df['GDS_NM']= df['GDS_NM'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
df['GDS_NM']
# Out:
# 0            청량초
# 1            청량초
# 2            청량초
# 3            청량초
# 4            청량초
#            ...
# 608934    히츠퍼플라벨
# 608935    히츠퍼플라벨
# 608936    히츠퍼플라벨
# 608937    히츠퍼플라벨
# 608938    히츠퍼플라벨
# Name: GDS_NM, Length: 608939, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608939 entries, 0 to 608938
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   GDS_NM    608938 non-null  object
#  1   SAL_DT    608939 non-null  datetime64[ns]
#  2   SALE_QTY  608939 non-null  int64
#  3   SALE_PRC  608939 non-null  int64
#  4   SALE_AMT  608939 non-null  int64
#  5   year      608939 non-null  int64
#  6   month     608939 non-null  int64
#  7   day       608939 non-null  int64
#  8   weekday   608939 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 41.8+ MB

# %%
df['GDS_NM'].to_list()
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# 0          청량초 2021-11-13         5      3000      5000  2021     11   13
# 1          청량초 2021-11-14         3      2000      3000  2021     11   14
# 2          청량초 2021-11-18         3      2000      3000  2021     11   18
# 3          청량초 2022-03-20         3      1000      3000  2022      3   20
# 4          청량초 2022-07-04         3      2000      3000  2022      7    4
# ...        ...        ...       ...       ...       ...   ...    ...  ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022      7   30
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022      8    9
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022      8   23
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022      8   26
#
#         weekday
# 0             5
# 1             6
# 2             3
# ...

# %%
test = df[df['GDS_NM'] == '히츠퍼플']
test
# Out:
#        GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# 608906   히츠퍼플 2021-10-16         3     49500     54000  2021     10   16
# 608907   히츠퍼플 2021-11-01         3     49500     54000  2021     11    1
# 608908   히츠퍼플 2021-11-04        10      4500     45000  2021     11    4
# 608909   히츠퍼플 2021-12-04         3     49500     54000  2021     12    4
# 608910   히츠퍼플 2022-01-23         4     54000     58500  2022      1   23
# 608911   히츠퍼플 2022-01-27         3      9000     13500  2022      1   27
# 608912   히츠퍼플 2022-01-30         3     49500     54000  2022      1   30
# 608913   히츠퍼플 2022-07-27         3      4500     13500  2022      7   27
#
#         weekday
# 608906        5
# 608907        0
# 608908        3
# 608909        5
# 608910        6
# 608911        3
# 608912        6
# 608913        2

# %%
df['GDS_NM'].value_counts()
# Out:
# 쓰레기봉투L              1608
# 종량L                  844
# 서울우유                 826
# 재사용봉투L               732
# 카스큐팩L                722
#                     ...
# 화미데리야끼소스               1
# 유한킴벌리디펜드안심언더웨어대형       1
# 분햄버거스테이크               1
# 헤어롤브러쉬                 1
# 다시다쇠고기골드               1
# Name: GDS_NM, Length: 16785, dtype: int64

# %%
test.plot(kind='bar',y=['SALE_QTY'])
# Out:
# <AxesSubplot:>

# %%
test.plot(kind='bar',y=['SALE_AMT'])
# Out:
# <AxesSubplot:>

# %%
test1 = df[df['GDS_NM'] == '쓰레기봉투L']
test1
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# 333916  쓰레기봉투L 2021-09-01        12     68200     74400  2021      9    1
# 333917  쓰레기봉투L 2021-09-02        12     68200     74400  2021      9    2
# 333918  쓰레기봉투L 2021-09-03         8     37200     49600  2021      9    3
# 333919  쓰레기봉투L 2021-09-04        10     49600     62000  2021      9    4
# 333920  쓰레기봉투L 2021-09-05        12     74400     74400  2021      9    5
# ...        ...        ...       ...       ...       ...   ...    ...  ...
# 335521  쓰레기봉투L 2022-08-28        31     11120     86180  2022      8   28
# 335522  쓰레기봉투L 2022-08-29        11      5560     30580  2022      8   29
# 335523  쓰레기봉투L 2022-08-30        15     11120     41700  2022      8   30
# 335524  쓰레기봉투L 2022-08-31        40      8340    111200  2022      8   31
# 335525  쓰레기봉투L 2022-09-01        52     13900    144560  2022      9    1
#
#         weekday
# 333916        2
# 333917        3
# 333918        4
# ...

# %%
test1.plot(kind='bar',y=['SALE_QTY'])
# Out:
# <AxesSubplot:>

# %%
test1.plot(kind='bar',y=['SALE_AMT'])
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#         GDS_NM     SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# 0          청량초 2021-11-13         5      3000      5000  2021     11   13
# 1          청량초 2021-11-14         3      2000      3000  2021     11   14
# 2          청량초 2021-11-18         3      2000      3000  2021     11   18
# 3          청량초 2022-03-20         3      1000      3000  2022      3   20
# 4          청량초 2022-07-04         3      2000      3000  2022      7    4
# ...        ...        ...       ...       ...       ...   ...    ...  ...
# 608934  히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26
# 608935  히츠퍼플라벨 2022-07-30         4      9000     18000  2022      7   30
# 608936  히츠퍼플라벨 2022-08-09         4      9000     18000  2022      8    9
# 608937  히츠퍼플라벨 2022-08-23         4      9000     18000  2022      8   23
# 608938  히츠퍼플라벨 2022-08-26         3      9000     13500  2022      8   26
#
#         weekday
# 0             5
# 1             6
# 2             3
# ...

# %%
test = df.groupby('year').sum()
test
# Out:
#       SALE_QTY     SALE_PRC     SALE_AMT    month      day  weekday
# year
# 2021   2493237   6902551600   6867036830  2194783  3288645   654543
# 2022   4493706  12323468844  14659461070  1795292  6281251  1242090

# %%
test = df.groupby('month').sum()
test
# Out:
#        SALE_QTY    SALE_PRC    SALE_AMT       year     day  weekday
# month
# 1        695356  1840718620  2291390290  110108010  896007   174077
# 2        535982  1280640580  1606114990   91964604  685488   143345
# 3        573143  1496456584  1744136740  103744776  819996   154597
# 4        531608  1751955220  1989063940   97409850  741754   155339
# 5        543842  1460273060  1713840970  100501488  796895   150955
# 6        537620  1403275000  1662549420   98174166  750486   149691
# 7        543447  1625551340  1912217170  102402168  807027   166125
# 8        518092  1421588840  1689343050  100040472  782143   143596
# 9        682236  2079450870  2822853160  115356093  846119   177905
# 10       621461  1891209100  2379002818  106900795  838029   173178
# 11       585149  1459981710  -231508138   98628842  756224   144783
# 12       619007  1514919520  1947493490  105833707  849728   163042

# %%
test = df.groupby('SAL_DT').sum()
test
# Out:
#             SALE_QTY  SALE_PRC  SALE_AMT     year  month    day  weekday
# SAL_DT
# 2021-09-01     21478  54594650  71708540  3342734  14886   1654     3308
# 2021-09-02     18711  48905200  60935000  3419532  15228   3384     5076
# 2021-09-03     21856  56360050  69519600  3890425  17325   5775     7700
# 2021-09-04     23910  68332850  81908260  4120819  18351   8156    10195
# 2021-09-05     20754  63336520  71025010  3878299  17271   9595    11514
# ...              ...       ...       ...      ...    ...    ...      ...
# 2022-08-28     19119  59996910  68817870  3401004  13456  47096    10092
# 2022-08-29     15143  43656840  53464220  3115902  12328  44689        0
# 2022-08-30     12308  32456420  47531020  2640732  10448  39180     1306
# 2022-08-31     14544  41376600  49340860  2980428  11792  45694     2948
# 2022-09-01     14616  43009600  50804500  2942010  13095   1455     4365
#
# [366 rows x 7 columns]

# %%
test = df.groupby(['GDS_NM', 'SAL_DT']).sum()
test
# Out:
#                    SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  weekday
# GDS_NM SAL_DT
# ABC초코  2021-11-01         5      2180     10900  2021     11    1        0
#        2021-12-12         5     10920     10920  2021     12   12        6
#        2021-12-20        15      4360     32700  2021     12   20        0
#        2021-12-23         5      2180     10900  2021     12   23        3
#        2022-01-09         3      6540      6540  2022      1    9        6
# ...                     ...       ...       ...   ...    ...  ...      ...
# 히츠퍼플라벨 2022-07-26         4      9000     18000  2022      7   26        1
#        2022-07-30         4      9000     18000  2022      7   30        5
#        2022-08-09         4      9000     18000  2022      8    9        1
#        2022-08-23         4      9000     18000  2022      8   23        1
#        2022-08-26         3      9000     13500  2022      8   26        4
#
# [600712 rows x 7 columns]

# %%
test = df.groupby(['SAL_DT', 'GDS_NM']).sum()
test
# Out:
#                          SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# SAL_DT     GDS_NM
# 2021-09-01 CJNew중력등            10     13500     13500  2021      9    1
#            CJ가쓰오우동인             8     49000     56000  2021      9    1
#            CJ가쓰오크래빌             3      2400      3600  2021      9    1
#            CJ가쓰오튀김우동인           4     28000     28000  2021      9    1
#            CJ가지자연재료부침가루         6      9900      9900  2021      9    1
# ...                           ...       ...       ...   ...    ...  ...
# 2022-09-01 황태포왕                 3     22800     22800  2022      9    1
#            황태포특대               10     45710     65300  2022      9    1
#            흙당근                 64    162820    162820  2022      9    1
#            흙당근g특품              10       450      4500  2022      9    1
#            흙당근봉비닐              28     84000     98000  2022      9    1
#
#                          weekday
# SAL_DT     GDS_NM
# ...

# %%
test.head(50)
# Out:
#                             SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# SAL_DT     GDS_NM
# 2021-09-01 CJNew중력등               10     13500     13500  2021      9    1
#            CJ가쓰오우동인                8     49000     56000  2021      9    1
#            CJ가쓰오크래빌                3      2400      3600  2021      9    1
#            CJ가쓰오튀김우동인              4     28000     28000  2021      9    1
#            CJ가지자연재료부침가루            6      9900      9900  2021      9    1
#            CJ감자수제비가루               6      2500      7500  2021      9    1
#            CJ고메치즈크리스피핫도그           3     19500     19500  2021      9    1
#            CJ고메클래식불고기피자            4     18000     18000  2021      9    1
#            CJ고메클래식콤비네이션피자          4     18000     18000  2021      9    1
#            CJ고메함박스테이크             21     44160    154560  2021      9    1
#            CJ구수한집된장                6     34000     51000  2021      9    1
# ...

# %%
test1 = test.query('SAL_DT == 20210902')
test1
# Out:
#                           SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# SAL_DT     GDS_NM
# 2021-09-02 B쇠고기진한다시              3     28980     25830  2021      9    2
#            CJ가쓰오우동인              4     28980     28000  2021      9    2
#            CJ가쓰오튀김우동인            4     28000     28000  2021      9    2
#            CJ가지자연재료부침가루          3      4950      4950  2021      9    2
#            CJ고메갈릭베이컨치즈피자         3     15880     24780  2021      9    2
# ...                            ...       ...       ...   ...    ...  ...
#            후레시아물티슈캡형            14      8000     14000  2021      9    2
#            훈제목심                  3     19440     19440  2021      9    2
#            훈제삼겹                  3     19440     19440  2021      9    2
#            흙당근                 151    197560    197560  2021      9    2
#            흙당근봉비닐               11     19800     21780  2021      9    2
#
#                           weekday
# SAL_DT     GDS_NM
# ...

# %%
x = test.query('SAL_DT == 20210902')
x
# Out:
#                           SALE_QTY  SALE_PRC  SALE_AMT  year  month  day  \
# SAL_DT     GDS_NM
# 2021-09-02 B쇠고기진한다시              3     28980     25830  2021      9    2
#            CJ가쓰오우동인              4     28980     28000  2021      9    2
#            CJ가쓰오튀김우동인            4     28000     28000  2021      9    2
#            CJ가지자연재료부침가루          3      4950      4950  2021      9    2
#            CJ고메갈릭베이컨치즈피자         3     15880     24780  2021      9    2
# ...                            ...       ...       ...   ...    ...  ...
#            후레시아물티슈캡형            14      8000     14000  2021      9    2
#            훈제목심                  3     19440     19440  2021      9    2
#            훈제삼겹                  3     19440     19440  2021      9    2
#            흙당근                 151    197560    197560  2021      9    2
#            흙당근봉비닐               11     19800     21780  2021      9    2
#
#                           weekday
# SAL_DT     GDS_NM
# ...

# %%
xx = df[['GDS_NM' == 'CJ가쓰오우동인']
# Out:
#   File "<ipython-input-69-19d5e5a79a57>", line 1
#     xx = df[['GDS_NM' == 'CJ가쓰오우동인']
#                                     ^
# SyntaxError: unexpected EOF while parsing
