# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df3_1_10_11.csv')
df
# Out:
#            GDS_NM    SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0        스니커즈피넛싱글  20210904         1      1100      1100
# 1        스니커즈피넛싱글  20210907         2      1100      2200
# 2        스니커즈피넛싱글  20210910         1      1100      1100
# 3        스니커즈피넛싱글  20210910         1      1100      1100
# 4        스니커즈피넛싱글  20210910         1      1100      1100
# ...           ...       ...       ...       ...       ...
# 6379513       갈대비  20211007         1      4200      4200
# 6379514       갈대비  20211102         1      4200      4200
# 6379515       갈대비  20220118         1      4200      4200
# 6379516       갈대비  20220118         1      4200      4200
# 6379517       갈대비  20220316         1      4200      4200
#
# [6379518 rows x 5 columns]

# %%
df['GDS_NM'].value_counts()
# Out:
# 재사용봉투20L           185969
# 대파1단                64797
# 배달봉투                58278
# 깻잎4묶음봉              39566
# 백오이1개               38043
#                     ...
# 청아딥클린징컨디셔너550ml         1
# 오뚜기미니핫도그                1
# 접마늘                     1
# 키친아트금상첨화2로스팬            1
# 해태맛동산3000               1
# Name: GDS_NM, Length: 29278, dtype: int64

# %%
df.groupby(['GDS_NM', 'SAL_DT']).sum()
# Out:
#                      SALE_QTY  SALE_PRC  SALE_AMT
# GDS_NM     SAL_DT
# 0000       20210911         1      1800      1800
#            20210928         3      1800      5400
#            20211205         1      1800      1800
#            20211213         1      1800      1800
#            20220107         1      1800      1800
# ...                       ...       ...       ...
# 히츨러수수깡캔디   20211008         1      3500      3500
#            20211014         1      3500      3500
#            20211203         2      3500      7000
#            20211204         2      3500      7000
# 히포LED파인등기구 20220303         1     11500     11500
#
# [1777927 rows x 3 columns]

# %%
df1 = df.groupby(['GDS_NM', 'SAL_DT']).sum()

# %%
df1
# Out:
#                      SALE_QTY  SALE_PRC  SALE_AMT
# GDS_NM     SAL_DT
# 0000       20210911         1      1800      1800
#            20210928         3      1800      5400
#            20211205         1      1800      1800
#            20211213         1      1800      1800
#            20220107         1      1800      1800
# ...                       ...       ...       ...
# 히츨러수수깡캔디   20211008         1      3500      3500
#            20211014         1      3500      3500
#            20211203         2      3500      7000
#            20211204         2      3500      7000
# 히포LED파인등기구 20220303         1     11500     11500
#
# [1777927 rows x 3 columns]

# %%
pd.set_option('display.max_rows', 4000)

# %%
df['GDS_NM'].value_counts().head(4000)
# Out:
# 재사용봉투20L                185969
# 대파1단                     64797
# 배달봉투                     58278
# 깻잎4묶음봉                   39566
# 백오이1개                    38043
# 흙당근                      33622
# 서울우유                     33237
# 적상추1봉비닐                  30126
# 청양고추소                    29863
# 인큐애호박2개행사                29194
# 느타리버섯1팩                  27791
# 감자                       25546
# 토속대란1판                   25339
# 처음처럼                     23676
# 남양맛있는우유GT기획              21838
# 팽이버섯1봉                   21810
# 양파중1망                    20836
# 참이슬후레쉬                   20682
# 새송이버섯1봉                  19874
# 인큐애호박1개                  19733
# 청상추1봉                    19477
# CJ양념이잘배는찌개두부             19281
# 쌈배추알배기1통                 18448
# 가지5입봉                    18322
# 새송이버섯2봉1인2봉한정            18112
# 부추1단                     17921
# 야채                       17847
# 국내산돈앞다리살                 17693
# 대림신선한콩나물                 17666
# 시금치1단                    17426
# ...

# %%
df1 = df[['GDS_NM', 'SALE_QTY', 'SALE_PRC', 'SALE_AMT']]
df1
# Out:
#            GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0        스니커즈피넛싱글         1      1100      1100
# 1        스니커즈피넛싱글         2      1100      2200
# 2        스니커즈피넛싱글         1      1100      1100
# 3        스니커즈피넛싱글         1      1100      1100
# 4        스니커즈피넛싱글         1      1100      1100
# ...           ...       ...       ...       ...
# 6379513       갈대비         1      4200      4200
# 6379514       갈대비         1      4200      4200
# 6379515       갈대비         1      4200      4200
# 6379516       갈대비         1      4200      4200
# 6379517       갈대비         1      4200      4200
#
# [6379518 rows x 4 columns]

# %%
df1.duplicated(['GDS_NM'])
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 6379513    False
# 6379514     True
# 6379515     True
# 6379516     True
# 6379517     True
# Length: 6379518, dtype: bool

# %%
df1.groupby('GDS_NM').sum()
# Out:
#                SALE_QTY  SALE_PRC  SALE_AMT
# GDS_NM
# 0000                 28     45600     52800
# 0241405572666         3      1800      2700
# 1                     2     18000     18000
# 10000벨트               9     90000     90000
# 10001200청량초         111    100000    111000
# ...                 ...       ...       ...
# 히츠퍼플                115   1503000   1692000
# 히츠퍼플라벨              302    805500   1359000
# 히츠퍼플라벨1보루            16    720000    720000
# 히츨러수수깡캔디             19     59500     66500
# 히포LED파인등기구            1     11500     11500
#
# [29278 rows x 3 columns]

# %%
df1_1 = df1.groupby('GDS_NM').sum()
df1_1
# Out:
#                SALE_QTY  SALE_PRC  SALE_AMT
# GDS_NM
# 0000                 28     45600     52800
# 0241405572666         3      1800      2700
# 1                     2     18000     18000
# 10000벨트               9     90000     90000
# 10001200청량초         111    100000    111000
# ...                 ...       ...       ...
# 히츠퍼플                115   1503000   1692000
# 히츠퍼플라벨              302    805500   1359000
# 히츠퍼플라벨1보루            16    720000    720000
# 히츨러수수깡캔디             19     59500     66500
# 히포LED파인등기구            1     11500     11500
#
# [29278 rows x 3 columns]

# %%
df1_2 = df1_1.reset_index() # GDS_NM1011 랑 같은파일
df1_2
# Out:
#               GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0               0000        28     45600     52800
# 1      0241405572666         3      1800      2700
# 2                  1         2     18000     18000
# 3            10000벨트         9     90000     90000
# 4        10001200청량초       111    100000    111000
# ...              ...       ...       ...       ...
# 29273           히츠퍼플       115   1503000   1692000
# 29274         히츠퍼플라벨       302    805500   1359000
# 29275      히츠퍼플라벨1보루        16    720000    720000
# 29276       히츨러수수깡캔디        19     59500     66500
# 29277     히포LED파인등기구         1     11500     11500
#
# [29278 rows x 4 columns]

# %%
df1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29278 entries, 0 to 29277
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GDS_NM    29278 non-null  object
#  1   SALE_QTY  29278 non-null  int64
#  2   SALE_PRC  29278 non-null  int64
#  3   SALE_AMT  29278 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 915.1+ KB

# %%
df1_2['GDS_NM'].head(1000)
# Out:
# 0                           0000
# 1                  0241405572666
# 2                              1
# 3                        10000벨트
# 4                    10001200청량초
# 5                       1000cc뚜껑
# 6                      1000가나초코바
# 7                   1000가나초코바아몬드
# 8                        1000누크바
# 9                     1000더블크런치바
# 10                       1000메가톤
# 11                  1000몰랑피규패턴샤프
# 12                       1000바밤바
# 13                     1000빅딸기샌드
# 14                       1000빙빙바
# 15                       1000수박바
# 16                      1000순수밀크
# 17                      1000스크류바
# 18                      1000신큰사발
# 19                    1000악세서리잡화
# 20                     1000와일드바디
# 21                       1000원완구
# 22                     1000자일리톨w
# 23                       1000죠스바
# 24                1000촥붙는라바몬12개입
# 25                       1000크런키
# 26                   1000통팥가득앙꼬바
# 27               1000포케몬카드퓨전아트30
# ...

# %%
df1_2.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#                 GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 7466         롯데빼빼로초코젤리         0      2500         0
# 1298       CJ행복한콩국산콩나물         0      5700         0
# 24272      크라운참ing크림치즈         0      3800         0
# 13356    샤프란시어버터핑크리필기획         0      4980         0
# 791              CJ맛군밤         0     12740         0
# 8007        롯데한아름소시지봉지         0      4200         0
# 26328  풀무원순두부치즈그라탕뽀모도로         0      4900         0
# 24375      크리넥스3겹순수소프트         0     39000         0
# 13085         샘표국시장국메밀         0      3850         0
# 26973             하림북채         0      6900         0
# 13454         서울민트초코라떼         0      2700         0
# 3610          남양웰빙피자치즈         0      5780         0
# 995            CJ비트파우치         0     12000         0
# 5807          동서피넛버터오즈         0      7480         0
# 9789              몰티져스         0      4300         0
# 6301            동원펭수참치         0      7600         0
# 8918      매일상하목장사과딸기케일         0      3200         0
# ...

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('롯데빼빼로초코젤리')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('CJ행복한콩국산콩나물')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('크라운참ing크림치즈')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('샤프란시어버터핑크리필기획')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('CJ맛군밤')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('롯데한아름소시지봉지')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('풀무원순두부치즈그라탕뽀모도로')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('크리넥스3겹순수소프트')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('샘표국시장국메밀')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('하림북채')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('서울민트초코라떼')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('남양웰빙피자치즈')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('CJ비트파우치')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('동서피넛버터오즈')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('몰티져스')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('동원펭수참치')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('매일상하목장사과딸기케일')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('오뚜기라면사리')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('매일상하목장사과오렌지케일')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('뿌리원치자통단무지')].index
df1_2.drop(drap, inplace=True)

# %%
drap = df1_2[df1_2['GDS_NM'].str.contains('부자되는집벨벳3겹')].index
df1_2.drop(drap, inplace=True)

# %%
df1_2.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#                       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 29277             히포LED파인등기구         1     11500     11500
# 3793                    노끈특대         1      4500      4500
# 1508        KS퀸엘레강스퍼퓸샴푸600ML         1      7500      7500
# 1507        KS퀸엘레강스퍼퓸린스600ML         1      7500      7500
# 24780              키친아트배수구망대         1      4300      4300
# 9389                메밀소바멀티박스         1     36000     36000
# 16883              오가닉순면좋은느낌         1      7200      7200
# 6253               동원참치쿡짜글이용         1      2400      2400
# 24794              키커바미니392g         1      9500      9500
# 24796                키티어린이치약         1      2400      2400
# 3815                  노을브러쉬중         1      2200      2200
# 24818                킵프리저小31         1      3900      3900
# 6708                라라루루휴지걸이         1      4000      4000
# 6252               동원참치쿡볶음밥용         1      2680      2680
# 24830                 타원물병18         1      8500      8500
# ...

# %%
df1_2.sort_values('SALE_QTY', ascending=False).head(50)
# Out:
#               GDS_NM  SALE_QTY   SALE_PRC   SALE_AMT
# 20460       재사용봉투20L    201215  121760090  131245180
# 5040            대파1단     77223  105012410  118091760
# 10613           배달봉투     75359    2331120    3014360
# 3348          깻잎4묶음봉     51035   51630120   65224910
# 11063          백오이1개     45988  106694040  123285920
# 21823           처음처럼     44611   44365630   84431180
# 13911           소주공병     44123     187540    4400960
# 20116      인큐애호박2개행사     40383   46369000   59521840
# 21767         참이슬후레쉬     39608   34562230   63137130
# 13502           서울우유     39008  117656900  129403500
# 4256         느타리버섯1팩     37821   25841170   34579310
# 15065           쌀소성주     37521   21055000   46901250
# 25582         팽이버섯1봉     35684   11442050   18574140
# 2580          공병100원     35193     113240    3519200
# 29223            흙당근     33671   52541260   52633210
# 20487        적상추1봉비닐     32926   52484810   57530870
# 22022          청양고추소     31613   59965420   63282090
# ...

# %%
df2 = df1_2[['GDS_NM', 'SALE_QTY', 'SALE_AMT']]
df2
# Out:
#               GDS_NM  SALE_QTY  SALE_AMT
# 0               0000        28     52800
# 1      0241405572666         3      2700
# 2                  1         2     18000
# 3            10000벨트         9     90000
# 4        10001200청량초       111    111000
# ...              ...       ...       ...
# 29273           히츠퍼플       115   1692000
# 29274         히츠퍼플라벨       302   1359000
# 29275      히츠퍼플라벨1보루        16    720000
# 29276       히츨러수수깡캔디        19     66500
# 29277     히포LED파인등기구         1     11500
#
# [29248 rows x 3 columns]

# %%
df2.to_csv('df21011.csv', index=False)

# %%
df2.head(1000) # GDS_NM 에서 무슨 물건인지 알 수 없는 물건들 제거.
# Out:
#                          GDS_NM  SALE_QTY  SALE_AMT
# 0                          0000        28     52800
# 1                 0241405572666         3      2700
# 2                             1         2     18000
# 3                       10000벨트         9     90000
# 4                   10001200청량초       111    111000
# 5                      1000cc뚜껑         9     37800
# 6                     1000가나초코바        17     13600
# 7                  1000가나초코바아몬드        32     25600
# 8                       1000누크바       112     56000
# 9                    1000더블크런치바         4      4000
# 10                      1000메가톤        95     47500
# 11                 1000몰랑피규패턴샤프         2      2000
# 12                      1000바밤바         6      3000
# 13                    1000빅딸기샌드       127    152400
# 14                      1000빙빙바       180     90000
# 15                      1000수박바       183     91500
# 16                     1000순수밀크         1       500
# ...

# %%
drap = df2[df2['GDS_NM'].str.contains('0241405572666')].index
df2.drop(drap, inplace=True)
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df2
# Out:
#             GDS_NM  SALE_QTY  SALE_AMT
# 0             0000        28     52800
# 2                1         2     18000
# 3          10000벨트         9     90000
# 4      10001200청량초       111    111000
# 5         1000cc뚜껑         9     37800
# ...            ...       ...       ...
# 29273         히츠퍼플       115   1692000
# 29274       히츠퍼플라벨       302   1359000
# 29275    히츠퍼플라벨1보루        16    720000
# 29276     히츨러수수깡캔디        19     66500
# 29277   히포LED파인등기구         1     11500
#
# [29247 rows x 3 columns]
