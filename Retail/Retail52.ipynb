# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
pd.set_option('display.max_rows', 2400)

# %%
df = pd.read_csv(base_path + 'df1007-2.csv')

# %% [markdown]
# df1['GDS_NM'] = df1['GDS_NM'].str.replace("4묶음봉", "")
# 바꾸기

# %% [markdown]
# drap = df[df['GDS_NM'].str.contains('버지니아')].index
# df.drop(drap, inplace=True)
# df
# 제거

# %%
df
# Out:
#          month   GDS_NM  SALE_AMT  day
# 0            9    의성햇사과      9960    3
# 1            9    쌈배추벌크      1980    3
# 2            9   성주꿀참외특      9800    3
# 3            9  대패삼겹살수입     13060    3
# 4            9     거봉포도      6420    3
# ...        ...      ...       ...  ...
# 2079019      4       찹쌀     49500    4
# 2079020      7       찹쌀     49500    2
# 2079021     11      늘보리      7300    6
# 2079022      3      늘보리      7300    3
# 2079023      6      늘보리      7300    4
#
# [2079024 rows x 4 columns]

# %%
df['GDS_NM'].nunique()
# Out:
# 2346

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('라크')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('락앤락믹싱볼')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('음료수번들15ℓ')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('질프로플렉스볼파워기')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('퓨젼하이드라젤200ml')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('아코록엠필러블강화볼')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('수수마당비')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('아트릭스핸드크림')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('아트릭스75')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('다용도상')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('520cc750CC뚜껑')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('연꽃접시')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('토스코코팅북경팬')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('아이알파캔디믹서기')].index
df.drop(drap, inplace=True)

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('계란찜기')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('카드로얄녹색')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('앰보우산')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('손가락장갑')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('850cc뚜껑')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('이안투명용기500G')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('퓨젼하이드젤')].index
df.drop(drap, inplace=True)

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('심플')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('화미물티슈')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('썬파워4EA')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('쌀포대')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('타임라이트')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('양손가위1001')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('컴플리트5웨이40모')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('하이썬부탄가스박스')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('뚝배기받침')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('모닝식자재랩')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('도브화이트뷰티바')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('포오미센서티브')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('파인컷스위치')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('암앤세탁세제트로피컬')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('홍끈')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('맥주공병')].index
df.drop(drap, inplace=True)

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('바이오뚝배기유')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('바이오뚝배기')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('하이드로5날')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('배송비')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('썬파워1EA')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('펜틴실키스무드트리트먼트')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('오스랍듀렉스36W')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('소주공병')].index
df.drop(drap, inplace=True)

# %%
df['GDS_NM'].nunique()
# Out:
# 2295

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('그린매실주통')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('도브비누뷰티')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('매입에서등록한상품')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('하이드로5프리미엄날')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('뉴긔린매실통')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('H쿨맨솔')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('테망사각석쇠특왕대')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('파스텔가든머그컵')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('4711269689931')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('맥스부탄가스4EA')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('쿼트로티타늄날')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('1000cc뚜껑')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('세이프부탄1EA')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('백만송이')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('펭귄샌딩티스픈')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('덴탈케어오리지날')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('페브리지은은한')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('사이버변신로봇')].index
df.drop(drap, inplace=True)

# %%
df['GDS_NM'].nunique()
# Out:
# 2277

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('말보르비스타트로피컬')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('도브비누')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('플라스틱병016')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('반코팅장갑')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('쉐이브가드센서티브라임폼')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('물풍선')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('매입등록상품')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('스웨디시플레이트파티접시')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('질프로플렉스기')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('플라스틱병300g')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('캠핑매트')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('쉬크하이드로폼')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('레인보우목걸이')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('젤센스티브스킨')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('젤센스티브스킨200ml')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('플라스틱300g')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('플라스틱병800')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('플라스틱300g')].index
df.drop(drap, inplace=True)

# %%
df['GDS_NM'].nunique()
# Out:
# 2260

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파                      70798
# 백오이                     70088
# 인큐애호박                   53633
# 깻잎                      42029
# 새송이버섯                   41361
# 느타리버섯                   40444
# 흙당근                     40112
# 파프리카                    38262
# 감자                      34512
# 적상추                     33067
# 팽이버섯                    32711
# 청양고추소                   29863
# 시금치                     24670
# 부추                      22632
# 양배추                     21598
# 청상추                     21358
# 양파중                     20830
# 빨강대추방울토마토               19792
# 추부깻잎                    18739
# 쌈배추알배기                  18446
# 가지봉                     18322
# 청양고추                    17828
# 부사사과                    17745
# 국내산돈앞다리살                17692
# 바나나                     17162
# 무우봉투명비닐                 16446
# 일반애호박                   15645
# 야채                      14441
# 단감                      14437
# 포기상추                    14229
# 양파특대                    14141
# ...

# %%
drap = df[df['GDS_NM'].str.contains('대원PET병800G')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('대원PET병800G')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('타임리스타임')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('리뉴후레쉬')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('퍼퓸블랙미스티크향')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('쿠진그라라스실버락')].index
df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('란체티록2P타올')].index
df.drop(drap, inplace=True)

# %%
df.to_csv('df1007-3.csv', index=False)
