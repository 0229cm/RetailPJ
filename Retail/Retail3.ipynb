# %%
import pandas as pd

df = pd.read_csv('gds_a.csv')

df
# Out:
#          CO_CD  STR_CD         PLU_CD           GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0      1001739   72005              1              배송비       999999       배송료
# 1      1001739   72005              2           사은행사쿠폰       999999       배송료
# 2      1001739   72005        1801828         버드와이저(캔)        10702        일반
# 3      1001739   72005        1801859         버드와이저(캔)        10702        일반
# 4      1001739   72005       40122731   퀴네발사믹코드레싱250ML       140101        일반
# ...        ...     ...            ...              ...          ...       ...
# 30521  1001739   72005  9901234001249           그린매실주통        20301        일반
# 30522  1001739   72005  9901345698772          담배케이스스틸        20301        일반
# 30523  1001739   72005  9902345678771  9902345678771등록        70202        일반
# 30524  1001739   72005         990891        ok캐쉬백 포인트        70101        일반
# 30525  1001739   72005         990942             맥주공병        10801        일반
#
#        VEN_CD
# 0           0
# ...

# %%
import pandas as pd

df1 = pd.read_csv('tr_dtl_list_d.csv')

df1
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0      20210901  142011       1        2       1            정상판매
# 1      20210901  142011       1        2       2            정상판매
# 2      20210901  142011       1        2       3            정상판매
# 3      20210901  142011       1        3       1            정상판매
# 4      20210901  142011       1        3       2            정상판매
# ...         ...     ...     ...      ...     ...             ...
# 91807  20220901  142011       1      118       5            정상판매
# 91808  20220901  142011       1      119       1            정상판매
# 91809  20220901  142011       1      119       2            정상판매
# 91810  20220901  142011       1      119       3            정상판매
# 91811  20220901  142011       1      119       4            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0                 1  8801097250048     999999.0       1.0    1500.0    1500.0
# ...

# %%
import pandas as pd

df2= pd.read_csv('tr_dtl_list_d.csv')

df2
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0      20210901  142011       1        2       1            정상판매
# 1      20210901  142011       1        2       2            정상판매
# 2      20210901  142011       1        2       3            정상판매
# 3      20210901  142011       1        3       1            정상판매
# 4      20210901  142011       1        3       2            정상판매
# ...         ...     ...     ...      ...     ...             ...
# 91807  20220901  142011       1      118       5            정상판매
# 91808  20220901  142011       1      119       1            정상판매
# 91809  20220901  142011       1      119       2            정상판매
# 91810  20220901  142011       1      119       3            정상판매
# 91811  20220901  142011       1      119       4            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0                 1  8801097250048     999999.0       1.0    1500.0    1500.0
# ...

# %%
df1.dtypes
# Out:
# SAL_DT                  int64
# STR_CD                  int64
# POS_NO                  int64
# TRAN_NO                 int64
# SEQ_NO                  int64
# DESI_CNCL_TP_NM        object
# SALE_RTN_SGN            int64
# PLU_CD                  int64
# GDS_CLSS_CD           float64
# SALE_QTY              float64
# SALE_PRC              float64
# SALE_AMT              float64
# SGDS_DC_TP_NM          object
# SGDS_DC_PRC           float64
# SUBTOT_DC_AMT         float64
# EVT_DC_AMT            float64
# CPON_DC_AMT           float64
# SCALES_GDS_TP_NM       object
# GDS_CPON_DC_AMT       float64
# BASKET_CPON_DC_AMT    float64
# dtype: object

# %%
df1['DESI_CNCL_TP_NM'].value_counts()
# Out:
# 정상판매    90425
# 지정취소     1047
# 전체취소      340
# Name: DESI_CNCL_TP_NM, dtype: int64

# %%
df1.loc[df1['DESI_CNCL_TP_NM'] == '정상판매']
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0      20210901  142011       1        2       1            정상판매
# 1      20210901  142011       1        2       2            정상판매
# 2      20210901  142011       1        2       3            정상판매
# 3      20210901  142011       1        3       1            정상판매
# 4      20210901  142011       1        3       2            정상판매
# ...         ...     ...     ...      ...     ...             ...
# 91807  20220901  142011       1      118       5            정상판매
# 91808  20220901  142011       1      119       1            정상판매
# 91809  20220901  142011       1      119       2            정상판매
# 91810  20220901  142011       1      119       3            정상판매
# 91811  20220901  142011       1      119       4            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0                 1  8801097250048     999999.0       1.0    1500.0    1500.0
# ...

# %%
df1.loc[df1['DESI_CNCL_TP_NM'] == '지정취소']
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 54     20210901  142011       1       27       1            지정취소
# 70     20210901  142011       1       33       1            지정취소
# 72     20210901  142011       1       34       1            지정취소
# 73     20210901  142011       1       34       2            지정취소
# 74     20210901  142011       1       34       3            지정취소
# ...         ...     ...     ...      ...     ...             ...
# 91538  20220901  142011       1       23       1            지정취소
# 91586  20220901  142011       1       47       1            지정취소
# 91588  20220901  142011       1       47       3            지정취소
# 91673  20220901  142011       1       74       1            지정취소
# 91674  20220901  142011       1       74       2            지정취소
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 54                1  8801007865676     999999.0       1.0   11000.0   11000.0
# ...

# %%
df1.loc[df1['DESI_CNCL_TP_NM'] == '전체취소']
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 3727   20210914  142011       1       34       1            전체취소
# 5330   20210919  142011       1       96       1            전체취소
# 5331   20210919  142011       1       96       2            전체취소
# 5332   20210919  142011       1       96       3            전체취소
# 5333   20210919  142011       1       96       4            전체취소
# ...         ...     ...     ...      ...     ...             ...
# 91622  20220901  142011       1       55       2            전체취소
# 91623  20220901  142011       1       55       3            전체취소
# 91624  20220901  142011       1       55       4            전체취소
# 91625  20220901  142011       1       55       5            전체취소
# 91626  20220901  142011       1       55       6            전체취소
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 3727              1  8801052732138      10301.0       1.0    7100.0    7100.0
# ...

# %%
df1['SAL_DT'] = df1['SAL_DT'].astype(str)

# %%
df1[['SAL_DT']]
# Out:
#          SAL_DT
# 0      20210901
# 1      20210901
# 2      20210901
# 3      20210901
# 4      20210901
# ...         ...
# 91807  20220901
# 91808  20220901
# 91809  20220901
# 91810  20220901
# 91811  20220901
#
# [91812 rows x 1 columns]

# %%
df1.dtypes
# Out:
# SAL_DT                 object
# STR_CD                  int64
# POS_NO                  int64
# TRAN_NO                 int64
# SEQ_NO                  int64
# DESI_CNCL_TP_NM        object
# SALE_RTN_SGN            int64
# PLU_CD                  int64
# GDS_CLSS_CD           float64
# SALE_QTY              float64
# SALE_PRC              float64
# SALE_AMT              float64
# SGDS_DC_TP_NM          object
# SGDS_DC_PRC           float64
# SUBTOT_DC_AMT         float64
# EVT_DC_AMT            float64
# CPON_DC_AMT           float64
# SCALES_GDS_TP_NM       object
# GDS_CPON_DC_AMT       float64
# BASKET_CPON_DC_AMT    float64
# dtype: object

# %%
pd.to_datetime(df1['SAL_DT'])
# Out:
# 0       2021-09-01
# 1       2021-09-01
# 2       2021-09-01
# 3       2021-09-01
# 4       2021-09-01
#            ...
# 91807   2022-09-01
# 91808   2022-09-01
# 91809   2022-09-01
# 91810   2022-09-01
# 91811   2022-09-01
# Name: SAL_DT, Length: 91812, dtype: datetime64[ns]

# %%
df1['년월일'] = pd.to_datetime(df1['SAL_DT'])

# %%
df1['월'] = df1['년월일'].dt.month
df1['일'] = df1['년월일'].dt.day
df1['요일'] = df1['년월일'].dt.day_name()
# df1['시'] = df1['년월일'].dt.hour #sal_dt 에는 시간은 없으니 이 부분은 시간 컬럼쪽에서 확인
df1
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0      20210901  142011       1        2       1            정상판매
# 1      20210901  142011       1        2       2            정상판매
# 2      20210901  142011       1        2       3            정상판매
# 3      20210901  142011       1        3       1            정상판매
# 4      20210901  142011       1        3       2            정상판매
# ...         ...     ...     ...      ...     ...             ...
# 91807  20220901  142011       1      118       5            정상판매
# 91808  20220901  142011       1      119       1            정상판매
# 91809  20220901  142011       1      119       2            정상판매
# 91810  20220901  142011       1      119       3            정상판매
# 91811  20220901  142011       1      119       4            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  ...  SUBTOT_DC_AMT  \
# 0                 1  8801097250048     999999.0       1.0  ...            0.0
# ...

# %%
df1.dtypes
# Out:
# SAL_DT                        object
# STR_CD                         int64
# POS_NO                         int64
# TRAN_NO                        int64
# SEQ_NO                         int64
# DESI_CNCL_TP_NM               object
# SALE_RTN_SGN                   int64
# PLU_CD                         int64
# GDS_CLSS_CD                  float64
# SALE_QTY                     float64
# SALE_PRC                     float64
# SALE_AMT                     float64
# SGDS_DC_TP_NM                 object
# SGDS_DC_PRC                  float64
# SUBTOT_DC_AMT                float64
# EVT_DC_AMT                   float64
# CPON_DC_AMT                  float64
# SCALES_GDS_TP_NM              object
# GDS_CPON_DC_AMT              float64
# BASKET_CPON_DC_AMT           float64
# 년월일                   datetime64[ns]
# 월                              int64
# 일                              int64
# 요일                            object
# dtype: object

# %%
from collections import Counter
Counter(df1['DESI_CNCL_TP_NM'])['정상판매']
# Out:
# 90425

# %%
Counter(df1['DESI_CNCL_TP_NM'])['지정취소']
# Out:
# 1047

# %%
Counter(df1['DESI_CNCL_TP_NM'])['전체취소']
# Out:
# 340

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['월'] ==  9)].shape[0]
# Out:
# 8437

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['월'] ==  10)].shape[0]
# Out:
# 7606

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['월'] ==  11)].shape[0]
# Out:
# 7291

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['월'] ==  12)].shape[0]
# Out:
# 7060

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['월'] ==  1)].shape[0]
# Out:
# 7898

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['일'] ==  31)].shape[0]
# Out:
# 1751

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['일'] ==  30)].shape[0]
# Out:
# 2626

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['일'] ==  1)].shape[0]
# Out:
# 3388

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['일'] ==  15)].shape[0]
# Out:
# 3040

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['요일'] ==  'Monday')].shape[0]
# Out:
# 13180

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['요일'] ==  'Wednesday')].shape[0]
# Out:
# 13079

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['요일'] ==  'Saturday')].shape[0]
# Out:
# 13352

# %%
df1.loc[(df1['DESI_CNCL_TP_NM'] == '정상판매') & (df1['요일'] ==  'Sunday')].shape[0]
# Out:
# 13253

# %%
import pandas as pd

df1 = pd.read_csv('tr_dtl_list_d.csv')

df1
# Out:
#          SAL_DT  STR_CD  POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0      20210901  142011       1        2       1            정상판매
# 1      20210901  142011       1        2       2            정상판매
# 2      20210901  142011       1        2       3            정상판매
# 3      20210901  142011       1        3       1            정상판매
# 4      20210901  142011       1        3       2            정상판매
# ...         ...     ...     ...      ...     ...             ...
# 91807  20220901  142011       1      118       5            정상판매
# 91808  20220901  142011       1      119       1            정상판매
# 91809  20220901  142011       1      119       2            정상판매
# 91810  20220901  142011       1      119       3            정상판매
# 91811  20220901  142011       1      119       4            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0                 1  8801097250048     999999.0       1.0    1500.0    1500.0
# ...
