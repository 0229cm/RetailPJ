# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# a 마트 gds+list+dtl
bmart = pd.read_csv(base_path + 'tr_list_b.csv')
bmart
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 0       20210901   72005     01        1            영업개시             1
# 1       20210901   72005     01        2             준비금             1
# 2       20210901   72005     01        3              매출             1
# 3       20210901   72005     01        4              매출             1
# 4       20210901   72005     01        5              매출             1
# ...          ...     ...    ...      ...             ...           ...
# 300079  20220901   72005     03      334            캐셔정산             1
# 300080  20220901   72005     03      335           POS정산             1
# 300081  20220901   72005     03      336            영업종료             1
# ...

# %%
bmart.isnull().sum()
# Out:
# SAL_DT                  0
# STR_CD                  0
# POS_NO                  0
# TRAN_NO                 0
# SALE_KIND_TP_NM         0
# SALE_RTN_SGN            0
# REAL_SAL_DT             0
# REAL_SAL_TTM            0
# PAY_AMT                 0
# MSHP_ID            114000
# ORN_SAL_DT         296723
# ORN_POS_NO         296723
# ORN_TRAN_NO        296723
# dtype: int64

# %%
c = cmart[cmart['MSHP_ID']]
c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-66fdca4af089> in <module>
# ----> 1 c = cmart[cmart['MSHP_ID']]
#       2 c
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...
