# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\min\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\min\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv(base_path + 'df1014_1.csv')
df
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2022-09-29              1          배송비    5000.0       1.0    5000.0
# 1         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23       93682091     스니커즈피넛싱글       2.0     990.0    1980.0
# ...              ...            ...          ...       ...       ...       ...
# 41369777  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369778  2022-09-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369779  2021-11-11  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369780  2021-12-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369781  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
#
# ...

# %%
df['GDS_NM'].value_counts().head(100)
# Out:
# 재사용봉투20L    972300
# 대파1단        361252
# 배달봉투        301870
# 재사용봉투       246648
# 흙당근         220380
#              ...
# 농심안성탕면멀티     45010
# 가지3입봉        44903
# 가지5입봉        44903
# 백설하얀설탕       44619
# 팽이버섯2봉       44550
# Name: GDS_NM, Length: 100, dtype: int64

# %%
df[df['GDS_NM'] == '가지']
# Out:
#               SAL_DT  PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 646065    2020-12-28  201094     가지       1.0    1200.0    1200.0
# 646066    2021-01-04  201094     가지       1.0    1500.0    1500.0
# 646067    2021-01-04  201094     가지       1.0    1500.0    1500.0
# 646068    2021-01-04  201094     가지       1.0    1500.0    1500.0
# 646069    2021-01-06  201094     가지       1.0    1000.0    1000.0
# ...              ...     ...    ...       ...       ...       ...
# 40665289  2022-08-16  205005     가지       1.0    1700.0    1700.0
# 40665290  2022-08-21  205005     가지       1.0    1700.0    1700.0
# 40665291  2022-08-21  205005     가지       1.0    1700.0    1700.0
# 40665292  2022-08-23  205005     가지       2.0    1700.0    3400.0
# 40665293  2022-08-26  205005     가지       1.0    1700.0    1700.0
#
# [28051 rows x 6 columns]

# %%
df[df['GDS_NM'] == '가지3입봉']
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 7808801  2021-05-12  2908990043640  가지3입봉       1.0    1000.0    1000.0
# 7808802  2021-05-12  2908990043640  가지3입봉       1.0    1000.0    1000.0
# 7808803  2021-05-12  2908990043640  가지3입봉       1.0    1000.0    1000.0
# 7808804  2021-05-12  2908990043640  가지3입봉       3.0    1000.0    3000.0
# 7808805  2021-05-12  2908990043640  가지3입봉       2.0    1000.0    2000.0
# ...             ...            ...    ...       ...       ...       ...
# 7853699  2022-09-01  2908990043640  가지3입봉       3.0    1950.0    5850.0
# 7853700  2022-09-01  2908990043640  가지3입봉       1.0    1950.0    1950.0
# 7853701  2022-09-01  2908990043640  가지3입봉       1.0    1950.0    1950.0
# 7853702  2022-09-01  2908990043640  가지3입봉       1.0    1950.0    1950.0
# 7853703  2022-09-01  2908990043640  가지3입봉       2.0    1950.0    3900.0
#
# [44903 rows x 6 columns]

# %%
df[df['GDS_NM'] == '가지5입봉']
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 7853704  2021-05-12  2908990043640  가지5입봉       1.0    1000.0    1000.0
# 7853705  2021-05-12  2908990043640  가지5입봉       1.0    1000.0    1000.0
# 7853706  2021-05-12  2908990043640  가지5입봉       1.0    1000.0    1000.0
# 7853707  2021-05-12  2908990043640  가지5입봉       3.0    1000.0    3000.0
# 7853708  2021-05-12  2908990043640  가지5입봉       2.0    1000.0    2000.0
# ...             ...            ...    ...       ...       ...       ...
# 7898602  2022-09-01  2908990043640  가지5입봉       3.0    1950.0    5850.0
# 7898603  2022-09-01  2908990043640  가지5입봉       1.0    1950.0    1950.0
# 7898604  2022-09-01  2908990043640  가지5입봉       1.0    1950.0    1950.0
# 7898605  2022-09-01  2908990043640  가지5입봉       1.0    1950.0    1950.0
# 7898606  2022-09-01  2908990043640  가지5입봉       2.0    1950.0    3900.0
#
# [44903 rows x 6 columns]

# %%
df['PLU_CD'].value_counts()
# Out:
# 2908990008649    772242
# 2908990006331    348478
# 290000000018     301870
# 2908990004313    216124
# 2909441427316    204778
#                   ...
# 8807099014152         1
# 8807099013469         1
# 8809383946163         1
# 8807099013445         1
# 8801047169949         1
# Name: PLU_CD, Length: 39301, dtype: int64

# %%
pd.set_option('display.max_rows', 1000)

# %%
df['GDS_NM'].value_counts().head(1000)
# Out:
# 재사용봉투20L             972300
# 대파1단                 361252
# 배달봉투                 301870
# 재사용봉투                246648
# 흙당근                  220380
# 백오이1개                204778
# 서울우유                 193305
# 감자                   176417
# 청양고추소                171902
# 적상추1봉비닐              166798
# 인큐애호박2개행사            166572
# 느타리버섯1팩              150767
# 새송이버섯1봉              139154
# 토속대란1판               136594
# 처음처럼                 135082
# 양파중1망                127152
# 남양맛있는우유GT기획          122795
# 참이슬후레쉬               121232
# 인큐애호박1개              118469
# 청상추1봉                117913
# CJ양념이잘배는찌개두부         113190
# 깻잎4묶음봉               108062
# 깻잎5묶음봉               108062
# 부추1단                 103615
# 추부깻잎1봉               103557
# 쌀소성주                  96962
# 국내산돈앞다리살              96772
# 백오이                   91971
# 대림신선한콩나물              91562
# 토속특란1판                86734
# 풀무원씻어나온콩나물            84700
# 농심신라면멀티               84182
# 무우1개봉투명비닐             83746
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41369782 entries, 0 to 41369781
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    object
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  float64
#  4   SALE_PRC  float64
#  5   SALE_AMT  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.8+ GB

# %%
df1 = df.copy()
df1
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2022-09-29              1          배송비    5000.0       1.0    5000.0
# 1         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23       93682091     스니커즈피넛싱글       2.0     990.0    1980.0
# ...              ...            ...          ...       ...       ...       ...
# 41369777  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369778  2022-09-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369779  2021-11-11  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369780  2021-12-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369781  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
#
# ...

# %%
df1 = df.astype({'PLU_CD':'str'})
df1
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2022-09-29              1          배송비    5000.0       1.0    5000.0
# 1         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23       93682091     스니커즈피넛싱글       2.0     990.0    1980.0
# ...              ...            ...          ...       ...       ...       ...
# 41369777  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369778  2022-09-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369779  2021-11-11  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369780  2021-12-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369781  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41369782 entries, 0 to 41369781
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    object
#  1   PLU_CD    object
#  2   GDS_NM    object
#  3   SALE_QTY  float64
#  4   SALE_PRC  float64
#  5   SALE_AMT  float64
# dtypes: float64(3), object(3)
# memory usage: 1.8+ GB

# %%
df1
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2022-09-29              1          배송비    5000.0       1.0    5000.0
# 1         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23       93682091     스니커즈피넛싱글       2.0     990.0    1980.0
# ...              ...            ...          ...       ...       ...       ...
# 41369777  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369778  2022-09-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369779  2021-11-11  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369780  2021-12-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369781  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
#
# ...

# %%
df1[df1['PLU_CD'] == '93682091']
# Out:
#               SAL_DT    PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 1         2020-12-22  93682091  스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22  93682091  스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23  93682091  스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23  93682091  스니커즈피넛싱글       2.0     990.0    1980.0
# 5         2020-12-26  93682091  스니커즈피넛싱글       1.0     990.0     990.0
# ...              ...       ...       ...       ...       ...       ...
# 40859645  2022-06-29  93682091  마즈스니커즈피넛       2.0     900.0    1800.0
# 40859646  2022-07-26  93682091  마즈스니커즈피넛       3.0     900.0    2700.0
# 40859647  2022-07-28  93682091  마즈스니커즈피넛       3.0     900.0    2700.0
# 40859648  2022-07-31  93682091  마즈스니커즈피넛       2.0     900.0    1800.0
# 40859649  2022-08-12  93682091  마즈스니커즈피넛       1.0     900.0     900.0
#
# [3637 rows x 6 columns]

# %%
df1[df1['PLU_CD'] == '22000088']
# Out:
# Empty DataFrame
# Columns: [SAL_DT, PLU_CD, GDS_NM, SALE_QTY, SALE_PRC, SALE_AMT]
# Index: []

# %%
pd.set_option('display.max_rows', 30000)

# %%
df['GDS_NM'].value_counts().head(30000) # 65286개
# Out:
# 재사용봉투20L                    972300
# 대파1단                        361252
# 배달봉투                        301870
# 재사용봉투                       246648
# 흙당근                         220380
# 백오이1개                       204778
# 서울우유                        193305
# 감자                          176417
# 청양고추소                       171902
# 적상추1봉비닐                     166798
# 인큐애호박2개행사                   166572
# 느타리버섯1팩                     150767
# 새송이버섯1봉                     139154
# 토속대란1판                      136594
# 처음처럼                        135082
# 양파중1망                       127152
# 남양맛있는우유GT기획                 122795
# 참이슬후레쉬                      121232
# 인큐애호박1개                     118469
# 청상추1봉                       117913
# CJ양념이잘배는찌개두부                113190
# 깻잎4묶음봉                      108062
# 깻잎5묶음봉                      108062
# 부추1단                        103615
# 추부깻잎1봉                      103557
# 쌀소성주                         96962
# 국내산돈앞다리살                     96772
# ...

# %% [markdown]
# 깻잎4묶음봉
# 백오이3개
# 가지3입봉
# 새송이버섯2봉1인2봉한정
# 바나나1봉행사
# 시금치2단구입시
# 천도복숭아8입1팩
# 햇양파
# CJ콩기름2개한정

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41369782 entries, 0 to 41369781
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    object
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  float64
#  4   SALE_PRC  float64
#  5   SALE_AMT  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.8+ GB

# %%
df.isnull().sum()
# Out:
# SAL_DT         0
# PLU_CD         0
# GDS_NM      5274
# SALE_QTY       0
# SALE_PRC       0
# SALE_AMT       0
# dtype: int64

# %%
df = df[~df['GDS_NM'].isnull()]

# %%
df
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2022-09-29              1          배송비    5000.0       1.0    5000.0
# 1         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23       93682091     스니커즈피넛싱글       2.0     990.0    1980.0
# ...              ...            ...          ...       ...       ...       ...
# 41369777  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369778  2022-09-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369779  2021-11-11  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369780  2021-12-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369781  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
#
# ...

# %%
df.isnull().sum()
# Out:
# SAL_DT      0
# PLU_CD      0
# GDS_NM      0
# SALE_QTY    0
# SALE_PRC    0
# SALE_AMT    0
# dtype: int64

# %%
drap = df[df['GDS_NM'].str.contains('깻잎4묶음봉')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-24-cdb850f1ae84>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('백오이3개')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-25-0a11ab37b981>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('가지3입봉')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-26-b120405e0528>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('새송이버섯2봉1인2봉한정')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-27-3a1d51afc8cb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('바나나1봉행사')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-28-02b118b5c5d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('시금치2단구입시')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-29-4d4f2d74c443>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('천도복숭아8입1팩')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-30-c3b209e84884>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('햇양파')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-31-82419fa3d58e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('CJ콩기름2개한정')].index
df.drop(drap, inplace=True)
# Out:
# <ipython-input-32-b706e56e8697>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
df
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2022-09-29              1          배송비    5000.0       1.0    5000.0
# 1         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 2         2020-12-22       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 3         2020-12-23       93682091     스니커즈피넛싱글       1.0     990.0     990.0
# 4         2020-12-23       93682091     스니커즈피넛싱글       2.0     990.0    1980.0
# ...              ...            ...          ...       ...       ...       ...
# 41369777  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369778  2022-09-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369779  2021-11-11  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369780  2021-12-21  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
# 41369781  2022-02-28  8809071466140  코텍에스S자고리10P       1.0    2000.0    2000.0
#
# ...

# %%
df[df['GDS_NM'] == '가지5입봉']
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 7853704  2021-05-12  2908990043640  가지5입봉       1.0    1000.0    1000.0
# 7853705  2021-05-12  2908990043640  가지5입봉       1.0    1000.0    1000.0
# 7853706  2021-05-12  2908990043640  가지5입봉       1.0    1000.0    1000.0
# 7853707  2021-05-12  2908990043640  가지5입봉       3.0    1000.0    3000.0
# 7853708  2021-05-12  2908990043640  가지5입봉       2.0    1000.0    2000.0
# ...             ...            ...    ...       ...       ...       ...
# 7898602  2022-09-01  2908990043640  가지5입봉       3.0    1950.0    5850.0
# 7898603  2022-09-01  2908990043640  가지5입봉       1.0    1950.0    1950.0
# 7898604  2022-09-01  2908990043640  가지5입봉       1.0    1950.0    1950.0
# 7898605  2022-09-01  2908990043640  가지5입봉       1.0    1950.0    1950.0
# 7898606  2022-09-01  2908990043640  가지5입봉       2.0    1950.0    3900.0
#
# [44903 rows x 6 columns]

# %%
df[df['GDS_NM'] == '백오이5개']
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 8842865  2021-02-25  2909441429150  백오이5개       1.0    1000.0    1000.0
# 8842866  2021-02-25  2909441429150  백오이5개       1.0    1000.0    1000.0
# 8842867  2021-02-25  2909441429150  백오이5개       2.0    1000.0    2000.0
# 8842868  2021-02-25  2909441429150  백오이5개       1.0    1000.0    1000.0
# 8842869  2021-02-25  2909441429150  백오이5개       1.0    1000.0    1000.0
# ...             ...            ...    ...       ...       ...       ...
# 8898126  2022-08-09  2909441429150  백오이5개       1.0    2980.0    2980.0
# 8898127  2022-08-09  2909441429150  백오이5개       1.0    2980.0    2980.0
# 8898128  2022-08-09  2909441429150  백오이5개       1.0    2980.0    2980.0
# 8898129  2022-08-09  2909441429150  백오이5개       1.0    2980.0    2980.0
# 8898130  2022-08-09  2909441429150  백오이5개       1.0    2980.0    2980.0
#
# [55266 rows x 6 columns]

# %%
#df.to_csv('df1014_2.csv', index=False)
