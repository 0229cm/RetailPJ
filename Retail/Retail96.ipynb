# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df1005.csv')
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 1         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 2         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 3         2021-05-30  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 4         2021-05-31  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# ...              ...            ...    ...       ...       ...       ...
# 23660707  2022-08-27  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660708  2022-08-28  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660709  2022-09-13  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660710  2022-09-20  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660711  2022-09-22  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df = df.astype({'SALE_AMT' : 'int'})

# %%
test = df.sort_values('SALE_QTY', ascending=False).head(50)
test
# Out:
#               SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 840608    2022-01-24  8801045299419         오옛날사골곰탕    9999.0    1000.0
# 23272520  2021-09-19  2501130000710          소금20kg    9999.0   27000.0
# 5867762   2022-04-02         200131           모듬쌈채류    9999.0  170210.0
# 9093548   2022-04-21  8809517210078           에그탑특란    9999.0   10000.0
# 23304225  2021-11-06  2599990000117              잡화    9999.0  400000.0
# 6172715   2022-01-14       22001566            츄파춥스    9999.0     250.0
# 23303810  2021-11-06  2599990000100          아이스콘1개    9999.0     900.0
# 7625845   2022-03-17         202024              딸기    9999.0   10000.0
# 23508536  2021-09-19  8802521125819        국순당대박막걸리    9999.0    1000.0
# 5867761   2022-04-02         200131           모듬쌈채류    9999.0  172720.0
# 23545475  2021-09-19  8809440820009           종이컵박스    9999.0    9900.0
# 6565460   2022-05-24  8801045420042  오뚜기바삭하고고소한튀김가루    9999.0    3900.0
# ...

# %%
test1 = df.sort_values('SALE_AMT', ascending=False).head(50)
test1
# Out:
#               SAL_DT         PLU_CD           GDS_NM  SALE_QTY     SALE_PRC  \
# 13953223  2022-03-23         201044               딸기       2.0  880491120.0
# 5867761   2022-04-02         200131            모듬쌈채류    9999.0     172720.0
# 5867762   2022-04-02         200131            모듬쌈채류    9999.0     170210.0
# 5867760   2022-04-02         200131            모듬쌈채류    9000.0     176650.0
# 2663438   2021-09-26      520000009             망고스틴       1.0  941181000.0
# 2086866   2022-02-10         200000             청량고추       1.0  930144000.0
# 2326423   2022-01-10       22000033               식품    3000.0     300000.0
# 77228     2021-10-18         200047            청상추1봉       1.0  880306000.0
# 985165    2022-08-13  8801051088151    엘자연퐁용기베이킹소다레몬       1.0  880109440.0
# 1074764   2022-07-22  8801056227708  롯데칠성사이다플러스500ml       1.0  880104890.0
# 10730020  2022-01-22  8801045442723            오옥수수유       1.0  880100780.0
# ...

# %%
test2 = df.sort_values('SALE_AMT', ascending=True).head(50)
test2
# Out:
#               SAL_DT         PLU_CD        GDS_NM  SALE_QTY  SALE_PRC  \
# 23304225  2021-11-06  2599990000117            잡화    9999.0  400000.0
# 2084302   2021-09-01              2        사은행사쿠폰       1.0   -5000.0
# 5829710   2021-09-02              2        사은행사쿠폰       1.0   -5000.0
# 5829711   2021-09-02              2        사은행사쿠폰       1.0   -5000.0
# 5829837   2021-09-12              2        사은행사쿠폰       1.0   -5000.0
# 5829712   2021-09-02              2        사은행사쿠폰       1.0   -5000.0
# 5829713   2021-09-02              2        사은행사쿠폰       1.0   -5000.0
# 2084291   2021-09-01              2        사은행사쿠폰       1.0   -5000.0
# 5829835   2021-09-12              2        사은행사쿠폰       1.0   -5000.0
# 10388469  2021-09-25              2  벌집삼겹살500g국내산       1.0   -5000.0
# 2084858   2021-09-14              2        사은행사쿠폰       1.0   -5000.0
# 10388468  2021-09-23              2  벌집삼겹살500g국내산       1.0   -5000.0
# ...

# %%
test3 = df.sort_values('SALE_PRC', ascending=False).head(100)
test3
# Out:
#               SAL_DT         PLU_CD         GDS_NM  SALE_QTY     SALE_PRC  \
# 2663438   2021-09-26      520000009           망고스틴       1.0  941181000.0
# 2086866   2022-02-10         200000           청량고추       1.0  930144000.0
# 13953223  2022-03-23         201044             딸기       2.0  880491120.0
# 77228     2021-10-18         200047          청상추1봉       1.0  880306000.0
# 985165    2022-08-13  8801051088151  엘자연퐁용기베이킹소다레몬       1.0  880109440.0
# ...              ...            ...            ...       ...          ...
# 292072    2022-04-23         211027             야채       1.0    8588500.0
# 282157    2022-07-16         211023             식품       1.0    7217000.0
# 5838734   2022-07-22         200049            햇감자       1.0    7027370.0
# 5838735   2022-07-22         200049            햇감자       1.0    7027370.0
# 12618627  2022-03-25         290016             잡화       1.0    6427300.0
#
#             SALE_AMT  month  weekday
# 2663438    941181000      9        6
# ...

# %%
df['SALE_QTY'].value_counts()
# Out:
# 1.0       20058595
# 2.0        2501029
# 3.0         512049
# 4.0         232075
# 5.0         124753
#             ...
# 730.0            1
# 2960.0           1
# 2700.0           1
# 5450.0           1
# 3600.0           1
# Name: SALE_QTY, Length: 427, dtype: int64

# %%
test
# Out:
#               SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 840608    2022-01-24  8801045299419         오옛날사골곰탕    9999.0    1000.0
# 23272520  2021-09-19  2501130000710          소금20kg    9999.0   27000.0
# 5867762   2022-04-02         200131           모듬쌈채류    9999.0  170210.0
# 9093548   2022-04-21  8809517210078           에그탑특란    9999.0   10000.0
# 23304225  2021-11-06  2599990000117              잡화    9999.0  400000.0
# 6172715   2022-01-14       22001566            츄파춥스    9999.0     250.0
# 23303810  2021-11-06  2599990000100          아이스콘1개    9999.0     900.0
# 7625845   2022-03-17         202024              딸기    9999.0   10000.0
# 23508536  2021-09-19  8802521125819        국순당대박막걸리    9999.0    1000.0
# 5867761   2022-04-02         200131           모듬쌈채류    9999.0  172720.0
# 23545475  2021-09-19  8809440820009           종이컵박스    9999.0    9900.0
# 6565460   2022-05-24  8801045420042  오뚜기바삭하고고소한튀김가루    9999.0    3900.0
# ...

# %%
df.sort_values('SALE_QTY', ascending=False)
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  \
# 840608    2022-01-24  8801045299419      오옛날사골곰탕    9999.0    1000.0
# 23272520  2021-09-19  2501130000710       소금20kg    9999.0   27000.0
# 5867762   2022-04-02         200131        모듬쌈채류    9999.0  170210.0
# 9093548   2022-04-21  8809517210078        에그탑특란    9999.0   10000.0
# 23304225  2021-11-06  2599990000117           잡화    9999.0  400000.0
# ...              ...            ...          ...       ...       ...
# 3664135   2021-12-17  8801155978136  동원소와나무고칼슘우유       0.0    4800.0
# 5942546   2021-09-16         201034      한우양지국거리       0.0    5500.0
# 5977449   2021-11-20         201231   도드람한돈생목살구이       0.0   11500.0
# 5942548   2021-09-16         201034      한우양지국거리       0.0    5500.0
# 2216148   2022-01-06         204229    한돈암돼지생삼겹살       0.0   15800.0
#
#               SALE_AMT  month  weekday
# 840608    9.999000e+06      1        0
# 23272520  2.699730e+08      9        6
# ...

# %%
df = df.astype({'SALE_QTY' : 'int'})

# %%
df = df.astype({'SALE_AMT' : 'int'})

# %%
df.sort_values('SALE_QTY', ascending=False)
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  \
# 840608    2022-01-24  8801045299419      오옛날사골곰탕      9999    1000.0
# 23272520  2021-09-19  2501130000710       소금20kg      9999   27000.0
# 5867762   2022-04-02         200131        모듬쌈채류      9999  170210.0
# 9093548   2022-04-21  8809517210078        에그탑특란      9999   10000.0
# 23304225  2021-11-06  2599990000117           잡화      9999  400000.0
# ...              ...            ...          ...       ...       ...
# 3664135   2021-12-17  8801155978136  동원소와나무고칼슘우유         0    4800.0
# 5942546   2021-09-16         201034      한우양지국거리         0    5500.0
# 5977449   2021-11-20         201231   도드람한돈생목살구이         0   11500.0
# 5942548   2021-09-16         201034      한우양지국거리         0    5500.0
# 2216148   2022-01-06         204229    한돈암돼지생삼겹살         0   15800.0
#
#             SALE_AMT  month  weekday
# 840608       9999000      1        0
# 23272520   269973000      9        6
# ...

# %%
df.sort_values('SALE_QTY', ascending=False).head(50)
# Out:
#               SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 840608    2022-01-24  8801045299419         오옛날사골곰탕      9999    1000.0
# 23272520  2021-09-19  2501130000710          소금20kg      9999   27000.0
# 5867762   2022-04-02         200131           모듬쌈채류      9999  170210.0
# 9093548   2022-04-21  8809517210078           에그탑특란      9999   10000.0
# 23304225  2021-11-06  2599990000117              잡화      9999  400000.0
# 6172715   2022-01-14       22001566            츄파춥스      9999     250.0
# 23303810  2021-11-06  2599990000100          아이스콘1개      9999     900.0
# 7625845   2022-03-17         202024              딸기      9999   10000.0
# 23508536  2021-09-19  8802521125819        국순당대박막걸리      9999    1000.0
# 5867761   2022-04-02         200131           모듬쌈채류      9999  172720.0
# 23545475  2021-09-19  8809440820009           종이컵박스      9999    9900.0
# 6565460   2022-05-24  8801045420042  오뚜기바삭하고고소한튀김가루      9999    3900.0
# ...

# %%
df.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#               SAL_DT         PLU_CD              GDS_NM  SALE_QTY  SALE_PRC  \
# 5992873   2022-07-30         201238            한돈생칼집삼겹살         0   10950.0
# 5144803   2022-07-09  8801069173603           남양맛있는우유GT         0    2600.0
# 12051345  2022-02-22  8801037088168           오레오화이트크림소         0    1450.0
# 3434451   2022-02-19  8801111770217             크라운야채타임         0    1200.0
# 5953008   2021-10-25         201048              한우다짐육1         0    4300.0
# 5953010   2021-10-25         201048              한우다짐육1         0    4300.0
# 11362497  2022-08-04         201163               햇배추낱개         0    5800.0
# 11362496  2022-08-04         201163               햇배추낱개         0    5800.0
# 9889518   2022-06-28  8801068402247        삼립다그다딸기카스타드빵         0    1500.0
# 10921073  2021-12-25  8801094749491             코카콜라암바사         0    3980.0
# 2122241   2022-02-13         201153                  봄동         0     450.0
# ...

# %%
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드         1    1100.0      1100
# 1         2021-05-29  8801068097474   땅콩샌드         1    1100.0      1100
# 2         2021-05-29  8801068097474   땅콩샌드         1    1100.0      1100
# 3         2021-05-30  8801068097474   땅콩샌드         1    1100.0      1100
# 4         2021-05-31  8801068097474   땅콩샌드         1    1100.0      1100
# ...              ...            ...    ...       ...       ...       ...
# 23660707  2022-08-27  9556486800210   망고푸딩         1    3500.0      3500
# 23660708  2022-08-28  9556486800210   망고푸딩         1    3500.0      3500
# 23660709  2022-09-13  9556486800210   망고푸딩         1    3500.0      3500
# 23660710  2022-09-20  9556486800210   망고푸딩         1    3500.0      3500
# 23660711  2022-09-22  9556486800210   망고푸딩         1    3500.0      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df = df.replace(0, np.NaN)

# %%
df
# Out:
#               SAL_DT        PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 1         2021-05-29  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 2         2021-05-29  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 3         2021-05-30  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 4         2021-05-31  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# ...              ...           ...    ...       ...       ...       ...
# 23660707  2022-08-27  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660708  2022-08-28  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660709  2022-09-13  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660710  2022-09-20  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660711  2022-09-22  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
#
#           month  weekday
# 0             5      3.0
# 1             5      5.0
# ...

# %%
df.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#               SAL_DT        PLU_CD   GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8.801068e+12     땅콩샌드       1.0    1100.0    1100.0
# 15144016  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144015  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144014  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144012  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144011  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144010  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144009  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144018  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144008  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144006  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# 15144005  2021-01-29  2.908990e+12  쌈배추봉지1통       1.0    1500.0    1500.0
# ...

# %%
df.isnull().sum()
# Out:
# SAL_DT            0
# PLU_CD          405
# GDS_NM            0
# SALE_QTY      24402
# SALE_PRC        314
# SALE_AMT      24841
# month             0
# weekday     3278039
# dtype: int64

# %%
df = df.dropna(how='any',axis=0)

# %%
df
# Out:
#               SAL_DT        PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 1         2021-05-29  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 2         2021-05-29  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 3         2021-05-30  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 6         2021-06-01  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# ...              ...           ...    ...       ...       ...       ...
# 23660707  2022-08-27  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660708  2022-08-28  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660709  2022-09-13  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660710  2022-09-20  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660711  2022-09-22  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
#
#           month  weekday
# 0             5      3.0
# 1             5      5.0
# ...

# %%
df.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#               SAL_DT        PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8.801068e+12      땅콩샌드       1.0    1100.0    1100.0
# 15184538  2021-07-01  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184539  2021-07-01  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184540  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184541  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184542  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184543  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184544  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184545  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184546  2021-07-02  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# 15184550  2021-07-04  2.908990e+11  일자콩나물1박스       1.0    2280.0    2280.0
# ...

# %%
df
# Out:
#               SAL_DT        PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 1         2021-05-29  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 2         2021-05-29  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 3         2021-05-30  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# 6         2021-06-01  8.801068e+12   땅콩샌드       1.0    1100.0    1100.0
# ...              ...           ...    ...       ...       ...       ...
# 23660707  2022-08-27  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660708  2022-08-28  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660709  2022-09-13  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660710  2022-09-20  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
# 23660711  2022-09-22  9.556487e+12   망고푸딩       1.0    3500.0    3500.0
#
#           month  weekday
# 0             5      3.0
# 1             5      5.0
# ...
