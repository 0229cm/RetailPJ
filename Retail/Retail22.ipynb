# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''
pd.set_option('display.max_row', 800)

# %%
# 0 파일과 1 파일을 그냥 합쳤음.


# 제품목록 gds_list_0, gds_list_1
gds_2 = pd.read_csv(base_path + 'gds2.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
gdsclss_2 = pd.read_csv(base_path + 'gdsclss_2.csv')

# 매출 데이터 마스터(장바구니 단위): tr_list_0, tr_list_1
tr_list_2 = pd.read_csv(base_path + 'tr_list_2.csv')

# 매출 제품 데이터 상세: tr_dtl_list_0, tr_dtl_list_1
tr_dtl_list_2 = pd.read_csv(base_path + 'tr_dtl_list_2.csv')
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,9,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
gds_2
# Out:
#           CO_CD  STR_CD         PLU_CD     GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0       1001294   12018              1        배송비       999999       배송료
# 1       1001294   12018              2     사은행사쿠폰       999999       배송료
# 2       1001294   12018          91770     코지유리물병        93331        일반
# 3       1001294   12018          91770       크지물병        91701        일반
# 4       1001294   12018       50390427      POM석류        12579        일반
# ...         ...     ...            ...        ...          ...       ...
# 172730  1002056  168009  9805817760205        포카칩       898989        일반
# 172731  1002056  168009  9808205106111  매입에서등록한상품       997979        일반
# 172732  1002056  168009  9808862878406        월드콘       898989        일반
# 172733  1002056  168009  9880913160015  매입에서등록한상품       997979        일반
# 172734  1002056  168009       99889906     버디 토스트       898989        일반
#
#         VEN_CD
# 0            0
# 1            0
# 2            0
# 3            0
# ...

# %%
gdsclss_2
# Out:
#         CO_CD  STR_CD  GDS_CLSS_CD GDS_CLSS_NM  GDS_CLSS_LVL_TP  \
# 0     1001294   12018            1          식품                1
# 1     1001294   12018          101       가공농산물                2
# 2     1001294   12018        10151       가공농산물                3
# 3     1001294   12018        10152         김치류                3
# 4     1001294   12018        10153          소스                3
# ...       ...     ...          ...         ...              ...
# 1134  1002056       0           99         미등록                1
# 1135  1002056       0         9979   임시핸디매입등록용                2
# 1136  1002056       0       997979   임시핸디매입등록용                3
# 1137  1002056       0         9999         미등록                2
# 1138  1002056       0       999999         미등록                3
#
#       UP_GDS_CLSS_CD  GDS_CLSS_GRP_TP
# 0                  0                1
# 1                  1                1
# 2                101                1
# 3                101                1
# ...

# %%
gdsclss_2['GDS_CLSS_NM'].value_counts()
# Out:
# 기타          16
# 식품          15
# 쓰레기봉투        7
# 화장품          7
# 아이스크림        6
#             ..
# 욕실잡화류        1
# 기타-종량봉투      1
# 기타-기타주류      1
# 일회용품류        1
# 해초류/특수야채     1
# Name: GDS_CLSS_NM, Length: 713, dtype: int64

# %%
gdsclss_2['GDS_CLSS_NM'].value_counts().head(720)
# Out:
# 기타                 16
# 식품                 15
# 쓰레기봉투               7
# 화장품                 7
# 아이스크림               6
# 비식품                 6
# 미등록                 6
# 수산                  6
# 계란                  6
# 야채                  6
# 샴푸린스                6
# 건어물                 6
# 담배                  6
# 유아용품                5
# 모기약                 5
# 부자재                 5
# 양곡                  5
# 일회용품                5
# 주류                  5
# 수입류                 5
# 액세서리                5
# 욕실용품                4
# 기타잡화                4
# 방향제                 4
# 잡곡                  4
# 세트                  4
# 유제품                 4
# 콩나물                 4
# 청과                  4
# 세제류                 4
# 반찬                  4
# 냉동식품                4
# 위생용품                4
# 식자재                 4
# 염색약                 4
# 쨈류                  4
# 치약칫솔                4
# 팬시                  3
# 사내소비                3
# 스프류                 3
# 생선                  3
# ...

# %%
tr_list_2
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 0        20210901   12018     01        1            영업개시             1
# 1        20210901   12018     01        2             준비금             1
# 2        20210901   12018     01        3              매출             1
# 3        20210901   12018     01        4            전체취소             1
# 4        20210901   12018     01        5              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 1551504  20220901  168009      1      284              매출             1
# 1551505  20220901  168009      1      285            캐셔정산             1
# 1551506  20220901  168009      1      286           POS정산             1
# 1551507  20220901  168009      1      287            영업종료             1
# 1551508  20220901  168009      1      288             로그인             1
#
#          REAL_SAL_DT  REAL_SAL_TTM    PAY_AMT   MSHP_ID  ORN_SAL_DT  \
# ...

# %%
tr_dtl_list_2
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 6521910  20220901  168009      1      282       4            정상판매
# 6521911  20220901  168009      1      282       5            정상판매
# 6521912  20220901  168009      1      283       1            정상판매
# 6521913  20220901  168009      1      284       1            정상판매
# 6521914  20220901  168009      1      284       2            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
gds_2.columns
# Out:
# Index(['CO_CD', 'STR_CD', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD', 'GDS_TP_NM',
#        'VEN_CD'],
#       dtype='object')

# %%
mer1 = pd.merge(gds_2[['CO_CD', 'STR_CD', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD', 'GDS_TP_NM',
       'VEN_CD']], gdsclss_2[['STR_CD', 'GDS_CLSS_NM']])

# %%
mer1
# Out:
#             CO_CD  STR_CD         PLU_CD    GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0         1001294   12018              1       배송비       999999       배송료
# 1         1001294   12018              1       배송비       999999       배송료
# 2         1001294   12018              1       배송비       999999       배송료
# 3         1001294   12018              1       배송비       999999       배송료
# 4         1001294   12018              1       배송비       999999       배송료
# ...           ...     ...            ...       ...          ...       ...
# 43793224  1001294   12018  9999999915833  맥 웰빙원후 7        91701        일반
# 43793225  1001294   12018  9999999915833  맥 웰빙원후 7        91701        일반
# 43793226  1001294   12018  9999999915833  맥 웰빙원후 7        91701        일반
# 43793227  1001294   12018  9999999915833  맥 웰빙원후 7        91701        일반
# 43793228  1001294   12018  9999999915833  맥 웰빙원후 7        91701        일반
#
#           VEN_CD GDS_CLSS_NM
# 0              0          식품
# ...

# %%
mer1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43793229 entries, 0 to 43793228
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   CO_CD        int64
#  1   STR_CD       int64
#  2   PLU_CD       int64
#  3   GDS_NM       object
#  4   GDS_CLSS_CD  int64
#  5   GDS_TP_NM    object
#  6   VEN_CD       int64
#  7   GDS_CLSS_NM  object
# dtypes: int64(5), object(3)
# memory usage: 2.9+ GB

# %%
mer1.isnull().sum()
# Out:
# CO_CD          0
# STR_CD         0
# PLU_CD         0
# GDS_NM         0
# GDS_CLSS_CD    0
# GDS_TP_NM      0
# VEN_CD         0
# GDS_CLSS_NM    0
# dtype: int64

# %%
mer2 = pd.merge(tr_dtl_list_2[['SAL_DT', 'STR_CD', 'POS_NO', 'TRAN_NO', 'SEQ_NO', 'DESI_CNCL_TP_NM',
       'SALE_RTN_SGN', 'PLU_CD', 'GDS_CLSS_CD', 'SALE_QTY', 'SALE_PRC',
       'SALE_AMT']], gds_2[['PLU_CD', 'GDS_NM', 'GDS_CLSS_CD']])

# %%
mer2
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210902   12018     01       15       1            정상판매
# 2        20210902   12018     01      457       1            정상판매
# 3        20210902   12018     05      231       3            정상판매
# 4        20210903   12018     01        8       1            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 6472169  20220831  168009      1      217       4            정상판매
# 6472170  20220831  168009      1      255       4            정상판매
# 6472171  20220831  168009      1      255       6            정상판매
# 6472172  20220901  168009      1       10       9            정상판매
# 6472173  20220901  168009      1      229       3            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
mer2.isnull().sum()
# Out:
# SAL_DT             0
# STR_CD             0
# POS_NO             0
# TRAN_NO            0
# SEQ_NO             0
# DESI_CNCL_TP_NM    0
# SALE_RTN_SGN       0
# PLU_CD             0
# GDS_CLSS_CD        0
# SALE_QTY           0
# SALE_PRC           0
# SALE_AMT           0
# GDS_NM             0
# dtype: int64

# %%
mer3 = pd.merge(mer2[['SAL_DT', 'STR_CD', 'POS_NO', 'TRAN_NO', 'SEQ_NO', 'DESI_CNCL_TP_NM',
       'SALE_RTN_SGN', 'PLU_CD', 'GDS_CLSS_CD', 'SALE_QTY', 'SALE_PRC',
       'SALE_AMT', 'GDS_NM']], tr_list_2[['SAL_DT', 'STR_CD', 'POS_NO', 'TRAN_NO', 'SALE_KIND_TP_NM', 'SALE_RTN_SGN', 'REAL_SAL_DT', 'REAL_SAL_TTM', 'PAY_AMT', 'MSHP_ID']])

# %%
mer3
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 5975278  20220830  168009      1      280       1            전체취소
# 5975279  20220830  168009      1      280       2            전체취소
# 5975280  20220830  168009      1       53       1            정상판매
# 5975281  20220830  168009      1       53       1            정상판매
# 5975282  20220831  168009      1      132       1            전체취소
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
mer3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5975283 entries, 0 to 5975282
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     int64
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: float64(5), int64(8), object(5)
# memory usage: 866.2+ MB

# %%
mer3.isnull().sum()
# Out:
# SAL_DT                   0
# STR_CD                   0
# POS_NO                   0
# TRAN_NO                  0
# SEQ_NO                   0
# DESI_CNCL_TP_NM          0
# SALE_RTN_SGN             0
# PLU_CD                   0
# GDS_CLSS_CD              0
# SALE_QTY                 0
# SALE_PRC                 0
# SALE_AMT                 0
# GDS_NM                   0
# SALE_KIND_TP_NM          0
# REAL_SAL_DT              0
# REAL_SAL_TTM             0
# PAY_AMT                  0
# MSHP_ID            1197037
# dtype: int64

# %%
mer3.value_counts()
# Out:
# SAL_DT    STR_CD  POS_NO  TRAN_NO  SEQ_NO  DESI_CNCL_TP_NM  SALE_RTN_SGN  PLU_CD         GDS_CLSS_CD  SALE_QTY  SALE_PRC  SALE_AMT  GDS_NM                 SALE_KIND_TP_NM  REAL_SAL_DT  REAL_SAL_TTM  PAY_AMT  MSHP_ID
# 20220304  72005   R1      3        5       정상판매              1            1              999999.0     2000.0    1.0       2000.0    배송비                    매출               20220304     135330        26660.0  072005_4567     4
#                           1        5       정상판매              1            1              999999.0     2000.0    1.0       2000.0    배송비                    매출               20220304     133010        14200.0  072005_4567     4
#                   02      10       5       정상판매             -1            1              999999.0     2000.0    1.0       2000.0    배송비                    배달매출             20220304     133333        0.0      072005_4567     4
# ...

# %%
#mer3.to_csv('mer0929.csv', index=False) # abcd 마트 합해서 이전 파일처럼 merge

# %%
mer3
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 5975278  20220830  168009      1      280       1            전체취소
# 5975279  20220830  168009      1      280       2            전체취소
# 5975280  20220830  168009      1       53       1            정상판매
# 5975281  20220830  168009      1       53       1            정상판매
# 5975282  20220831  168009      1      132       1            전체취소
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
CTNM = mer3[['SAL_DT', 'REAL_SAL_TTM', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD', 'SALE_AMT']]
CTNM
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD              GDS_NM  \
# 0        20210901         71138  8801039939499         해표 더고소한 파래김
# 1        20210901         71138  8801045312316         오뚜기 3분쇠고기카레
# 2        20210901         71138  8801045291314         오뚜기 3분쇠고기짜장
# 3        20210901         71138  8803712127018              목우촌 뚝심
# 4        20210901         71138  8801045890333          오뚜기 맛있는밥기획
# ...           ...           ...            ...                 ...
# 5975278  20220830        132102  8809713911199              바나나 톡톡
# 5975279  20220830        132102  8809713913896         정신차리솟에너지드링크
# 5975280  20220830        164030  8801007029795            가스오+튀김4인
# 5975281  20220830        164030  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인
# 5975282  20220831        220214  8801115382027             스타벅스 돌체
#
#          GDS_CLSS_CD   SALE_AMT
# 0            12301.0   540000.0
# 1            12101.0   360000.0
# 2            12101.0   360000.0
# ...

# %%
CTNM.value_counts()
# Out:
# PLU_CD         GDS_NM               GDS_CLSS_CD
# 2908990008649  재사용봉투(20L)           159999.0       142551
# 2908990006331  *대파 1단               30702.0         64792
# 290000000018   배달봉투                 809999.0        57135
# 2908990004313  *깻잎(4묶음)/봉           30101.0         39561
# 2909441427316  *백오이 1개              30201.0         38042
#                                                     ...
# 8801052095585  쉐프원 볶음 반찬소스 달콤짭짤한 맛  12579.0             1
# 8801052095806  사천식마라탕450g           11313.0             1
# 8801052095875  크리미시저드레싱315g         10303.0             1
# 8801052431024  청)사과식초900ml          10303.0             1
# 0              간고등어                 898989.0            1
# Length: 33510, dtype: int64

# %%
CTNM.value_counts()

# %%
CTNM['PLU_CD'].value_counts()
# Out:
# 2908990008649    142551
# 2908990006331     64792
# 290000000018      57135
# 2908990004313     39561
# 2909441427316     38042
#                   ...
# 63864564              1
# 8801052042671         1
# 8809306482068         1
# 88019154              1
# 8806384875904         1
# Name: PLU_CD, Length: 22399, dtype: int64

# %%
CTNM['GDS_NM'].value_counts()
# Out:
# 재사용봉투(20L)       142551
# *대파 1단            64792
# 배달봉투              57135
# *깻잎(4묶음)/봉        39561
# *백오이 1개           38042
#                   ...
# 뉴원소쿠리 4호              1
# 머거본맛땅콩캔               1
# 물냉면양념장                1
# 아웃도어롤온                1
# 엠비코뚜껑제빙기18-1c         1
# Name: GDS_NM, Length: 30018, dtype: int64

# %%
CTNM['GDS_CLSS_CD'].value_counts()
# Out:
# 30201.0     366202
# 30101.0     266469
# 30702.0     183693
# 11502.0     180616
# 159999.0    161697
#              ...
# 100106.0         1
# 119999.0         1
# 10106.0          1
# 10307.0          1
# 40606.0          1
# Name: GDS_CLSS_CD, Length: 441, dtype: int64

# %%
CTNM[CTNM['PLU_CD'] == 8801052431024] # 얘는 청정원 결국 다 같은거임.
# Out:
#                 PLU_CD       GDS_NM  GDS_CLSS_CD
# 197297   8801052431024     청정원 사과식초      11164.0
# 234007   8801052431024     청정원 사과식초      11164.0
# 299403   8801052431024     청정원 사과식초      11164.0
# 333575   8801052431024     청정원 사과식초      11164.0
# 381314   8801052431024     청정원 사과식초      11164.0
# 431759   8801052431024     청정원 사과식초      11164.0
# 715388   8801052431024     청정원 사과식초      11164.0
# 924907   8801052431024     청정원 사과식초      11164.0
# 927795   8801052431024     청정원 사과식초      11164.0
# 1152332  8801052431024     청정원 사과식초      11164.0
# 1255803  8801052431024     청정원 사과식초      11164.0
# 1364868  8801052431024     청정원 사과식초      11164.0
# 1372454  8801052431024     청정원 사과식초      11164.0
# 1450594  8801052431024     청정원 사과식초      11164.0
# 1463974  8801052431024     청정원 사과식초      11164.0
# 1609208  8801052431024     청정원 사과식초      11164.0
# 1647691  8801052431024     청정원 사과식초      11164.0
# 1835870  8801052431024     청정원 사과식초      11164.0
# ...

# %%
CTNM[CTNM['GDS_NM'] == '사과식초'] # 얘는 오뚜기
# Out:
#                 PLU_CD GDS_NM  GDS_CLSS_CD
# 5691612  8801045202518   사과식초      10101.0
# 5719068  8801045202518   사과식초      10101.0
# 5723618  8801007168760   사과식초      10101.0

# %%
CTNM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5975283 entries, 0 to 5975282
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   PLU_CD       int64
#  1   GDS_NM       object
#  2   GDS_CLSS_CD  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 182.4+ MB

# %%
CTNM
# Out:
#                 PLU_CD              GDS_NM  GDS_CLSS_CD
# 0        8801039939499         해표 더고소한 파래김      12301.0
# 1        8801045312316         오뚜기 3분쇠고기카레      12101.0
# 2        8801045291314         오뚜기 3분쇠고기짜장      12101.0
# 3        8803712127018              목우촌 뚝심      11363.0
# 4        8801045890333          오뚜기 맛있는밥기획      12102.0
# ...                ...                 ...          ...
# 5975278  8809713911199              바나나 톡톡      20202.0
# 5975279  8809713913896         정신차리솟에너지드링크      20202.0
# 5975280  8801007029795            가스오+튀김4인     999999.0
# 5975281  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인     999999.0
# 5975282  8801115382027             스타벅스 돌체     999999.0
#
# [5975283 rows x 3 columns]

# %%
CTNM[CTNM['PLU_CD'] >= 8800000000000]
# Out:
#                 PLU_CD              GDS_NM  GDS_CLSS_CD
# 0        8801039939499         해표 더고소한 파래김      12301.0
# 1        8801045312316         오뚜기 3분쇠고기카레      12101.0
# 2        8801045291314         오뚜기 3분쇠고기짜장      12101.0
# 3        8803712127018              목우촌 뚝심      11363.0
# 4        8801045890333          오뚜기 맛있는밥기획      12102.0
# ...                ...                 ...          ...
# 5975278  8809713911199              바나나 톡톡      20202.0
# 5975279  8809713913896         정신차리솟에너지드링크      20202.0
# 5975280  8801007029795            가스오+튀김4인     999999.0
# 5975281  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인     999999.0
# 5975282  8801115382027             스타벅스 돌체     999999.0
#
# [3604704 rows x 3 columns]

# %%
CTNM[CTNM['PLU_CD'] == 8800000000000]
# Out:
# Empty DataFrame
# Columns: [PLU_CD, GDS_NM, GDS_CLSS_CD]
# Index: []

# %%
CTNM[CTNM['PLU_CD'] <= 8800000000000]
# Out:
#                 PLU_CD          GDS_NM  GDS_CLSS_CD
# 14       2908990043152       구호물품 포장박스      29999.0
# 15       2908990043169        구호물품 택배비      29999.0
# 30       2908990043152       구호물품 포장박스      29999.0
# 31       2908990043169        구호물품 택배비      29999.0
# 35       2999000001262   *의성햇사과/8입(1봉)      40601.0
# ...                ...             ...          ...
# 5975264  2599990000780   탐스제로 오렌지600*6      11010.0
# 5975265  2599990000834        조지아커피6번들      11010.0
# 5975266  2599990000827       맥스웰마스터6번들      11010.0
# 5975267  2599990000803  칠성사이다 플러스500*6      11010.0
# 5975268  2599990000834        조지아커피6번들      11010.0
#
# [2370579 rows x 3 columns]

# %%
CTNM880 = CTNM[CTNM['PLU_CD'] >= 8800000000000]
CTNM880
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD              GDS_NM  \
# 0        20210901         71138  8801039939499         해표 더고소한 파래김
# 1        20210901         71138  8801045312316         오뚜기 3분쇠고기카레
# 2        20210901         71138  8801045291314         오뚜기 3분쇠고기짜장
# 3        20210901         71138  8803712127018              목우촌 뚝심
# 4        20210901         71138  8801045890333          오뚜기 맛있는밥기획
# ...           ...           ...            ...                 ...
# 5975278  20220830        132102  8809713911199              바나나 톡톡
# 5975279  20220830        132102  8809713913896         정신차리솟에너지드링크
# 5975280  20220830        164030  8801007029795            가스오+튀김4인
# 5975281  20220830        164030  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인
# 5975282  20220831        220214  8801115382027             스타벅스 돌체
#
#          GDS_CLSS_CD   SALE_AMT
# 0            12301.0   540000.0
# 1            12101.0   360000.0
# 2            12101.0   360000.0
# ...

# %%
N880 = CTNM[CTNM['PLU_CD'] <= 8800000000000]
N880
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD          GDS_NM  GDS_CLSS_CD  \
# 14       20210901         71138  2908990043152       구호물품 포장박스      29999.0
# 15       20210901         71138  2908990043169        구호물품 택배비      29999.0
# 30       20210902         73547  2908990043152       구호물품 포장박스      29999.0
# 31       20210902         73547  2908990043169        구호물품 택배비      29999.0
# 35       20210902        185158  2999000001262   *의성햇사과/8입(1봉)      40601.0
# ...           ...           ...            ...             ...          ...
# 5975264  20220823         80114  2599990000780   탐스제로 오렌지600*6      11010.0
# 5975265  20220823         80408  2599990000834        조지아커피6번들      11010.0
# 5975266  20220823         80408  2599990000827       맥스웰마스터6번들      11010.0
# 5975267  20220823         80408  2599990000803  칠성사이다 플러스500*6      11010.0
# 5975268  20220823         82751  2599990000834        조지아커피6번들      11010.0
#
#          SALE_AMT
# 14       216000.0
# ...

# %%
CTNM880.to_csv('cn8801006-2.csv', index=False)

# %%
N880.to_csv('n8801006-2.csv', index=False)

# %%
N880.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2370579 entries, 14 to 5975268
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   PLU_CD       int64
#  1   GDS_NM       object
#  2   GDS_CLSS_CD  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 72.3+ MB

# %%
N880.isnull().sum()
# Out:
# PLU_CD         0
# GDS_NM         0
# GDS_CLSS_CD    0
# dtype: int64

# %%
N880['PLU_CD'].value_counts().head(30)
# Out:
# 2908990008649    142551
# 2908990006331     64792
# 290000000018      57135
# 2908990004313     39561
# 2909441427316     38042
# 201016            33657
# 2908990004337     30120
# 2908990005099     29863
# 2909441429020     29190
# 2909441427286     27791
# 22000422          27091
# 201001            25515
# 2908990003323     21808
# 2908990004573     20830
# 2908990006904     19871
# 2908990004344     19475
# 2909441429037     18446
# 2908990043640     18322
# 2908990005709     18111
# 2909441429044     17918
# 351006            17692
# 2908990006539     17362
# 2908990007246     16908
# 2909441429150     16698
# 2909441429228     16618
# 2908990006508     16446
# 2908990043459     14916
# 2909441428856     14141
# 2599990000049     13776
# 351001            13264
# Name: PLU_CD, dtype: int64

# %%
N880[N880['PLU_CD'] == 2599990000834]
# Out:
#                 PLU_CD    GDS_NM  GDS_CLSS_CD
# 5975260  2599990000834  조지아커피6번들      11010.0
# 5975265  2599990000834  조지아커피6번들      11010.0
# 5975268  2599990000834  조지아커피6번들      11010.0

# %%
N880[N880['PLU_CD'] == 2908990008649]
# Out:
#                 PLU_CD      GDS_NM  GDS_CLSS_CD
# 118      2908990008649  재사용봉투(20L)     159999.0
# 185      2908990008649  재사용봉투(20L)     159999.0
# 324      2908990008649  재사용봉투(20L)     159999.0
# 399      2908990008649  재사용봉투(20L)     159999.0
# 413      2908990008649  재사용봉투(20L)     159999.0
# ...                ...         ...          ...
# 3262373  2908990008649  재사용봉투(20L)     159999.0
# 3262381  2908990008649  재사용봉투(20L)     159999.0
# 3262384  2908990008649  재사용봉투(20L)     159999.0
# 3262390  2908990008649  재사용봉투(20L)     159999.0
# 3262397  2908990008649  재사용봉투(20L)     159999.0
#
# [142551 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990006331]
# Out:
#                 PLU_CD  GDS_NM  GDS_CLSS_CD
# 488      2908990006331  *대파 1단      30702.0
# 686      2908990006331  *대파 1단      30702.0
# 843      2908990006331  *대파 1단      30702.0
# 861      2908990006331  *대파 1단      30702.0
# 928      2908990006331  *대파 1단      30702.0
# ...                ...     ...          ...
# 1404146  2908990006331  *대파 1단      30702.0
# 1404149  2908990006331  *대파 1단      30702.0
# 1404156  2908990006331  *대파 1단      30702.0
# 1404160  2908990006331  *대파 1단      30702.0
# 1404161  2908990006331  *대파 1단      30702.0
#
# [64792 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 290000000018]
# Out:
#                PLU_CD GDS_NM  GDS_CLSS_CD
# 98       290000000018   배달봉투     809999.0
# 99       290000000018   배달봉투     809999.0
# 249      290000000018   배달봉투     809999.0
# 250      290000000018   배달봉투     809999.0
# 263      290000000018   배달봉투     809999.0
# ...               ...    ...          ...
# 4666653  290000000018   배달봉투     809999.0
# 4666662  290000000018   배달봉투     809999.0
# 4666674  290000000018   배달봉투     809999.0
# 4666681  290000000018   배달봉투     809999.0
# 4666690  290000000018   배달봉투     809999.0
#
# [57135 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990004313]
# Out:
#                 PLU_CD      GDS_NM  GDS_CLSS_CD
# 698      2908990004313  *깻잎(4묶음)/봉      30101.0
# 1694     2908990004313  *깻잎(4묶음)/봉      30101.0
# 2955     2908990004313  *깻잎(4묶음)/봉      30101.0
# 3142     2908990004313  *깻잎(4묶음)/봉      30101.0
# 3482     2908990004313  *깻잎(4묶음)/봉      30101.0
# ...                ...         ...          ...
# 3740898  2908990004313  *깻잎(4묶음)/봉      30101.0
# 3740900  2908990004313  *깻잎(4묶음)/봉      30101.0
# 3740901  2908990004313  *깻잎(4묶음)/봉      30101.0
# 3740903  2908990004313  *깻잎(4묶음)/봉      30101.0
# 3740905  2908990004313  *깻잎(4묶음)/봉      30101.0
#
# [39561 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2909441427316]
# Out:
#                 PLU_CD   GDS_NM  GDS_CLSS_CD
# 139      2909441427316  *백오이 1개      30201.0
# 410      2909441427316  *백오이 1개      30201.0
# 509      2909441427316  *백오이 1개      30201.0
# 1140     2909441427316  *백오이 1개      30201.0
# 2040     2909441427316  *백오이 1개      30201.0
# ...                ...      ...          ...
# 1848496  2909441427316  *백오이 1개      30201.0
# 1848499  2909441427316  *백오이 1개      30201.0
# 1848509  2909441427316  *백오이 1개      30201.0
# 1848520  2909441427316  *백오이 1개      30201.0
# 1848531  2909441427316  *백오이 1개      30201.0
#
# [38042 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 201016]
# Out:
#          PLU_CD GDS_NM  GDS_CLSS_CD
# 173      201016    흙당근      30202.0
# 469      201016    흙당근      30202.0
# 644      201016    흙당근      30202.0
# 688      201016    흙당근      30202.0
# 1479     201016    흙당근      30202.0
# ...         ...    ...          ...
# 5628932  201016   골드키위      30201.0
# 5628935  201016   골드키위      30201.0
# 5628937  201016   골드키위      30201.0
# 5628939  201016   골드키위      30201.0
# 5628940  201016   골드키위      30201.0
#
# [33657 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990004337]
# Out:
#                 PLU_CD     GDS_NM  GDS_CLSS_CD
# 1185     2908990004337  적상추 1봉/비닐      30101.0
# 1235     2908990004337  적상추 1봉/비닐      30101.0
# 1514     2908990004337  적상추 1봉/비닐      30101.0
# 1520     2908990004337  적상추 1봉/비닐      30101.0
# 2068     2908990004337  적상추 1봉/비닐      30101.0
# ...                ...        ...          ...
# 4063436  2908990004337  적상추 1봉/비닐      30101.0
# 4063437  2908990004337  적상추 1봉/비닐      30101.0
# 4063439  2908990004337  적상추 1봉/비닐      30101.0
# 4063443  2908990004337  적상추 1봉/비닐      30101.0
# 4063446  2908990004337  적상추 1봉/비닐      30101.0
#
# [30120 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990005099]
# Out:
#                 PLU_CD    GDS_NM  GDS_CLSS_CD
# 109      2908990005099  *청양고추(소)      30201.0
# 165      2908990005099  *청양고추(소)      30201.0
# 218      2908990005099  *청양고추(소)      30201.0
# 347      2908990005099  *청양고추(소)      30201.0
# 357      2908990005099  *청양고추(소)      30201.0
# ...                ...       ...          ...
# 3333834  2908990005099  *청양고추(소)      30201.0
# 3333838  2908990005099  *청양고추(소)      30201.0
# 3333841  2908990005099  *청양고추(소)      30201.0
# 3333846  2908990005099  *청양고추(소)      30201.0
# 3333848  2908990005099  *청양고추(소)      30201.0
#
# [29863 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2909441429020]
# Out:
#                 PLU_CD         GDS_NM  GDS_CLSS_CD
# 1456     2909441429020  *인큐애호박 2개(행사)      30201.0
# 1865     2909441429020  *인큐애호박 2개(행사)      30201.0
# 2233     2909441429020  *인큐애호박 2개(행사)      30201.0
# 2632     2909441429020  *인큐애호박 2개(행사)      30201.0
# 3598     2909441429020  *인큐애호박 2개(행사)      30201.0
# ...                ...            ...          ...
# 4985120  2909441429020  *인큐애호박 2개(행사)      30201.0
# 4985122  2909441429020  *인큐애호박 2개(행사)      30201.0
# 4985123  2909441429020  *인큐애호박 2개(행사)      30201.0
# 4985124  2909441429020  *인큐애호박 2개(행사)      30201.0
# 4985125  2909441429020  *인큐애호박 2개(행사)      30201.0
#
# [29190 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2909441427286]
# Out:
#                 PLU_CD     GDS_NM  GDS_CLSS_CD
# 318      2909441427286  *느타리버섯 1팩      30302.0
# 1508     2909441427286  *느타리버섯 1팩      30302.0
# 1769     2909441427286  *느타리버섯 1팩      30302.0
# 1918     2909441427286  *느타리버섯 1팩      30302.0
# 2277     2909441427286  *느타리버섯 1팩      30302.0
# ...                ...        ...          ...
# 4908151  2909441427286  *느타리버섯 1팩      30302.0
# 4908152  2909441427286  *느타리버섯 1팩      30302.0
# 4908154  2909441427286  *느타리버섯 1팩      30302.0
# 4908157  2909441427286  *느타리버섯 1팩      30302.0
# 4908159  2909441427286  *느타리버섯 1팩      30302.0
#
# [27791 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 22000422]
# Out:
#            PLU_CD      GDS_NM  GDS_CLSS_CD
# 2466419  22000422  재사용봉투 -20L     110101.0
# 2466434  22000422  재사용봉투 -20L     110101.0
# 2466458  22000422  재사용봉투 -20L     110101.0
# 2466511  22000422  재사용봉투 -20L     110101.0
# 2466544  22000422  재사용봉투 -20L     110101.0
# ...           ...         ...          ...
# 5237680  22000422  재사용봉투 -20L     110101.0
# 5237702  22000422  재사용봉투 -20L     110101.0
# 5237711  22000422  재사용봉투 -20L     110101.0
# 5237718  22000422  재사용봉투 -20L     110101.0
# 5237726  22000422  재사용봉투 -20L     110101.0
#
# [27091 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 201001]
# Out:
#          PLU_CD GDS_NM  GDS_CLSS_CD
# 368      201001     감자      30202.0
# 690      201001     감자      30202.0
# 790      201001     감자      30202.0
# 1240     201001     감자      30202.0
# 1849     201001     감자      30202.0
# ...         ...    ...          ...
# 5633056  201001    청과류      30201.0
# 5668391  201001    청과류      30201.0
# 5668393  201001    청과류      30201.0
# 5668394  201001    청과류      30201.0
# 5668395  201001    청과류      30201.0
#
# [25515 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990003323]
# Out:
#                 PLU_CD   GDS_NM  GDS_CLSS_CD
# 316      2908990003323  팽이버섯 1봉      30302.0
# 2906     2908990003323  팽이버섯 1봉      30302.0
# 3299     2908990003323  팽이버섯 1봉      30302.0
# 3562     2908990003323  팽이버섯 1봉      30302.0
# 3839     2908990003323  팽이버섯 1봉      30302.0
# ...                ...      ...          ...
# 4866208  2908990003323  팽이버섯 1봉      30302.0
# 4866210  2908990003323  팽이버섯 1봉      30302.0
# 4866211  2908990003323  팽이버섯 1봉      30302.0
# 4866214  2908990003323  팽이버섯 1봉      30302.0
# 4866216  2908990003323  팽이버섯 1봉      30302.0
#
# [21808 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990004573]
# Out:
#                 PLU_CD     GDS_NM  GDS_CLSS_CD
# 195      2908990004573  *양파(중) 1망      30702.0
# 704      2908990004573  *양파(중) 1망      30702.0
# 796      2908990004573  *양파(중) 1망      30702.0
# 1378     2908990004573  *양파(중) 1망      30702.0
# 2151     2908990004573  *양파(중) 1망      30702.0
# ...                ...        ...          ...
# 4277068  2908990004573  *양파(중) 1망      30702.0
# 4277069  2908990004573  *양파(중) 1망      30702.0
# 4277070  2908990004573  *양파(중) 1망      30702.0
# 4277071  2908990004573  *양파(중) 1망      30702.0
# 4277072  2908990004573  *양파(중) 1망      30702.0
#
# [20830 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990006904]
# Out:
#                 PLU_CD     GDS_NM  GDS_CLSS_CD
# 108      2908990006904  *새송이버섯 1봉      30302.0
# 241      2908990006904  *새송이버섯 1봉      30302.0
# 346      2908990006904  *새송이버섯 1봉      30302.0
# 356      2908990006904  *새송이버섯 1봉      30302.0
# 687      2908990006904  *새송이버섯 1봉      30302.0
# ...                ...        ...          ...
# 1589225  2908990006904  *새송이버섯 1봉      30302.0
# 1589229  2908990006904  *새송이버섯 1봉      30302.0
# 1589232  2908990006904  *새송이버섯 1봉      30302.0
# 1589235  2908990006904  *새송이버섯 1봉      30302.0
# 1589239  2908990006904  *새송이버섯 1봉      30302.0
#
# [19871 rows x 3 columns]

# %%
N880[N880['PLU_CD'] == 2908990004344]
# Out:
#                 PLU_CD   GDS_NM  GDS_CLSS_CD
# 177      2908990004344  *청상추 1봉      30101.0
# 220      2908990004344  *청상추 1봉      30101.0
# 2869     2908990004344  *청상추 1봉      30101.0
# 3671     2908990004344  *청상추 1봉      30101.0
# 5476     2908990004344  *청상추 1봉      30101.0
# ...                ...      ...          ...
# 4101810  2908990004344  *청상추 1봉      30101.0
# 4101814  2908990004344  *청상추 1봉      30101.0
# 4101816  2908990004344  *청상추 1봉      30101.0
# 4101818  2908990004344  *청상추 1봉      30101.0
# 4101820  2908990004344  *청상추 1봉      30101.0
#
# [19475 rows x 3 columns]

# %%
N880['GDS_NM'] = N880['GDS_NM'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
N880['GDS_NM']
# Out:
# <ipython-input-95-5c14f8013137>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N880['GDS_NM'] = N880['GDS_NM'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
# 14              구호물품 포장박스
# 15               구호물품 택배비
# 30              구호물품 포장박스
# 31               구호물품 택배비
# 35           의성햇사과 8입 1봉
#                 ...
# 5975264     탐스제로 오렌지600 6
# 5975265          조지아커피6번들
# 5975266         맥스웰마스터6번들
# 5975267    칠성사이다 플러스500 6
# 5975268          조지아커피6번들
# Name: GDS_NM, Length: 2370579, dtype: object

# %%
N880[N880['PLU_CD'] == 2908990004573]
# Out:
#                 PLU_CD     GDS_NM  GDS_CLSS_CD
# 195      2908990004573   양파 중  1망      30702.0
# 704      2908990004573   양파 중  1망      30702.0
# 796      2908990004573   양파 중  1망      30702.0
# 1378     2908990004573   양파 중  1망      30702.0
# 2151     2908990004573   양파 중  1망      30702.0
# ...                ...        ...          ...
# 4277068  2908990004573   양파 중  1망      30702.0
# 4277069  2908990004573   양파 중  1망      30702.0
# 4277070  2908990004573   양파 중  1망      30702.0
# 4277071  2908990004573   양파 중  1망      30702.0
# 4277072  2908990004573   양파 중  1망      30702.0
#
# [20830 rows x 3 columns]

# %%
N880[N880['GDS_NM'].str.contains('중')]
# Out:
#                 PLU_CD         GDS_NM  GDS_CLSS_CD
# 195      2908990004573       양파 중  1망      30702.0
# 704      2908990004573       양파 중  1망      30702.0
# 709      2908990003477    마늘쫑 대   중국산      30701.0
# 796      2908990004573       양파 중  1망      30702.0
# 1378     2908990004573       양파 중  1망      30702.0
# ...                ...            ...          ...
# 5862760  2599990000230  3중 국산마스크 50매      999999.0
# 5883082  2599990000230  3중 국산마스크 50매      999999.0
# 5887167  2599990000230  3중 국산마스크 50매      999999.0
# 5938315  2599990000230  3중 국산마스크 50매      999999.0
# 5938316  2599990000230  3중 국산마스크 50매      999999.0
#
# [31260 rows x 3 columns]

# %%
N880[N880['GDS_NM'].str.contains('봉')]
# Out:
#                 PLU_CD           GDS_NM  GDS_CLSS_CD
# 35       2999000001262     의성햇사과 8입 1봉       40601.0
# 37       2908990003866   성주꿀참외 특  6입 1봉      40101.0
# 39              201447             거봉포도      40702.0
# 40              201447             거봉포도      40702.0
# 95       2901458741254    햇홍로사과 8개 8개1봉      40601.0
# ...                ...              ...          ...
# 5964382  2504010000060             쇼핑봉투      40101.0
# 5964383  2504010000060             쇼핑봉투      40101.0
# 5964384  2504010000060             쇼핑봉투      40101.0
# 5964385  2504010000060             쇼핑봉투      40101.0
# 5964386  2504010000060             쇼핑봉투      40101.0
#
# [581266 rows x 3 columns]

# %%
N880[N880['GDS_NM'].str.contains('비닐')]
# Out:
#                 PLU_CD              GDS_NM  GDS_CLSS_CD
# 246      2908990006508      무우 1개 봉  투명비닐       30899.0
# 260      2908990006508      무우 1개 봉  투명비닐       30899.0
# 274      2908990006508      무우 1개 봉  투명비닐       30899.0
# 795      2908990006508      무우 1개 봉  투명비닐       30899.0
# 1020     2908990006508      무우 1개 봉  투명비닐       30899.0
# ...                ...                 ...          ...
# 5041658  2999000034147      햇양파 비닐  1봉 행사       30702.0
# 5041659  2999000034147      햇양파 비닐  1봉 행사       30702.0
# 5041661  2999000034147      햇양파 비닐  1봉 행사       30702.0
# 5052574  2999000035243   딱딱이복숭아 8개입 비닐  1봉      40205.0
# 5052575  2999000035243   딱딱이복숭아 8개입 비닐  1봉      40205.0
#
# [61712 rows x 3 columns]
