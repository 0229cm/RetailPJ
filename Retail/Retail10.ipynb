# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# a 마트 gds+list+dtl
amartsum = pd.read_csv(base_path + 'amartsum.csv')
amartsum
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# ...

# %%
amartsum['SALE_KIND_TP_NM'].value_counts()
# Out:
# 매출      4907080
# 배달매출      32147
# 배달착불      29307
# Name: SALE_KIND_TP_NM, dtype: int64

# %%
amartsum.isnull().sum()
# Out:
# SAL_DT                  0
# STR_CD                  0
# POS_NO                  0
# TRAN_NO                 0
# SEQ_NO                  0
# DESI_CNCL_TP_NM         0
# SALE_RTN_SGN            0
# PLU_CD                  0
# GDS_CLSS_CD             0
# SALE_QTY                0
# SALE_PRC                0
# SALE_AMT                0
# GDS_NM                  0
# SALE_KIND_TP_NM         0
# REAL_SAL_DT             0
# REAL_SAL_TTM            0
# PAY_AMT                 0
# MSHP_ID            688555
# dtype: int64

# %%
a = amartsum.loc[amartsum['SALE_KIND_TP_NM'].isin(['매출'])]
a
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
pd.set_option('display.max_row', 300)

# %%
a['MSHP_ID'].sort_values(ascending=False).head(300)
# Out:
# 4051082    012018_9999
# 1244168    012018_9999
# 4051079    012018_9999
# 4051080    012018_9999
# 4051081    012018_9999
# 4673174    012018_9999
# 4673175    012018_9999
# 4673176    012018_9999
# 2204131    012018_9999
# 1244166    012018_9999
# 1244167    012018_9999
# 1244169    012018_9999
# 2755910    012018_9999
# 1244170    012018_9999
# 1244171    012018_9999
# 2755916    012018_9999
# 1244172    012018_9999
# 1244173    012018_9999
# 4261855    012018_9999
# 1244174    012018_9999
# 2755908    012018_9999
# 2755909    012018_9999
# 2755917    012018_9999
# 2755918    012018_9999
# 2204127    012018_9999
# 4261856    012018_9999
# 4779632    012018_9999
# 4779631    012018_9999
# 4874899    012018_9999
# 2204128    012018_9999
# 4667828    012018_9999
# 4874900    012018_9999
# 2204130    012018_9999
# 4234381    012018_9999
# 4234380    012018_9999
# 2201081    012018_9999
# 2201082    012018_9999
# 2201083    012018_9999
# 2201084    012018_9999
# 1733420    012018_9999
# ...

# %%
b = a.dropna(subset=['MSHP_ID'])
b
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 32       20210902   12018     01      457       1            정상판매
# 33       20210902   12018     01      457       2            정상판매
# 34       20210902   12018     05      231       3            정상판매
# 35       20210902   12018     05      231       5            정상판매
# 36       20210902   12018     05      231       7            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968528  20220901   12018      7      167       1            정상판매
# 4968529  20220901   12018      7      175       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 32                  1  8801039939499      12301.0       1.0    2980.0
# ...

# %%
b.isnull().sum()
# Out:
# SAL_DT             0
# STR_CD             0
# POS_NO             0
# TRAN_NO            0
# SEQ_NO             0
# DESI_CNCL_TP_NM    0
# SALE_RTN_SGN       0
# PLU_CD             0
# GDS_CLSS_CD        0
# SALE_QTY           0
# SALE_PRC           0
# SALE_AMT           0
# GDS_NM             0
# SALE_KIND_TP_NM    0
# REAL_SAL_DT        0
# REAL_SAL_TTM       0
# PAY_AMT            0
# MSHP_ID            0
# dtype: int64

# %%
c = b[['SAL_DT', 'MSHP_ID']]
c
# Out:
#            SAL_DT      MSHP_ID
# 32       20210902  012018_2494
# 33       20210902  012018_2494
# 34       20210902    012018_25
# 35       20210902    012018_25
# 36       20210902    012018_25
# ...           ...          ...
# 4968528  20220901  012018_3736
# 4968529  20220901  012018_1636
# 4968531  20220901  012018_6700
# 4968532  20220901  012018_2764
# 4968533  20220901  012018_4787
#
# [4219589 rows x 2 columns]

# %%
c.head(300)
# Out:
#        SAL_DT       MSHP_ID
# 32   20210902   012018_2494
# 33   20210902   012018_2494
# 34   20210902     012018_25
# 35   20210902     012018_25
# 36   20210902     012018_25
# 37   20210902     012018_25
# 38   20210902     012018_25
# 39   20210902     012018_25
# 40   20210902     012018_25
# 41   20210902     012018_25
# 58   20210903   012018_4221
# 59   20210903   012018_4221
# 60   20210903   012018_4221
# 61   20210903   012018_4221
# 62   20210903   012018_4221
# 63   20210903   012018_4221
# 64   20210903   012018_4221
# 65   20210903   012018_4221
# 82   20210904   012018_3704
# 83   20210904   012018_3704
# 84   20210904   012018_3704
# 85   20210904   012018_3704
# 86   20210904   012018_3704
# 87   20210904   012018_5775
# 88   20210904   012018_5775
# 89   20210904   012018_5775
# 90   20210904   012018_5775
# 91   20210904   012018_5948
# 92   20210904   012018_5948
# 93   20210904   012018_5948
# 94   20210904   012018_5948
# 95   20210904   012018_5948
# ...

# %%
d = b[['SAL_DT', 'GDS_NM', 'MSHP_ID']]
d
# Out:
#            SAL_DT         GDS_NM      MSHP_ID
# 32       20210902    해표 더고소한 파래김  012018_2494
# 33       20210902    빙그레 굿모닝우유기획  012018_2494
# 34       20210902    해표 더고소한 파래김    012018_25
# 35       20210902  *의성햇사과/8입(1봉)    012018_25
# 36       20210902      쌈배추(벌크)1통    012018_25
# ...           ...            ...          ...
# 4968528  20220901       햇배 4개/행사  012018_3736
# 4968529  20220901       햇배 4개/행사  012018_1636
# 4968531  20220901       햇배 4개/행사  012018_6700
# 4968532  20220901       햇배 4개/행사  012018_2764
# 4968533  20220901   청정원 올리브유 재래김  012018_4787
#
# [4219589 rows x 3 columns]

# %%
d[d['MSHP_ID'] == '012018_2494']
# Out:
#            SAL_DT                GDS_NM      MSHP_ID
# 32       20210902           해표 더고소한 파래김  012018_2494
# 33       20210902           빙그레 굿모닝우유기획  012018_2494
# 2549     20211021           해표 더고소한 파래김  012018_2494
# 2550     20211021              검은콩깨보리건빵  012018_2494
# 2551     20211021               빙그레요구르트  012018_2494
# ...           ...                   ...          ...
# 4955029  20220612         *호박고구마 1봉(비닐)  012018_2494
# 4955823  20220613          *파프리카 2개(행사)  012018_2494
# 4964535  20220629          *초당옥수수 2개입/팩  012018_2494
# 4965298  20220708                부라보콘우유  012018_2494
# 4967668  20220728  *밤고구마(소)10kg/1박스(행사)  012018_2494
#
# [593 rows x 3 columns]

# %%
e = b[['GDS_NM','MSHP_ID']]
e
# Out:
#                 GDS_NM      MSHP_ID
# 32         해표 더고소한 파래김  012018_2494
# 33         빙그레 굿모닝우유기획  012018_2494
# 34         해표 더고소한 파래김    012018_25
# 35       *의성햇사과/8입(1봉)    012018_25
# 36           쌈배추(벌크)1통    012018_25
# ...                ...          ...
# 4968528       햇배 4개/행사  012018_3736
# 4968529       햇배 4개/행사  012018_1636
# 4968531       햇배 4개/행사  012018_6700
# 4968532       햇배 4개/행사  012018_2764
# 4968533   청정원 올리브유 재래김  012018_4787
#
# [4219589 rows x 2 columns]

# %%
f = b[['MSHP_ID']]
f
# Out:
#              MSHP_ID
# 32       012018_2494
# 33       012018_2494
# 34         012018_25
# 35         012018_25
# 36         012018_25
# ...              ...
# 4968528  012018_3736
# 4968529  012018_1636
# 4968531  012018_6700
# 4968532  012018_2764
# 4968533  012018_4787
#
# [4219589 rows x 1 columns]

# %%
# gmer = pd.merge(e,f,how='left', on='MSHP_ID')

# %%
# pd.set_option('display.max_row', 2000)

# %%
# gmer = pd.merge(e,f,how='right', on='MSHP_ID')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-685b93cdce3c> in <module>
# ----> 1 gmer = pd.merge(e,f,how='right', on='MSHP_ID')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     675         rindexers = {1: right_indexer} if right_indexer is not None else {}
#     676
# --> 677         result_data = concatenate_block_managers(
#     678             [(self.left._mgr, lindexers), (self.right._mgr, rindexers)],
#     679             axes=[llabels.append(rlabels), join_index],
#
# ...

# %%
# gmer = pd.merge(e,f,how='inner', on='MSHP_ID')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-19-f54b3a49819a> in <module>
# ----> 1 gmer = pd.merge(e,f,how='inner', on='MSHP_ID')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     666             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     667
# --> 668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
# ...

# %%
# d랑 f랑 해보기 날짜까지

# %%
# gmer = pd.merge(e,f,how='outer', on='MSHP_ID')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-3d323c80189e> in <module>
# ----> 1 gmer = pd.merge(e,f,how='outer', on='MSHP_ID')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     666             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     667
# --> 668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
# ...

# %%
# gmer = pd.merge(e,f,how='left', on='MSHP_ID')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-f6ba0f350c53> in <module>
# ----> 1 gmer = pd.merge(e,f,how='left', on='MSHP_ID')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     666             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     667
# --> 668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
# ...

# %%
gmer.head(2000)

# %%
#gmer = pd.merge(e,f,how='left', on='MSHP_ID')

# %%
#gmer = pd.merge(e,f,how='inner', on='MSHP_ID')

# %%
#gmer = pd.merge(e,f,how='outer', on='MSHP_ID')
