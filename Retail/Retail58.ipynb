# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'GDS_NM1011.csv')
df
# Out:
#               GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0               0000        28     45600     52800
# 1      0241405572666         3      1800      2700
# 2                  1         2     18000     18000
# 3            10000벨트         9     90000     90000
# 4        10001200청량초       111    100000    111000
# ...              ...       ...       ...       ...
# 29273           히츠퍼플       115   1503000   1692000
# 29274         히츠퍼플라벨       302    805500   1359000
# 29275      히츠퍼플라벨1보루        16    720000    720000
# 29276       히츨러수수깡캔디        19     59500     66500
# 29277     히포LED파인등기구         1     11500     11500
#
# [29278 rows x 4 columns]

# %%
df1 = pd.read_csv(base_path + 'SALDT_1011.csv')
df1
# Out:
#          SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT
# 0    2021-09-01     25366  71134820   88900250
# 1    2021-09-02     23037  67250910   79845510
# 2    2021-09-03     26213  74816270   88865770
# 3    2021-09-04     28451  87991110  102255800
# 4    2021-09-05     25358  82154230   90567380
# ..          ...       ...       ...        ...
# 361  2022-08-28     23034  78083280   87506200
# 362  2022-08-29     19007  61371590   71878240
# 363  2022-08-30     15962  48352460   63892370
# 364  2022-08-31     18477  59208170   67850910
# 365  2022-09-01     18512  60020760   68505190
#
# [366 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SAL_DT    366 non-null    object
#  1   SALE_QTY  366 non-null    int64
#  2   SALE_PRC  366 non-null    int64
#  3   SALE_AMT  366 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 11.6+ KB

# %%
df1.SAL_DT = pd.to_datetime(df1.SAL_DT)

df1
# Out:
#         SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT
# 0   2021-09-01     25366  71134820   88900250
# 1   2021-09-02     23037  67250910   79845510
# 2   2021-09-03     26213  74816270   88865770
# 3   2021-09-04     28451  87991110  102255800
# 4   2021-09-05     25358  82154230   90567380
# ..         ...       ...       ...        ...
# 361 2022-08-28     23034  78083280   87506200
# 362 2022-08-29     19007  61371590   71878240
# 363 2022-08-30     15962  48352460   63892370
# 364 2022-08-31     18477  59208170   67850910
# 365 2022-09-01     18512  60020760   68505190
#
# [366 rows x 4 columns]

# %%
df1['year'] = pd.to_datetime(df1['SAL_DT'], format='%Y-%m-%d').dt.year
df1
# Out:
#         SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT  year
# 0   2021-09-01     25366  71134820   88900250  2021
# 1   2021-09-02     23037  67250910   79845510  2021
# 2   2021-09-03     26213  74816270   88865770  2021
# 3   2021-09-04     28451  87991110  102255800  2021
# 4   2021-09-05     25358  82154230   90567380  2021
# ..         ...       ...       ...        ...   ...
# 361 2022-08-28     23034  78083280   87506200  2022
# 362 2022-08-29     19007  61371590   71878240  2022
# 363 2022-08-30     15962  48352460   63892370  2022
# 364 2022-08-31     18477  59208170   67850910  2022
# 365 2022-09-01     18512  60020760   68505190  2022
#
# [366 rows x 5 columns]

# %%
df1['month'] = pd.to_datetime(df1['SAL_DT'], format='%Y-%m-%d').dt.month
df1
# Out:
#         SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT  year  month
# 0   2021-09-01     25366  71134820   88900250  2021      9
# 1   2021-09-02     23037  67250910   79845510  2021      9
# 2   2021-09-03     26213  74816270   88865770  2021      9
# 3   2021-09-04     28451  87991110  102255800  2021      9
# 4   2021-09-05     25358  82154230   90567380  2021      9
# ..         ...       ...       ...        ...   ...    ...
# 361 2022-08-28     23034  78083280   87506200  2022      8
# 362 2022-08-29     19007  61371590   71878240  2022      8
# 363 2022-08-30     15962  48352460   63892370  2022      8
# 364 2022-08-31     18477  59208170   67850910  2022      8
# 365 2022-09-01     18512  60020760   68505190  2022      9
#
# [366 rows x 6 columns]

# %%
df1['day'] = pd.to_datetime(df1['SAL_DT'], format='%Y-%m-%d').dt.day
df1
# Out:
#         SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT  year  month  day
# 0   2021-09-01     25366  71134820   88900250  2021      9    1
# 1   2021-09-02     23037  67250910   79845510  2021      9    2
# 2   2021-09-03     26213  74816270   88865770  2021      9    3
# 3   2021-09-04     28451  87991110  102255800  2021      9    4
# 4   2021-09-05     25358  82154230   90567380  2021      9    5
# ..         ...       ...       ...        ...   ...    ...  ...
# 361 2022-08-28     23034  78083280   87506200  2022      8   28
# 362 2022-08-29     19007  61371590   71878240  2022      8   29
# 363 2022-08-30     15962  48352460   63892370  2022      8   30
# 364 2022-08-31     18477  59208170   67850910  2022      8   31
# 365 2022-09-01     18512  60020760   68505190  2022      9    1
#
# [366 rows x 7 columns]

# %%
df1['weekday'] = pd.to_datetime(df1['SAL_DT'], format='%Y-%m-%d').dt.weekday
df1
# Out:
#         SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT  year  month  day  weekday
# 0   2021-09-01     25366  71134820   88900250  2021      9    1        2
# 1   2021-09-02     23037  67250910   79845510  2021      9    2        3
# 2   2021-09-03     26213  74816270   88865770  2021      9    3        4
# 3   2021-09-04     28451  87991110  102255800  2021      9    4        5
# 4   2021-09-05     25358  82154230   90567380  2021      9    5        6
# ..         ...       ...       ...        ...   ...    ...  ...      ...
# 361 2022-08-28     23034  78083280   87506200  2022      8   28        6
# 362 2022-08-29     19007  61371590   71878240  2022      8   29        0
# 363 2022-08-30     15962  48352460   63892370  2022      8   30        1
# 364 2022-08-31     18477  59208170   67850910  2022      8   31        2
# 365 2022-09-01     18512  60020760   68505190  2022      9    1        3
#
# [366 rows x 8 columns]

# %%
df1_1 = df1[['month', 'SALE_QTY']]
df1_1
# Out:
#      month  SALE_QTY
# 0        9     25366
# 1        9     23037
# 2        9     26213
# 3        9     28451
# 4        9     25358
# ..     ...       ...
# 361      8     23034
# 362      8     19007
# 363      8     15962
# 364      8     18477
# 365      9     18512
#
# [366 rows x 2 columns]

# %%
df1['date1'] = pd.to_datetime(df1[['year', 'month', 'day']])

# %%
df1.plot(x='date1', y='SALE_QTY')
# Out:
# <AxesSubplot:xlabel='date1'>

# %%
df1['1y'] = df1['SALE_QTY'].rolling(window=12).mean()

# %%
ax = df1.plot(x='date1', y='SALE_QTY')
df1.plot(x='date1', y='1y', color='red', ax=ax)
# Out:
# <AxesSubplot:xlabel='date1'>

# %%
df1.plot(x='date1', y='SALE_PRC')
# Out:
# <AxesSubplot:xlabel='date1'>

# %%
df1['1y'] = df1['SALE_PRC'].rolling(window=12).mean()

# %%
ax = df1.plot(x='date1', y='SALE_PRC')
df1.plot(x='date1', y='1y', color='red', ax=ax)
# Out:
# <AxesSubplot:xlabel='date1'>

# %%
df1.plot(x='date1', y='SALE_AMT')
# Out:
# <AxesSubplot:xlabel='date1'>
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df1['1y'] = df1['SALE_AMT'].rolling(window=12).mean()

# %%
ax = df1.plot(x='date1', y='SALE_AMT')
df1.plot(x='date1', y='1y', color='red', ax=ax)
# Out:
# <AxesSubplot:xlabel='date1'>
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SAL_DT    366 non-null    datetime64[ns]
#  1   SALE_QTY  366 non-null    int64
#  2   SALE_PRC  366 non-null    int64
#  3   SALE_AMT  366 non-null    int64
#  4   year      366 non-null    int64
#  5   month     366 non-null    int64
#  6   day       366 non-null    int64
#  7   weekday   366 non-null    int64
#  8   date1     366 non-null    datetime64[ns]
#  9   1y        355 non-null    float64
# dtypes: datetime64[ns](2), float64(1), int64(7)
# memory usage: 28.7 KB

# %%
df1_1 = df1.reset_index()
df1_1
# Out:
#         SAL_DT  SALE_QTY  SALE_PRC   SALE_AMT  year  month  day  weekday  \
# 0   2021-09-01     25366  71134820   88900250  2021      9    1        2
# 1   2021-09-02     23037  67250910   79845510  2021      9    2        3
# 2   2021-09-03     26213  74816270   88865770  2021      9    3        4
# 3   2021-09-04     28451  87991110  102255800  2021      9    4        5
# 4   2021-09-05     25358  82154230   90567380  2021      9    5        6
# ..         ...       ...       ...        ...   ...    ...  ...      ...
# 361 2022-08-28     23034  78083280   87506200  2022      8   28        6
# 362 2022-08-29     19007  61371590   71878240  2022      8   29        0
# 363 2022-08-30     15962  48352460   63892370  2022      8   30        1
# 364 2022-08-31     18477  59208170   67850910  2022      8   31        2
# 365 2022-09-01     18512  60020760   68505190  2022      9    1        3
#
#          date1            1y
# 0   2021-09-01           NaN
# 1   2021-09-02           NaN
# ...

# %%
df1_2 = df1_1[['SAL_DT', 'SALE_QTY']]
df1_2
# Out:
#         SAL_DT  SALE_QTY
# 0   2021-09-01     25366
# 1   2021-09-02     23037
# 2   2021-09-03     26213
# 3   2021-09-04     28451
# 4   2021-09-05     25358
# ..         ...       ...
# 361 2022-08-28     23034
# 362 2022-08-29     19007
# 363 2022-08-30     15962
# 364 2022-08-31     18477
# 365 2022-09-01     18512
#
# [366 rows x 2 columns]

# %%
df1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SAL_DT    366 non-null    datetime64[ns]
#  1   SALE_QTY  366 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.8 KB

# %%
df1_2.index = df1_2['SAL_DT']
df1_2.set_index('SAL_DT', inplace=True)

# %%
df1_2.plot()
plt.show()

# %% [markdown]
# from statsmodels.tsa.arima_model import ARIMA
# import statsmodels.api as sm
#
# # (AR=2, 차분=1, MA=2) 파라미터로 ARIMA 모델을 학습합니다.
# model = ARIMA(df1_2.SALE_QTY.values, order=(2,1,2))
#
# #trend : constant를 가지고 있는지, c - constant / nc - no constant
# #disp : 수렴 정보를 나타냄
# model_fit = model.fit(trend='c', full_output=True, disp=True)
# print(model_fit.summary())

# %%
df.plot(kind='bar',y=['SALE_QTY'])
# Out:
# <AxesSubplot:>

# %%
test = df[df['GDS_NM'] == '히츠퍼플']
test
# Out:
#       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT         1y
# 29273   히츠퍼플       115   1503000   1692000  78.416667
