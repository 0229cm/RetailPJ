# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'df1018.csv')
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드         1      1100      1100
# 1         2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 2         2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 3         2021-05-30  8801068097474   땅콩샌드         1      1100      1100
# 4         2021-05-31  8801068097474   땅콩샌드         1      1100      1100
# ...              ...            ...    ...       ...       ...       ...
# 24805738  2022-08-27  9556486800210   망고푸딩         1      3500      3500
# 24805739  2022-08-28  9556486800210   망고푸딩         1      3500      3500
# 24805740  2022-09-13  9556486800210   망고푸딩         1      3500      3500
# 24805741  2022-09-20  9556486800210   망고푸딩         1      3500      3500
# 24805742  2022-09-22  9556486800210   망고푸딩         1      3500      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# 2             5        5
# 3             5        6
# 4             5        0
# ...         ...      ...
# 24805738      8        5
# 24805739      8        6
# 24805740      9        1
# 24805741      9        1
# 24805742      9        3
#
# [24805743 rows x 8 columns]

# %%
df1 = pd.read_excel(base_path + 'gds1018 (1).xlsx')
df1
# Out:
#              GDS_NM  대분류
# 0              대파1단   채소
# 1            참이슬후레쉬   주류
# 2              처음처럼   주류
# 3              서울우유  유제품
# 4               백오이   채소
# ...             ...  ...
# 10327   한사누끼우동면800g  NaN
# 10328  청정원명란크림파스타소스  NaN
# 10329   서울저지방우유기획2입  NaN
# 10330           통우엉  NaN
# 10331   자연퐁오렌지112kg  NaN
#
# [10332 rows x 2 columns]

# %%
df2 = pd.merge(df, df1)
df2
# Out:
#               SAL_DT         PLU_CD      GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474        땅콩샌드         1      1100      1100
# 1         2021-05-29  8801068097474        땅콩샌드         1      1100      1100
# 2         2021-05-29  8801068097474        땅콩샌드         1      1100      1100
# 3         2021-05-30  8801068097474        땅콩샌드         1      1100      1100
# 4         2021-05-31  8801068097474        땅콩샌드         1      1100      1100
# ...              ...            ...         ...       ...       ...       ...
# 18256528  2022-09-27  8809359010232  650별애별란30구         1      8000      8000
# 18256529  2022-09-28  8809359010232  650별애별란30구         1      8000      8000
# 18256530  2022-09-28  8809359010232  650별애별란30구         1      8000      8000
# 18256531  2022-09-28  8809359010232  650별애별란30구         1      8000      8000
# 18256532  2022-09-30  8809359010232  650별애별란30구         1      8000      8000
#
#           month  weekday  대분류
# 0             5        3  NaN
# 1             5        5  NaN
# 2             5        5  NaN
# 3             5        6  NaN
# 4             5        0  NaN
# ...         ...      ...  ...
# 18256528      9        1  NaN
# 18256529      9        2  NaN
# 18256530      9        2  NaN
# 18256531      9        2  NaN
# 18256532      9        4  NaN
#
# [18256533 rows x 9 columns]

# %%
df2.isnull().sum()
# Out:
# SAL_DT             0
# PLU_CD             0
# GDS_NM             0
# SALE_QTY           0
# SALE_PRC           0
# SALE_AMT           0
# month              0
# weekday            0
# 대분류         12449530
# dtype: int64

# %%
df3 = df2.dropna()

# %%
df3
# Out:
#               SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 9670      2021-07-04            101       대파1단         1       900       900
# 9671      2021-07-04            101       대파1단         1       900       900
# 9672      2021-07-04            101       대파1단         1       900       900
# 9673      2021-07-04            101       대파1단         1       900       900
# 9674      2021-07-04            101       대파1단         1       900       900
# ...              ...            ...        ...       ...       ...       ...
# 18213552  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
# 18213553  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
# 18213554  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
# 18213555  2022-09-30  2599990000094  아이스크림바10개         3      3980     11940
# 18213556  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
#
#           month  weekday 대분류
# 9670          7        6  채소
# 9671          7        6  채소
# 9672          7        6  채소
# 9673          7        6  채소
# 9674          7        6  채소
# ...         ...      ...  ..
# 18213552      9        4  냉동
# 18213553      9        4  냉동
# 18213554      9        4  냉동
# 18213555      9        4  냉동
# 18213556      9        4  냉동
#
# [5807003 rows x 9 columns]

# %%
df3.isnull().sum()
# Out:
# SAL_DT      0
# PLU_CD      0
# GDS_NM      0
# SALE_QTY    0
# SALE_PRC    0
# SALE_AMT    0
# month       0
# weekday     0
# 대분류         0
# dtype: int64

# %%
data = df3.copy()
data
# Out:
#               SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 9670      2021-07-04            101       대파1단         1       900       900
# 9671      2021-07-04            101       대파1단         1       900       900
# 9672      2021-07-04            101       대파1단         1       900       900
# 9673      2021-07-04            101       대파1단         1       900       900
# 9674      2021-07-04            101       대파1단         1       900       900
# ...              ...            ...        ...       ...       ...       ...
# 18213552  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
# 18213553  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
# 18213554  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
# 18213555  2022-09-30  2599990000094  아이스크림바10개         3      3980     11940
# 18213556  2022-09-30  2599990000094  아이스크림바10개         1      3980      3980
#
#           month  weekday 대분류
# 9670          7        6  채소
# 9671          7        6  채소
# 9672          7        6  채소
# 9673          7        6  채소
# 9674          7        6  채소
# ...         ...      ...  ..
# 18213552      9        4  냉동
# 18213553      9        4  냉동
# 18213554      9        4  냉동
# 18213555      9        4  냉동
# 18213556      9        4  냉동
#
# [5807003 rows x 9 columns]

# %%
data.head()
# Out:
#           SAL_DT  PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  month  weekday  \
# 9670  2021-07-04     101   대파1단         1       900       900      7        6
# 9671  2021-07-04     101   대파1단         1       900       900      7        6
# 9672  2021-07-04     101   대파1단         1       900       900      7        6
# 9673  2021-07-04     101   대파1단         1       900       900      7        6
# 9674  2021-07-04     101   대파1단         1       900       900      7        6
#
#      대분류
# 9670  채소
# 9671  채소
# 9672  채소
# 9673  채소
# 9674  채소

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
data1 = data[['GDS_NM', 'SALE_QTY', 'SALE_AMT']]
data1
# Out:
#              GDS_NM  SALE_QTY  SALE_AMT
# 9670           대파1단         1       900
# 9671           대파1단         1       900
# 9672           대파1단         1       900
# 9673           대파1단         1       900
# 9674           대파1단         1       900
# ...             ...       ...       ...
# 18213552  아이스크림바10개         1      3980
# 18213553  아이스크림바10개         1      3980
# 18213554  아이스크림바10개         1      3980
# 18213555  아이스크림바10개         3     11940
# 18213556  아이스크림바10개         1      3980
#
# [5807003 rows x 3 columns]

# %%
data2 = data1.groupby('GDS_NM').mean()

# %%
display(data2.head())
# Out:
#                SALE_QTY      SALE_AMT
# GDS_NM
# CJ비비고버섯야채죽    11.829825  37999.403509
# CJ비비고사골곰탕      2.247867   2545.920944
# CJ비비고소고기죽      7.816073  24948.279396
# CJ삼호부산어묵바른사각   1.179198   1191.917347
# CJ양념이잘배는찌개두부   1.239978   1333.606910

# %%
plt.rcParams['font.family'] = 'NanumGothic'
# k=3 클러스터 생성
estimator = KMeans(n_clusters = 3)
cluster_ids = estimator.fit_predict(data2)

# 플롯
plt.scatter(data2['SALE_AMT'], data2['SALE_QTY'], c=cluster_ids)
plt.xlabel("Attended classes")
plt.ylabel("SALE_QTY")

# 범례 달기
for GDS_NM, SALE_QTY, SALE_AMT in data2.itertuples():
    plt.annotate(GDS_NM, (SALE_AMT, SALE_QTY))
    
plt.show()
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# normalizer 생성
min_max_scaler = preprocessing.MinMaxScaler()

# 표준화하기
data2[['SALE_QTY', 'SALE_QTY']] = min_max_scaler.fit_transform(data2[['SALE_QTY', 'SALE_QTY']])

# 클러스터링 생성
estimator = KMeans(n_clusters = 3)
cluster_ids = estimator.fit_predict(data2)


plt.scatter(data2['SALE_QTY'], data2['SALE_QTY'], c=cluster_ids)
plt.xlabel("Attended classes")
plt.ylabel("SALE_QTY")

for GDS_NM, SALE_QTY, SALE_QTY in data2.itertuples():
    plt.annotate(GDS_NM, (SALE_QTY, SALE_QTY))
    
plt.show()
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# ---

# %%
data2 = data[['GDS_NM', 'SALE_QTY', 'SALE_AMT', 'month', 'weekday']]
data2
# Out:
#              GDS_NM  SALE_QTY  SALE_AMT  month  weekday
# 9670           대파1단         1       900      7        6
# 9671           대파1단         1       900      7        6
# 9672           대파1단         1       900      7        6
# 9673           대파1단         1       900      7        6
# 9674           대파1단         1       900      7        6
# ...             ...       ...       ...    ...      ...
# 18213552  아이스크림바10개         1      3980      9        4
# 18213553  아이스크림바10개         1      3980      9        4
# 18213554  아이스크림바10개         1      3980      9        4
# 18213555  아이스크림바10개         3     11940      9        4
# 18213556  아이스크림바10개         1      3980      9        4
#
# [5807003 rows x 5 columns]

# %%
data3 = data2.copy()

# %%
display(data3.head())
# Out:
#      GDS_NM  SALE_QTY  SALE_AMT  month  weekday
# 9670   대파1단         1       900      7        6
# 9671   대파1단         1       900      7        6
# 9672   대파1단         1       900      7        6
# 9673   대파1단         1       900      7        6
# 9674   대파1단         1       900      7        6

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
processed_data = data3.copy()

# %%
# 데이터 전처리 - 정규화를 위한 작업
scaler = preprocessing.MinMaxScaler()
processed_data[['SALE_QTY', 'SALE_AMT']] = scaler.fit_transform(processed_data[['SALE_QTY', 'SALE_AMT']])

# 화면(figure) 생성
plt.figure(figsize = (10, 6))

# %%
# K 값을 늘려가며 반복 테스트
for i in range(1, 7) :
       # 클러스터 생성
       estimator = KMeans(n_clusters = i)
       ids = estimator.fit_predict(processed_data[['SALE_QTY', 'SALE_AMT']])

# %%
plt.subplot(3, 2, i)
plt.tight_layout()
        # 서브플롯의 라벨링
plt.title("K value = {}".format(i))
plt.xlabel('SALE_QTY')
plt.ylabel('SALE_AMT')
        # 클러스터링 그리기
plt.scatter(processed_data['SALE_QTY'], processed_data['SALE_AMT'], c=ids)  
plt.show()
