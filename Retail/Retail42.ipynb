# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
pd.set_option('display.max_rows', 1000)

# %%
# 제품목록 gds_list_0, gds_list_1
cn = pd.read_csv(base_path + 'cn8801006-1.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
n8 = pd.read_csv(base_path + 'n8801006-1.csv')

# %%
cn # 바코드 880 위
# Out:
#                 PLU_CD              GDS_NM  GDS_CLSS_CD
# 0        8801039939499         해표 더고소한 파래김      12301.0
# 1        8801045312316         오뚜기 3분쇠고기카레      12101.0
# 2        8801045291314         오뚜기 3분쇠고기짜장      12101.0
# 3        8803712127018              목우촌 뚝심      11363.0
# 4        8801045890333          오뚜기 맛있는밥기획      12102.0
# ...                ...                 ...          ...
# 3604699  8809713911199              바나나 톡톡      20202.0
# 3604700  8809713913896         정신차리솟에너지드링크      20202.0
# 3604701  8801007029795            가스오+튀김4인     999999.0
# 3604702  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인     999999.0
# 3604703  8801115382027             스타벅스 돌체     999999.0
#
# [3604704 rows x 3 columns]

# %%
n8 # 바코드 880 아래
# Out:
#                 PLU_CD          GDS_NM  GDS_CLSS_CD
# 0        2908990043152       구호물품 포장박스      29999.0
# 1        2908990043169        구호물품 택배비      29999.0
# 2        2908990043152       구호물품 포장박스      29999.0
# 3        2908990043169        구호물품 택배비      29999.0
# 4        2999000001262   *의성햇사과/8입(1봉)      40601.0
# ...                ...             ...          ...
# 2370574  2599990000780   탐스제로 오렌지600*6      11010.0
# 2370575  2599990000834        조지아커피6번들      11010.0
# 2370576  2599990000827       맥스웰마스터6번들      11010.0
# 2370577  2599990000803  칠성사이다 플러스500*6      11010.0
# 2370578  2599990000834        조지아커피6번들      11010.0
#
# [2370579 rows x 3 columns]

# %% [markdown]
# -------

# %%
cn.sort_values(by=["PLU_CD"], ascending=[False]).head(1000)
# Out:
#                     PLU_CD                   GDS_NM  GDS_CLSS_CD
# 936416   35104002974014091        35104002974014091     999999.0
# 1455175     88097721891617                 코디순수데코3겹      20501.0
# 2924876     88012520162478               마마손니트릴고무장갑      91701.0
# 1687954     88012520162478               마마손니트릴고무장갑      91701.0
# 2226302     88011260113507             깨끗한나라 뉴3겹소프트      20501.0
# 2891971     67484000003455                쿠진그라라스실버락      91701.0
# 2927537     29089900415645                  *애플수박1통      49999.0
# 552230      29089900415645                  *애플수박1통      49999.0
# 552745      29089900415645                  *애플수박1통      49999.0
# 2896144     29089900415645                  *애플수박1통      49999.0
# 2927539     29089900415645                  *애플수박1통      49999.0
# 2534725     29089900415645                  *애플수박1통      49999.0
# 149532      29089900415645                  *애플수박1통      49999.0
# ...

# %%
cn.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#                 PLU_CD          GDS_NM  GDS_CLSS_CD
# 755701   8800000000206        늘보리쌀(국산)     105152.0
# 2108389  8800000000206        늘보리쌀(국산)     105152.0
# 2683535  8800042800550            다용도상      99999.0
# 1004703  8800042800550            다용도상      99999.0
# 321924   8800789080000             늘보리     105152.0
# 1921975  8800789080000             늘보리     105152.0
# 1737122  8800789080000             늘보리     105152.0
# 1221988  8800789080000             늘보리     105152.0
# 2908737  8800789080000             늘보리     105152.0
# 2908736  8800789080000             늘보리     105152.0
# 435709   8800789080000             늘보리     105152.0
# 338173   8800789080000             늘보리     105152.0
# 1870277  8800789080000             늘보리     105152.0
# 2847052  8800789080000             늘보리     105152.0
# 859295   8800789080000             늘보리     105152.0
# 2908735  8800789080000             늘보리     105152.0
# 1115041  8800789080000             늘보리     105152.0
# ...

# %%
n8.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#          PLU_CD     GDS_NM  GDS_CLSS_CD
# 2332727       0       간고등어     898989.0
# 2332726       0         동태     898989.0
# 2350599       1  매입에서등록한상품     997979.0
# 2216332       1        배송비     999999.0
# 2216333       1        배송비     999999.0
# 2359076       1  매입에서등록한상품     997979.0
# 2216334       1        배송비     999999.0
# 2216336       1        배송비     999999.0
# 2216337       1        배송비     999999.0
# 2216338       1        배송비     999999.0
# 2216339       1        배송비     999999.0
# 2216340       1        배송비     999999.0
# 2216341       1        배송비     999999.0
# 2216342       1        배송비     999999.0
# 2216343       1        배송비     999999.0
# 2216344       1        배송비     999999.0
# 2216346       1        배송비     999999.0
# 2216347       1        배송비     999999.0
# 2351141       1  매입에서등록한상품     997979.0
# 2301336       1  매입에서등록한상품     997979.0
# 2216331       1        배송비     999999.0
# 2319826       1  매입에서등록한상품     997979.0
# ...

# %%
n8.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#          PLU_CD     GDS_NM  GDS_CLSS_CD
# 2332727       0       간고등어     898989.0
# 2332726       0         동태     898989.0
# 2350599       1  매입에서등록한상품     997979.0
# 2216332       1        배송비     999999.0
# 2216333       1        배송비     999999.0
# 2359076       1  매입에서등록한상품     997979.0
# 2216334       1        배송비     999999.0
# 2216336       1        배송비     999999.0
# 2216337       1        배송비     999999.0
# 2216338       1        배송비     999999.0
# 2216339       1        배송비     999999.0
# 2216340       1        배송비     999999.0
# 2216341       1        배송비     999999.0
# 2216342       1        배송비     999999.0
# 2216343       1        배송비     999999.0
# 2216344       1        배송비     999999.0
# 2216346       1        배송비     999999.0
# 2216347       1        배송비     999999.0
# 2351141       1  매입에서등록한상품     997979.0
# 2301336       1  매입에서등록한상품     997979.0
# 2216331       1        배송비     999999.0
# 2319826       1  매입에서등록한상품     997979.0
# ...

# %%
n8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2370579 entries, 0 to 2370578
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   PLU_CD       int64
#  1   GDS_NM       object
#  2   GDS_CLSS_CD  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 54.3+ MB

# %%
n8_1 = n8[~n8['GDS_NM'].str.contains("매입에서등록한상품", na=False, case=False)]

# %%
n8_1.head(500)
# Out:
#             PLU_CD                   GDS_NM  GDS_CLSS_CD
# 0    2908990043152                구호물품 포장박스      29999.0
# 1    2908990043169                 구호물품 택배비      29999.0
# 2    2908990043152                구호물품 포장박스      29999.0
# 3    2908990043169                 구호물품 택배비      29999.0
# 4    2999000001262            *의성햇사과/8입(1봉)      40601.0
# 5    2908990004443                쌈배추(벌크)1통      30101.0
# 6    2908990003866          *성주꿀참외(특)/6입.1봉      40101.0
# 7           351060                대패삼겹살(수입)      52599.0
# 8           201447                     거봉포도      40702.0
# 9           201447                     거봉포도      40702.0
# 10   2908990043152                구호물품 포장박스      29999.0
# 11   2908990043169                 구호물품 택배비      29999.0
# 12   2908990006874             *꽈리고추 (500g)      30201.0
# 13   2908990005082                   *노각 1개      30201.0
# 14          201503                      바나나      40501.0
# ...
