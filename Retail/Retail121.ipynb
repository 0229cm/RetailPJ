# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'data1019.csv')
df
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-07-24              0     황도복숭아         1      5980      5980
# 1         2021-07-24              0     황도복숭아         1      5980      5980
# 2         2021-07-24              0     황도복숭아         1      5980      5980
# 3         2021-07-24              0     황도복숭아         1      5980      5980
# 4         2021-07-24              0     황도복숭아         1      5980      5980
# ...              ...            ...       ...       ...       ...       ...
# 13085615  2022-09-29  8809267390136  서라벌특란30구         1      7800      7800
# 13085616  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13085617  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13085618  2022-09-30  8809267390136  서라벌특란30구         2      7800     15600
# 13085619  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
#
#           month  weekday        대분류   소분류
# ...

# %%
df.sort_values('SALE_QTY', ascending=False)
# Out:
#               SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 1486199   2022-03-17         202024              딸기      9999     10000
# 615753    2022-01-14         200160             백오이      9999      2480
# 9427107   2022-04-21  8809517210078           에그탑특란      9999     10000
# 4882840   2022-05-24  8801045420042  오뚜기바삭하고고소한튀김가루      9999      3900
# 13068571  2021-09-19  2501130000710          소금20kg      9999     27000
# ...              ...            ...             ...       ...       ...
# 3526791   2021-11-27         204219       한돈앞다리살수육용         0     14500
# 6353115   2022-03-27  8801115114338       서울목장저지방우유         0      3600
# 7666252   2022-07-12  8801007769783      백설고소함가득참기름         0      8950
# 3526806   2021-11-29         204219       한돈앞다리살수육용         0     12000
# 4465171   2021-10-03  8801024946457     종가집숨쉬는전통콩나물         0      1450
#
#            SALE_AMT  month  weekday        대분류       소분류
# ...

# %%
df.sort_values('SALE_PRC', ascending=False)
# Out:
#               SAL_DT    PLU_CD    GDS_NM  SALE_QTY   SALE_PRC    SALE_AMT  \
# 1503183   2022-03-23    201044        딸기         2  880491120  1760982240
# 530840    2021-10-18    200047     청상추1봉         1  880306000   880306000
# 12181523  2021-10-10    351030  국내산돈가브리살         1  351028000   351028000
# 11986628  2022-04-11    351001   국내산돈삼겹살         1  351008000   351008000
# 1683594   2022-04-20   2000804       천혜향         1  279002000   279002000
# ...              ...       ...       ...       ...        ...         ...
# 1812729   2022-02-16      3074    누드애호박개         1          0           0
# 1512675   2022-05-07    201463        딸기         1          0           0
# 676880    2022-03-13    200223       애호박         1          0           0
# 1812730   2022-02-26      3074    누드애호박개         1          0           0
# 646445    2022-02-24  22001146       백오이         1          0           0
#
#           month  weekday 대분류   소분류
# 1503183       3        2  과일    딸기
# ...

# %%
df.sort_values('SALE_AMT', ascending=False)
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY   SALE_PRC  \
# 1503183   2022-03-23         201044           딸기         2  880491120
# 530840    2021-10-18         200047        청상추1봉         1  880306000
# 12181523  2021-10-10         351030     국내산돈가브리살         1  351028000
# 11986628  2022-04-11         351001      국내산돈삼겹살         1  351008000
# 9954989   2022-08-20  8809182054694  자연담은쌀21년산햅쌀      5940      68000
# ...              ...            ...          ...       ...        ...
# 7072916   2021-09-01  8850389106211      모구모구복숭아         0       1500
# 7072913   2021-08-31  8850389106211      모구모구복숭아         0       1500
# 7072912   2021-08-31  8850389106211      모구모구복숭아         0       1500
# 7047933   2022-06-15  8809331505657    아워홈요리두부찌개         0       1500
# 4346730   2021-11-21  8801007851891  CJ더건강한직화구이햄         0       2800
#
#             SALE_AMT  month  weekday        대분류     소분류
# 1503183   1760982240      3        2         과일      딸기
# ...

# %%
df.sort_values('SALE_PRC', ascending=False).head(10)
# Out:
#               SAL_DT    PLU_CD    GDS_NM  SALE_QTY   SALE_PRC    SALE_AMT  \
# 1503183   2022-03-23    201044        딸기         2  880491120  1760982240
# 530840    2021-10-18    200047     청상추1봉         1  880306000   880306000
# 12181523  2021-10-10    351030  국내산돈가브리살         1  351028000   351028000
# 11986628  2022-04-11    351001   국내산돈삼겹살         1  351008000   351008000
# 1683594   2022-04-20   2000804       천혜향         1  279002000   279002000
# 9693429   2022-01-07    255341   생삼겹살구이용         1  255103000   229592700
# 1644590   2021-12-18    201352        섬초         1  205356010   205356010
# 2165377   2021-10-02  22002693        자두         1  205260010   205260010
# 1022419   2022-08-16    201344       흙당근         1  205168010   205168010
# 8993799   2022-05-06    201321    표고버섯국산         1  205045000   205045000
#
#           month  weekday 대분류   소분류
# 1503183       3        2  과일    딸기
# 530840       10        0  채소    상추
# 12181523     10        6  정육  등심덧살
# ...

# %% [markdown]
# df1 = df[df['SALE_PRC'] < 150000]
# df1

# %% [markdown]
# df1.sort_values('SALE_PRC', ascending=False).head(50)

# %%
df.sort_values('SALE_AMT', ascending=False).head(10)
# Out:
#               SAL_DT         PLU_CD       GDS_NM  SALE_QTY   SALE_PRC  \
# 1503183   2022-03-23         201044           딸기         2  880491120
# 530840    2021-10-18         200047        청상추1봉         1  880306000
# 12181523  2021-10-10         351030     국내산돈가브리살         1  351028000
# 11986628  2022-04-11         351001      국내산돈삼겹살         1  351008000
# 9954989   2022-08-20  8809182054694  자연담은쌀21년산햅쌀      5940      68000
# 1683594   2022-04-20        2000804          천혜향         1  279002000
# 13068571  2021-09-19  2501130000710       소금20kg      9999      27000
# 9693429   2022-01-07         255341      생삼겹살구이용         1  255103000
# 1644590   2021-12-18         201352           섬초         1  205356010
# 2165377   2021-10-02       22002693           자두         1  205260010
#
#             SALE_AMT  month  weekday        대분류   소분류
# 1503183   1760982240      3        2         과일    딸기
# 530840     880306000     10        0         채소    상추
# ...

# %%
df1 = df[df['SALE_AMT'] < 200002900]

# %%
df1.sort_values('SALE_AMT', ascending=False).head(30)
# Out:
#               SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 7710975   2021-10-31  8801033786259            베지밀B      7256     14800
# 8671856   2022-04-02  6971804652211          딸기모양젤리      1789     90000
# 1486199   2022-03-17         202024              딸기      9999     10000
# 7678308   2022-07-04  8801013120479          큐원갈색설탕      9000     12500
# 7363914   2022-03-03       22002853       스치딸기1kg행사      7020     14800
# 8677163   2022-07-04  8801007144641          CJ갈색설탕      9000     14500
# 1689210   2022-09-12  2200408605779           샤인머스켓       999     86500
# 7677194   2022-07-04  8801013113136          큐원하얀설탕      9000     11500
# 9427107   2022-04-21  8809517210078           에그탑특란      9999     10000
# 2628402   2022-09-13  8801119740151      테라캔500ml6입      5600     14000
# 8677211   2022-07-04  8801007227320        CJ백설하얀설탕      9000     12000
# 1450751   2022-03-25        2002033             한라봉      7900      7900
# ...

# %%
df1
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-07-24              0     황도복숭아         1      5980      5980
# 1         2021-07-24              0     황도복숭아         1      5980      5980
# 2         2021-07-24              0     황도복숭아         1      5980      5980
# 3         2021-07-24              0     황도복숭아         1      5980      5980
# 4         2021-07-24              0     황도복숭아         1      5980      5980
# ...              ...            ...       ...       ...       ...       ...
# 13085615  2022-09-29  8809267390136  서라벌특란30구         1      7800      7800
# 13085616  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13085617  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13085618  2022-09-30  8809267390136  서라벌특란30구         2      7800     15600
# 13085619  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
#
#           month  weekday        대분류   소분류
# ...

# %%
df1.sort_values('SALE_QTY', ascending=False)
# Out:
#              SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 9427107  2022-04-21  8809517210078           에그탑특란      9999     10000
# 615753   2022-01-14         200160             백오이      9999      2480
# 1486199  2022-03-17         202024              딸기      9999     10000
# 4882840  2022-05-24  8801045420042  오뚜기바삭하고고소한튀김가루      9999      3900
# 5142604  2021-04-03  8801048101023           진로이즈백      9982      1350
# ...             ...            ...             ...       ...       ...
# 6764406  2022-07-18  8801299300046        삼부자광천돌자반         0      3950
# 1316720  2021-12-17       22001191              달래         0      1500
# 1316721  2021-12-17       22001191              달래         0      1500
# 1316722  2021-12-18       22001191              달래         0      1500
# 3783538  2022-06-11         201500          미니파프리카         0      2500
#
#          SALE_AMT  month  weekday        대분류   소분류
# 9427107  79792020      4        3  두부/콩나물/계란    계란
# ...

# %%
df1.sort_values('SALE_PRC', ascending=False)
# Out:
#              SAL_DT  PLU_CD   GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  month  \
# 1594146  2022-09-22  202103      무화과         1  18000000  18000000      9
# 2885549  2022-07-22  200049      햇감자         1   7027370   7027370      7
# 2885548  2022-07-22  200049      햇감자         1   7027370   7027370      7
# 9647108  2022-02-03    1237     음료묶음         1   1800000   1800000      2
# 9647110  2022-02-03    1237     음료묶음         1   1800000   1800000      2
# ...             ...     ...      ...       ...       ...       ...    ...
# 1733630  2022-08-10    3029   묶음깻잎1봉         1         0         0      8
# 1733629  2022-07-25    3029   묶음깻잎1봉         1         0         0      7
# 1733628  2022-07-22    3029   묶음깻잎1봉         1         0         0      7
# 2097088  2021-12-17     333  백오이2개1팩         1         0         0     12
# 1733625  2022-07-17    3029   묶음깻잎1봉         3         0         0      7
#
#          weekday       대분류  소분류
# 1594146        3        과일  무화과
# ...

# %%
df1.sort_values('SALE_AMT', ascending=False)
# Out:
#              SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC   SALE_AMT  \
# 7710975  2021-10-31  8801033786259       베지밀B      7256     14800  107388800
# 8671856  2022-04-02  6971804652211     딸기모양젤리      1789     90000  100184000
# 1486199  2022-03-17         202024         딸기      9999     10000   99990000
# 7678308  2022-07-04  8801013120479     큐원갈색설탕      9000     12500   99000000
# 7363914  2022-03-03       22002853  스치딸기1kg행사      7020     14800   89856000
# ...             ...            ...        ...       ...       ...        ...
# 8489315  2022-02-19         201034    한우양지국거리         0      5500          0
# 8489429  2022-02-26         201034    한우양지국거리         0      5500          0
# 8489432  2022-02-26         201034    한우양지국거리         0      5500          0
# 8489518  2022-03-02         201034    한우양지국거리         0     11000          0
# 7605999  2021-08-20  8801104301862    빙그레요구르트         0      1050          0
#
#          month  weekday        대분류   소분류
# ...

# %%
df2 = df1[df1['SALE_PRC'] < 151800]

# %%
df2.sort_values('SALE_PRC', ascending=False).head(30)
# Out:
#              SAL_DT   PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 7223718  2022-04-15   209101       한돈생삼겹살         1    151530    151530
# 9459759  2021-09-19   521009      양념소LA갈비         1    151350    151350
# 1635846  2021-10-15   202110           생율         1    150200    150200
# 9453122  2021-04-12   711015        한우꽃등심         1    150120    150120
# 1590223  2022-04-15   202204         추희자두         1    150100    150100
# 3477067  2021-11-15   202111         찰토마토         1    150100    150100
# 3519722  2022-09-08   206031         LA갈비         1    150000    150000
# 3529592  2022-09-03   204219    한돈앞다리살수육용         1    150000    150000
# 8495449  2022-04-29   218428      한우양지국거리         1    150000    150000
# 8543626  2021-12-14   201243  한돈흑돼지생오겹살구이         1    150000    150000
# 9452706  2021-01-17   711015        한우꽃등심         1    150000    150000
# 9646977  2021-09-28     1237         음료묶음         1    150000    150000
# ...

# %%
df2
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-07-24              0     황도복숭아         1      5980      5980
# 1         2021-07-24              0     황도복숭아         1      5980      5980
# 2         2021-07-24              0     황도복숭아         1      5980      5980
# 3         2021-07-24              0     황도복숭아         1      5980      5980
# 4         2021-07-24              0     황도복숭아         1      5980      5980
# ...              ...            ...       ...       ...       ...       ...
# 13085615  2022-09-29  8809267390136  서라벌특란30구         1      7800      7800
# 13085616  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13085617  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13085618  2022-09-30  8809267390136  서라벌특란30구         2      7800     15600
# 13085619  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
#
#           month  weekday        대분류   소분류
# ...

# %%
df2.sort_values('SALE_QTY', ascending=False)
# Out:
#              SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 9427107  2022-04-21  8809517210078           에그탑특란      9999     10000
# 4882840  2022-05-24  8801045420042  오뚜기바삭하고고소한튀김가루      9999      3900
# 615753   2022-01-14         200160             백오이      9999      2480
# 1486199  2022-03-17         202024              딸기      9999     10000
# 5142604  2021-04-03  8801048101023           진로이즈백      9982      1350
# ...             ...            ...             ...       ...       ...
# 8580056  2022-05-19         201370       프라임척아이롤구이         0      3300
# 380616   2022-06-16       23000636           느타리버섯         0       700
# 8649214  2021-12-17  2200408601948       산청설향딸기특34         0      7980
# 2429114  2022-07-31  8801068107562         삼립미니꿀약과         0      1800
# 6099980  2021-09-26  8801111922517           크라운콘칩         0      3000
#
#          SALE_AMT  month  weekday        대분류    소분류
# 9427107  79792020      4        3  두부/콩나물/계란     계란
# ...

# %%
df2.sort_values('SALE_PRC', ascending=False)
# Out:
#              SAL_DT  PLU_CD         GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 7223718  2022-04-15  209101         한돈생삼겹살         1    151530    151530
# 9459759  2021-09-19  521009        양념소LA갈비         1    151350    151350
# 1635846  2021-10-15  202110             생율         1    150200    150200
# 9453122  2021-04-12  711015          한우꽃등심         1    150120    150120
# 1590223  2022-04-15  202204           추희자두         1    150100    150100
# ...             ...     ...            ...       ...       ...       ...
# 2157667  2022-07-13    4015  말랑이복숭아910수1박스         1         0         0
# 1812718  2022-01-15    3074         누드애호박개         1         0         0
# 1812719  2022-01-17    3074         누드애호박개         1         0         0
# 1812720  2022-01-18    3074         누드애호박개         1         0         0
# 1812717  2022-01-12    3074         누드애호박개         1         0         0
#
#          month  weekday 대분류    소분류
# 7223718      4        4  정육    삼겹살
# ...

# %%
df2.sort_values('SALE_AMT', ascending=False)
# Out:
#              SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC   SALE_AMT  \
# 7710975  2021-10-31  8801033786259       베지밀B      7256     14800  107388800
# 8671856  2022-04-02  6971804652211     딸기모양젤리      1789     90000  100184000
# 1486199  2022-03-17         202024         딸기      9999     10000   99990000
# 7678308  2022-07-04  8801013120479     큐원갈색설탕      9000     12500   99000000
# 7363914  2022-03-03       22002853  스치딸기1kg행사      7020     14800   89856000
# ...             ...            ...        ...       ...       ...        ...
# 3592969  2021-10-11         204260      한돈생등뼈         0     10000          0
# 8486889  2021-11-07         201034    한우양지국거리         0      5500          0
# 8486892  2021-11-07         201034    한우양지국거리         0      5500          0
# 3592971  2021-10-11         204260      한돈생등뼈         0     10000          0
# 7255191  2022-02-22         203170     한돈돼지등뼈         0      2500          0
#
#          month  weekday        대분류  소분류
# ...

# %%
df2.to_csv('df1019_1.csv', index=False)
