# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df1005.csv') # 1015 인데 1005로 저장 잘못했네..
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 1         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 2         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 3         2021-05-30  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 4         2021-05-31  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# ...              ...            ...    ...       ...       ...       ...
# 23660707  2022-08-27  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660708  2022-08-28  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660709  2022-09-13  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660710  2022-09-20  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660711  2022-09-22  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
#           month  weekday
# 0             5        3
# 1             5        5
# 2             5        5
# 3             5        6
# 4             5        0
# ...         ...      ...
# 23660707      8        5
# 23660708      8        6
# 23660709      9        1
# 23660710      9        1
# 23660711      9        3
#
# [23660712 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23660712 entries, 0 to 23660711
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    object
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  float64
#  4   SALE_PRC  float64
#  5   SALE_AMT  float64
#  6   month     int64
#  7   weekday   int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.4+ GB

# %%
df = df.astype({'SALE_QTY' : 'int'})

# %%
df = df.astype({'SALE_PRC' : 'int'})

# %%
df = df.astype({'SALE_AMT' : 'int'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23660712 entries, 0 to 23660711
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    object
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  int32
#  4   SALE_PRC  int32
#  5   SALE_AMT  int32
#  6   month     int64
#  7   weekday   int64
# dtypes: int32(3), int64(3), object(2)
# memory usage: 1.1+ GB

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파1단           127103
# 흙당근            102456
# 서울우유            93327
# 감자              86819
# 대파              77448
#                 ...
# 라일락슬림65mg갑          1
# 고구마빵                1
# 백설딸기요거트드레싱          1
# 2단우산체크              1
# 아기상어우주선분수놀이         1
# Name: GDS_NM, Length: 95292, dtype: int64

# %%
data = df[['SAL_DT', 'SALE_QTY', 'SALE_PRC', 'SALE_AMT']]
data
# Out:
#               SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0         2021-05-27         1      1100      1100
# 1         2021-05-29         1      1100      1100
# 2         2021-05-29         1      1100      1100
# 3         2021-05-30         1      1100      1100
# 4         2021-05-31         1      1100      1100
# ...              ...       ...       ...       ...
# 23660707  2022-08-27         1      3500      3500
# 23660708  2022-08-28         1      3500      3500
# 23660709  2022-09-13         1      3500      3500
# 23660710  2022-09-20         1      3500      3500
# 23660711  2022-09-22         1      3500      3500
#
# [23660712 rows x 4 columns]

# %%
data['SAL_DT'] = pd.to_datetime(data['SAL_DT'])
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_12664\249976737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SAL_DT'] = pd.to_datetime(data['SAL_DT'])

# %%
data
# Out:
#              SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0        2021-05-27         1      1100      1100
# 1        2021-05-29         1      1100      1100
# 2        2021-05-29         1      1100      1100
# 3        2021-05-30         1      1100      1100
# 4        2021-05-31         1      1100      1100
# ...             ...       ...       ...       ...
# 23660707 2022-08-27         1      3500      3500
# 23660708 2022-08-28         1      3500      3500
# 23660709 2022-09-13         1      3500      3500
# 23660710 2022-09-20         1      3500      3500
# 23660711 2022-09-22         1      3500      3500
#
# [23660712 rows x 4 columns]

# %%
data = data[['SAL_DT', 'SALE_AMT']]
data
# Out:
#              SAL_DT  SALE_AMT
# 0        2021-05-27      1100
# 1        2021-05-29      1100
# 2        2021-05-29      1100
# 3        2021-05-30      1100
# 4        2021-05-31      1100
# ...             ...       ...
# 23660707 2022-08-27      3500
# 23660708 2022-08-28      3500
# 23660709 2022-09-13      3500
# 23660710 2022-09-20      3500
# 23660711 2022-09-22      3500
#
# [23660712 rows x 2 columns]

# %%
data.sort_values('SAL_DT')
# Out:
#              SAL_DT  SALE_AMT
# 14646504 2020-12-20      1500
# 22301250 2020-12-20      4100
# 22301249 2020-12-20      2050
# 22301248 2020-12-20      2050
# 21149152 2020-12-20      3800
# ...             ...       ...
# 1593893  2022-09-30      2980
# 4962456  2022-09-30      3960
# 4962455  2022-09-30      1980
# 12149450 2022-09-30      1000
# 893536   2022-09-30      1500
#
# [23660712 rows x 2 columns]

# %%
data = data.groupby('SAL_DT').sum()
data
# Out:
#              SALE_AMT
# SAL_DT
# 2020-12-20   64765180
# 2020-12-21   74824270
# 2020-12-22   66124340
# 2020-12-23   65115330
# 2020-12-24   74519050
# ...               ...
# 2022-09-26  196120680
# 2022-09-27  195920800
# 2022-09-28  195999820
# 2022-09-29  191564160
# 2022-09-30  490049680
#
# [650 rows x 1 columns]

# %%
data.index
# Out:
# DatetimeIndex(['2020-12-20', '2020-12-21', '2020-12-22', '2020-12-23',
#                '2020-12-24', '2020-12-25', '2020-12-26', '2020-12-27',
#                '2020-12-28', '2020-12-29',
#                ...
#                '2022-09-21', '2022-09-22', '2022-09-23', '2022-09-24',
#                '2022-09-25', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30'],
#               dtype='datetime64[ns]', name='SAL_DT', length=650, freq=None)

# %%
plt.figure(figsize = (20,10))
sns.lineplot(x = data.index, y = data['SALE_AMT'])
# Out:
# <AxesSubplot:xlabel='SAL_DT', ylabel='SALE_AMT'>

# %%
data.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='SAL_DT'>

# %%
data.resample('MS').mean() # 월별
# Out:
#                 SALE_AMT
# SAL_DT
# 2020-12-01  7.010060e+07
# 2021-01-01  6.791026e+07
# 2021-02-01  7.285080e+07
# 2021-03-01  6.444706e+07
# 2021-04-01  6.303750e+07
# 2021-05-01  6.885596e+07
# 2021-06-01  9.183999e+07
# 2021-07-01  9.565125e+07
# 2021-08-01  2.017169e+08
# 2021-09-01  3.454606e+08
# 2021-10-01  3.189451e+08
# 2021-11-01  1.950216e+08
# 2021-12-01  2.948700e+08
# 2022-01-01  4.008399e+08
# 2022-02-01  2.946492e+08
# 2022-03-01  3.258124e+08
# 2022-04-01  4.956836e+08
# 2022-05-01  2.648782e+08
# 2022-06-01  2.615133e+08
# 2022-07-01  2.863198e+08
# 2022-08-01  3.151347e+08
# 2022-09-01  2.979855e+08

# %%
data.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='SAL_DT'>

# %%
from fbprophet import Prophet

# %%
data
# Out:
#              SALE_AMT
# SAL_DT
# 2020-12-20   64765180
# 2020-12-21   74824270
# 2020-12-22   66124340
# 2020-12-23   65115330
# 2020-12-24   74519050
# ...               ...
# 2022-09-26  196120680
# 2022-09-27  195920800
# 2022-09-28  195999820
# 2022-09-29  191564160
# 2022-09-30  490049680
#
# [650 rows x 1 columns]

# %%
df = data.reset_index()

# %%
df
# Out:
#         SAL_DT   SALE_AMT
# 0   2020-12-20   64765180
# 1   2020-12-21   74824270
# 2   2020-12-22   66124340
# 3   2020-12-23   65115330
# 4   2020-12-24   74519050
# ..         ...        ...
# 645 2022-09-26  196120680
# 646 2022-09-27  195920800
# 647 2022-09-28  195999820
# 648 2022-09-29  191564160
# 649 2022-09-30  490049680
#
# [650 rows x 2 columns]

# %%
df.columns = ['ds','y']

# %%
df
# Out:
#             ds          y
# 0   2020-12-20   64765180
# 1   2020-12-21   74824270
# 2   2020-12-22   66124340
# 3   2020-12-23   65115330
# 4   2020-12-24   74519050
# ..         ...        ...
# 645 2022-09-26  196120680
# 646 2022-09-27  195920800
# 647 2022-09-28  195999820
# 648 2022-09-29  191564160
# 649 2022-09-30  490049680
#
# [650 rows x 2 columns]

# %%
model = Prophet()

# %%
model.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = model.make_future_dataframe(periods = 12, freq = 'MS')
# 12개월 / 월 단위 리셋을 나타내는 파라미터 (periods = 12, freq = 'MS')

# %%
future
# Out:
#             ds
# 0   2020-12-20
# 1   2020-12-21
# 2   2020-12-22
# 3   2020-12-23
# 4   2020-12-24
# ..         ...
# 657 2023-05-01
# 658 2023-06-01
# 659 2023-07-01
# 660 2023-08-01
# 661 2023-09-01
#
# [662 rows x 1 columns]

# %%
model.predict(future)
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2020-12-20  1.828474e+07 -3.736586e+08  3.428603e+08  1.828474e+07
# 1   2020-12-21  1.893486e+07 -3.538008e+08  3.847965e+08  1.893486e+07
# 2   2020-12-22  1.958497e+07 -4.067483e+08  3.121261e+08  1.958497e+07
# 3   2020-12-23  2.023509e+07 -3.607827e+08  3.680345e+08  2.023509e+07
# 4   2020-12-24  2.088521e+07 -3.302384e+08  3.761529e+08  2.088521e+07
# ..         ...           ...           ...           ...           ...
# 657 2023-05-01  2.028549e+08 -1.260523e+08  5.806170e+08  1.681667e+08
# 658 2023-06-01  1.914594e+08 -2.006441e+08  5.434715e+08  1.484735e+08
# 659 2023-07-01  1.804315e+08 -1.023493e+08  6.444525e+08  1.277419e+08
# 660 2023-08-01  1.690360e+08 -2.232429e+08  4.890778e+08  1.084992e+08
# 661 2023-09-01  1.576406e+08 -2.025629e+08  5.456173e+08  8.909575e+07
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    1.828474e+07   -1.203979e+07         -1.203979e+07         -1.203979e+07
# 1    1.893486e+07    1.046065e+07          1.046065e+07          1.046065e+07
# 2    1.958497e+07   -4.133861e+07         -4.133861e+07         -4.133861e+07
# 3    2.023509e+07   -1.542362e+07         -1.542362e+07         -1.542362e+07
# 4    2.088521e+07   -1.694578e+07         -1.694578e+07         -1.694578e+07
# ..            ...             ...                   ...                   ...
# 657  2.425072e+08    1.046065e+07          1.046065e+07          1.046065e+07
# 658  2.415204e+08   -1.694578e+07         -1.694578e+07         -1.694578e+07
# 659  2.401852e+08    7.934123e+07          7.934123e+07          7.934123e+07
# 660  2.400827e+08   -4.133861e+07         -4.133861e+07         -4.133861e+07
# 661  2.406976e+08   -4.054070e+06         -4.054070e+06         -4.054070e+06
#
#            weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0   -1.203979e+07 -1.203979e+07 -1.203979e+07                   0.0
# 1    1.046065e+07  1.046065e+07  1.046065e+07                   0.0
# 2   -4.133861e+07 -4.133861e+07 -4.133861e+07                   0.0
# 3   -1.542362e+07 -1.542362e+07 -1.542362e+07                   0.0
# 4   -1.694578e+07 -1.694578e+07 -1.694578e+07                   0.0
# ..            ...           ...           ...                   ...
# 657  1.046065e+07  1.046065e+07  1.046065e+07                   0.0
# 658 -1.694578e+07 -1.694578e+07 -1.694578e+07                   0.0
# 659  7.934123e+07  7.934123e+07  7.934123e+07                   0.0
# 660 -4.133861e+07 -4.133861e+07 -4.133861e+07                   0.0
# 661 -4.054070e+06 -4.054070e+06 -4.054070e+06                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0  6.244949e+06
# 1                           0.0                         0.0  2.939550e+07
# 2                           0.0                         0.0 -2.175364e+07
# 3                           0.0                         0.0  4.811469e+06
# 4                           0.0                         0.0  3.939433e+06
# ..                          ...                         ...           ...
# 657                         0.0                         0.0  2.133155e+08
# 658                         0.0                         0.0  1.745136e+08
# 659                         0.0                         0.0  2.597728e+08
# 660                         0.0                         0.0  1.276974e+08
# 661                         0.0                         0.0  1.535865e+08
#
# [662 rows x 16 columns]

# %%
pred = model.predict(future)
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
pred = pred[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]

# %%
pred
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 0   2020-12-20  6.244949e+06 -3.497831e+08  3.297658e+08
# 1   2020-12-21  2.939550e+07 -3.219045e+08  4.064941e+08
# 2   2020-12-22 -2.175364e+07 -3.817596e+08  3.209672e+08
# 3   2020-12-23  4.811469e+06 -3.499671e+08  3.679148e+08
# 4   2020-12-24  3.939433e+06 -3.505254e+08  3.527253e+08
# ..         ...           ...           ...           ...
# 657 2023-05-01  2.133155e+08 -1.478608e+08  5.645438e+08
# 658 2023-06-01  1.745136e+08 -1.721499e+08  5.265021e+08
# 659 2023-07-01  2.597728e+08 -1.193267e+08  5.974732e+08
# 660 2023-08-01  1.276974e+08 -2.204176e+08  5.028005e+08
# 661 2023-09-01  1.535865e+08 -2.222253e+08  5.093711e+08
#
# [662 rows x 4 columns]

# %%
model.plot(pred)
plt.show()

# %%
data.head()
# Out:
#             SALE_AMT
# SAL_DT
# 2020-12-20  64765180
# 2020-12-21  74824270
# 2020-12-22  66124340
# 2020-12-23  65115330
# 2020-12-24  74519050

# %%
data[:'2022']
# Out:
#              SALE_AMT
# SAL_DT
# 2020-12-20   64765180
# 2020-12-21   74824270
# 2020-12-22   66124340
# 2020-12-23   65115330
# 2020-12-24   74519050
# ...               ...
# 2022-09-26  196120680
# 2022-09-27  195920800
# 2022-09-28  195999820
# 2022-09-29  191564160
# 2022-09-30  490049680
#
# [650 rows x 1 columns]

# %%
new_df = data[:'2022']

# %%
new_df = new_df.reset_index()

# %%
new_df.columns = ['ds', 'y']

# %%
new_df
# Out:
#             ds          y
# 0   2020-12-20   64765180
# 1   2020-12-21   74824270
# 2   2020-12-22   66124340
# 3   2020-12-23   65115330
# 4   2020-12-24   74519050
# ..         ...        ...
# 645 2022-09-26  196120680
# 646 2022-09-27  195920800
# 647 2022-09-28  195999820
# 648 2022-09-29  191564160
# 649 2022-09-30  490049680
#
# [650 rows x 2 columns]

# %%
model = Prophet()

# %%
model.fit(new_df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = model.make_future_dataframe(periods = 12, freq = 'MS') # 예상할 범위 지정

# %%
pred = model.predict(future)
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\min\Anaconda3\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
pred
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2020-12-20  1.828474e+07 -3.261163e+08  3.763275e+08  1.828474e+07
# 1   2020-12-21  1.893486e+07 -3.044537e+08  3.929586e+08  1.893486e+07
# 2   2020-12-22  1.958497e+07 -3.519959e+08  3.395623e+08  1.958497e+07
# 3   2020-12-23  2.023509e+07 -3.332450e+08  3.677405e+08  2.023509e+07
# 4   2020-12-24  2.088521e+07 -3.358560e+08  3.663694e+08  2.088521e+07
# ..         ...           ...           ...           ...           ...
# 657 2023-05-01  2.028549e+08 -1.589711e+08  5.818574e+08  1.664031e+08
# 658 2023-06-01  1.914594e+08 -1.728544e+08  5.556582e+08  1.464094e+08
# 659 2023-07-01  1.804315e+08 -9.343227e+07  6.330807e+08  1.261515e+08
# 660 2023-08-01  1.690360e+08 -2.239507e+08  4.885505e+08  1.066118e+08
# 661 2023-09-01  1.576406e+08 -2.056678e+08  5.308764e+08  8.555016e+07
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    1.828474e+07   -1.203979e+07         -1.203979e+07         -1.203979e+07
# 1    1.893486e+07    1.046065e+07          1.046065e+07          1.046065e+07
# 2    1.958497e+07   -4.133861e+07         -4.133861e+07         -4.133861e+07
# 3    2.023509e+07   -1.542362e+07         -1.542362e+07         -1.542362e+07
# 4    2.088521e+07   -1.694578e+07         -1.694578e+07         -1.694578e+07
# ..            ...             ...                   ...                   ...
# 657  2.385175e+08    1.046065e+07          1.046065e+07          1.046065e+07
# 658  2.351908e+08   -1.694578e+07         -1.694578e+07         -1.694578e+07
# 659  2.325468e+08    7.934123e+07          7.934123e+07          7.934123e+07
# 660  2.320890e+08   -4.133861e+07         -4.133861e+07         -4.133861e+07
# 661  2.328878e+08   -4.054070e+06         -4.054070e+06         -4.054070e+06
#
#            weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0   -1.203979e+07 -1.203979e+07 -1.203979e+07                   0.0
# 1    1.046065e+07  1.046065e+07  1.046065e+07                   0.0
# 2   -4.133861e+07 -4.133861e+07 -4.133861e+07                   0.0
# 3   -1.542362e+07 -1.542362e+07 -1.542362e+07                   0.0
# 4   -1.694578e+07 -1.694578e+07 -1.694578e+07                   0.0
# ..            ...           ...           ...                   ...
# 657  1.046065e+07  1.046065e+07  1.046065e+07                   0.0
# 658 -1.694578e+07 -1.694578e+07 -1.694578e+07                   0.0
# 659  7.934123e+07  7.934123e+07  7.934123e+07                   0.0
# 660 -4.133861e+07 -4.133861e+07 -4.133861e+07                   0.0
# 661 -4.054070e+06 -4.054070e+06 -4.054070e+06                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0  6.244949e+06
# 1                           0.0                         0.0  2.939550e+07
# 2                           0.0                         0.0 -2.175364e+07
# 3                           0.0                         0.0  4.811469e+06
# 4                           0.0                         0.0  3.939433e+06
# ..                          ...                         ...           ...
# 657                         0.0                         0.0  2.133155e+08
# 658                         0.0                         0.0  1.745136e+08
# 659                         0.0                         0.0  2.597728e+08
# 660                         0.0                         0.0  1.276974e+08
# 661                         0.0                         0.0  1.535865e+08
#
# [662 rows x 16 columns]

# %%
pred = pred[['ds', 'yhat']]

# %%
pred.set_index('ds', inplace=True)

# %%
pred = pred['2023':]

# %%
pred
# Out:
#                     yhat
# ds
# 2023-01-01  2.349267e+08
# 2023-02-01  2.201473e+08
# 2023-03-01  2.098546e+08
# 2023-04-01  2.932240e+08
# 2023-05-01  2.133155e+08
# 2023-06-01  1.745136e+08
# 2023-07-01  2.597728e+08
# 2023-08-01  1.276974e+08
# 2023-09-01  1.535865e+08

# %%
data
# Out:
#              SALE_AMT
# SAL_DT
# 2020-12-20   64765180
# 2020-12-21   74824270
# 2020-12-22   66124340
# 2020-12-23   65115330
# 2020-12-24   74519050
# ...               ...
# 2022-09-26  196120680
# 2022-09-27  195920800
# 2022-09-28  195999820
# 2022-09-29  191564160
# 2022-09-30  490049680
#
# [650 rows x 1 columns]

# %%
ax = data.plot()
ax.get_xaxis().get_major_formatter().set_scientific(False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [63], in <cell line: 2>()
#       1 ax = data.plot()
# ----> 2 ax.get_xaxis().get_major_formatter().set_scientific(False)
#
# AttributeError: 'TimeSeries_DateFormatter' object has no attribute 'set_scientific'

# %%
ax = data.plot()
pred.plot(ax=ax, figsize=(20,10))
# ax plot에 pred plot를 겹처서 그리게 하는 파라미터를 추가한다.
