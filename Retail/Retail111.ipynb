# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'cat1014.csv')
df
# Out:
#             SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         20210527  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 1         20210529  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 2         20210529  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 3         20210530  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 4         20210531  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# ...            ...            ...    ...       ...       ...       ...
# 24805738  20220827  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805739  20220828  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805740  20220913  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805741  20220920  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805742  20220922  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
# [24805743 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24805743 entries, 0 to 24805742
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    int64
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  float64
#  4   SALE_PRC  float64
#  5   SALE_AMT  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 1.1+ GB

# %%
df.sort_values('SALE_QTY', ascending=False)
# Out:
#             SAL_DT         PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  \
# 24399828  20210919  2501130000710       소금20kg    9999.0   27000.0
# 24446362  20211106  2599990000117           잡화    9999.0  400000.0
# 24651563  20210919  8802521125819     국순당대박막걸리    9999.0    1000.0
# 24445947  20211106  2599990000100       아이스콘1개    9999.0     900.0
# 24688659  20210919  8809440820009        종이컵박스    9999.0    9900.0
# ...            ...            ...          ...       ...       ...
# 7646456   20220220  8806371303274  푸르밀비피더스블루베리       0.0    3800.0
# 3669817   20210919  8801111941136     크라운죠리퐁번들       0.0    5500.0
# 3669816   20210919  8801111941136     크라운죠리퐁번들       0.0    5500.0
# 3515520   20220629  8801068113525     삼립옥수수꿀호떡       0.0    2700.0
# 2333975   20220113         204219    한돈앞다리살수육용       0.0   13000.0
#
#               SALE_AMT
# 24399828  2.699730e+08
# 24446362  3.999600e+09
# 24651563  9.999000e+06
# 24445947  8.999100e+06
# 24688659  9.899010e+07
# ...

# %%
df.SAL_DT = df.SAL_DT.astype('str')
df.SAL_DT
# Out:
# 0           20210527
# 1           20210529
# 2           20210529
# 3           20210530
# 4           20210531
#               ...
# 24805738    20220827
# 24805739    20220828
# 24805740    20220913
# 24805741    20220920
# 24805742    20220922
# Name: SAL_DT, Length: 24805743, dtype: object

# %%
df.SAL_DT = pd.to_datetime(df.SAL_DT)

df
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0        2021-05-27  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 1        2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 2        2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 3        2021-05-30  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 4        2021-05-31  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# ...             ...            ...    ...       ...       ...       ...
# 24805738 2022-08-27  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805739 2022-08-28  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805740 2022-09-13  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805741 2022-09-20  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805742 2022-09-22  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
# [24805743 rows x 6 columns]

# %%
df = df.astype({'SALE_QTY' : 'int'})

# %%
df = df.astype({'SALE_PRC' : 'int'})

# %%
df = df.astype({'SALE_AMT' : 'int'})

# %%
df['month'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.month
df
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  month
# 0        2021-05-27  8801068097474   땅콩샌드         1      1100      1100      5
# 1        2021-05-29  8801068097474   땅콩샌드         1      1100      1100      5
# 2        2021-05-29  8801068097474   땅콩샌드         1      1100      1100      5
# 3        2021-05-30  8801068097474   땅콩샌드         1      1100      1100      5
# 4        2021-05-31  8801068097474   땅콩샌드         1      1100      1100      5
# ...             ...            ...    ...       ...       ...       ...    ...
# 24805738 2022-08-27  9556486800210   망고푸딩         1      3500      3500      8
# 24805739 2022-08-28  9556486800210   망고푸딩         1      3500      3500      8
# 24805740 2022-09-13  9556486800210   망고푸딩         1      3500      3500      9
# 24805741 2022-09-20  9556486800210   망고푸딩         1      3500      3500      9
# 24805742 2022-09-22  9556486800210   망고푸딩         1      3500      3500      9
#
# ...

# %%
df['weekday'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.weekday
df
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2021-05-27  8801068097474   땅콩샌드         1      1100      1100
# 1        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 2        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 3        2021-05-30  8801068097474   땅콩샌드         1      1100      1100
# 4        2021-05-31  8801068097474   땅콩샌드         1      1100      1100
# ...             ...            ...    ...       ...       ...       ...
# 24805738 2022-08-27  9556486800210   망고푸딩         1      3500      3500
# 24805739 2022-08-28  9556486800210   망고푸딩         1      3500      3500
# 24805740 2022-09-13  9556486800210   망고푸딩         1      3500      3500
# 24805741 2022-09-20  9556486800210   망고푸딩         1      3500      3500
# 24805742 2022-09-22  9556486800210   망고푸딩         1      3500      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24805743 entries, 0 to 24805742
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    datetime64[ns]
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  int32
#  4   SALE_PRC  int32
#  5   SALE_AMT  int32
#  6   month     int64
#  7   weekday   int64
# dtypes: datetime64[ns](1), int32(3), int64(3), object(1)
# memory usage: 1.2+ GB

# %%
df
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2021-05-27  8801068097474   땅콩샌드         1      1100      1100
# 1        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 2        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 3        2021-05-30  8801068097474   땅콩샌드         1      1100      1100
# 4        2021-05-31  8801068097474   땅콩샌드         1      1100      1100
# ...             ...            ...    ...       ...       ...       ...
# 24805738 2022-08-27  9556486800210   망고푸딩         1      3500      3500
# 24805739 2022-08-28  9556486800210   망고푸딩         1      3500      3500
# 24805740 2022-09-13  9556486800210   망고푸딩         1      3500      3500
# 24805741 2022-09-20  9556486800210   망고푸딩         1      3500      3500
# 24805742 2022-09-22  9556486800210   망고푸딩         1      3500      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
# df.to_csv('df1018.csv', index=False)

# %%
df.sort_values('SALE_QTY', ascending=True)
# Out:
#              SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC    SALE_AMT  \
# 6236759  2022-01-20         201033    한우갈비양지         0      6000           0
# 19055295 2021-08-05  8801007054605  CJ1등급목초란         0      5460           0
# 2307128  2022-03-11         204016  한우1등급꽃등심         0     31000           0
# 3660794  2022-05-29  8801111912143  크라운마이쮸사과         0      1200           0
# 3364587  2022-04-18  8801056005221    롯데비타파워         0      5000           0
# ...             ...            ...       ...       ...       ...         ...
# 24445947 2021-11-06  2599990000100    아이스콘1개      9999       900     8999100
# 6163297  2022-04-02         200131     모듬쌈채류      9999    170210  1701929790
# 6163296  2022-04-02         200131     모듬쌈채류      9999    172720  1727027280
# 9579528  2022-04-21  8809517210078     에그탑특란      9999     10000    79792020
# 24446362 2021-11-06  2599990000117        잡화      9999    400000 -2147483648
#
#           month  weekday
# ...

# %%
df2 = df[df['SALE_QTY'] > 0]
df2
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2021-05-27  8801068097474   땅콩샌드         1      1100      1100
# 1        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 2        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 3        2021-05-30  8801068097474   땅콩샌드         1      1100      1100
# 4        2021-05-31  8801068097474   땅콩샌드         1      1100      1100
# ...             ...            ...    ...       ...       ...       ...
# 24805738 2022-08-27  9556486800210   망고푸딩         1      3500      3500
# 24805739 2022-08-28  9556486800210   망고푸딩         1      3500      3500
# 24805740 2022-09-13  9556486800210   망고푸딩         1      3500      3500
# 24805741 2022-09-20  9556486800210   망고푸딩         1      3500      3500
# 24805742 2022-09-22  9556486800210   망고푸딩         1      3500      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df2.sort_values('SALE_PRC', ascending=True)
# Out:
#              SAL_DT         PLU_CD         GDS_NM  SALE_QTY   SALE_PRC  \
# 7914009  2021-09-23              2         사은행사쿠폰         1      -5000
# 2209893  2021-09-12              2         사은행사쿠폰         1      -5000
# 6125382  2021-09-12              2         사은행사쿠폰         1      -5000
# 6125381  2021-09-12              2         사은행사쿠폰         1      -5000
# 2209890  2021-09-12              2         사은행사쿠폰         1      -5000
# ...             ...            ...            ...       ...        ...
# 1110322  2022-08-13  8801051088151  엘자연퐁용기베이킹소다레몬         1  880109440
# 81077    2021-10-18         200047          청상추1봉         1  880306000
# 14669319 2022-03-23         201044             딸기         2  880491120
# 2212025  2022-02-10         200000           청량고추         1  930144000
# 2884339  2021-09-26      520000009           망고스틴         1  941181000
#
#             SALE_AMT  month  weekday
# 7914009        -5000      9        3
# 2209893        -5000      9        6
# ...

# %%
df3 = df2[df2['SALE_PRC'] > 1000]
df3
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2021-05-27  8801068097474   땅콩샌드         1      1100      1100
# 1        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 2        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 3        2021-05-30  8801068097474   땅콩샌드         1      1100      1100
# 4        2021-05-31  8801068097474   땅콩샌드         1      1100      1100
# ...             ...            ...    ...       ...       ...       ...
# 24805738 2022-08-27  9556486800210   망고푸딩         1      3500      3500
# 24805739 2022-08-28  9556486800210   망고푸딩         1      3500      3500
# 24805740 2022-09-13  9556486800210   망고푸딩         1      3500      3500
# 24805741 2022-09-20  9556486800210   망고푸딩         1      3500      3500
# 24805742 2022-09-22  9556486800210   망고푸딩         1      3500      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df3.sort_values('SALE_PRC', ascending=True)
# Out:
#              SAL_DT         PLU_CD         GDS_NM  SALE_QTY   SALE_PRC  \
# 4323830  2021-11-28         201352             섬초         1       1010
# 6134713  2022-09-28         200049            햇감자         1       1010
# 6210883  2022-06-11         200427            흙당근         1       1010
# 4259868  2021-11-24         201153             봄동         1       1010
# 15122590 2021-05-18         201016            흙당근         1       1010
# ...             ...            ...            ...       ...        ...
# 1110322  2022-08-13  8801051088151  엘자연퐁용기베이킹소다레몬         1  880109440
# 81077    2021-10-18         200047          청상추1봉         1  880306000
# 14669319 2022-03-23         201044             딸기         2  880491120
# 2212025  2022-02-10         200000           청량고추         1  930144000
# 2884339  2021-09-26      520000009           망고스틴         1  941181000
#
#             SALE_AMT  month  weekday
# 4323830         1010     11        6
# 6134713         1010      9        2
# ...

# %%
df3.sort_values('SALE_PRC', ascending=False)
# Out:
#              SAL_DT         PLU_CD         GDS_NM  SALE_QTY   SALE_PRC  \
# 2884339  2021-09-26      520000009           망고스틴         1  941181000
# 2212025  2022-02-10         200000           청량고추         1  930144000
# 14669319 2022-03-23         201044             딸기         2  880491120
# 81077    2021-10-18         200047          청상추1봉         1  880306000
# 1110322  2022-08-13  8801051088151  엘자연퐁용기베이킹소다레몬         1  880109440
# ...             ...            ...            ...       ...        ...
# 6205357  2021-10-01         200420          홍청양고추         1       1010
# 6205358  2021-10-01         200420          홍청양고추         1       1010
# 6205360  2021-10-02         200420          홍청양고추         1       1010
# 15160491 2022-06-11         201016            흙당근         1       1010
# 8017089  2022-08-17         201344            흙당근         1       1010
#
#             SALE_AMT  month  weekday
# 2884339    941181000      9        6
# 2212025    930144000      2        3
# ...

# %%
df3.sort_values('SALE_AMT', ascending=True)
# Out:
#              SAL_DT         PLU_CD               GDS_NM  SALE_QTY   SALE_PRC  \
# 24446362 2021-11-06  2599990000117                   잡화      9999     400000
# 13071090 2022-05-24  8809069304010  Dole스위티오후룻볼파인애플198g         1       2500
# 21622063 2021-04-18  8801066010123           대림숯불구이맛김밥햄         1       1100
# 13071136 2022-07-11  8809069304812    Dole스위티오후룻볼망고198g         1       2500
# 13071133 2022-06-02  8809069304812    Dole스위티오후룻볼망고198g         1       2500
# ...             ...            ...                  ...       ...        ...
# 2884339  2021-09-26      520000009                 망고스틴         1  941181000
# 6163295  2022-04-02         200131                모듬쌈채류      9000     176650
# 6163297  2022-04-02         200131                모듬쌈채류      9999     170210
# 6163296  2022-04-02         200131                모듬쌈채류      9999     172720
# 14669319 2022-03-23         201044                   딸기         2  880491120
#
#             SALE_AMT  month  weekday
# ...

# %%
df3.sort_values('SALE_AMT', ascending=False)
# Out:
#              SAL_DT         PLU_CD             GDS_NM  SALE_QTY   SALE_PRC  \
# 14669319 2022-03-23         201044                 딸기         2  880491120
# 6163296  2022-04-02         200131              모듬쌈채류      9999     172720
# 6163297  2022-04-02         200131              모듬쌈채류      9999     170210
# 6163295  2022-04-02         200131              모듬쌈채류      9000     176650
# 2884339  2021-09-26      520000009               망고스틴         1  941181000
# ...             ...            ...                ...       ...        ...
# 13071133 2022-06-02  8809069304812  Dole스위티오후룻볼망고198g         1       2500
# 13071113 2022-06-01  8809069304034       Dole복숭아컵198g         1       2500
# 13071111 2022-05-24  8809069304034       Dole복숭아컵198g         1       2500
# 13635858 2022-08-18  8801858133368       카스라이트1600PET         1       5900
# 24446362 2021-11-06  2599990000117                 잡화      9999     400000
#
#             SALE_AMT  month  weekday
# ...

# %%
df4 = df3[df3['SALE_AMT'] < 90000000]
df4
# Out:
#              SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2021-05-27  8801068097474   땅콩샌드         1      1100      1100
# 1        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 2        2021-05-29  8801068097474   땅콩샌드         1      1100      1100
# 3        2021-05-30  8801068097474   땅콩샌드         1      1100      1100
# 4        2021-05-31  8801068097474   땅콩샌드         1      1100      1100
# ...             ...            ...    ...       ...       ...       ...
# 24805738 2022-08-27  9556486800210   망고푸딩         1      3500      3500
# 24805739 2022-08-28  9556486800210   망고푸딩         1      3500      3500
# 24805740 2022-09-13  9556486800210   망고푸딩         1      3500      3500
# 24805741 2022-09-20  9556486800210   망고푸딩         1      3500      3500
# 24805742 2022-09-22  9556486800210   망고푸딩         1      3500      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df4.sort_values('SALE_AMT', ascending=False)
# Out:
#              SAL_DT         PLU_CD               GDS_NM  SALE_QTY  SALE_PRC  \
# 4579581  2022-03-03       22002853            스치딸기1kg행사      7020     14800
# 6735817  2022-07-04  8801007144641               CJ갈색설탕      9000     14500
# 14729440 2022-06-13       22000539                 제스프리      7723     11400
# 6661250  2022-09-12  2200408605779                샤인머스켓       999     86500
# 6811858  2022-07-04  8801013113136               큐원하얀설탕      9000     11500
# ...             ...            ...                  ...       ...       ...
# 13071111 2022-05-24  8809069304034         Dole복숭아컵198g         1      2500
# 13830146 2022-01-13  2489898980805                양배추1통         5      1500
# 13071136 2022-07-11  8809069304812    Dole스위티오후룻볼망고198g         1      2500
# 13071090 2022-05-24  8809069304010  Dole스위티오후룻볼파인애플198g         1      2500
# 24446362 2021-11-06  2599990000117                   잡화      9999    400000
#
#             SALE_AMT  month  weekday
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
# 재사용봉투20L               375557
# 재사용봉투                  251539
# 대파1단                   127103
# 배달봉투                   105428
# 흙당근                    102456
#                         ...
# 충화반점라구짜장350g                1
# 피코크툭툭누들타이새우팟퐁커리600g         1
# 청정원양조진간장플러스                 1
# 화이트캄파10p                    1
# 루카스나인라떼더블샷                  1
# Name: GDS_NM, Length: 95457, dtype: int64

# %%
data = df.groupby('GDS_NM').sum()
data
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_19396\304229761.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = df.groupby('GDS_NM').sum()
#                            PLU_CD  SALE_QTY  SALE_PRC  SALE_AMT  month  \
# GDS_NM
# 0                               0         1         0         0      9
# 0000              278348505698694        36     60000     67200    207
# 000340000024360      340000024360         1       700       700      6
# 0241405572666        482811145332         3      1800      2700     12
# 030유리뚜껑             9999999004766         1      3800      3800      1
# ...                           ...       ...       ...       ...    ...
# 히포LED파인등기구          8809490841092         1     11500     11500      3
# ...

# %%
df1 = data.reset_index()
df1
# Out:
#                 GDS_NM            PLU_CD  SALE_QTY  SALE_PRC  SALE_AMT  month  \
# 0                    0                 0         1         0         0      9
# 1                 0000   278348505698694        36     60000     67200    207
# 2      000340000024360      340000024360         1       700       700      6
# 3        0241405572666      482811145332         3      1800      2700     12
# 4              030유리뚜껑     9999999004766         1      3800      3800      1
# ...                ...               ...       ...       ...       ...    ...
# 95452       히포LED파인등기구     8809490841092         1     11500     11500      3
# 95453             히핑크림   316840359886776        43    117000    139750    232
# 95454          힐링덕오리훈제  1841190564138552       392   1862640   3001560    923
# 95455         힐링칼라업슬라임   132140089468020        18     30000     36000    102
# 95456        힘센KF94마스크   299528228203868        81     17000     40500    146
#
#        weekday
# 0            3
# ...

# %% [markdown]
# df1.sort_values('SALE_QTY', ascending=True)

# %% [markdown]
# df2 = df1[df1['SALE_QTY'] > 0]
# df2

# %% [markdown]
# df3 = df2[df2['SALE_PRC'] > 0]
# df3

# %% [markdown]
# df4 = df3[df3['SALE_AMT'] > 0]
# df4

# %% [markdown]
# df4.sort_values('SALE_QTY', ascending=False)

# %% [markdown]
# df4['SALE_QTY'].mean()

# %% [markdown]
# df4['SALE_QTY'].median()

# %% [markdown]
# df5 = df4[df4['SALE_QTY'] > 31]
# df5

# %% [markdown]
# df5.sort_values('SALE_AMT', ascending=False).head(100)

# %% [markdown]
# df5.sort_values('SALE_PRC', ascending=False)

# %%
df1[df1['GDS_NM'] == '재사용봉투20L']
# Out:
#          GDS_NM              PLU_CD  SALE_QTY   SALE_PRC   SALE_AMT    month  \
# 66190  재사용봉투20L  922767821743267198    420077  244466650  273685010  2290478
#
#        weekday
# 66190  1171789

# %% [markdown]
# df5 = df4[['GDS_NM']]
# df5

# %%
df2 = df1[['GDS_NM']]
df2
# Out:
#                 GDS_NM
# 0                    0
# 1                 0000
# 2      000340000024360
# 3        0241405572666
# 4              030유리뚜껑
# ...                ...
# 95452       히포LED파인등기구
# 95453             히핑크림
# 95454          힐링덕오리훈제
# 95455         힐링칼라업슬라임
# 95456        힘센KF94마스크
#
# [95457 rows x 1 columns]

# %%
#df2.to_excel('df2gdsnm.xlsx', index=False)

# %%
category = pd.read_excel(base_path + 'category.xlsx')

# %%
category
# Out:
#             대       중       소       세
# 0          과일  국산연중과일      사과      미광
# 1          과일  국산연중과일      사과      조홍
# 2          과일  국산연중과일      사과      서홍
# 3          과일  국산연중과일      사과     아오리
# 4          과일  국산연중과일      사과     썸머킹
# ...       ...     ...     ...     ...
# 3631  소형가전・공구     DIY    기타용품    기타용품
# 3632  소형가전・공구  안전관련용품     소화기     소화기
# 3633  소형가전・공구  안전관련용품    호신용품    호신용품
# 3634  소형가전・공구  안전관련용품     경보기     경보기
# 3635  소형가전・공구  안전관련용품  기타안전용품  기타안전용품
#
# [3636 rows x 4 columns]

# %%
category['대'].value_counts()
# Out:
# 정육            337
# 주방용품          246
# 과일            239
# 채소            236
# 의류잡화          170
# 뷰티            167
# 완구            166
# 소형가전・공구       150
# 소스/양념/조미료     147
# 스포츠레저         131
# 리빙용품          124
# 자동차용품         117
# 수산            117
# 헤어바디구강        114
# 건조식품           92
# 문구             85
# 냉장식품           80
# 냉동             78
# 욕실용품           75
# 과자/대용식         75
# 반려동물           73
# 생수/음료/커피       70
# 화장지/물티슈/위생     63
# 세제             60
# 주류             57
# 김치/반찬          51
# 커피/원두/차        51
# 유아             48
# 통조림/즉석밥        47
# 유제품            46
# 양곡             46
# 라면/면류          29
# 두부/콩나물/계란      29
# 세탁용품           20
# Name: 대, dtype: int64

# %%
category['소'].value_counts()
# Out:
# 기타소형가전            34
# 공구                26
# 부산물               25
# 포도                24
# 생나물               21
# 기타조리도구            20
# 여성의류              20
# 사과                19
# 갈비                18
# 유아동의류             18
# 식기                17
# 남성의류              17
# 데스크용품             16
# 필기도구              16
# 앞다리               15
# 세정제               15
# 노트                15
# 철물                15
# 허브                14
# 전기배선              14
# 냉방/난방가전           14
# 피트니스              14
# 칼                 14
# 수입산갈비             13
# 수입산돼지부산물          13
# 멜론                12
# 미술/제도용품           12
# 수박                12
# 작동완구              12
# 반려묘간식             11
# 젓갈                11
# 냉장면류              11
# 기타용품              11
# 반려견간식             11
# 김                 11
# 잔/컵               11
# 회                 11
# 기타 쌈채소            10
# 낚시                10
# 티백차               10
# 홈베이킹재료            10
# 지갑                10
# 가방                10
# ...

# %%
pd.set_option('display.max_rows', 10000)

# %%
df['GDS_NM'].value_counts().head(10000)
# Out:
# 재사용봉투20L                  375557
# 재사용봉투                     251539
# 대파1단                      127103
# 배달봉투                      105428
# 흙당근                       102456
# 서울우유                       93327
# 감자                         86819
# 종량제재사용봉투20L                78606
# 대파                         77448
# 깻잎5묶음봉                     70839
# 백오이                        70753
# 백오이1개                      67155
# 인큐애호박                      65423
# 참이슬후레쉬                     65169
# 청양고추                       61247
# 양배추                        59195
# 청양고추소                      57384
# 인큐애호박2개행사                  56224
# 적상추1봉비닐                    55414
# 팽이버섯                       53815
# 종량제봉투20L                   52939
# 처음처럼                       52700
# 야채                         52626
# 깐마늘                        51896
# 새송이버섯1봉                    51630
# 바나나                        50927
# 남양맛있는우유GT기획                50727
# 느타리버섯1팩                    49495
# ...

# %%
testdf = df['GDS_NM'].value_counts()
testdf
# Out:
# 재사용봉투20L               375557
# 재사용봉투                  251539
# 대파1단                   127103
# 배달봉투                   105428
# 흙당근                    102456
#                         ...
# 충화반점라구짜장350g                1
# 피코크툭툭누들타이새우팟퐁커리600g         1
# 청정원양조진간장플러스                 1
# 화이트캄파10p                    1
# 루카스나인라떼더블샷                  1
# Name: GDS_NM, Length: 95457, dtype: int64

# %%
testdf = df.value_counts().rename_axis('unique_values').to_frame('counts')
print (testdf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 testdf = df.value_counts().rename_axis('unique_values').to_frame('counts')
#       2 print (testdf)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:330, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     328 @wraps(func)
#     329 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 330     return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# ...

# %%
testdf

# %%
#testdf.to_excel('testdf1018.xlsx', index=False)
