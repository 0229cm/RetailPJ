# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
pd.set_option('display.max_rows', 1000)

# %%
# 제품목록 gds_list_0, gds_list_1
cn = pd.read_csv(base_path + 'cn8801006-2.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
n8 = pd.read_csv(base_path + 'n8801006-2.csv')

# %%
cn
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD              GDS_NM  \
# 0        20210901         71138  8801039939499         해표 더고소한 파래김
# 1        20210901         71138  8801045312316         오뚜기 3분쇠고기카레
# 2        20210901         71138  8801045291314         오뚜기 3분쇠고기짜장
# 3        20210901         71138  8803712127018              목우촌 뚝심
# 4        20210901         71138  8801045890333          오뚜기 맛있는밥기획
# ...           ...           ...            ...                 ...
# 3604699  20220830        132102  8809713911199              바나나 톡톡
# 3604700  20220830        132102  8809713913896         정신차리솟에너지드링크
# 3604701  20220830        164030  8801007029795            가스오+튀김4인
# 3604702  20220830        164030  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인
# 3604703  20220831        220214  8801115382027             스타벅스 돌체
#
#          GDS_CLSS_CD   SALE_AMT
# 0            12301.0   540000.0
# 1            12101.0   360000.0
# 2            12101.0   360000.0
# ...

# %%
cn['GDS_NM'].value_counts()
# Out:
# 서울 우유           31893
# 토속대란 1판         25335
# 처음처럼            23675
# 남양 맛있는우유GT기획    20791
# 참이슬후레쉬          20494
#                 ...
# 그루머츄 연어&참치          1
# 중발1호                1
# 울트라쿠키앤크림(대)         1
# 비비고)  갈치구이          1
# 에프킬라/매트( 무향)        1
# Name: GDS_NM, Length: 26653, dtype: int64

# %%
cn.sort_values(by=["PLU_CD"], ascending=[False]).head(10000)
# Out:
#            SAL_DT  REAL_SAL_TTM             PLU_CD             GDS_NM  \
# 936416   20211121        144433  35104002974014091  35104002974014091
# 1455175  20220820        154956     88097721891617           코디순수데코3겹
# 2924876  20220330        145948     88012520162478         마마손니트릴고무장갑
# 1687954  20220330        145319     88012520162478         마마손니트릴고무장갑
# 2226302  20220615        101511     88011260113507       깨끗한나라 뉴3겹소프트
# ...           ...           ...                ...                ...
# 1942826  20220104        185827      8886013505181                 에낙
# 903134   20220422        105910      8886013505181                 에낙
# 1559526  20211017        154151      8886013505181                 에낙
# 1807034  20220802        180524      8886013505181                 에낙
# 2671329  20211012        110929      8886013505181                 에낙
#
#          GDS_CLSS_CD  SALE_AMT
# 936416      999999.0   10400.0
# 1455175      20501.0   16500.0
# ...

# %%
cn.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD          GDS_NM  GDS_CLSS_CD  \
# 755701   20220704        165216  8800000000206        늘보리쌀(국산)     105152.0
# 2108389  20220704         84814  8800000000206        늘보리쌀(국산)     105152.0
# 2683535  20211210        213758  8800042800550            다용도상      99999.0
# 1004703  20210905        123404  8800042800550            다용도상      99999.0
# 321924   20211211        132405  8800789080000             늘보리     105152.0
# 1921975  20220729        165246  8800789080000             늘보리     105152.0
# 1737122  20220606        153411  8800789080000             늘보리     105152.0
# 1221988  20211229        152124  8800789080000             늘보리     105152.0
# 2908737  20220617        140922  8800789080000             늘보리     105152.0
# 2908736  20220303        165411  8800789080000             늘보리     105152.0
# 435709   20210916        152051  8800789080000             늘보리     105152.0
# ...

# %%
cn0 = cn[cn['PLU_CD'] <= 8800789888880] # 진로.토닉워터 밑으로 찹쌀부터
cn0
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD    GDS_NM  GDS_CLSS_CD  \
# 6811     20220408        141319  8800789155555        현미     105152.0
# 7935     20220517        155227  8800789144443      현미찹쌀     105152.0
# 34845    20210907        155353  8800789499987        현미     105153.0
# 37209    20210913        160310  8800789144443      현미찹쌀     105152.0
# 38798    20210918         95711  8800789800509        약콩     105152.0
# 38960    20210918        155628  8800789080000       늘보리     105152.0
# 41539    20210926        192601  8800789096506       찰보리     105152.0
# 48008    20211106        170447  8800789888880        찹쌀     105152.0
# 48501    20211107        183437  8800789888880        찹쌀     105152.0
# 100181   20220608        180219  8800789888880        찹쌀     105152.0
# 110975   20220718        132231  8800789080000       늘보리     105152.0
# 123053   20210907        194829  8800789144443      현미찹쌀     105152.0
# ...

# %%
cn0.sort_values(by=["PLU_CD"], ascending=[True]).head(1000) # 진로.토닉워터 밑으로 찹쌀부터 확인
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD    GDS_NM  GDS_CLSS_CD  \
# 755701   20220704        165216  8800000000206  늘보리쌀(국산)     105152.0
# 2108389  20220704         84814  8800000000206  늘보리쌀(국산)     105152.0
# 2683535  20211210        213758  8800042800550      다용도상      99999.0
# 1004703  20210905        123404  8800042800550      다용도상      99999.0
# 1659457  20220222        150804  8800789080000       늘보리     105152.0
# 1737122  20220606        153411  8800789080000       늘보리     105152.0
# 384519   20220702        113100  8800789080000       늘보리     105152.0
# 435709   20210916        152051  8800789080000       늘보리     105152.0
# 2847052  20220504        204405  8800789080000       늘보리     105152.0
# 1814203  20211009        132755  8800789080000       늘보리     105152.0
# 2843951  20210924        165652  8800789080000       늘보리     105152.0
# 1221988  20211229        152124  8800789080000       늘보리     105152.0
# ...

# %%
cn1 = cn[cn['PLU_CD'] >= 9788087049099] # 쿨토시
cn1
# Out:
#            SAL_DT  REAL_SAL_TTM             PLU_CD                   GDS_NM  \
# 8848     20220625        133027     29087875454125       *꿀수박 10kg이상/1통(행사)
# 9857     20220807        145636     29087875454125       *꿀수박 10kg이상/1통(행사)
# 9869     20220807        145654     29087875454125       *꿀수박 10kg이상/1통(행사)
# 26707    20220803        182653     29012541305698                 *미니수박 1통
# 46838    20211101        121335     18801551302112              하이썬 부탄가스 박스
# 101349   20220612        182353     29012541305698                 *미니수박 1통
# 103378   20220620        150508     29087875454125       *꿀수박 10kg이상/1통(행사)
# 103895   20220622        164728     29087875454125       *꿀수박 10kg이상/1통(행사)
# 103924   20220622        200817     29087875454125       *꿀수박 10kg이상/1통(행사)
# 104042   20220622        173704     29087875454125       *꿀수박 10kg이상/1통(행사)
# 104501   20220624        211252     29087875454125       *꿀수박 10kg이상/1통(행사)
# ...

# %%
cn1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 8848 to 3604537
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SAL_DT        984 non-null    int64
#  1   REAL_SAL_TTM  984 non-null    int64
#  2   PLU_CD        984 non-null    int64
#  3   GDS_NM        984 non-null    object
#  4   GDS_CLSS_CD   984 non-null    float64
#  5   SALE_AMT      984 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 53.8+ KB

# %%
cn1['GDS_NM'].value_counts()
# Out:
# *꿀수박 10kg이상/1통(행사)         399
# *미니수박 1통                   364
# 화미 물티슈                     100
# *애플수박1통                     45
# 하이썬 부탄가스 박스                 45
# *딱딱한복숭아(풍족)/4.kg/1박스/라벨      8
# 그린매실주통                       6
# 갈대비                          5
# 마마손니트릴고무장갑                   2
# 35104002974014091            1
# 매일)소화가잘되는우유(멸균)              1
#  소화가잘되는우유 초콜릿 190ml x 6      1
# 수수마당비                        1
# 쿠진그라라스실버락                    1
# 쿨토시                          1
# 코디순수데코3겹                     1
# 롯데 종이컵박스                     1
# 깨끗한나라 뉴3겹소프트                 1
# 케이스/동화)까스활명수                 1
# Name: GDS_NM, dtype: int64
