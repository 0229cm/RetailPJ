# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
pd.set_option('display.max_rows', 4000)

# %%
# 제품목록 gds_list_0, gds_list_1
cn = pd.read_csv(base_path + 'cn8801006-2.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
n8 = pd.read_csv(base_path + 'n8801006-2.csv')

# %%
cn # 바코드 880 위
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD              GDS_NM  \
# 0        20210901         71138  8801039939499         해표 더고소한 파래김
# 1        20210901         71138  8801045312316         오뚜기 3분쇠고기카레
# 2        20210901         71138  8801045291314         오뚜기 3분쇠고기짜장
# 3        20210901         71138  8803712127018              목우촌 뚝심
# 4        20210901         71138  8801045890333          오뚜기 맛있는밥기획
# ...           ...           ...            ...                 ...
# 3604699  20220830        132102  8809713911199              바나나 톡톡
# 3604700  20220830        132102  8809713913896         정신차리솟에너지드링크
# 3604701  20220830        164030  8801007029795            가스오+튀김4인
# 3604702  20220830        164030  8801007029795  CJ 가쓰오우동2인+덴푸라우동2인
# 3604703  20220831        220214  8801115382027             스타벅스 돌체
#
#          GDS_CLSS_CD   SALE_AMT
# 0            12301.0   540000.0
# 1            12101.0   360000.0
# 2            12101.0   360000.0
# ...

# %%
n8 # 바코드 880 아래
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD          GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152       구호물품 포장박스      29999.0
# 1        20210901         71138  2908990043169        구호물품 택배비      29999.0
# 2        20210902         73547  2908990043152       구호물품 포장박스      29999.0
# 3        20210902         73547  2908990043169        구호물품 택배비      29999.0
# 4        20210902        185158  2999000001262   *의성햇사과/8입(1봉)      40601.0
# ...           ...           ...            ...             ...          ...
# 2370574  20220823         80114  2599990000780   탐스제로 오렌지600*6      11010.0
# 2370575  20220823         80408  2599990000834        조지아커피6번들      11010.0
# 2370576  20220823         80408  2599990000827       맥스웰마스터6번들      11010.0
# 2370577  20220823         80408  2599990000803  칠성사이다 플러스500*6      11010.0
# 2370578  20220823         82751  2599990000834        조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
cn.sort_values(by=["PLU_CD"], ascending=[False]).head(1000)
# Out:
#            SAL_DT  REAL_SAL_TTM             PLU_CD                   GDS_NM  \
# 936416   20211121        144433  35104002974014091        35104002974014091
# 1455175  20220820        154956     88097721891617                 코디순수데코3겹
# 2924876  20220330        145948     88012520162478               마마손니트릴고무장갑
# 1687954  20220330        145319     88012520162478               마마손니트릴고무장갑
# 2226302  20220615        101511     88011260113507             깨끗한나라 뉴3겹소프트
# 2891971  20211107        122024     67484000003455                쿠진그라라스실버락
# 2927537  20220622        115749     29089900415645                  *애플수박1통
# 552230   20220624        111530     29089900415645                  *애플수박1통
# 552745   20220624        111935     29089900415645                  *애플수박1통
# 2896144  20220621        195206     29089900415645                  *애플수박1통
# 2927539  20220624        180634     29089900415645                  *애플수박1통
# ...

# %%
cn.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD          GDS_NM  GDS_CLSS_CD  \
# 755701   20220704        165216  8800000000206        늘보리쌀(국산)     105152.0
# 2108389  20220704         84814  8800000000206        늘보리쌀(국산)     105152.0
# 2683535  20211210        213758  8800042800550            다용도상      99999.0
# 1004703  20210905        123404  8800042800550            다용도상      99999.0
# 321924   20211211        132405  8800789080000             늘보리     105152.0
# 1921975  20220729        165246  8800789080000             늘보리     105152.0
# 1737122  20220606        153411  8800789080000             늘보리     105152.0
# 1221988  20211229        152124  8800789080000             늘보리     105152.0
# 2908737  20220617        140922  8800789080000             늘보리     105152.0
# 2908736  20220303        165411  8800789080000             늘보리     105152.0
# 435709   20210916        152051  8800789080000             늘보리     105152.0
# ...

# %%
n8.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#            SAL_DT  REAL_SAL_TTM  PLU_CD     GDS_NM  GDS_CLSS_CD     SALE_AMT
# 2332727  20220209        102749       0       간고등어     898989.0       4500.0
# 2332726  20220209        102749       0         동태     898989.0       4500.0
# 2350599  20220111        182121       1  매입에서등록한상품     997979.0       1500.0
# 2216332  20220304        133241       1        배송비     999999.0       2000.0
# 2216333  20220304        133241       1        배송비     999999.0       2000.0
# 2359076  20211025        220240       1  매입에서등록한상품     997979.0       1500.0
# 2216334  20220304        133241       1        배송비     999999.0       2000.0
# 2216336  20220304        133333       1        배송비     999999.0       2000.0
# 2216337  20220304        133333       1        배송비     999999.0       2000.0
# 2216338  20220304        133333       1        배송비     999999.0       2000.0
# 2216339  20220304        133333       1        배송비     999999.0       2000.0
# ...

# %%
n8.sort_values(by=["PLU_CD"], ascending=[True]).head(1000)
# Out:
#            SAL_DT  REAL_SAL_TTM  PLU_CD     GDS_NM  GDS_CLSS_CD     SALE_AMT
# 2332727  20220209        102749       0       간고등어     898989.0       4500.0
# 2332726  20220209        102749       0         동태     898989.0       4500.0
# 2350599  20220111        182121       1  매입에서등록한상품     997979.0       1500.0
# 2216332  20220304        133241       1        배송비     999999.0       2000.0
# 2216333  20220304        133241       1        배송비     999999.0       2000.0
# 2359076  20211025        220240       1  매입에서등록한상품     997979.0       1500.0
# 2216334  20220304        133241       1        배송비     999999.0       2000.0
# 2216336  20220304        133333       1        배송비     999999.0       2000.0
# 2216337  20220304        133333       1        배송비     999999.0       2000.0
# 2216338  20220304        133333       1        배송비     999999.0       2000.0
# 2216339  20220304        133333       1        배송비     999999.0       2000.0
# ...

# %%
n8_1 = n8[~n8['GDS_NM'].str.contains("매입에서등록한상품", na=False, case=False)]

# %%
n8_1.head(500)
# Out:
#        SAL_DT  REAL_SAL_TTM         PLU_CD                   GDS_NM  \
# 0    20210901         71138  2908990043152                구호물품 포장박스
# 1    20210901         71138  2908990043169                 구호물품 택배비
# 2    20210902         73547  2908990043152                구호물품 포장박스
# 3    20210902         73547  2908990043169                 구호물품 택배비
# 4    20210902        185158  2999000001262            *의성햇사과/8입(1봉)
# 5    20210902        185158  2908990004443                쌈배추(벌크)1통
# 6    20210902        185158  2908990003866          *성주꿀참외(특)/6입.1봉
# 7    20210902        185158         351060                대패삼겹살(수입)
# 8    20210902        185158         201447                     거봉포도
# 9    20210902        185158         201447                     거봉포도
# 10   20210903         73908  2908990043152                구호물품 포장박스
# 11   20210903         73908  2908990043169                 구호물품 택배비
# 12   20210903        161025  2908990006874             *꽈리고추 (500g)
# ...

# %%
n8_2 = n8_1[~n8_1['GDS_NM'].str.contains("구호물품 포장박스", na=False, case=False)]

# %%
n8_3 = n8_2[~n8_2['GDS_NM'].str.contains("구호물품 택배비", na=False, case=False)]

# %%
n8_3.head(1000)
# Out:
#         SAL_DT  REAL_SAL_TTM         PLU_CD                   GDS_NM  \
# 0     20210901         71138  2908990043152                구호물품 포장박스
# 2     20210902         73547  2908990043152                구호물품 포장박스
# 4     20210902        185158  2999000001262            *의성햇사과/8입(1봉)
# 5     20210902        185158  2908990004443                쌈배추(벌크)1통
# 6     20210902        185158  2908990003866          *성주꿀참외(특)/6입.1봉
# 7     20210902        185158         351060                대패삼겹살(수입)
# 8     20210902        185158         201447                     거봉포도
# 9     20210902        185158         201447                     거봉포도
# 10    20210903         73908  2908990043152                구호물품 포장박스
# 12    20210903        161025  2908990006874             *꽈리고추 (500g)
# 13    20210903        161025  2908990005082                   *노각 1개
# 14    20210903        161025         201503                      바나나
# 15    20210904         74620  2908990043152                구호물품 포장박스
# ...

# %%
n8_3['GDS_NM'].value_counts().head(4000)
# Out:
# 재사용봉투(20L)                              142551
# *대파 1단                                   64792
# 배달봉투                                     57135
# *깻잎(4묶음)/봉                               39561
# *백오이 1개                                  38042
# 흙당근                                      33614
# 적상추 1봉/비닐                                30120
# *청양고추(소)                                 29863
# *인큐애호박 2개(행사)                            29190
# *느타리버섯 1팩                                27791
# 재사용봉투 -20L                               27091
# 감자                                       25492
# 팽이버섯 1봉                                  21808
# *양파(중) 1망                                20830
# *새송이버섯 1봉                                19871
# *청상추 1봉                                  19475
# *쌈배추(알배기) 1통                             18446
# *가지 5입/봉                                 18322
# *새송이버섯 2봉/1인2봉한정                         18111
# *부추 1단                                   17918
# ...

# %% [markdown]
# 재사용봉투(20L)
# 배달봉투
# 종량20L
# 재사용봉투 - 10L
# 종량10L
# 쓰레기봉투(20L*20)
# 황색봉투(60L)
# 쓰레기봉투(5L*20)
# 음식물스티커(3L)
# 황색봉투(125L)
# 쓰레기봉투(75L)
# 잡화
# 교통카드충전
#
#
#
# 가정용  10L
# 가정용  20L
# 음식물쓰레기봉투(20L)
# 황색봉투(30L)
# 음식물스티커(5L)
# 영업용  50L- 1장
#
# ----------------------고민
#
# 청과(국내산) (고민)
# 야채류(국산) (고민)
# 듀라셀 디럭스알카  (건전지) (고민)
# 질레트 일회용블루3심플 (면도기) (고민)
# 다우니 블루라일락 (세탁용품) (고민)
# 다우니 화이트릴리
# 페브리즈 상쾌한향
# 비식품
# 페브리즈 다우니향
# 종량100L
# 페브리즈 은은한향
# 듀라셀 알카
# 다우니 베리베리바닐라
# 다우니 엑스퍼트실내건조
# 야채류(수입)
# 듀라셀 리튬2032
# 듀라셀 울트라건전지
# *마대-50L
# 오스람(주광색)26w
# 다우니 퍼플 화이트릴리
# 오랄비 잇몸케어
#
#
#
#
#
# 담배류
#
#
# --------------------
#
# 영업용 75L-1장
# 종량50L
# 가정용 5L
# 베스트마트가방

# %%
n8_3['GDS_NM'].value_counts().head(4000)

# %%
n8_3
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152        구호물품 포장박스      29999.0
# 2        20210902         73547  2908990043152        구호물품 포장박스      29999.0
# 4        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 5        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 6        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# ...           ...           ...            ...              ...          ...
# 2370574  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370575  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370576  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370577  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370578  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
n8_3['GDS_NM'].replace('페브리즈', '', regex=True, inplace=True)

# %%
n8_3
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152        구호물품 포장박스      29999.0
# 2        20210902         73547  2908990043152        구호물품 포장박스      29999.0
# 4        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 5        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 6        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# ...           ...           ...            ...              ...          ...
# 2370574  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370575  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370576  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370577  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370578  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
n8_3['GDS_NM'].replace('오랄비', '', regex=True, inplace=True)

# %%
n8_3
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152        구호물품 포장박스      29999.0
# 2        20210902         73547  2908990043152        구호물품 포장박스      29999.0
# 4        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 5        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 6        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# ...           ...           ...            ...              ...          ...
# 2370574  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370575  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370576  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370577  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370578  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
n8_3[n8_3.GDS_NM != '구호물품']
n8_3
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152        구호물품 포장박스      29999.0
# 1        20210902         73547  2908990043152        구호물품 포장박스      29999.0
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
n8_3.reset_index(drop=True, inplace=True)
n8_3
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152        구호물품 포장박스      29999.0
# 1        20210902         73547  2908990043152        구호물품 포장박스      29999.0
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
mask = n8_3['GDS_NM'].isin(['구호물품'])

n8_4 = n8_3[~mask]

# %%
n8_4
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 0        20210901         71138  2908990043152        구호물품 포장박스      29999.0
# 1        20210902         73547  2908990043152        구호물품 포장박스      29999.0
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 0        216000.0
# ...

# %%
n8_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2370520 entries, 0 to 2370519
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   SAL_DT        int64
#  1   REAL_SAL_TTM  int64
#  2   PLU_CD        int64
#  3   GDS_NM        object
#  4   GDS_CLSS_CD   float64
#  5   SALE_AMT      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 108.5+ MB

# %%
n8_4 = n8_3[~n8_3['GDS_NM'].str.contains("구호물품", na=False, case=False)]
n8_4
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
n8_5 = n8_4[~n8_4['GDS_NM'].str.contains("다우니", na=False, case=False)]
n8_5
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
n8_6 = n8_5[~n8_5['GDS_NM'].str.contains("듀라셀 ", na=False, case=False)]
n8_6
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
n8_7 = n8_6[~n8_6['GDS_NM'].str.contains("페브리즈 ", na=False, case=False)]
n8_7
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
n8_8 = n8_7[~n8_7['GDS_NM'].str.contains("오랄비", na=False, case=False)]
n8_8
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
drap = n8_8[n8_8['GDS_NM'].str.contains('오랄비')].index
n8_8.drop(drap, inplace=True)
n8_8
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
drap = n8_8[n8_8['GDS_NM'].str.contains('페브리즈')].index
n8_8.drop(drap, inplace=True)
n8_8
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262    *의성햇사과/8입(1봉)      40601.0
# 3        20210902        185158  2908990004443        쌈배추(벌크)1통      30101.0
# 4        20210902        185158  2908990003866  *성주꿀참외(특)/6입.1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살(수입)      52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600*6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500*6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
n8_8['GDS_NM']= n8_8['GDS_NM'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
n8_8['GDS_NM']
# Out:
# 2             의성햇사과 8입 1봉
# 3                쌈배추 벌크 1통
# 4           성주꿀참외 특  6입 1봉
# 5                대패삼겹살 수입
# 6                     거봉포도
#                 ...
# 2370515      탐스제로 오렌지600 6
# 2370516           조지아커피6번들
# 2370517          맥스웰마스터6번들
# 2370518     칠성사이다 플러스500 6
# 2370519           조지아커피6번들
# Name: GDS_NM, Length: 2364880, dtype: object

# %%
n8_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2364880 entries, 2 to 2370519
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   SAL_DT        int64
#  1   REAL_SAL_TTM  int64
#  2   PLU_CD        int64
#  3   GDS_NM        object
#  4   GDS_CLSS_CD   float64
#  5   SALE_AMT      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 206.3+ MB

# %%
drap = n8_8[n8_8['GDS_NM'].str.contains('오랄비')].index
n8_8.drop(drap, inplace=True)
n8_8
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262     의성햇사과 8입 1봉       40601.0
# 3        20210902        185158  2908990004443        쌈배추 벌크 1통      30101.0
# 4        20210902        185158  2908990003866   성주꿀참외 특  6입 1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살 수입       52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600 6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500 6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
drrop = n8_8[(n8_8['GDS_NM'] == '오랄비') | (n8_8['GDS_NM'] == '듀라셀')].index
new = n8_8.drop(drrop)
new
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262     의성햇사과 8입 1봉       40601.0
# 3        20210902        185158  2908990004443        쌈배추 벌크 1통      30101.0
# 4        20210902        185158  2908990003866   성주꿀참외 특  6입 1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살 수입       52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600 6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500 6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
drrop = n8_8[(n8_8['GDS_NM'] == '오랄비') | (n8_8['GDS_NM'] == '듀라셀') | (n8_8['GDS_NM'] == '재사용')].index
new = n8_8.drop(drrop)
new
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262     의성햇사과 8입 1봉       40601.0
# 3        20210902        185158  2908990004443        쌈배추 벌크 1통      30101.0
# 4        20210902        185158  2908990003866   성주꿀참외 특  6입 1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살 수입       52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600 6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500 6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
drrop = new[(new['GDS_NM'] == '재사용') | (new['GDS_NM'] == '배달봉투') | (new['GDS_NM'] == '음식물')].index
new1 = n8_8.drop(drrop)
new1
# Out:
#            SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  GDS_CLSS_CD  \
# 2        20210902        185158  2999000001262     의성햇사과 8입 1봉       40601.0
# 3        20210902        185158  2908990004443        쌈배추 벌크 1통      30101.0
# 4        20210902        185158  2908990003866   성주꿀참외 특  6입 1봉      40101.0
# 5        20210902        185158         351060        대패삼겹살 수입       52599.0
# 6        20210902        185158         201447             거봉포도      40702.0
# ...           ...           ...            ...              ...          ...
# 2370515  20220823         80114  2599990000780    탐스제로 오렌지600 6      11010.0
# 2370516  20220823         80408  2599990000834         조지아커피6번들      11010.0
# 2370517  20220823         80408  2599990000827        맥스웰마스터6번들      11010.0
# 2370518  20220823         80408  2599990000803   칠성사이다 플러스500 6      11010.0
# 2370519  20220823         82751  2599990000834         조지아커피6번들      11010.0
#
#          SALE_AMT
# 2          9960.0
# ...

# %%
new1['GDS_NM'].value_counts().head(4000)
# Out:
# 재사용봉투 20L                               142551
#  대파 1단                                   64792
#  깻잎 4묶음  봉                               39561
#  백오이 1개                                  38042
# 흙당근                                      33614
# 적상추 1봉 비닐                                30120
#  청양고추 소                                  29863
#  인큐애호박 2개 행사                             29190
#  느타리버섯 1팩                                27791
# 재사용봉투  20L                               27091
# 감자                                       25492
# 팽이버섯 1봉                                  21808
#  양파 중  1망                                20830
#  새송이버섯 1봉                                19871
#  청상추 1봉                                  19475
#  쌈배추 알배기  1통                             18446
#  가지 5입 봉                                 18322
#  새송이버섯 2봉 1인2봉한정                         18111
#  부추 1단                                   17918
# 국내산돈앞다리살                                 17692
# ...
