# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df21011_2.csv')
df
# Out:
#              GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0              0000  2021-09-11         1    1800.0      1800
# 1              0000  2021-09-28         3    1800.0      5400
# 2              0000  2021-12-05         1    1800.0      1800
# 3              0000  2021-12-13         1    1800.0      1800
# 4              0000  2022-01-07         1    1800.0      1800
# ...             ...         ...       ...       ...       ...
# 1776826    히츨러수수깡캔디  2021-10-08         1    3500.0      3500
# 1776827    히츨러수수깡캔디  2021-10-14         1    3500.0      3500
# 1776828    히츨러수수깡캔디  2021-12-03         2    3500.0      7000
# 1776829    히츨러수수깡캔디  2021-12-04         2    3500.0      7000
# 1776830  히포LED파인등기구  2022-03-03         1   11500.0     11500
#
# [1776831 rows x 5 columns]

# %%
df.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#                    GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 1100633        오뚜기컵밥춘천닭갈비  2022-08-05         0    3350.0         0
# 1103035        오뚜기콩국수라면멀티  2021-12-06         0    5780.0         0
# 1472427               콩기름  2022-05-17         0   20600.0         0
# 1773631        흑마늘힐링덕훈제오리  2022-08-21         0    9900.0         0
# 1773571        흑마늘힐링덕훈제오리  2022-05-24         0    7900.0         0
# 1248671             제주용암수  2021-09-05         0    8000.0         0
# 1146977           오리온오징어톡  2021-10-26         0    2100.0         0
# 1636164         피지파워젤오리지널  2022-04-04         0   13200.0         0
# 1707727           해태에이스샌드  2022-01-18         0    1200.0         0
# 247959           농심수미칩어니언  2022-07-02         0    1980.0         0
# 1773314  흑대추방울토마토500g1팩행사  2022-02-08         0    4980.0         0
# 1335915        청정원가쓰오우동2인  2022-04-24         0    6200.0         0
# 82525        CJ햄스빌두툼한굿베이컨  2022-03-21         0    7000.0         0
# ...

# %%
df
# Out:
#              GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0              0000  2021-09-11         1    1800.0      1800
# 1              0000  2021-09-28         3    1800.0      5400
# 2              0000  2021-12-05         1    1800.0      1800
# 3              0000  2021-12-13         1    1800.0      1800
# 4              0000  2022-01-07         1    1800.0      1800
# ...             ...         ...       ...       ...       ...
# 1776826    히츨러수수깡캔디  2021-10-08         1    3500.0      3500
# 1776827    히츨러수수깡캔디  2021-10-14         1    3500.0      3500
# 1776828    히츨러수수깡캔디  2021-12-03         2    3500.0      7000
# 1776829    히츨러수수깡캔디  2021-12-04         2    3500.0      7000
# 1776830  히포LED파인등기구  2022-03-03         1   11500.0     11500
#
# [1776831 rows x 5 columns]

# %%
df = df[df.SALE_QTY > 1]

# %%
df
# Out:
#                 GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 1                 0000  2021-09-28         3    1800.0      5400
# 15                0000  2022-05-26         2    3600.0      3600
# 19                0000  2022-07-28         2    1800.0      3600
# 21                0000  2022-08-14         2    1800.0      3600
# 23       0241405572666  2022-06-22         2     900.0      1800
# ...                ...         ...       ...       ...       ...
# 1776816       히츨러수수깡캔디  2021-09-01         2    7000.0      7000
# 1776817       히츨러수수깡캔디  2021-09-06         2    7000.0      7000
# 1776825       히츨러수수깡캔디  2021-09-26         2    7000.0      7000
# 1776828       히츨러수수깡캔디  2021-12-03         2    3500.0      7000
# 1776829       히츨러수수깡캔디  2021-12-04         2    3500.0      7000
#
# [943752 rows x 5 columns]

# %%
df.sort_values('SALE_QTY', ascending=True).head(50)
# Out:
#                GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 1776829      히츨러수수깡캔디  2021-12-04         2    3500.0      7000
# 1151331      오리온촉촉초코칩  2021-11-15         2    5960.0      5960
# 1151332      오리온촉촉초코칩  2021-11-16         2    5960.0      5960
# 1151341      오리온촉촉초코칩  2021-12-12         2    5960.0      5960
# 482336    롯데빼빼로3번들꼬아크  2022-04-05         2    5960.0      5960
# 1151347      오리온촉촉초코칩  2021-12-19         2    5960.0      5960
# 482331    롯데빼빼로3번들꼬아크  2022-03-31         2    5960.0      5960
# 1151349      오리온촉촉초코칩  2021-12-22         2    5960.0      5960
# 1151355      오리온촉촉초코칩  2021-12-30         2    5960.0      5960
# 1151330      오리온촉촉초코칩  2021-11-14         2    5960.0      5960
# 1151360      오리온촉촉초코칩  2022-01-04         2    5960.0      5960
# 1151363      오리온촉촉초코칩  2022-01-07         2    5960.0      5960
# 482317    롯데빼빼로3번들꼬아크  2022-03-16         2    5960.0      5960
# 482314    롯데빼빼로3번들꼬아크  2022-03-13         2    5960.0      5960
# ...

# %%
df.sort_values('SALE_QTY', ascending=False).head(50)
# Out:
#                 GDS_NM      SAL_DT  SALE_QTY   SALE_PRC    SALE_AMT
# 951798          아이스콘1개  2021-11-06     10999     1800.0     9899100
# 173047        국순당대박막걸리  2021-09-19     10003     4000.0    10003000
# 1234603             잡화  2021-11-06     10003   407900.0 -2147475748
# 1268064          종이컵박스  2021-09-19     10000    19800.0    99000000
# 875599          소금20kg  2021-09-19      9999    27000.0   269973000
# 847179         서울우유18ℓ  2021-11-26      9001    11600.0    52205800
# 657780             배송비  2022-03-04      8000        4.0        8000
# 952159       아이스크림바10개  2022-06-18      7962     2000.0     3981000
# 297518            달래1단  2022-02-10      7414    69000.0     7414000
# 701981            베지밀B  2021-10-31      7258    32900.0   107406900
# 939513        쓰레기봉투50L  2021-10-06      7075     6160.0    10895500
# 865364      성경구운김밥김10매  2021-10-15      5001     4100.0    10252050
# 877666            소주공병  2022-01-25      4968     3600.0      496800
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
# 남양프로바이오틱포도      366
# 흙당근             366
# 남양맛있는우유GT기획     366
# 청경채             366
# 인큐애호박           366
#                ...
# 맛간장국찌개용930ml      1
# 데톨핸드오리지날          1
# 금강양은냄비            1
# 프레고소시지앤갈릭         1
# 튀김전용유18L          1
# Name: GDS_NM, Length: 22576, dtype: int64

# %%
df.to_csv('df21011_3.csv', index=False)

# %%
df
# Out:
#                 GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 1                 0000  2021-09-28         3    1800.0      5400
# 15                0000  2022-05-26         2    3600.0      3600
# 19                0000  2022-07-28         2    1800.0      3600
# 21                0000  2022-08-14         2    1800.0      3600
# 23       0241405572666  2022-06-22         2     900.0      1800
# ...                ...         ...       ...       ...       ...
# 1776816       히츨러수수깡캔디  2021-09-01         2    7000.0      7000
# 1776817       히츨러수수깡캔디  2021-09-06         2    7000.0      7000
# 1776825       히츨러수수깡캔디  2021-09-26         2    7000.0      7000
# 1776828       히츨러수수깡캔디  2021-12-03         2    3500.0      7000
# 1776829       히츨러수수깡캔디  2021-12-04         2    3500.0      7000
#
# [943752 rows x 5 columns]

# %%
df['SALE_QTY'].max()
# Out:
# 10999

# %%
df['SALE_QTY'].min()
# Out:
# 3

# %%
df['SALE_QTY'].mean()
# Out:
# 8.113217243513127

# %%
df['SALE_QTY'].median()
# Out:
# 3.0

# %%
df = df[df.SALE_QTY > 2]

# %%
df
# Out:
#               GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 1               0000  2021-09-28         3    1800.0      5400
# 37       10001200청량초  2021-11-13         5    3000.0      5000
# 38       10001200청량초  2021-11-14         3    2000.0      3000
# 39       10001200청량초  2021-11-18         3    2000.0      3000
# 65       10001200청량초  2022-03-20         3    1000.0      3000
# ...              ...         ...       ...       ...       ...
# 1776773       히츠퍼플라벨  2022-07-26         4    9000.0     18000
# 1776775       히츠퍼플라벨  2022-07-30         4    9000.0     18000
# 1776783       히츠퍼플라벨  2022-08-09         4    9000.0     18000
# 1776793       히츠퍼플라벨  2022-08-23         4    9000.0     18000
# 1776796       히츠퍼플라벨  2022-08-26         3    9000.0     13500
#
# [609070 rows x 5 columns]

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace(r'[0-9]+', repl=r'')
# Out:
# <ipython-input-23-d66f946a4fd9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GDS_NM'] = df['GDS_NM'].str.replace(r'[0-9]+', repl=r'')

# %%
df
# Out:
#          GDS_NM      SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 1                2021-09-28         3    1800.0      5400
# 37          청량초  2021-11-13         5    3000.0      5000
# 38          청량초  2021-11-14         3    2000.0      3000
# 39          청량초  2021-11-18         3    2000.0      3000
# 65          청량초  2022-03-20         3    1000.0      3000
# ...         ...         ...       ...       ...       ...
# 1776773  히츠퍼플라벨  2022-07-26         4    9000.0     18000
# 1776775  히츠퍼플라벨  2022-07-30         4    9000.0     18000
# 1776783  히츠퍼플라벨  2022-08-09         4    9000.0     18000
# 1776793  히츠퍼플라벨  2022-08-23         4    9000.0     18000
# 1776796  히츠퍼플라벨  2022-08-26         3    9000.0     13500
#
# [609070 rows x 5 columns]

# %%
df.to_csv('df21011_4.csv', index=False)
