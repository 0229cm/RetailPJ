# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
path=''
gds_a = pd.read_csv(path+'gds_a.csv')
gds_b = pd.read_csv(path+'gds_b.csv')
gds_c = pd.read_csv(path+'gds_c.csv')
gds_d = pd.read_csv(path+'gds_d.csv')
gdsclss_1 = pd.read_csv(base_path + 'gdsclss_list_1.csv')
tr_list_a = pd.read_csv(path+'tr_list_a.csv')
tr_list_b = pd.read_csv(path+'tr_list_b.csv')
tr_list_c = pd.read_csv(path+'tr_list_c.csv')
tr_list_d = pd.read_csv(path+'tr_list_d.csv')
tr_dtl_list_a = pd.read_csv(path+'tr_dtl_list_a.csv')
tr_dtl_list_b = pd.read_csv(path+'tr_dtl_list_b.csv')
tr_dtl_list_c = pd.read_csv(path+'tr_dtl_list_c.csv')
tr_dtl_list_d = pd.read_csv(path+'tr_dtl_list_d.csv')

# %%
a_mer = pd.merge(tr_dtl_list_c[['STR_CD', 'SAL_DT','SEQ_NO', 'PLU_CD']],gds_c[['STR_CD', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD', 'GDS_TP_NM']])
a_mer
# Out:
#        STR_CD    SAL_DT  SEQ_NO         PLU_CD         GDS_NM  GDS_CLSS_CD  \
# 0      142011  20210901       1  8801097250048         포카리스웨트       999999
# 1      142011  20210903       1  8801097250048         포카리스웨트       999999
# 2      142011  20210903       1  8801097250048         포카리스웨트       999999
# 3      142011  20210903       1  8801097250048         포카리스웨트       999999
# 4      142011  20210905       2  8801097250048         포카리스웨트       999999
# ...       ...       ...     ...            ...            ...          ...
# 91855  142011  20220901       5  8801019611391       허니버터칩(대)       999999
# 91856  142011  20220901       6  8801019611261       허니버터칩88g       999999
# 91857  142011  20220901       1  8801062866663  8801062866663       999999
# 91858  142011  20220901       2  8801062866670  8801062866670       999999
# 91859  142011  20220901       8  8801133000583      머거본후렌치아몬드       999999
#
#       GDS_TP_NM
# 0            일반
# 1            일반
# 2            일반
# 3            일반
# 4            일반
# ...         ...
# 91855        일반
# 91856        일반
# 91857        일반
# 91858        일반
# 91859        일반
#
# [91860 rows x 7 columns]

# %%
a_mer.columns
# Out:
# Index(['STR_CD', 'SAL_DT', 'SEQ_NO', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD',
#        'GDS_TP_NM'],
#       dtype='object')

# %%
gdsclss_1
# Out:
#        CO_CD  STR_CD  GDS_CLSS_CD GDS_CLSS_NM  GDS_CLSS_LVL_TP  \
# 0    1001993       0            1       식 품 류                1
# 1    1001993       0          101        가공식품                2
# 2    1001993       0        10101        가공식품                3
# 3    1001993       0        10199     기타-가공식품                3
# 4    1001993       0          102       식 용 유                2
# ..       ...     ...          ...         ...              ...
# 362  1002056       0           99         미등록                1
# 363  1002056       0         9979   임시핸디매입등록용                2
# 364  1002056       0       997979   임시핸디매입등록용                3
# 365  1002056       0         9999         미등록                2
# 366  1002056       0       999999         미등록                3
#
#      UP_GDS_CLSS_CD  GDS_CLSS_GRP_TP
# 0                 0                1
# 1                 1                1
# 2               101                1
# 3               101                1
# 4                 1                1
# ..              ...              ...
# 362               0                1
# 363              99                1
# 364            9979                1
# 365              99                1
# 366            9999                1
#
# [367 rows x 7 columns]

# %%
gdsclss_1['STR_CD'].value_counts()
# Out:
# 0    367
# Name: STR_CD, dtype: int64

# %%
b_mer = pd.merge(a_mer[['STR_CD', 'SAL_DT', 'SEQ_NO', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD', 'GDS_TP_NM']],gdsclss_1[['GDS_CLSS_CD', 'GDS_CLSS_NM']])
b_mer
# Out:
#         STR_CD    SAL_DT  SEQ_NO         PLU_CD       GDS_NM  GDS_CLSS_CD  \
# 0       142011  20210901       1  8801097250048       포카리스웨트       999999
# 1       142011  20210901       1  8801097250048       포카리스웨트       999999
# 2       142011  20210903       1  8801097250048       포카리스웨트       999999
# 3       142011  20210903       1  8801097250048       포카리스웨트       999999
# 4       142011  20210903       1  8801097250048       포카리스웨트       999999
# ...        ...       ...     ...            ...          ...          ...
# 169179  142011  20220729       9  8801074256605  한성크래미H90g32        10501
# 169180  142011  20220731       2  8801074256605  한성크래미H90g32        10501
# 169181  142011  20220831       4  8801074256605  한성크래미H90g32        10501
# 169182  142011  20220831       5  8801074256605  한성크래미H90g32        10501
# 169183  142011  20220901       9  8801074256605  한성크래미H90g32        10501
#
#        GDS_TP_NM GDS_CLSS_NM
# 0             일반     기타미 분 류
# 1             일반         미등록
# 2             일반     기타미 분 류
# 3             일반         미등록
# 4             일반     기타미 분 류
# ...          ...         ...
# 169179        일반       냉장/냉동
# 169180        일반       냉장/냉동
# 169181        일반       냉장/냉동
# 169182        일반       냉장/냉동
# 169183        일반       냉장/냉동
#
# [169184 rows x 8 columns]

# %%
b_mer.columns
# Out:
# Index(['STR_CD', 'SAL_DT', 'SEQ_NO', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD',
#        'GDS_TP_NM', 'GDS_CLSS_NM'],
#       dtype='object')

# %%
test = pd.read_csv(base_path + 'test0928.csv')
test
# Out:
#                 GDS_NM  hour  month  day  SALE_QTY
# 0               메가촉 초코     8      9    1       2.0
# 1               메가촉 초코     8      9    6       1.0
# 2               메가촉 초코     8     10    5       1.0
# 3               메가촉 초코    10     10    5       1.0
# 4               메가촉 초코    11      9    6       1.0
# ...                ...   ...    ...  ...       ...
# 4237060  히말라야핑크솔트플로럴민트    10      7    1       1.0
# 4237061  히말라야핑크솔트플로럴민트    13      4    6       1.0
# 4237062  히말라야핑크솔트플로럴민트    17      5    6       1.0
# 4237063  히말라야핑크솔트플로럴민트    18      8    5       1.0
# 4237064  히말라야핑크솔트플로럴민트    18     12    3       1.0
#
# [4237065 rows x 5 columns]

# %%
test['GDS_NM'].value_counts()
# Out:
# 재사용봉투 20L         104752
#  대파 1단             55670
# 배달봉투               51688
#  깻잎 4묶음  봉         33217
#  백오이 1개            32161
#                    ...
# 정통보리식초                 1
# CJ더건강한햄페퍼 갈릭           1
# 롯데 알파벳변신로봇 LS          1
# 폰티나 올리브유               1
# 자연으로돌아가는위생롤백           1
# Name: GDS_NM, Length: 13430, dtype: int64

# %%
test['GDS_NM'].describe()
# Out:
# count        4237065
# unique         13430
# top       재사용봉투 20L
# freq          104752
# Name: GDS_NM, dtype: object

# %%
name = test['GDS_NM'].value_counts()
name
# Out:
# 재사용봉투 20L         104752
#  대파 1단             55670
# 배달봉투               51688
#  깻잎 4묶음  봉         33217
#  백오이 1개            32161
#                    ...
# 정통보리식초                 1
# CJ더건강한햄페퍼 갈릭           1
# 롯데 알파벳변신로봇 LS          1
# 폰티나 올리브유               1
# 자연으로돌아가는위생롤백           1
# Name: GDS_NM, Length: 13430, dtype: int64

# %%
name.plot.barh(figsize=(15,50), grid = True)
# Out:
# <AxesSubplot:>
