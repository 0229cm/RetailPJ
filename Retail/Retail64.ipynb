# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df3_1_10_11.csv')
df
# Out:
#            GDS_NM    SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0        스니커즈피넛싱글  20210904         1      1100      1100
# 1        스니커즈피넛싱글  20210907         2      1100      2200
# 2        스니커즈피넛싱글  20210910         1      1100      1100
# 3        스니커즈피넛싱글  20210910         1      1100      1100
# 4        스니커즈피넛싱글  20210910         1      1100      1100
# ...           ...       ...       ...       ...       ...
# 6379513       갈대비  20211007         1      4200      4200
# 6379514       갈대비  20211102         1      4200      4200
# 6379515       갈대비  20220118         1      4200      4200
# 6379516       갈대비  20220118         1      4200      4200
# 6379517       갈대비  20220316         1      4200      4200
#
# [6379518 rows x 5 columns]

# %%
df['SALE_QTY'].median()
# Out:
# 1.0

# %%
df['SALE_QTY'].mean()
# Out:
# 1.331060434346294

# %%
df1 = df.groupby(['GDS_NM', 'SAL_DT']).sum()
df1
# Out:
#                      SALE_QTY  SALE_PRC  SALE_AMT
# GDS_NM     SAL_DT
# 0000       20210911         1      1800      1800
#            20210928         3      1800      5400
#            20211205         1      1800      1800
#            20211213         1      1800      1800
#            20220107         1      1800      1800
# ...                       ...       ...       ...
# 히츨러수수깡캔디   20211008         1      3500      3500
#            20211014         1      3500      3500
#            20211203         2      3500      7000
#            20211204         2      3500      7000
# 히포LED파인등기구 20220303         1     11500     11500
#
# [1777927 rows x 3 columns]

# %%
df
# Out:
#            GDS_NM    SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0        스니커즈피넛싱글  20210904         1      1100      1100
# 1        스니커즈피넛싱글  20210907         2      1100      2200
# 2        스니커즈피넛싱글  20210910         1      1100      1100
# 3        스니커즈피넛싱글  20210910         1      1100      1100
# 4        스니커즈피넛싱글  20210910         1      1100      1100
# ...           ...       ...       ...       ...       ...
# 6379513       갈대비  20211007         1      4200      4200
# 6379514       갈대비  20211102         1      4200      4200
# 6379515       갈대비  20220118         1      4200      4200
# 6379516       갈대비  20220118         1      4200      4200
# 6379517       갈대비  20220316         1      4200      4200
#
# [6379518 rows x 5 columns]

# %%
df.groupby('GDS_NM').get_group('히츨러수수깡캔디')
# Out:
#            GDS_NM    SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 5317733  히츨러수수깡캔디  20210901         1      3500      3500
# 5317734  히츨러수수깡캔디  20210901         1      3500      3500
# 5317735  히츨러수수깡캔디  20210906         1      3500      3500
# 5317736  히츨러수수깡캔디  20210906         1      3500      3500
# 5317737  히츨러수수깡캔디  20210908         1      3500      3500
# 5317738  히츨러수수깡캔디  20210909         1      3500      3500
# 5317739  히츨러수수깡캔디  20210915         1      3500      3500
# 5317740  히츨러수수깡캔디  20210918         1      3500      3500
# 5317741  히츨러수수깡캔디  20210919         1      3500      3500
# 5317742  히츨러수수깡캔디  20210920         1      3500      3500
# 5317743  히츨러수수깡캔디  20210924         1      3500      3500
# 5317744  히츨러수수깡캔디  20210926         1      3500      3500
# 5317745  히츨러수수깡캔디  20210926         1      3500      3500
# 5317746  히츨러수수깡캔디  20211008         1      3500      3500
# 5317747  히츨러수수깡캔디  20211014         1      3500      3500
# 5317748  히츨러수수깡캔디  20211203         2      3500      7000
# 5317749  히츨러수수깡캔디  20211204         2      3500      7000

# %%
df
# Out:
#            GDS_NM    SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0        스니커즈피넛싱글  20210904         1      1100      1100
# 1        스니커즈피넛싱글  20210907         2      1100      2200
# 2        스니커즈피넛싱글  20210910         1      1100      1100
# 3        스니커즈피넛싱글  20210910         1      1100      1100
# 4        스니커즈피넛싱글  20210910         1      1100      1100
# ...           ...       ...       ...       ...       ...
# 6379513       갈대비  20211007         1      4200      4200
# 6379514       갈대비  20211102         1      4200      4200
# 6379515       갈대비  20220118         1      4200      4200
# 6379516       갈대비  20220118         1      4200      4200
# 6379517       갈대비  20220316         1      4200      4200
#
# [6379518 rows x 5 columns]

# %%
x = df[df['GDS_NM'].str.contains('스니커즈피넛싱글')]
x
# Out:
#            GDS_NM    SAL_DT  SALE_QTY  SALE_PRC  SALE_AMT
# 0        스니커즈피넛싱글  20210904         1      1100      1100
# 1        스니커즈피넛싱글  20210907         2      1100      2200
# 2        스니커즈피넛싱글  20210910         1      1100      1100
# 3        스니커즈피넛싱글  20210910         1      1100      1100
# 4        스니커즈피넛싱글  20210910         1      1100      1100
# ...           ...       ...       ...       ...       ...
# 6379513  스니커즈피넛싱글  20211007         1      4200      4200
# 6379514  스니커즈피넛싱글  20211102         1      4200      4200
# 6379515  스니커즈피넛싱글  20220118         1      4200      4200
# 6379516  스니커즈피넛싱글  20220118         1      4200      4200
# 6379517  스니커즈피넛싱글  20220316         1      4200      4200
#
# [6379518 rows x 5 columns]

# %%
y = df['SALE_AMT']
y
# Out:
# 0          1100
# 1          2200
# 2          1100
# 3          1100
# 4          1100
#            ...
# 6379513    4200
# 6379514    4200
# 6379515    4200
# 6379516    4200
# 6379517    4200
# Name: SALE_AMT, Length: 6379518, dtype: int64

# %%
plt.plot(x, y)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-466c2af60390> in <module>
# ----> 1 plt.plot(x, y)
#       2 plt.show
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     491
#     492         if self.axes.xaxis is not None:
# --> 493             self.axes.xaxis.update_units(x)
#     494         if self.axes.yaxis is not None:
#     495             self.axes.yaxis.update_units(y)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     223         # check if convertible to number:
#     224         convertible = True
# --> 225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
#     227             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'
