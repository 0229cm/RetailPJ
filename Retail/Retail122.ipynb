# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'df1019_1.csv')

# %%
data = df.copy()
data
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-07-24              0     황도복숭아         1      5980      5980
# 1         2021-07-24              0     황도복숭아         1      5980      5980
# 2         2021-07-24              0     황도복숭아         1      5980      5980
# 3         2021-07-24              0     황도복숭아         1      5980      5980
# 4         2021-07-24              0     황도복숭아         1      5980      5980
# ...              ...            ...       ...       ...       ...       ...
# 13084836  2022-09-29  8809267390136  서라벌특란30구         1      7800      7800
# 13084837  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13084838  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 13084839  2022-09-30  8809267390136  서라벌특란30구         2      7800     15600
# 13084840  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
#
#           month  weekday        대분류   소분류
# 0             7        5         과일   복숭아
# 1             7        5         과일   복숭아
# 2             7        5         과일   복숭아
# 3             7        5         과일   복숭아
# 4             7        5         과일   복숭아
# ...         ...      ...        ...   ...
# 13084836      9        3  두부/콩나물/계란  일반계란
# 13084837      9        4  두부/콩나물/계란  일반계란
# 13084838      9        4  두부/콩나물/계란  일반계란
# 13084839      9        4  두부/콩나물/계란  일반계란
# 13084840      9        4  두부/콩나물/계란  일반계란
#
# [13084841 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# 두 가지 feature를 대상
data = df[['SALE_QTY', 'SALE_AMT']]

# 정규화 진행
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(data)

# %%
from sklearn.cluster import KMeans

k = 5

# 그룹 수, random_state 설정
model = KMeans(n_clusters = k, random_state = 10)

# 정규화된 데이터에 학습
model.fit(data_scale)

# 클러스터링 결과 각 데이터가 몇 번째 그룹에 속하는지 저장
df['cluster'] = model.fit_predict(data_scale)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 8))

for i in range(k):
    plt.scatter(df.loc[df['cluster'] == i, 'SALE_QTY'], df.loc[df['cluster'] == i, 'SALE_AMT'], 
                label = 'cluster ' + str(i))
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
plt.legend()
plt.title('K = %d results'%k , size = 15)
plt.xlabel('SALE_QTY', size = 12)
plt.ylabel('SALE_AMT', size = 12)
plt.show()
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_6668\3005184690.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
