# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# a 마트 gds+list+dtl
amartsum = pd.read_csv(base_path + 'amartsum.csv')
amartsum
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# ...

# %%
amartsum.SAL_DT = amartsum.SAL_DT.astype('str')

# %%
amartsum.REAL_SAL_DT = amartsum.REAL_SAL_DT.astype('str')

# %%
amartsum.REAL_SAL_TTM = amartsum.REAL_SAL_TTM.astype('str')

# %%
amartsum.SAL_DT = pd.to_datetime(amartsum.SAL_DT)

# %%
t1 = amartsum['REAL_SAL_TTM'].astype(str).str.zfill(6)
amartsum['REAL_SAL_TTM'] = pd.to_datetime(t1, format='%H%M%S').dt.time

print (amartsum)
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0       2021-09-01   12018     01        3       1            정상판매
# 1       2021-09-01   12018     01        3       2            정상판매
# 2       2021-09-01   12018     01        3       3            정상판매
# 3       2021-09-01   12018     01        3       4            정상판매
# 4       2021-09-01   12018     01        3       5            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 4968529 2022-09-01   12018      7      175       1            정상판매
# 4968530 2022-09-01   12018      7      242       1            정상판매
# 4968531 2022-09-01   12018      7      245       1            정상판매
# 4968532 2022-09-01   12018      7      385       1            정상판매
# 4968533 2022-09-01   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
amartsum['hour'] = pd.to_datetime(amartsum['REAL_SAL_TTM'], format='%H:%M:%S').dt.hour
amartsum
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0       2021-09-01   12018     01        3       1            정상판매
# 1       2021-09-01   12018     01        3       2            정상판매
# 2       2021-09-01   12018     01        3       3            정상판매
# 3       2021-09-01   12018     01        3       4            정상판매
# 4       2021-09-01   12018     01        3       5            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 4968529 2022-09-01   12018      7      175       1            정상판매
# 4968530 2022-09-01   12018      7      242       1            정상판매
# 4968531 2022-09-01   12018      7      245       1            정상판매
# 4968532 2022-09-01   12018      7      385       1            정상판매
# 4968533 2022-09-01   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
amartsum.head(50)
# Out:
#        SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  SALE_RTN_SGN  \
# 0  2021-09-01   12018     01        3       1            정상판매             1
# 1  2021-09-01   12018     01        3       2            정상판매             1
# 2  2021-09-01   12018     01        3       3            정상판매             1
# 3  2021-09-01   12018     01        3       4            정상판매             1
# 4  2021-09-01   12018     01        3       5            정상판매             1
# 5  2021-09-01   12018     01        3       6            정상판매             1
# 6  2021-09-01   12018     01        3       7            정상판매             1
# 7  2021-09-01   12018     01        3       8            정상판매             1
# 8  2021-09-01   12018     01        3       9            정상판매             1
# 9  2021-09-01   12018     01        3      10            정상판매             1
# 10 2021-09-01   12018     01        3      11            정상판매             1
# ...

# %%
amartsum.sort_values('SALE_QTY', ascending=False).head(50)
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 7440    2022-02-17   12018     01        5       5            정상판매
# 7359    2022-02-15   12018     01        3       5            정상판매
# 7439    2022-02-17   12018     01        5      15            정상판매
# 7434    2022-02-17   12018     01        5      11            정상판매
# 7428    2022-02-17   12018     01        5       4            정상판매
# 7427    2022-02-17   12018     01        5       3            정상판매
# 6726    2022-01-25   12018     02        3       4            정상판매
# 4858703 2021-10-18   12018     07      393       1            정상판매
# 4858702 2021-10-18   12018     07      392       1            정상판매
# 6741    2022-01-26   12018     01        6       4            정상판매
# 1773    2021-10-13   12018     01        9       2            정상판매
# 1781    2021-10-13   12018     01        9      15            정상판매
# 1774    2021-10-13   12018     01        9       3            정상판매
# ...

# %%
amartsum.isnull().sum()
# Out:
# SAL_DT                  0
# STR_CD                  0
# POS_NO                  0
# TRAN_NO                 0
# SEQ_NO                  0
# DESI_CNCL_TP_NM         0
# SALE_RTN_SGN            0
# PLU_CD                  0
# GDS_CLSS_CD             0
# SALE_QTY                0
# SALE_PRC                0
# SALE_AMT                0
# GDS_NM                  0
# SALE_KIND_TP_NM         0
# REAL_SAL_DT             0
# REAL_SAL_TTM            0
# PAY_AMT                 0
# MSHP_ID            688555
# hour                    0
# dtype: int64

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 19 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           datetime64[ns]
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      object
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
#  18  hour             int64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(7)
# memory usage: 720.2+ MB

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 19 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           datetime64[ns]
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      object
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
#  18  hour             int64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(7)
# memory usage: 720.2+ MB

# %%
amartsum
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0       2021-09-01   12018     01        3       1            정상판매
# 1       2021-09-01   12018     01        3       2            정상판매
# 2       2021-09-01   12018     01        3       3            정상판매
# 3       2021-09-01   12018     01        3       4            정상판매
# 4       2021-09-01   12018     01        3       5            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 4968529 2022-09-01   12018      7      175       1            정상판매
# 4968530 2022-09-01   12018      7      242       1            정상판매
# 4968531 2022-09-01   12018      7      245       1            정상판매
# 4968532 2022-09-01   12018      7      385       1            정상판매
# 4968533 2022-09-01   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
amartsum['GDS_CLSS_CD'].value_counts()
# Out:
# 30201.0     308741
# 30101.0     260754
# 30702.0     181424
# 11502.0     179839
# 159999.0    158610
#              ...
# 93004.0          7
# 12900.0          5
# 91117.0          2
# 11364.0          2
# 91102.0          1
# Name: GDS_CLSS_CD, Length: 330, dtype: int64

# %%
test1 = amartsum.groupby('hour')['GDS_NM'].count()
test1
# Out:
# hour
# 5         23
# 6       2957
# 7      17734
# 8      50708
# 9     132917
# 10    280625
# 11    373160
# 12    391502
# 13    402508
# 14    442707
# 15    522335
# 16    568225
# 17    555699
# 18    499291
# 19    350578
# 20    259178
# 21    118387
# Name: GDS_NM, dtype: int64

# %% [markdown]
# ## a마트의 카테고리도 추가한 test 데이터

# %%
test = amartsum.groupby(['SAL_DT', 'TRAN_NO', 'hour', 'SALE_AMT','GDS_CLSS_CD'])['GDS_NM'].apply(list)
test
# Out:
# SAL_DT      TRAN_NO  hour  SALE_AMT  GDS_CLSS_CD
# 2021-09-01  1        10    1000.0    30201.0                     [*청양고추(소)]
#                            1280.0    30702.0                       [*대파 1단]
#                            2500.0    30201.0        [*꽈리고추 (500g), *백오이 3개]
#                            2850.0    12560.0                    [CJ 안심김밥맛살]
#                            2980.0    30702.0                       [*양파(소)]
#                                                              ...
# 2022-09-01  689      21    12450.0   20901.0                    [죽염 시린고 치약]
#             690      21    1200.0    12573.0               [CJ 양념이잘배는찌개두부 ]
#             691      21    9800.0    40601.0                      [홍로사과/8개]
#             692      21    1950.0    30201.0                      [*단호박 1개]
#                            11800.0   30101.0                      [*청상추 1봉]
# Name: GDS_NM, Length: 4774183, dtype: object

# %%
test = test.to_frame()
test
# Out:
#                                                                GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT GDS_CLSS_CD
# 2021-09-01 1       10   1000.0   30201.0                   [*청양고추(소)]
#                         1280.0   30702.0                     [*대파 1단]
#                         2500.0   30201.0      [*꽈리고추 (500g), *백오이 3개]
#                         2850.0   12560.0                  [CJ 안심김밥맛살]
#                         2980.0   30702.0                     [*양파(소)]
# ...                                                               ...
# 2022-09-01 689     21   12450.0  20901.0                  [죽염 시린고 치약]
#            690     21   1200.0   12573.0             [CJ 양념이잘배는찌개두부 ]
#            691     21   9800.0   40601.0                    [홍로사과/8개]
#            692     21   1950.0   30201.0                    [*단호박 1개]
#                         11800.0  30101.0                    [*청상추 1봉]
#
# [4774183 rows x 1 columns]

# %%
amartsumgr1 = amartsum.groupby(['SAL_DT', 'TRAN_NO', 'hour', 'SALE_AMT'])['GDS_NM'].apply(list)
amartsumgr1
# Out:
# SAL_DT      TRAN_NO  hour  SALE_AMT
# 2021-09-01  1        10    1000.0                   [*청양고추(소)]
#                            1280.0                     [*대파 1단]
#                            2500.0      [*꽈리고추 (500g), *백오이 3개]
#                            2850.0                  [CJ 안심김밥맛살]
#                            2980.0                     [*양파(소)]
#                                                 ...
# 2022-09-01  689      21    12450.0                 [죽염 시린고 치약]
#             690      21    1200.0             [CJ 양념이잘배는찌개두부 ]
#             691      21    9800.0                    [홍로사과/8개]
#             692      21    1950.0                    [*단호박 1개]
#                            11800.0                   [*청상추 1봉]
# Name: GDS_NM, Length: 4495149, dtype: object

# %%
# amartsumgr1.to_csv('amartsumgr1.csv', index = False)

# %%
amartsumgr1.head(30)
# Out:
# SAL_DT      TRAN_NO  hour  SALE_AMT
# 2021-09-01  1        10    1000.0                                          [*청양고추(소)]
#                            1280.0                                            [*대파 1단]
#                            2500.0                             [*꽈리고추 (500g), *백오이 3개]
#                            2850.0                                         [CJ 안심김밥맛살]
#                            2980.0                                            [*양파(소)]
#                            3750.0                                         [농심 신라면 멀티]
#                            4890.0                                         [오리온 후레쉬베리]
#                            5980.0                                      [롯데 카스타드 오리지날]
#                            19800.0                                    [*송산포도 3kg/1박스]
#             2        10    1000.0                                 [*청양고추(소), 팽이버섯 1봉]
# ...

# %%
amartsumgr1 = amartsumgr1.to_frame()
amartsumgr1
# Out:
#                                                    GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 1       10   1000.0                 [*청양고추(소)]
#                         1280.0                   [*대파 1단]
#                         2500.0    [*꽈리고추 (500g), *백오이 3개]
#                         2850.0                [CJ 안심김밥맛살]
#                         2980.0                   [*양파(소)]
# ...                                                   ...
# 2022-09-01 689     21   12450.0               [죽염 시린고 치약]
#            690     21   1200.0           [CJ 양념이잘배는찌개두부 ]
#            691     21   9800.0                  [홍로사과/8개]
#            692     21   1950.0                  [*단호박 1개]
#                         11800.0                 [*청상추 1봉]
#
# [4495149 rows x 1 columns]

# %%
amartsumgr1
# Out:
#                                                    GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 1       10   1000.0                 [*청양고추(소)]
#                         1280.0                   [*대파 1단]
#                         2500.0    [*꽈리고추 (500g), *백오이 3개]
#                         2850.0                [CJ 안심김밥맛살]
#                         2980.0                   [*양파(소)]
# ...                                                   ...
# 2022-09-01 689     21   12450.0               [죽염 시린고 치약]
#            690     21   1200.0           [CJ 양념이잘배는찌개두부 ]
#            691     21   9800.0                  [홍로사과/8개]
#            692     21   1950.0                  [*단호박 1개]
#                         11800.0                 [*청상추 1봉]
#
# [4495149 rows x 1 columns]

# %%
targer_month = 9
amartsumgr1.query('SAL_DT.dt.month == @targer_month')
# Out:
#                                                    GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 1       10   1000.0                 [*청양고추(소)]
#                         1280.0                   [*대파 1단]
#                         2500.0    [*꽈리고추 (500g), *백오이 3개]
#                         2850.0                [CJ 안심김밥맛살]
#                         2980.0                   [*양파(소)]
# ...                                                   ...
# 2022-09-01 689     21   12450.0               [죽염 시린고 치약]
#            690     21   1200.0           [CJ 양념이잘배는찌개두부 ]
#            691     21   9800.0                  [홍로사과/8개]
#            692     21   1950.0                  [*단호박 1개]
#                         11800.0                 [*청상추 1봉]
#
# [431269 rows x 1 columns]

# %%
targer_month = 10
amartsumgr1.query('SAL_DT.dt.month == @targer_month')
# Out:
#                                                   GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-10-01 1       10   850.0                [농심 육개장사발면]
#                         890.0               [농심 튀김우동큰사발]
#                         980.0     [*수입산)브로컬리 2송이구입시(행사)]
#                         990.0           [CJ 양념이잘배는찌개두부 ]
#                         1000.0         [*부추 1단, *백오이 3개]
# ...                                                  ...
# 2021-10-31 638     21   5480.0            [롯데 맛있는비엔나소시지]
#                         10200.0               [양념 목살왕구이]
#            639     21   980.0                 [*아보카도/1개]
#                         2980.0             [*델몬트바나나/1송이]
#            640     21   1750.0             [삼립 아침엔밀크토스트]
#
# [385341 rows x 1 columns]

# %%
targer_month = 11
amartsumgr1.query('SAL_DT.dt.month == @targer_month')
# Out:
#                                                 GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-11-01 1       9    0.0       [백설/요리올리고당, 동원 카놀라유]
#                         1100.0                [초야마늘가루]
#                         1200.0                   [순두부]
#                         1500.0       [*무우 1개(봉)(투명비닐)]
#                         1980.0    [남양 이오기획, *하우스팩귤/1팩]
# ...                                                ...
# 2021-11-30 528     20   5000.0           [*감귤(벌크)/13개]
#            529     20   3480.0                 [코카 순수]
#                         14800.0         [*토마토/5kg/1박스]
#            530     20   1250.0                [농심꿀꽈배기]
#            531     20   6980.0        [*감귤(2S)5kg/1박스]
#
# [364804 rows x 1 columns]

# %%
amartsumgr1.query('SAL_DT.dt.dayofweek == 0') # 월
# Out:
#                                                        GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-06 1       11   1350.0    [서울 비요뜨 초코팝, 서울 비요뜨 초코크리스피]
#                         2500.0                      [백설 갈색설탕]
#                         2980.0                       [*양파(소)]
#                         3980.0                     [송학 감자수제비]
#                         4380.0                   [오뚜기 진짬뽕 멀티]
# ...                                                       ...
# 2022-08-29 658     21   1000.0                       [서주 빵뚜르]
#                         1200.0                        [바밤바샌드]
#            659     21   1250.0                [*수입산)브로컬리 1송이]
#                         3950.0                      [*청상추 1봉]
#            660     21   10850.0                    [농심 우와한콩칩]
#
# [618767 rows x 1 columns]

# %%
amartsumgr1.query('SAL_DT.dt.dayofweek == 4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-332cd79e1c2b> in <module>
# ----> 1 amartsumgr1.query('SAL_DT.dt.dayofweek == 4')
#
# NameError: name 'amartsumgr1' is not defined

# %%
amartsumgr1.query('SAL_DT.dt.dayofweek == 5')
# Out:
#                                                         GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-04 1       10   1980.0                           [죠리퐁]
#                         2480.0    [남양 프로바이오틱 사과, 남양 프로바이오틱 포도]
#                         3980.0                   [빙그레 바나나우유기획]
#                         4900.0                    [CJ비비고/사골곰탕]
#                         5960.0                      [CJ명가 재래김]
# ...                                                        ...
# 2022-08-27 624     21   2560.0                    [콘트라베이스디카페인]
#                         2980.0                    [해태 스낵4번들기획]
#                         3480.0                        [삼립 보름달]
#                         4240.0                      [롯데 미니크런키]
#            625     21   4500.0                      [*청양고추 1k]
#
# [757202 rows x 1 columns]

# %%
amartsumgr1.query('SAL_DT.dt.dayofweek == 6') # 일
# Out:
#                                                 GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-05 1       11   980.0        [*무우 1개(봉)(투명비닐)]
#                         990.0           [청정원 숨쉬는전통콩나물]
#                         1480.0                [*대파 1단]
#                         2850.0         [오뚜기 진라면 매운 멀티]
#                         3960.0         [CJ 명가김 재래김 식탁]
# ...                                                ...
# 2022-08-28 685     21   3680.0          [농심 사천짜파게티 멀티]
#                         3980.0               [코카콜라 제로]
#            686     21   2600.0    [오뚜기 쉐이크핫케이크믹스 오리지널]
#                         2900.0                 [서울 우유]
#                         3480.0             [삼립 따베패스츄리]
#
# [745108 rows x 1 columns]

# %% [markdown]
# ## 이 부분은 내가 임의로 정하겠음.
# ### 오전 7시부터 찍혀있던걸로 기억하는데 6시를 기준으로
# ### 오전 6시 ~ 오전 10시 : 이른 오전
# ### 오전 10시 ~ 오후 2시 : 이른 오후
# ### 오후 2시 ~ 오후 7시 : 저녁
# ###  오후 7시 ~ 마감시간 : 늦은 저녁
#
# ## 이렇게 예상하는 이유는 해당 시간에 대하여 판매를 기대하는 상품이 다를 것임. 예상되는 판매내역.
# ## 아침(빵이나 유제품류, 달걀, 채소) 점심(일반적인 장 볼 때 제품)
# ## 저녁(저녁거리 및 주류) , 밤(주류, 안주거리 혹은 다음날 아침거리)

# %%
# pd.set_option('display.max_row', 300)

# %%
amartsumgr1.query('hour == 6')
# Out:
#                                          GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 3       6    400.0       [롯데 레쓰비마일드]
#            4       6    1900.0        [진주 천하장사]
# 2021-09-02 3       6    400.0       [롯데 레쓰비마일드]
#            4       6    990.0     [풀무원  소가찌개두부]
#                         1500.0          [공주알밤술]
# ...                                         ...
# 2022-09-01 7       6    450.0       [롯데 레쓰비마일드]
#            8       6    5200.0     [빙그레 바나나맛우유]
#            9       6    3600.0     [해태 구론산스파클링]
#            10      6    2700.0         [강릉초당두부]
#                         5480.0      [청정원 장아찌소스]
#
# [2810 rows x 1 columns]

# %%
amartsumgr1.query('hour == 5')

# %%
amartsumgr1.query('hour == 6').head(300)
# Out:
#                                                               GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 3       6    400.0                            [롯데 레쓰비마일드]
#            4       6    1900.0                             [진주 천하장사]
# 2021-09-02 3       6    400.0                            [롯데 레쓰비마일드]
#            4       6    990.0                          [풀무원  소가찌개두부]
#                         1500.0                               [공주알밤술]
#            5       6    2580.0                          [롯데 자일리톨 리필]
#                         6150.0                            [과탄산소다표백제]
#            6       6    2700.0                              [강릉초당두부]
#                         5000.0                         [풀무원 씻어나온콩나물]
#            7       6    1700.0                               [서울 우유]
#            8       6    990.0                             [대림 구운마늘햄]
#                         1500.0                   [행복한콩/2가지로만 국산콩부침용]
# ...

# %%
amartsumgr1.query('hour == 7')
# Out:
#                                                                           GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 3       7    990.0                                        [동원 골든스위트콘]
#                         2150.0                                         [청정원 맛소금]
#                         216000.0                                     [구호물품 포장박스]
#                         360000.0  [오뚜기 3분쇠고기카레, 오뚜기 3분쇠고기짜장, 종가집 볶음김치캔, 종가집 김치캔]
#                         450000.0                                 [오뚜기 진라면 순한 멀티]
# ...                                                                          ...
# 2022-09-01 15      7    3500.0                               [쑥갓, *호박고구마 1봉(비닐)]
#                         3950.0                                       [*쪽파(소) 1단]
#                         6500.0                                         [토속대란 1판]
#                         8900.0                                       [*알타리무 1박스]
# ...

# %%
amartsumgr1.query('hour == 10')
# Out:
#                                                     GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 1       10   1000.0                  [*청양고추(소)]
#                         1280.0                    [*대파 1단]
#                         2500.0     [*꽈리고추 (500g), *백오이 3개]
#                         2850.0                 [CJ 안심김밥맛살]
#                         2980.0                    [*양파(소)]
# ...                                                    ...
# 2022-09-01 139     10   5300.0                    [썬 부탄가스]
#            140     10   3980.0    [오리온 팝크랜베리, 오그래놀라팝현미아몬드]
#                         4980.0                  [맛간장조림볶음용]
#            141     10   5500.0                  [*쪽파(대)1단]
#            142     10   750.0                 [재사용봉투(20L)]
#
# [253713 rows x 1 columns]

# %%
amartsumgr1.query('hour == 14')
# Out:
#                                                        GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 12      14   980.0                     [*느타리버섯 2팩]
#                         3960.0                      [*양배추 1통]
#                         5960.0                 [가지 5개(벌크)/행사]
#                         7000.0                   [해표 올리브유김자반]
#                         11800.0          [칠곡자두(왕)5kg/1박스(행사)]
# ...                                                       ...
# 2022-09-01 295     14   1760.0                          [흙당근]
#                         1980.0    [크라운 마이쮸딸기 번들, 크라운 마이쮸사과번들]
#                         2530.0                           [감자]
#                         2950.0                    [*양파(중) 1망]
#                         9800.0                      [*홍고추 1봉]
#
# [399897 rows x 1 columns]

# %%
amartsumgr1.query('hour == 17')
# Out:
#                                                  GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-01 20      17   2500.0               [*청양고추 1k]
#                         15800.0             [*양파 15kg/]
#                         19600.0            [농심 사리면 BOX]
#                         24000.0              [*대파(10단)]
#            38      17   620.0              [재사용봉투(20L)]
# ...                                                 ...
# 2022-09-01 471     17   3500.0               [롯데 칠성사이다]
#                         3900.0             [오뚜기 육개장컵기획]
#                         3980.0    [CJ 햇자른당면, LG 자연퐁 솔잎]
#                         4980.0             [크라운 국희 2번들]
#                         10800.0     [퍼실파워젤일반, 코디)뉴테코3겹]
#
# [503123 rows x 1 columns]

# %% [markdown]
# -----------------------------------

# %%
amartsumgr1monday = amartsumgr1.query('SAL_DT.dt.dayofweek == 0') # 월요일 데이터만
amartsumgr1monday
# Out:
#                                                        GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-06 1       11   1350.0    [서울 비요뜨 초코팝, 서울 비요뜨 초코크리스피]
#                         2500.0                      [백설 갈색설탕]
#                         2980.0                       [*양파(소)]
#                         3980.0                     [송학 감자수제비]
#                         4380.0                   [오뚜기 진짬뽕 멀티]
# ...                                                       ...
# 2022-08-29 658     21   1000.0                       [서주 빵뚜르]
#                         1200.0                        [바밤바샌드]
#            659     21   1250.0                [*수입산)브로컬리 1송이]
#                         3950.0                      [*청상추 1봉]
#            660     21   10850.0                    [농심 우와한콩칩]
#
# [618767 rows x 1 columns]

# %%
amartsumgr1monday.query('hour == 6').head(30) # 월요일 데이터 중 6시만
# Out:
#                                                GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-06 3       6    1200.0      [롯데 칸타타 아이스아메리카노]
#                         1400.0            [푸드마크 암반얼음]
#                         4980.0          [*양배추(4*5)1망]
#            4       6    4980.0                 [명품사과]
#            5       6    2960.0      [*무우 1개(봉)(투명비닐)]
# 2021-09-13 3       6    1990.0            [서울 스타벅스라떼]
#            4       6    2250.0                 [박카스F]
#            5       6    950.0                [CJ 맛소금]
#                         9500.0             [(현미)찰고추장]
# 2021-09-20 3       6    2650.0                [칠성사이다]
#                         2700.0             [롯데 제로사이다]
#                         2980.0               [*대파 1단]
#            4       6    980.0             [동부묵  400g]
#                         1500.0     [알배기/쌈배추, 알배기/쌈배추]
#                         1960.0              [알배기/쌈배추]
#                         1980.0    [CJ 튀김가루, 오뚜기 튀김가루]
# ...

# %%
amartsumgr1monday['GDS_NM'].value_counts() # 월요일 기준 제일 많이 팔린 것
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [재사용봉투(20L)]                     17904
# [배달봉투]                            6990
# [*대파 1단]                          6195
# [*백오이 1개]                         4656
# [흙당근]                             4593
#                                  ...
# [애경 순샘 레몬 파우치, 필라이트]                 1
# [삼양라면 멀티, 청정원 두번달여더진한 진간장 ]          1
# [CJ더건강한직화구이햄, 해표 고소한참기름]             1
# [조미어채, 좋은세상 통산자]                     1
# ...

# %%
amartsumgr1Tue = amartsumgr1.query('SAL_DT.dt.dayofweek == 1') # 화요일 데이터만
amartsumgr1Tue
# Out:
#                                                      GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-07 1       10   1980.0            [*대파 1단, 롯데 초코파이]
#                         3980.0    [남양 맛있는우유GT기획, *양파(중) 1망]
#                         5900.0                  [오뚜기 옛날다시마]
#                         12400.0                      [돈삼겹살]
#                         13500.0              [풀무원 항생제통통신선란]
# ...                                                     ...
# 2022-08-30 582     21   3500.0                        [바나나]
#                         5200.0                 [빙그레 바나나맛우유]
#                         7980.0                    [풀무원 목초란]
#            583     21   3980.0               [소와나무 고칼슘우유기획]
#            584     21   1950.0                   [*고구마순 1단]
#
# [565333 rows x 1 columns]

# %%
amartsumgr1Tue['GDS_NM'].value_counts() # 화요일 기준 제일 많이 팔린 것
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [재사용봉투(20L)]                                                            16687
# [*대파 1단]                                                                 6709
# [배달봉투]                                                                   6458
# [서울 우유]                                                                  4121
# [흙당근]                                                                    4063
# ...

# %%
amartsumgr1Tue.query('TRAN_NO == 1').head(30)
# Out:
#                                                                              GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT
# 2021-09-07 1       10   1980.0                                    [*대파 1단, 롯데 초코파이]
#                         3980.0                            [남양 맛있는우유GT기획, *양파(중) 1망]
#                         5900.0                                          [오뚜기 옛날다시마]
#                         12400.0                                              [돈삼겹살]
#                         13500.0                                      [풀무원 항생제통통신선란]
# 2021-09-14 1       11   700.0                                     [*무우 1개(봉)(투명비닐)]
#                         980.0                                             [오양 파티맛살]
#                         990.0                                       [남양 프렌치카페 카푸치노]
#                         1900.0                                             [CJ 맛소금]
#                         1980.0    [*새송이버섯 1봉, *깻잎(4묶음)/봉, 쏘피 천연코튼라이너 일반라벤더, CJ 부...
# ...

# %% [markdown]
# ## 월별 요일별 시간별 어떤 상품이 가장 많이 팔렸는데 알고싶은데 방법 찾는중

# %% [markdown]
# ## 회원번호로 매칭을 해볼까 했는데 a 마트만 회원번호가 있고 bcd 는 의미가없음 아예 없는 매장도 있고 의미있는 추출이 불가능 이라는 결론
