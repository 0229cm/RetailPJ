# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df1007.csv')

# %%
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD      GDS_NM  GDS_CLSS_CD  \
# 0        2021-09-02        185158  2999000001262   의성햇사과8입1봉      40601.0
# 1        2021-09-02        185158  2908990004443     쌈배추벌크1통      30101.0
# 2        2021-09-02        185158  2908990003866  성주꿀참외특6입1봉      40101.0
# 3        2021-09-02        185158         351060     대패삼겹살수입      52599.0
# 4        2021-09-02        185158         201447        거봉포도      40702.0
# ...             ...           ...            ...         ...          ...
# 2079019  2022-04-29        202815  8800789888880          찹쌀     105152.0
# 2079020  2022-07-13        152301  8800789888880          찹쌀     105152.0
# 2079021  2021-11-21        143020  8800789080000         늘보리     105152.0
# 2079022  2022-03-03        165411  8800789080000         늘보리     105152.0
# 2079023  2022-06-17        140922  8800789080000         늘보리     105152.0
#
#          SALE_AMT
# 0            9960
# 1            1980
# 2            9800
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파1단       64792
# 깻잎4묶음봉     39561
# 백오이1개      38042
# 흙당근        33614
# 적상추1봉비닐    30120
#            ...
# 제주감굴           1
# 활도미회           1
# 페리에플레인         1
# 생채끝등심          1
# 츄파춥스쥬라기        1
# Name: GDS_NM, Length: 2716, dtype: int64

# %%
df.head(50)
# Out:
#         SAL_DT  REAL_SAL_TTM         PLU_CD       GDS_NM  GDS_CLSS_CD  \
# 0   2021-09-02        185158  2999000001262    의성햇사과8입1봉      40601.0
# 1   2021-09-02        185158  2908990004443      쌈배추벌크1통      30101.0
# 2   2021-09-02        185158  2908990003866   성주꿀참외특6입1봉      40101.0
# 3   2021-09-02        185158         351060      대패삼겹살수입      52599.0
# 4   2021-09-02        185158         201447         거봉포도      40702.0
# 5   2021-09-02        185158         201447         거봉포도      40702.0
# 6   2021-09-03        161025  2908990006874     꽈리고추500g      30201.0
# 7   2021-09-03        161025  2908990005082         노각1개      30201.0
# 8   2021-09-03        161025         201503          바나나      40501.0
# 9   2021-09-04        122335         201007          고구마      30202.0
# 10  2021-09-04        122335  2901458741254  햇홍로사과8개8개1봉      40601.0
# 11  2021-09-04        122335  2909441428856       양파특대1망      30702.0
# ...

# %%
df['GDS_NM'].nunique()
# Out:
# 2716

# %%
df['month'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.month
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD      GDS_NM  GDS_CLSS_CD  \
# 0        2021-09-02        185158  2999000001262   의성햇사과8입1봉      40601.0
# 1        2021-09-02        185158  2908990004443     쌈배추벌크1통      30101.0
# 2        2021-09-02        185158  2908990003866  성주꿀참외특6입1봉      40101.0
# 3        2021-09-02        185158         351060     대패삼겹살수입      52599.0
# 4        2021-09-02        185158         201447        거봉포도      40702.0
# ...             ...           ...            ...         ...          ...
# 2079019  2022-04-29        202815  8800789888880          찹쌀     105152.0
# 2079020  2022-07-13        152301  8800789888880          찹쌀     105152.0
# 2079021  2021-11-21        143020  8800789080000         늘보리     105152.0
# 2079022  2022-03-03        165411  8800789080000         늘보리     105152.0
# 2079023  2022-06-17        140922  8800789080000         늘보리     105152.0
#
#          SALE_AMT  month
# 0            9960      9
# 1            1980      9
# ...

# %%
df['day'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.weekday
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD      GDS_NM  GDS_CLSS_CD  \
# 0        2021-09-02        185158  2999000001262   의성햇사과8입1봉      40601.0
# 1        2021-09-02        185158  2908990004443     쌈배추벌크1통      30101.0
# 2        2021-09-02        185158  2908990003866  성주꿀참외특6입1봉      40101.0
# 3        2021-09-02        185158         351060     대패삼겹살수입      52599.0
# 4        2021-09-02        185158         201447        거봉포도      40702.0
# ...             ...           ...            ...         ...          ...
# 2079019  2022-04-29        202815  8800789888880          찹쌀     105152.0
# 2079020  2022-07-13        152301  8800789888880          찹쌀     105152.0
# 2079021  2021-11-21        143020  8800789080000         늘보리     105152.0
# 2079022  2022-03-03        165411  8800789080000         늘보리     105152.0
# 2079023  2022-06-17        140922  8800789080000         늘보리     105152.0
#
#          SALE_AMT  month  day
# 0            9960      9    3
# ...

# %%
df1 = df[['month', 'GDS_NM', 'SALE_AMT', 'day']]
df1
# Out:
#          month      GDS_NM  SALE_AMT  day
# 0            9   의성햇사과8입1봉      9960    3
# 1            9     쌈배추벌크1통      1980    3
# 2            9  성주꿀참외특6입1봉      9800    3
# 3            9     대패삼겹살수입     13060    3
# 4            9        거봉포도      6420    3
# ...        ...         ...       ...  ...
# 2079019      4          찹쌀     49500    4
# 2079020      7          찹쌀     49500    2
# 2079021     11         늘보리      7300    6
# 2079022      3         늘보리      7300    3
# 2079023      6         늘보리      7300    4
#
# [2079024 rows x 4 columns]

# %%
df2 = df1.query('month == 1')

# %%
df2
# Out:
#          month      GDS_NM  SALE_AMT  day
# 1112         1  깐마늘1kg이내국산      7980    5
# 1113         1       양배추1통      2500    5
# 1114         1   양념돈고추장주물럭     10740    5
# 1115         1    파인애플1통행사      2980    5
# 1116         1     감자2kg박스      6980    5
# ...        ...         ...       ...  ...
# 2078926      1          현미     38000    6
# 2078935      1          찹쌀     49500    0
# 2078952      1          찹쌀     49500    2
# 2078982      1          현미      8500    6
# 2078994      1          현미     38000    5
#
# [206729 rows x 4 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206729 entries, 1112 to 2078994
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   month     206729 non-null  int64
#  1   GDS_NM    206729 non-null  object
#  2   SALE_AMT  206729 non-null  int64
#  3   day       206729 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.9+ MB

# %%
df3 = df2['month'] == 1
df3
# Out:
# 1112       True
# 1113       True
# 1114       True
# 1115       True
# 1116       True
#            ...
# 2078926    True
# 2078935    True
# 2078952    True
# 2078982    True
# 2078994    True
# Name: month, Length: 206729, dtype: bool

# %%
df4 = df2['day'] == 1
df4
# Out:
# 1112       False
# 1113       False
# 1114       False
# 1115       False
# 1116       False
#            ...
# 2078926    False
# 2078935    False
# 2078952    False
# 2078982    False
# 2078994    False
# Name: day, Length: 206729, dtype: bool

# %%
df5 = df2[df3 & df4]
df5
# Out:
#          month GDS_NM  SALE_AMT  day
# 1125         1   대파1단      1500    1
# 1126         1    흙당근      1840    1
# 1127         1     감자      2750    1
# 1128         1  가지5입봉      2280    1
# 1129         1  청양고추소      2980    1
# ...        ...    ...       ...  ...
# 2077092      1     양곡    300000    1
# 2078568      1    갈대비      4200    1
# 2078570      1    갈대비      4200    1
# 2078762      1   현미찹쌀     10500    1
# 2078890      1   현미찹쌀     10500    1
#
# [21747 rows x 4 columns]

# %%
df5['GDS_NM'].value_counts() # ABCD마트 1년의 데이터중 1월 월요일들 판매 양.
# Out:
# 대파1단            823
# 느타리버섯1팩         574
# 남해초1단행사         538
# 인큐애호박2개행사       438
# 백오이1개           410
#                ...
# 논우렁살              1
# 파인애플              1
# 카수까이우유사탕125g      1
# 명품사과세트13과         1
# 동태                1
# Name: GDS_NM, Length: 890, dtype: int64

# %% [markdown]
# ---

# %%
pd.set_option('display.max_rows', 2800)

# %%
df1['GDS_NM'].value_counts()
# Out:
# 대파1단                        64792
# 깻잎4묶음봉                      39561
# 백오이1개                       38042
# 흙당근                         33614
# 적상추1봉비닐                     30120
# 청양고추소                       29863
# 인큐애호박2개행사                   29190
# 느타리버섯1팩                     27791
# 감자                          25492
# 팽이버섯1봉                      21808
# 양파중1망                       20830
# 새송이버섯1봉                     19871
# 인큐애호박1개                     19729
# 청상추1봉                       19475
# 쌈배추알배기1통                    18446
# 가지5입봉                       18322
# 새송이버섯2봉1인2봉한정               18111
# 부추1단                        17918
# 국내산돈앞다리살                    17692
# 시금치1단                       17421
# 부사사과6개                      16908
# 백오이3개                       16698
# 추부깻잎1봉                      16638
# 무우1개봉투명비닐                   16446
# 파프리카1개                      14916
# 야채                          14441
# 양파특대1망                      14141
# ...

# %%
df1['GDS_NM'] = df1['GDS_NM'].str.replace("1단", "")
# Out:
# <ipython-input-73-7a596215a286>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GDS_NM'] = df1['GDS_NM'].str.replace("1단", "")

# %%
df1['GDS_NM'].value_counts()
# Out:
# 대파                          69350
# 깻잎4묶음봉                      39561
# 백오이1개                       38042
# 흙당근                         33614
# 적상추1봉비닐                     30120
# 청양고추소                       29863
# 인큐애호박2개행사                   29190
# 느타리버섯1팩                     27791
# 감자                          25492
# 부추                          22604
# 팽이버섯1봉                      21808
# 시금치                         21602
# 양파중1망                       20830
# 새송이버섯1봉                     19871
# 인큐애호박1개                     19729
# 청상추1봉                       19475
# 쌈배추알배기1통                    18446
# 가지5입봉                       18322
# 새송이버섯2봉1인2봉한정               18111
# 국내산돈앞다리살                    17692
# 부사사과6개                      16908
# 백오이3개                       16698
# 추부깻잎1봉                      16638
# 무우1개봉투명비닐                   16446
# 파프리카1개                      14916
# 야채                          14441
# 양파특대1망                      14141
# ...

# %%
df1['GDS_NM'] = df1['GDS_NM'].str.replace("4묶음봉", "")
# Out:
# <ipython-input-75-5b3d13a6930a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GDS_NM'] = df1['GDS_NM'].str.replace("4묶음봉", "")

# %%
df1['GDS_NM'] = df1['GDS_NM'].str.replace("1개", "")
# Out:
# <ipython-input-76-3c287fd8a2aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GDS_NM'] = df1['GDS_NM'].str.replace("1개", "")

# %%
df1['GDS_NM'] = df1['GDS_NM'].str.replace("1봉비닐", "")
# Out:
# <ipython-input-77-5edd4f6850da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GDS_NM'] = df1['GDS_NM'].str.replace("1봉비닐", "")

# %%
df1.to_csv('df1007-1.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x="GDS_NM", data=df)
plt.show()
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 54663 (\N{HANGUL SYLLABLE HAES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.countplot(x="GDS_NM", data=df2)
plt.show()
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 47788 (\N{HANGUL SYLLABLE MON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 48148 (\N{HANGUL SYLLABLE BA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df2
# Out:
#          month     GDS_NM  SALE_AMT
# 1479         2  델몬트바나나1송이      3980
# 1480         2      백오이1개      4980
# 1481         2       마시멜로      1100
# 1482         2  롯데허쉬쿠키앤크림      2750
# 1483         2     부사사과6개      9800
# ...        ...        ...       ...
# 2078960      2       현미찹쌀     10500
# 2078967      2        찰보리      7300
# 2078987      2         현미      8500
# 2078988      2         현미      8500
# 2079017      2         찹쌀     49500
#
# [161092 rows x 3 columns]

# %%
sns.countplot(y="GDS_NM", data=df5)
plt.show()
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 55129 (\N{HANGUL SYLLABLE HEULG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
