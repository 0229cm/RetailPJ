# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# a 마트 gds+list+dtl, 정상판매만 남기고, -1 제거 , 회원번호 없는것 제거.
amartsum = pd.read_csv(base_path + 'amartsum0928.csv')
amartsum
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        2021-09-01   12018     01        3       1            정상판매
# 1        2021-09-01   12018     01        3       2            정상판매
# 2        2021-09-01   12018     01        3       3            정상판매
# 3        2021-09-01   12018     01        3       4            정상판매
# 4        2021-09-01   12018     01        3       5            정상판매
# ...             ...     ...    ...      ...     ...             ...
# 4968529  2022-09-01   12018      7      175       1            정상판매
# 4968530  2022-09-01   12018      7      242       1            정상판매
# 4968531  2022-09-01   12018      7      245       1            정상판매
# ...

# %%
amartsum.mode()
# Out:
#        SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  SALE_RTN_SGN  \
# 0  2021-09-19   12018     07        5       1            정상판매             1
#
#           PLU_CD  GDS_CLSS_CD  SALE_QTY  ...  SALE_AMT      GDS_NM  \
# 0  2908990008649      30201.0       1.0  ...    1980.0  재사용봉투(20L)
#
#   SALE_KIND_TP_NM REAL_SAL_DT  REAL_SAL_TTM PAY_AMT      MSHP_ID day  hour  \
# 0              매출    20210919      17:03:56     0.0  012018_8260   5    16
#
#    month
# 0      9
#
# [1 rows x 21 columns]

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 21 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           object
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
#  18  day              int64
#  19  hour             int64
#  20  month            int64
# dtypes: float64(5), int64(9), object(7)
# memory usage: 796.0+ MB

# %%
amartsum.describe()
# Out:
#           STR_CD       TRAN_NO        SEQ_NO  SALE_RTN_SGN        PLU_CD  \
# count  4968534.0  4.968534e+06  4.968534e+06  4.968534e+06  4.968534e+06
# mean     12018.0  2.592256e+02  5.335655e+00  9.723182e-01  5.968058e+12
# std          0.0  1.774987e+02  5.315938e+00  2.336607e-01  3.503294e+12
# min      12018.0  1.000000e+00  1.000000e+00 -1.000000e+00  2.010010e+05
# 25%      12018.0  1.170000e+02  2.000000e+00  1.000000e+00  2.908990e+12
# 50%      12018.0  2.370000e+02  4.000000e+00  1.000000e+00  8.801031e+12
# 75%      12018.0  3.710000e+02  7.000000e+00  1.000000e+00  8.801088e+12
# max      12018.0  1.155000e+03  9.100000e+01  1.000000e+00  8.809772e+13
#
#         GDS_CLSS_CD      SALE_QTY      SALE_PRC      SALE_AMT   REAL_SAL_DT  \
# count  4.968534e+06  4.968534e+06  4.968534e+06  4.968534e+06  4.968534e+06
# mean   4.632711e+04  1.289182e+00  3.924920e+03  4.551975e+03  2.021720e+07
# std    1.070165e+05  5.140495e+00  4.815473e+03  1.689483e+04  4.477742e+03
# ...

# %%
print(amartsum.set_index(keys='month'))
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# month
# 9      2021-09-01   12018     01        3       1            정상판매
# 9      2021-09-01   12018     01        3       2            정상판매
# 9      2021-09-01   12018     01        3       3            정상판매
# 9      2021-09-01   12018     01        3       4            정상판매
# 9      2021-09-01   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 9      2022-09-01   12018      7      175       1            정상판매
# 9      2022-09-01   12018      7      242       1            정상판매
# 9      2022-09-01   12018      7      245       1            정상판매
# 9      2022-09-01   12018      7      385       1            정상판매
# 9      2022-09-01   12018      1      354       1            정상판매
#
#        SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# month
# 9                 1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
# pd.set_option('display.max_row', 300)

# %%
#a1 = amartsum.groupby(['GDS_NM', 'GDS_CLSS_CD'])
# a1.mean()

# %%
#a2 = amartsum.groupby(['GDS_NM', 'hour'])
# a2.mean()

# %%
#a3 = amartsum.groupby(['GDS_NM', 'hour', 'month'])
#a3

# %%
#a3 = a3.sum().reset_index()
#a3

# %%
#a4 = amartsum.groupby(['GDS_NM', 'hour', 'month', 'SALE_QTY'])
#a4

# %%
#a4 = a4.sum().reset_index()
#a4

# %%
# a4.head(300)

# %%
# a4.to_csv('a40927.csv', index=False)

# %%
#a4

# %%
#a5 = amartsum.groupby(['GDS_NM', 'hour', 'month', 'SALE_QTY', 'TRAN_NO'])
##a5

# %%
#a5 = a5.sum().reset_index()
#a5

# %%
#a5.to_csv('a50927.csv', index=False)

# %%
# amartsum.columns

# %%
#a6 = amartsum.groupby(['SAL_DT', 'TRAN_NO', 'DESI_CNCL_TP_NM', 'SALE_RTN_SGN', 'PLU_CD',
    #   'GDS_CLSS_CD', 'SALE_QTY', 'SALE_PRC', 'SALE_AMT', 'GDS_NM',
    #   'SALE_KIND_TP_NM', 'MSHP_ID', 'hour', 'month'])
#a6

# %%
#a6 = a6.sum().reset_index()
#a6

# %%
# a6.to_csv('a60927.csv', index=False)

# %%
a7 = amartsum.groupby(['GDS_NM', 'hour', 'month', 'day', 'SALE_QTY', 'TRAN_NO', 'SAL_DT', 'DESI_CNCL_TP_NM', 'SALE_RTN_SGN', 'PLU_CD','GDS_CLSS_CD', 'SALE_PRC', 'SALE_AMT' ,'SALE_KIND_TP_NM', 'MSHP_ID'])
a7

# %%
a7 = a7.sum().reset_index()
a7
# Out:
#                 GDS_NM  hour  month  day  SALE_QTY  TRAN_NO      SAL_DT  \
# 0               메가촉 초코     8      9    1       2.0       45  2021-09-14
# 1               메가촉 초코     8      9    6       1.0       15  2021-09-12
# 2               메가촉 초코     8     10    5       1.0       32  2021-10-30
# 3               메가촉 초코    10     10    5       1.0        7  2021-10-23
# 4               메가촉 초코    11      9    6       1.0      217  2021-09-19
# ...                ...   ...    ...  ...       ...      ...         ...
# 4237060  히말라야핑크솔트플로럴민트    10      7    1       1.0      129  2022-07-26
# 4237061  히말라야핑크솔트플로럴민트    13      4    6       1.0       59  2022-04-17
# 4237062  히말라야핑크솔트플로럴민트    17      5    6       1.0      534  2022-05-29
# 4237063  히말라야핑크솔트플로럴민트    18      8    5       1.0      324  2022-08-20
# 4237064  히말라야핑크솔트플로럴민트    18     12    3       1.0      485  2021-12-09
#
#         DESI_CNCL_TP_NM  SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_PRC  \
# ...

# %%
#a7.to_csv('a70927.csv', index=False)

# %%
#a7.to_csv('a70928.csv', index=False)

# %%
# GDS_NM', 'hour', 'month', 'SALE_QTY', 'TRAN_NO'

# %%
test = amartsum.groupby(['SAL_DT', 'TRAN_NO', 'hour', 'SALE_AMT','GDS_CLSS_CD'])['GDS_NM'].apply(list)
test # 상품명 기준
# Out:
# SAL_DT      TRAN_NO  hour  SALE_AMT  GDS_CLSS_CD
# 2021-09-01  1        10    1000.0    30201.0                     [*청양고추(소)]
#                            1280.0    30702.0                       [*대파 1단]
#                            2500.0    30201.0        [*꽈리고추 (500g), *백오이 3개]
#                            2850.0    12560.0                    [CJ 안심김밥맛살]
#                            2980.0    30702.0                       [*양파(소)]
#                                                              ...
# 2022-09-01  688      21    9800.0    40601.0                   [홍로사과 10입/봉]
#             689      21    12450.0   20901.0                    [죽염 시린고 치약]
#             691      21    9800.0    40601.0                      [홍로사과/8개]
#             692      21    1950.0    30201.0                      [*단호박 1개]
#                            11800.0   30101.0                      [*청상추 1봉]
# Name: GDS_NM, Length: 4053101, dtype: object

# %%
test = test.to_frame()
test # 상품명 기준
# Out:
#                                                                GDS_NM
# SAL_DT     TRAN_NO hour SALE_AMT GDS_CLSS_CD
# 2021-09-01 1       10   1000.0   30201.0                   [*청양고추(소)]
#                         1280.0   30702.0                     [*대파 1단]
#                         2500.0   30201.0      [*꽈리고추 (500g), *백오이 3개]
#                         2850.0   12560.0                  [CJ 안심김밥맛살]
#                         2980.0   30702.0                     [*양파(소)]
# ...                                                               ...
# 2022-09-01 688     21   9800.0   40601.0                 [홍로사과 10입/봉]
#            689     21   12450.0  20901.0                  [죽염 시린고 치약]
#            691     21   9800.0   40601.0                    [홍로사과/8개]
#            692     21   1950.0   30201.0                    [*단호박 1개]
#                         11800.0  30101.0                    [*청상추 1봉]
#
# [4053101 rows x 1 columns]

# %%
test1 = amartsum.groupby(['SAL_DT', 'TRAN_NO', 'GDS_NM', 'SALE_AMT','GDS_CLSS_CD'])['hour'].apply(list)
test1 # 시간기준
# Out:
# SAL_DT      TRAN_NO  GDS_NM         SALE_AMT  GDS_CLSS_CD
# 2021-09-01  1        *꽈리고추 (500g)   2500.0    30201.0        [10]
#                      *대파 1단         1280.0    30702.0        [10]
#                      *백오이 3개        2500.0    30201.0        [10]
#                      *송산포도 3kg/1박스  19800.0   40701.0        [10]
#                      *양파(소)         2980.0    30702.0        [10]
#                                                              ...
# 2022-09-01  688      홍로사과 10입/봉     9800.0    40601.0        [21]
#             689      죽염 시린고 치약      12450.0   20901.0        [21]
#             691      홍로사과/8개        9800.0    40601.0        [21]
#             692      *단호박 1개        1950.0    30201.0        [21]
#                      *청상추 1봉        11800.0   30101.0        [21]
# Name: hour, Length: 4108284, dtype: object

# %%
test1 = test1.to_frame() 
test1 # 시간기준
# Out:
#                                                        hour
# SAL_DT     TRAN_NO GDS_NM        SALE_AMT GDS_CLSS_CD
# 2021-09-01 1       *꽈리고추 (500g)  2500.0   30201.0      [10]
#                    *대파 1단        1280.0   30702.0      [10]
#                    *백오이 3개       2500.0   30201.0      [10]
#                    *송산포도 3kg/1박스 19800.0  40701.0      [10]
#                    *양파(소)        2980.0   30702.0      [10]
# ...                                                     ...
# 2022-09-01 688     홍로사과 10입/봉    9800.0   40601.0      [21]
#            689     죽염 시린고 치약     12450.0  20901.0      [21]
#            691     홍로사과/8개       9800.0   40601.0      [21]
#            692     *단호박 1개       1950.0   30201.0      [21]
#                    *청상추 1봉       11800.0  30101.0      [21]
#
# [4108284 rows x 1 columns]

# %%
test2 = amartsum.groupby(['SAL_DT', 'TRAN_NO', 'hour', 'SALE_AMT','GDS_CLSS_CD','GDS_NM'])['month'].apply(list)
test2 # 달기준
# Out:
# SAL_DT      TRAN_NO  hour  SALE_AMT  GDS_CLSS_CD  GDS_NM
# 2021-09-01  1        10    1000.0    30201.0      *청양고추(소)        [9]
#                            1280.0    30702.0      *대파 1단          [9]
#                            2500.0    30201.0      *꽈리고추 (500g)    [9]
#                                                   *백오이 3개         [9]
#                            2850.0    12560.0      CJ 안심김밥맛살       [9]
#                                                                  ...
# 2022-09-01  688      21    9800.0    40601.0      홍로사과 10입/봉      [9]
#             689      21    12450.0   20901.0      죽염 시린고 치약       [9]
#             691      21    9800.0    40601.0      홍로사과/8개         [9]
#             692      21    1950.0    30201.0      *단호박 1개         [9]
#                            11800.0   30101.0      *청상추 1봉         [9]
# Name: month, Length: 4167329, dtype: object

# %%
test2= test2.to_frame() 
test2 # 달기준
# Out:
#                                                           month
# SAL_DT     TRAN_NO hour SALE_AMT GDS_CLSS_CD GDS_NM
# 2021-09-01 1       10   1000.0   30201.0     *청양고추(소)       [9]
#                         1280.0   30702.0     *대파 1단         [9]
#                         2500.0   30201.0     *꽈리고추 (500g)   [9]
#                                              *백오이 3개        [9]
#                         2850.0   12560.0     CJ 안심김밥맛살      [9]
# ...                                                         ...
# 2022-09-01 688     21   9800.0   40601.0     홍로사과 10입/봉     [9]
#            689     21   12450.0  20901.0     죽염 시린고 치약      [9]
#            691     21   9800.0   40601.0     홍로사과/8개        [9]
#            692     21   1950.0   30201.0     *단호박 1개        [9]
#                         11800.0  30101.0     *청상추 1봉        [9]
#
# [4167329 rows x 1 columns]
