# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''
pd.set_option('display.max_row', 500)

# %%
test = pd.read_csv(base_path + 'test0928.csv')
test
# Out:
#                 GDS_NM  hour  month  day  SALE_QTY
# 0               메가촉 초코     8      9    1       2.0
# 1               메가촉 초코     8      9    6       1.0
# 2               메가촉 초코     8     10    5       1.0
# 3               메가촉 초코    10     10    5       1.0
# 4               메가촉 초코    11      9    6       1.0
# ...                ...   ...    ...  ...       ...
# 4237060  히말라야핑크솔트플로럴민트    10      7    1       1.0
# 4237061  히말라야핑크솔트플로럴민트    13      4    6       1.0
# 4237062  히말라야핑크솔트플로럴민트    17      5    6       1.0
# 4237063  히말라야핑크솔트플로럴민트    18      8    5       1.0
# 4237064  히말라야핑크솔트플로럴민트    18     12    3       1.0
#
# [4237065 rows x 5 columns]

# %%
tmtest = test[['GDS_NM', 'hour']]
tmtest
# Out:
#                 GDS_NM  hour
# 0               메가촉 초코     8
# 1               메가촉 초코     8
# 2               메가촉 초코     8
# 3               메가촉 초코    10
# 4               메가촉 초코    11
# ...                ...   ...
# 4176442  히말라야핑크솔트플로럴민트    10
# 4176443  히말라야핑크솔트플로럴민트    13
# 4176444  히말라야핑크솔트플로럴민트    17
# 4176445  히말라야핑크솔트플로럴민트    18
# 4176446  히말라야핑크솔트플로럴민트    18
#
# [4176447 rows x 2 columns]

# %%
t5  = tmtest.query('hour == 5')
t5
# Out:
#              GDS_NM  hour
# 236212        대파 1단     5
# 306583        라임 1팩     5
# 402516       백오이 3개     5
# 2495256   서울 스타벅스라떼     5
# 2567205   세척당근 수입산      5
# 2874272  오뚜기 옛날자른미역     5
# 3093507  재사용봉투 20L      5

# %%
t5.value_counts().head(100)
# Out:
# GDS_NM      hour
# 재사용봉투 20L   5       1
# 오뚜기 옛날자른미역  5       1
# 세척당근 수입산    5       1
# 서울 스타벅스라떼   5       1
#  백오이 3개     5       1
#  라임 1팩      5       1
#  대파 1단      5       1
# dtype: int64

# %%
t6 = tmtest.query('hour == 6')

# %%
t6.value_counts().head(100)
# Out:
# GDS_NM            hour
# 재사용봉투 20L         6       50
# 롯데 칸타타 아이스아메리카노   6       27
#  대파 1단            6       26
# 오뚜기 컵얼음           6       24
# CJ 양념이잘배는찌개두부     6       21
# 롯데 칸타타 아이스블랙      6       21
# 서울 우유             6       19
# 토속대란 1판           6       16
# 쌀소성주              6       16
#  깻잎 4묶음  봉        6       15
#  청양고추 소           6       15
# 서울 스타벅스라떼         6       14
# 동서 맥심모카골드믹스       6       13
# 풀무원 씻어나온콩나물       6       11
# 오뚜기 생얼음           6       11
# 곱슬이콩나물 1박스        6       10
# 풀무원  소가찌개두부       6       10
#  단호박 1개           6        9
#  가지 5입 봉          6        9
# 팽이버섯 1봉           6        9
#  느타리버섯 1팩         6        9
#  꽈리고추  500g       6        8
# 시금치               6        8
#   빨강 대추방울토마토 1팩   6        8
# 서울 듀오안 프리바이오틱     6        7
# 빙그레 굿모닝우유기획       6        7
# 소와나무 고칼슘우유기획      6        7
# 한우양지국거리           6        7
#  인큐애호박 1개         6        7
#  양파 소             6        7
#  새송이버섯 2봉 1인2봉한정  6        7
# ...

# %%
t7 = tmtest.query('hour == 7')

# %%
t7.value_counts().head(100)
# Out:
# GDS_NM            hour
# 재사용봉투 20L         7       370
#  대파 1단            7       144
# 서울 우유             7       124
# 곱슬이콩나물 1박스        7       123
# 토속대란 1판           7       123
# 일자콩나물 1박스         7       106
# 남양 맛있는우유GT기획      7        92
# 숙주나물 박스           7        89
#  깻잎 4묶음  봉        7        83
# CJ 양념이잘배는찌개두부     7        80
#  청양고추 소           7        77
#  백오이 1개           7        74
# 팽이버섯 1봉           7        74
# 풀무원 씻어나온콩나물       7        71
# 적상추 1봉 비닐         7        68
# 흙당근               7        65
#  인큐애호박 2개 행사      7        64
# 청정원 숨쉬는전통콩나물      7        58
#  가지 5입 봉          7        55
#   빨강 대추방울토마토 1팩   7        55
# 남양 이오기획           7        51
# 대림 신선한콩나물         7        50
# 배달봉투              7        49
#  새송이버섯 2봉 1인2봉한정  7        49
#  양파 15kg          7        49
#  부추 1단            7        48
# 감자                7        47
# 국내산돈삼겹살           7        46
# 반판두부 3k           7        46
#  느타리버섯 1팩         7        46
# ...

# %%
t8 = tmtest.query('hour == 8')

# %%
t8.value_counts().head(100)
# Out:
# GDS_NM                  hour
# 재사용봉투 20L               8       1157
#  대파 1단                  8        505
# 토속대란 1판                 8        377
# 서울 우유                   8        301
# 배달봉투                    8        283
# 곱슬이콩나물 1박스              8        263
# 숙주나물 박스                 8        254
#  백오이 1개                 8        240
#  느타리버섯 1팩               8        230
#  깻잎 4묶음  봉              8        224
#  청양고추 소                 8        216
# 흙당근                     8        201
# 적상추 1봉 비닐               8        193
# 감자                      8        191
#  인큐애호박 2개 행사            8        189
# CJ 양념이잘배는찌개두부           8        180
# 팽이버섯 1봉                 8        178
# 토속특란 1판                 8        160
#  무우 1개 봉  투명비닐          8        147
# 풀무원 씻어나온콩나물             8        146
#   빨강 대추방울토마토 1팩         8        145
#  청상추 1봉                 8        142
# 남양 맛있는우유GT기획            8        141
# 표고버섯 수입산                8        140
# ...

# %%
t9 = tmtest.query('hour == 9')

# %%
t9.value_counts().head(100)
# Out:
# GDS_NM            hour
# 재사용봉투 20L         9       2872
# 배달봉투              9       1417
#  대파 1단            9       1378
# 흙당근               9        761
# 토속대란 1판           9        700
#  백오이 1개           9        695
# 서울 우유             9        680
#  느타리버섯 1팩         9        621
#  청양고추 소           9        613
#  인큐애호박 2개 행사      9        609
#  깻잎 4묶음  봉        9        596
# 감자                9        577
#  부추 1단            9        541
# 남양 맛있는우유GT기획      9        500
# 곱슬이콩나물 1박스        9        484
# 적상추 1봉 비닐         9        454
# 팽이버섯 1봉           9        450
# 풀무원 씻어나온콩나물       9        445
#  양파 중  1망         9        443
# CJ 양념이잘배는찌개두부     9        439
#  시금치 1단           9        397
# 처음처럼              9        392
#  새송이버섯 1봉         9        390
# 대림 신선한콩나물         9        386
# 농심 신라면 멀티         9        377
#  청상추 1봉           9        375
#  양파 특대  1망        9        372
#  새송이버섯 2봉 1인2봉한정  9        367
# 국내산돈앞다리살          9        357
# ...

# %%
t10 = tmtest.query('hour == 10')

# %%
t10.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             10      5275
#  대파 1단                10      3712
# 배달봉투                  10      3206
#  백오이 1개               10      2021
#  깻잎 4묶음  봉            10      1905
# 흙당근                   10      1812
# 서울 우유                 10      1701
#  느타리버섯 1팩             10      1654
#  인큐애호박 2개 행사          10      1469
#  청양고추 소               10      1379
# 토속대란 1판               10      1343
# 적상추 1봉 비닐             10      1309
#  부추 1단                10      1221
# 감자                    10      1195
#  시금치 1단               10      1156
#  양파 중  1망             10      1099
#  가지 5입 봉              10      1026
#  쌈배추 알배기  1통          10      1022
#  새송이버섯 1봉             10      1017
# CJ 양념이잘배는찌개두부         10      1006
# 남양 맛있는우유GT기획          10       999
# 풀무원 씻어나온콩나물           10       975
#  새송이버섯 2봉 1인2봉한정      10       961
# 팽이버섯 1봉               10       917
# 국내산돈앞다리살              10       895
# 대림 신선한콩나물             10       875
# ...

# %%
t11 = tmtest.query('hour == 11')

# %%
t11.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             11      6490
#  대파 1단                11      4805
# 배달봉투                  11      4625
#  백오이 1개               11      2923
#  깻잎 4묶음  봉            11      2714
# 흙당근                   11      2505
#  느타리버섯 1팩             11      2019
# 적상추 1봉 비닐             11      1977
#  인큐애호박 2개 행사          11      1973
# 서울 우유                 11      1967
#  청양고추 소               11      1851
# 감자                    11      1512
#  부추 1단                11      1501
#  쌈배추 알배기  1통          11      1497
#  시금치 1단               11      1450
# 토속대란 1판               11      1432
#  가지 5입 봉              11      1421
#  양파 중  1망             11      1410
# 팽이버섯 1봉               11      1352
#  새송이버섯 1봉             11      1351
# 국내산돈앞다리살              11      1345
# CJ 양념이잘배는찌개두부         11      1325
# 남양 맛있는우유GT기획          11      1324
#  청상추 1봉               11      1259
#  부사사과 6개              11      1251
#  백오이 3개               11      1208
# ...

# %%
t12 = tmtest.query('hour == 12')

# %%
t12.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             12      6987
# 배달봉투                  12      5011
#  대파 1단                12      4666
#  깻잎 4묶음  봉            12      2718
#  백오이 1개               12      2716
# 흙당근                   12      2516
# 서울 우유                 12      2107
# 적상추 1봉 비닐             12      2066
#  느타리버섯 1팩             12      2003
#  인큐애호박 2개 행사          12      1999
#  청양고추 소               12      1882
# 감자                    12      1686
# 토속대란 1판               12      1639
#  시금치 1단               12      1476
#  쌈배추 알배기  1통          12      1406
#  새송이버섯 1봉             12      1390
# 팽이버섯 1봉               12      1378
#  가지 5입 봉              12      1377
#  양파 중  1망             12      1370
#  부추 1단                12      1357
#  청상추 1봉               12      1312
# 국내산돈앞다리살              12      1310
# 남양 맛있는우유GT기획          12      1307
#  부사사과 6개              12      1254
# CJ 양념이잘배는찌개두부         12      1235
#  새송이버섯 2봉 1인2봉한정      12      1208
# ...

# %%
t13 = tmtest.query('hour == 13')

# %%
t13.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             13      7021
# 배달봉투                  13      5345
#  대파 1단                13      4909
#  백오이 1개               13      2719
#  깻잎 4묶음  봉            13      2586
# 흙당근                   13      2505
#  인큐애호박 2개 행사          13      2202
# 적상추 1봉 비닐             13      2069
#  느타리버섯 1팩             13      2059
#  청양고추 소               13      2029
# 서울 우유                 13      2002
# 감자                    13      1750
# 토속대란 1판               13      1675
# 팽이버섯 1봉               13      1503
#  가지 5입 봉              13      1429
#  양파 중  1망             13      1413
#  시금치 1단               13      1383
#  쌈배추 알배기  1통          13      1360
#  부추 1단                13      1333
#  새송이버섯 1봉             13      1327
# 국내산돈앞다리살              13      1324
# 남양 맛있는우유GT기획          13      1293
#  부사사과 6개              13      1275
#  청상추 1봉               13      1265
# CJ 양념이잘배는찌개두부         13      1237
#  새송이버섯 2봉 1인2봉한정      13      1226
# ...

# %%
t14 = tmtest.query('hour == 14')

# %%
t14.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             14      7892
# 배달봉투                  14      5710
#  대파 1단                14      5393
#  백오이 1개               14      3129
#  깻잎 4묶음  봉            14      3015
# 흙당근                   14      2766
#  인큐애호박 2개 행사          14      2579
# 서울 우유                 14      2385
#  느타리버섯 1팩             14      2374
#  청양고추 소               14      2334
# 적상추 1봉 비닐             14      2269
# 감자                    14      1971
# 토속대란 1판               14      1771
#  양파 중  1망             14      1692
# 팽이버섯 1봉               14      1655
#  쌈배추 알배기  1통          14      1583
#  새송이버섯 1봉             14      1583
# CJ 양념이잘배는찌개두부         14      1555
# 국내산돈앞다리살              14      1554
#  시금치 1단               14      1517
#  부사사과 6개              14      1449
# 남양 맛있는우유GT기획          14      1439
#  부추 1단                14      1436
#  가지 5입 봉              14      1412
#  청상추 1봉               14      1401
#  새송이버섯 2봉 1인2봉한정      14      1393
# ...

# %%
t15 = tmtest.query('hour == 15')

# %%
t15.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             15      9877
# 배달봉투                  15      6384
#  대파 1단                15      6349
#  백오이 1개               15      3772
#  깻잎 4묶음  봉            15      3532
# 흙당근                   15      3298
#  인큐애호박 2개 행사          15      3007
#  느타리버섯 1팩             15      2829
# 적상추 1봉 비닐             15      2806
# 서울 우유                 15      2798
#  청양고추 소               15      2552
# 감자                    15      2427
# 토속대란 1판               15      2146
#  양파 중  1망             15      1994
# 팽이버섯 1봉               15      1948
#  쌈배추 알배기  1통          15      1913
# 남양 맛있는우유GT기획          15      1876
#  새송이버섯 1봉             15      1826
# 국내산돈앞다리살              15      1804
# CJ 양념이잘배는찌개두부         15      1802
#  시금치 1단               15      1731
# 대림 신선한콩나물             15      1713
#  새송이버섯 2봉 1인2봉한정      15      1712
#  청상추 1봉               15      1698
#  부사사과 6개              15      1667
#  가지 5입 봉              15      1657
# ...

# %%
t16 = tmtest.query('hour == 16')

# %%
t16.value_counts().head(100)
# Out:
# GDS_NM                hour
# 재사용봉투 20L             16      11528
#  대파 1단                16       6592
# 배달봉투                  16       6017
#  깻잎 4묶음  봉            16       4098
#  백오이 1개               16       3895
# 흙당근                   16       3669
#  인큐애호박 2개 행사          16       3192
# 적상추 1봉 비닐             16       3094
# 서울 우유                 16       3071
#  느타리버섯 1팩             16       2938
#  청양고추 소               16       2859
# 감자                    16       2695
# 토속대란 1판               16       2440
# 남양 맛있는우유GT기획          16       2296
# 팽이버섯 1봉               16       2295
#  새송이버섯 1봉             16       2169
#  양파 중  1망             16       2112
#  청상추 1봉               16       2035
# 국내산돈앞다리살              16       2010
#  새송이버섯 2봉 1인2봉한정      16       1991
# CJ 양념이잘배는찌개두부         16       1979
# 처음처럼                  16       1881
#  쌈배추 알배기  1통          16       1875
#  추부깻잎 1봉              16       1858
# 대림 신선한콩나물             16       1848
# ...

# %%
t17 = tmtest.query('hour == 17')

# %%
t17.value_counts().head(100)
# Out:
# GDS_NM            hour
# 재사용봉투 20L         17      12796
#  대파 1단            17       5808
# 배달봉투              17       5101
#  깻잎 4묶음  봉        17       3943
#  백오이 1개           17       3291
# 흙당근               17       3189
# 서울 우유             17       3120
# 적상추 1봉 비닐         17       3031
#  인큐애호박 2개 행사      17       2885
#  청양고추 소           17       2781
#  느타리버섯 1팩         17       2661
# 토속대란 1판           17       2647
# 감자                17       2519
# 팽이버섯 1봉           17       2412
# 처음처럼              17       2395
# 남양 맛있는우유GT기획      17       2288
#  양파 중  1망         17       2069
#  새송이버섯 1봉         17       2061
#  청상추 1봉           17       2022
# CJ 양념이잘배는찌개두부     17       1986
# 국내산돈앞다리살          17       1892
#  새송이버섯 2봉 1인2봉한정  17       1891
#  추부깻잎 1봉          17       1876
# 참이슬후레쉬            17       1778
# 대림 신선한콩나물         17       1759
# 풀무원 씻어나온콩나물       17       1648
# 국내산돈삼겹살           17       1590
#  쌈배추 알배기  1통      17       1567
# ...

# %%
t18 = tmtest.query('hour == 18')

# %%
t18.value_counts().head(100)
# Out:
# GDS_NM            hour
# 재사용봉투 20L         18      12183
#  대파 1단            18       4665
# 배달봉투              18       3950
#  깻잎 4묶음  봉        18       3457
# 서울 우유             18       2832
#  백오이 1개           18       2783
# 적상추 1봉 비닐         18       2740
# 처음처럼              18       2585
# 흙당근               18       2583
#  청양고추 소           18       2472
# 토속대란 1판           18       2291
#  인큐애호박 2개 행사      18       2290
# 감자                18       2150
# 팽이버섯 1봉           18       2101
#  느타리버섯 1팩         18       2016
# 남양 맛있는우유GT기획      18       1943
#  청상추 1봉           18       1805
#  양파 중  1망         18       1777
#  새송이버섯 1봉         18       1741
# 참이슬후레쉬            18       1705
# CJ 양념이잘배는찌개두부     18       1699
#  추부깻잎 1봉          18       1670
# 대림 신선한콩나물         18       1664
#  새송이버섯 2봉 1인2봉한정  18       1646
# 국내산돈삼겹살           18       1431
# 참이슬후레쉬640ml       18       1396
# 농심 신라면 멀티         18       1355
# 쌀소성주              18       1348
# ...

# %%
t19 = tmtest.query('hour == 19')

# %%
t19.value_counts().head(100)
# Out:
# GDS_NM                  hour
# 재사용봉투 20L               19      9477
#  대파 1단                  19      2899
#  깻잎 4묶음  봉              19      2040
# 배달봉투                    19      1966
# 서울 우유                   19      1935
# 처음처럼                    19      1803
# 토속대란 1판                 19      1723
#  백오이 1개                 19      1710
#  청양고추 소                 19      1649
# 적상추 1봉 비닐               19      1604
# 흙당근                     19      1590
# 남양 맛있는우유GT기획            19      1468
# 감자                      19      1319
#  인큐애호박 2개 행사            19      1309
# 팽이버섯 1봉                 19      1266
# 참이슬후레쉬                  19      1241
#  느타리버섯 1팩               19      1213
#  청상추 1봉                 19      1075
# CJ 양념이잘배는찌개두부           19      1061
#  새송이버섯 2봉 1인2봉한정        19      1042
#  양파 중  1망               19      1032
# 대림 신선한콩나물               19      1008
#  새송이버섯 1봉               19       971
# 농심 신라면 멀티               19       956
# ...

# %%
t20 = tmtest.query('hour == 20')

# %%
t20.value_counts().head(100)
# Out:
# GDS_NM                  hour
# 재사용봉투 20L               20      6650
#  대파 1단                  20      2075
# 서울 우유                   20      1570
#  깻잎 4묶음  봉              20      1346
# 토속대란 1판                 20      1247
#  백오이 1개                 20      1219
# 남양 맛있는우유GT기획            20      1195
# 배달봉투                    20      1112
# 흙당근                     20      1099
# 처음처럼                    20      1064
#  청양고추 소                 20      1002
#  인큐애호박 2개 행사            20       846
# 참이슬후레쉬                  20       822
# 감자                      20       821
# 적상추 1봉 비닐               20       821
#  느타리버섯 1팩               20       809
# 농심 신라면 멀티               20       779
#  양파 중  1망               20       776
# CJ 양념이잘배는찌개두부           20       761
# 팽이버섯 1봉                 20       752
# 쌀소성주                    20       707
#   빨강 대추방울토마토 1팩         20       699
# 대림 신선한콩나물               20       695
#  부사사과 6개                20       644
# ...

# %%
t21 = tmtest.query('hour == 21')

# %%
t21.value_counts().head(100)
# Out:
# GDS_NM            hour
# 재사용봉투 20L         21      3238
# 서울 우유             21       871
#  대파 1단            21       771
# 남양 맛있는우유GT기획      21       637
# 토속대란 1판           21       608
# 처음처럼              21       524
#  깻잎 4묶음  봉        21       455
#  백오이 1개           21       427
#  청양고추 소           21       393
# CJ 양념이잘배는찌개두부     21       375
# 흙당근               21       370
# 참이슬후레쉬            21       368
#  인큐애호박 2개 행사      21       349
# 농심 신라면 멀티         21       331
#   빨강 대추방울토마토 1팩   21       325
# 적상추 1봉 비닐         21       319
# 쌀소성주              21       317
#  양파 중  1망         21       307
# 팽이버섯 1봉           21       306
# 감자                21       296
# 토속특란 1판           21       288
# 빙그레 굿모닝우유기획       21       287
#  부사사과 6개          21       279
#  느타리버섯 1팩         21       269
# 대림 신선한콩나물         21       265
# 남양 이오기획           21       263
# 대림 부산얇은사각어묵       21       262
#  델몬트바나나 1송이       21       256
# 농심 짜파게티 멀티        21       251
# ...

# %% [markdown]
# ----

# %%
tmtest1 = test[['GDS_NM', 'month']]
tmtest1
# Out:
#                 GDS_NM  month
# 0               메가촉 초코      9
# 1               메가촉 초코      9
# 2               메가촉 초코     10
# 3               메가촉 초코     10
# 4               메가촉 초코      9
# ...                ...    ...
# 4176442  히말라야핑크솔트플로럴민트      7
# 4176443  히말라야핑크솔트플로럴민트      4
# 4176444  히말라야핑크솔트플로럴민트      5
# 4176445  히말라야핑크솔트플로럴민트      8
# 4176446  히말라야핑크솔트플로럴민트     12
#
# [4176447 rows x 2 columns]

# %%
m1 = tmtest1.query('month == 1')
m1
# Out:
#                GDS_NM  month
# 71         냉동혼합야채 4종       1
# 74         냉동혼합야채 4종       1
# 75         냉동혼합야채 4종       1
# 78            다용도5호세트      1
# 79            다용도5호세트      1
# ...               ...    ...
# 4176351  히말라야핑크솔트 플로럴      1
# 4176372  히말라야핑크솔트 플로럴      1
# 4176391  히말라야핑크솔트 플로럴      1
# 4176405  히말라야핑크솔트 플로럴      1
# 4176416  히말라야핑크솔트 플로럴      1
#
# [397202 rows x 2 columns]

# %%
m1.value_counts().head(100)
# Out:
# GDS_NM                  month
# 재사용봉투 20L               1        9528
#  대파 1단                  1        6387
# 배달봉투                    1        4699
# 토속특란 1판                 1        4292
#  느타리버섯 1팩               1        3785
#  인큐애호박 2개 행사            1        3471
#  남해초 1단 행사              1        3346
#  백오이 1개                 1        3261
# 흙당근                     1        3244
#  무우 1개 봉  투명비닐          1        2959
#  깻잎 4묶음  봉              1        2955
#  새송이버섯 1봉               1        2899
# 팽이버섯 1봉                 1        2456
#  청양고추 소                 1        2386
# 서울 우유                   1        2369
# 감자                      1        2053
#  부사사과 6개                1        2003
# 적상추 1봉 비닐               1        1811
#  파프리카 1개                1        1773
# 처음처럼                    1        1681
#  양파 중  1망               1        1656
#  쌈배추 알배기  1통            1        1564
#  시금치 1단                 1        1556
# 한우양지국거리                 1        1533
# ...

# %%
m2 = tmtest1.query('month == 2')

# %%
m2.value_counts().head(100)
# Out:
# GDS_NM                    month
# 재사용봉투 20L                 2        8003
#  대파 1단                    2        4405
#  백오이 1개                   2        3695
# 배달봉투                      2        3290
#  인큐애호박 2개 행사              2        2865
# 적상추 1봉 비닐                 2        2662
#  깻잎 4묶음  봉                2        2361
#  팩딸기 3팩 전단                2        2321
# 서울 우유                     2        2114
#  청양고추 소                   2        2062
#  느타리버섯 1팩                 2        1997
# 토속대란 1판                   2        1903
# 흙당근                       2        1861
# 감자                        2        1717
#  시금치 1단                   2        1683
#  다라딸기 1다라 행사              2        1649
# 팽이버섯 1봉                   2        1483
#  청상추 1봉                   2        1472
#  무우 1개 봉  투명비닐            2        1471
# 처음처럼                      2        1403
#  부사사과 6개                  2        1321
# 토속특란 1판                   2        1263
#  새송이버섯 2봉 1인2봉한정          2        1260
# ...

# %%
m3 = tmtest1.query('month == 3')

# %%
m3.value_counts().head(100)
# Out:
# GDS_NM                  month
# 재사용봉투 20L               3        9411
#  대파 1단                  3        5207
#  인큐애호박 2개 행사            3        4945
#  백오이 1개                 3        4476
# 배달봉투                    3        3832
#  깻잎 4묶음  봉              3        3082
# 적상추 1봉 비닐               3        2869
#  느타리버섯 1팩               3        2857
#  무우 1개 행사용              3        2768
#  새송이버섯 2봉 1인2봉한정        3        2749
# 서울 우유                   3        2507
# 흙당근                     3        2356
# 팽이버섯 1봉                 3        2286
# 토속왕란 1판                 3        2279
#  청양고추 소                 3        2261
# 감자                      3        2260
#  부사사과 6개                3        1951
#  파프리카 1개                3        1919
# 토속대란 1판                 3        1866
#  팩딸기 3팩 전단              3        1821
#  시금치 1단                 3        1740
#  부추 1단                  3        1713
#  청상추 1봉                 3        1675
# 대림 신선한콩나물               3        1511
# ...

# %%
m4 = tmtest1.query('month == 4')

# %%
m4.value_counts().head(100)
# Out:
# GDS_NM                  month
# 재사용봉투 20L               4        8486
#  백오이 1개                 4        7480
#  인큐애호박 2개 행사            4        5800
# 배달봉투                    4        3956
#  대파 1단                  4        3939
#  새송이버섯 2봉 1인2봉한정        4        2993
# 적상추 1봉 비닐               4        2870
#  깻잎 4묶음  봉              4        2815
# 흙당근                     4        2414
# 서울 우유                   4        2165
# 팽이버섯 1봉                 4        2115
#  청양고추 소                 4        2073
#  무우 1개 행사용              4        1972
# 감자                      4        1957
# 남양 맛있는우유GT기획            4        1878
#  양파 중  1망               4        1848
#  파프리카 1개                4        1847
#  부추 1단                  4        1826
#  부사사과 6개                4        1672
#  청상추 1봉                 4        1600
# 토속대란 1판                 4        1499
# 대림 신선한콩나물               4        1496
#  시금치 1단                 4        1481
#  느타리버섯 2팩구입시            4        1464
# ...

# %%
m5 = tmtest1.query('month == 5')

# %%
m5.value_counts().head(100)
# Out:
# GDS_NM            month
# 재사용봉투 20L         5        8427
# 배달봉투              5        4355
#  대파 1단            5        3957
#  인큐애호박 1개         5        3467
#  성주참외 10개         5        3111
#  백오이 3개           5        3037
# 적상추 1봉 비닐         5        2723
#  백오이 1개           5        2694
# 토속왕란 1판           5        2502
#   빨강 대추방울토마토 1팩   5        2452
#  새송이버섯 2봉 1인2봉한정  5        2403
#  깻잎 4묶음  봉        5        2275
# 흙당근               5        2248
# 감자                5        2194
# 서울 우유             5        2164
# 남양 맛있는우유GT기획      5        2154
#  청양고추 소           5        2111
#  부추 1단            5        2069
#  시금치 1단           5        1946
#  부사사과 6개          5        1927
#  쌈배추 알배기  1통      5        1914
#  가지 5입 봉          5        1807
#  양파 중  1망         5        1661
#  느타리버섯 1팩         5        1646
#  청상추 1봉           5        1528
# 팽이버섯 2봉           5        1528
# CJ 양념이잘배는찌개두부     5        1513
#  양파 특대  1망        5        1465
# ...

# %%
m6 = tmtest1.query('month == 6')

# %%
m6.value_counts().head(100)
# Out:
# GDS_NM                  month
# 재사용봉투 20L               6        8070
#  백오이 3개                 6        5086
# 배달봉투                    6        4340
# 토속대란 1판                 6        4086
#  대파 1단                  6        3761
#  파프리카 2개 행사             6        3228
#  성주참외 10개               6        2897
#  깻잎 4묶음  봉              6        2633
#  새송이버섯 2봉 1인2봉한정        6        2624
#  인큐애호박 1개               6        2501
#   빨강 대추방울토마토 1팩         6        2484
# 감자                      6        2321
# 흙당근                     6        2297
#  가지 5입 봉                6        2198
# 남양 맛있는우유GT기획            6        2184
#  부추 1단                  6        2069
#  느타리버섯 1팩               6        2059
# 서울 우유                   6        2049
#  청양고추 소                 6        2020
# 적상추 1봉 비닐               6        1865
# 농심 신라면 멀티               6        1714
#  양파 중  1망               6        1692
#  무우 1개                  6        1408
#  부사사과 6개                6        1387
# ...

# %%
m7 = tmtest1.query('month == 7')

# %%
m7.value_counts().head(100)
# Out:
# GDS_NM            month
# 재사용봉투 20L         7        8396
# 배달봉투              7        4041
#  대파 1단            7        3771
#  백오이 3입 1봉        7        3703
# 토속대란 1판           7        3625
#  깻잎 4묶음  봉        7        3308
#  새송이버섯 2봉 1인2봉한정  7        2812
#  인큐애호박 1개         7        2624
# 남양 맛있는우유GT기획      7        2287
#  가지 5입 봉          7        2233
# 흙당근               7        2215
#  파프리카 2개 행사       7        2178
#  일반애호박 2개         7        2140
# 서울 우유             7        2132
#  천도복숭아 특  10개     7        2019
#  왕특딱딱이복숭아 6개      7        1858
#  청양고추 소           7        1699
# 적상추 1봉 비닐         7        1626
# 국내산돈앞다리살          7        1593
#  쌈배추 알배기  1통      7        1581
#  느타리버섯 1팩         7        1516
#   빨강 대추방울토마토 1팩   7        1481
#  무우 1개            7        1434
# 대림 신선한콩나물         7        1392
# 감자                7        1381
# CJ 양념이잘배는찌개두부     7        1341
#  양파 중  1망         7        1333
# 농심 신라면 멀티         7        1304
# ...

# %%
m8 = tmtest1.query('month == 8')

# %%
m8.value_counts().head(100)
# Out:
# GDS_NM            month
# 재사용봉투 20L         8        8074
#  대파 1단            8        4474
# 배달봉투              8        3865
# 토속대란 1판           8        3681
#  깻잎 4묶음  봉        8        2715
#  백오이 3입 1봉        8        2548
# 서울 우유             8        2274
# 흙당근               8        2131
#  새송이버섯 1봉         8        2007
# 팽이버섯 1봉           8        1935
#  양파 중  1망         8        1840
#  천도복숭아 특  10개     8        1822
# 적상추 1봉 비닐         8        1819
# CJ 양념이잘배는찌개두부     8        1811
#  아삭이고추 1팩         8        1783
#  무우 1개            8        1754
#  청양고추 소           8        1704
# 국내산돈앞다리살          8        1631
#  왕특딱딱이복숭아 6개      8        1627
#  느타리버섯 1팩         8        1597
#  쌈배추 알배기  1통      8        1591
# 대림 신선한콩나물         8        1533
#  일반애호박 1개         8        1496
#  느타리버섯 2팩         8        1473
#  가지 5입 봉          8        1462
# 감자                8        1443
#  아오리사과 5개 행사      8        1441
# 바나나 1송이 행사        8        1378
# ...

# %%
m9 = tmtest1.query('month == 9')

# %%
m9.value_counts().head(100)
# Out:
# GDS_NM                   month
# 재사용봉투 20L                9        8949
# 배달봉투                     9        4837
#  대파 1단                   9        4740
#  새송이버섯 1봉                9        3314
# 흙당근                      9        3129
# 토속대란 1판                  9        2990
#  무우 1개 봉  투명비닐           9        2829
#  일반애호박 1개                9        2728
#  깻잎 4묶음  봉               9        2622
#  백오이 1개                  9        2580
# 서울 우유                    9        2569
#  느타리버섯 2팩                9        2512
#   인큐애호박 1개               9        2462
# 팽이버섯 2봉                  9        2222
#  청양고추 소                  9        2218
#  가지 5입 봉                 9        2079
#  햇홍로사과 8개 8개1봉           9        2063
#  백오이 3개                  9        2010
# 시금치 2단 어플행사              9        1838
# 남양 맛있는우유GT기획             9        1815
# 처음처럼                     9        1572
#  양파 중  1망                9        1486
#  아보카도 1개                 9        1470
# ...

# %%
m10 = tmtest1.query('month == 10')

# %%
m10.value_counts().head(100)
# Out:
# GDS_NM                   month
# 재사용봉투 20L                10       8792
#  대파 1단                   10       4634
# 배달봉투                     10       4424
#  단감 5개                   10       3340
#  깻잎 4묶음  봉               10       2699
#  새송이버섯 1봉                10       2611
# 서울 우유                    10       2399
# 흙당근                      10       2321
#  무우 1개 봉  투명비닐           10       2268
#  느타리버섯 1팩                10       2153
# 토속특란 1판                  10       1916
#  델몬트바나나 1송이              10       1792
#  백오이 1개                  10       1736
#  청양고추 소                  10       1676
#   빨강 대추방울토마토 1팩          10       1673
# 적상추 1봉 비닐                10       1670
#  인큐애호박 2개 행사             10       1641
# 감자                       10       1641
# CJ 양념이잘배는찌개두부            10       1598
#  파프리카 2입 봉               10       1564
# 처음처럼                     10       1482
#  사과대추 1팩                 10       1439
#  시금치 1단                  10       1420
# ...

# %%
m11 = tmtest1.query('month == 11')

# %%
m11.value_counts().head(100)
# Out:
# GDS_NM                  month
# 재사용봉투 20L               11       8455
#  대파 1단                  11       5044
# 배달봉투                    11       4451
#  인큐애호박 2개 행사            11       3408
# 토속특란 1판                 11       2883
#  깻잎 4묶음  봉              11       2686
#  새송이버섯 1봉               11       2470
# 흙당근                     11       2307
# 서울 우유                   11       2298
#  단감 5개                  11       2278
#  백오이 1개                 11       2260
#  느타리버섯 1팩               11       2233
#  쪽파 대 1단                11       2171
#  델몬트바나나 1송이             11       2096
# 적상추 1봉 비닐               11       1995
# 팽이버섯 1봉                 11       1780
#  청양고추 소                 11       1771
#  청상추 1봉                 11       1767
# 국내산돈앞다리살                11       1591
#  부사사과 6개                11       1562
# 감자                      11       1525
# 남양 맛있는우유GT기획            11       1483
#  무우 1개 봉  투명비닐          11       1410
#  생강 1봉                  11       1377
# ...

# %%
m12 = tmtest1.query('month == 12')

# %%
m12.value_counts().head(100)
# Out:
# GDS_NM                  month
# 재사용봉투 20L               12       9273
#  대파 1단                  12       4379
# 배달봉투                    12       4320
#  남해초 1단 행사              12       3643
#  인큐애호박 2개 행사            12       2701
#  깻잎 4묶음  봉              12       2576
#  느타리버섯 1팩               12       2540
#  새송이버섯 1봉               12       2504
#  백오이 1개                 12       2480
# 서울 우유                   12       2443
# 흙당근                     12       2413
#  청양고추 소                 12       2123
# 팽이버섯 1봉                 12       2044
#  쌈배추 알배기  1통            12       1954
#  파프리카 1개                12       1897
#  시금치 1단                 12       1836
#  델몬트바나나 1송이             12       1798
# 감자                      12       1734
# 적상추 1봉 비닐               12       1723
#  청상추 1봉                 12       1713
# 처음처럼                    12       1584
#  부사사과 6개                12       1577
#  무우 1개 봉  투명비닐          12       1524
# CJ 양념이잘배는찌개두부           12       1380
# ...

# %% [markdown]
# ------

# %%
tmtest2 = test[['GDS_NM', 'day']]
tmtest2
# Out:
#                 GDS_NM  day
# 0               메가촉 초코    1
# 1               메가촉 초코    6
# 2               메가촉 초코    5
# 3               메가촉 초코    5
# 4               메가촉 초코    6
# ...                ...  ...
# 4237060  히말라야핑크솔트플로럴민트    1
# 4237061  히말라야핑크솔트플로럴민트    6
# 4237062  히말라야핑크솔트플로럴민트    6
# 4237063  히말라야핑크솔트플로럴민트    5
# 4237064  히말라야핑크솔트플로럴민트    3
#
# [4237065 rows x 2 columns]

# %%
d0 = tmtest2.query('day == 0')

# %%
d0.value_counts().head(100)
# Out:
# GDS_NM                day
# 재사용봉투 20L             0      14868
# 배달봉투                  0       7268
#  대파 1단                0       6915
#  백오이 1개               0       5419
# 서울 우유                 0       4198
# 흙당근                   0       4152
#  깻잎 4묶음  봉            0       4099
#  느타리버섯 1팩             0       3378
#  청양고추 소               0       3351
# 토속대란 1판               0       3334
#  인큐애호박 2개 행사          0       3158
# 적상추 1봉 비닐             0       3124
# 감자                    0       3019
# 남양 맛있는우유GT기획          0       2944
# 팽이버섯 1봉               0       2674
# CJ 양념이잘배는찌개두부         0       2643
#  양파 중  1망             0       2537
#  백오이 3개               0       2438
#  새송이버섯 1봉             0       2310
#  새송이버섯 2봉 1인2봉한정      0       2309
# 대림 신선한콩나물             0       2284
#  쌈배추 알배기  1통          0       2234
# 풀무원 씻어나온콩나물           0       2161
#  시금치 1단               0       2104
# 국내산돈앞다리살              0       2035
#  가지 5입 봉              0       2028
# ...

# %%
d1 = tmtest2.query('day == 1')

# %%
d1.value_counts().head(100)
# Out:
# GDS_NM                  day
# 재사용봉투 20L               1      14052
#  대파 1단                  1       7137
# 배달봉투                    1       6655
#  인큐애호박 2개 행사            1       4465
#  백오이 1개                 1       3945
# 서울 우유                   1       3822
#  깻잎 4묶음  봉              1       3766
# 흙당근                     1       3714
#  느타리버섯 1팩               1       3354
# 적상추 1봉 비닐               1       3296
#  청양고추 소                 1       3055
# 감자                      1       3048
# 토속대란 1판                 1       2933
# 팽이버섯 1봉                 1       2619
# 남양 맛있는우유GT기획            1       2557
#  양파 중  1망               1       2533
# CJ 양념이잘배는찌개두부           1       2222
#  새송이버섯 2봉 1인2봉한정        1       2137
# 대림 신선한콩나물               1       2121
#  쌈배추 알배기  1통            1       2082
#  가지 5입 봉                1       2074
#  부추 1단                  1       2037
# 국내산돈앞다리살                1       1967
#  청상추 1봉                 1       1949
# ...

# %%
d2 = tmtest2.query('day == 2')

# %%
d2.value_counts().head(100)
# Out:
# GDS_NM                day
# 재사용봉투 20L             2      14082
#  대파 1단                2       6984
# 배달봉투                  2       6651
#  깻잎 4묶음  봉            2       3993
#  백오이 1개               2       3813
# 흙당근                   2       3810
# 서울 우유                 2       3697
# 적상추 1봉 비닐             2       3210
#  인큐애호박 2개 행사          2       3170
#  청양고추 소               2       2994
# 감자                    2       2958
#  느타리버섯 1팩             2       2866
# 토속대란 1판               2       2851
# 남양 맛있는우유GT기획          2       2580
# 팽이버섯 1봉               2       2580
#  가지 5입 봉              2       2399
#  부추 1단                2       2342
# CJ 양념이잘배는찌개두부         2       2266
#  시금치 1단               2       2227
#  양파 중  1망             2       2207
#  새송이버섯 1봉             2       2143
# 대림 신선한콩나물             2       2089
# 처음처럼                  2       2044
#  청상추 1봉               2       1953
#  쌈배추 알배기  1통          2       1940
#  새송이버섯 2봉 1인2봉한정      2       1905
# ...

# %%
d3 = tmtest2.query('day == 3')

# %%
d3.value_counts().head(100)
# Out:
# GDS_NM            day
# 재사용봉투 20L         3      13805
#  대파 1단            3       7413
# 배달봉투              3       7068
#  깻잎 4묶음  봉        3       4258
# 흙당근               3       3935
#  백오이 1개           3       3931
# 서울 우유             3       3789
#  인큐애호박 2개 행사      3       3218
# 적상추 1봉 비닐         3       3169
#  청양고추 소           3       3079
#  느타리버섯 1팩         3       2929
# 토속대란 1판           3       2604
# 남양 맛있는우유GT기획      3       2560
#  새송이버섯 1봉         3       2554
# 감자                3       2541
#  시금치 1단           3       2321
#  양파 중  1망         3       2294
# 팽이버섯 1봉           3       2265
#  청상추 1봉           3       2247
# CJ 양념이잘배는찌개두부     3       2198
#  부추 1단            3       2146
#  새송이버섯 2봉 1인2봉한정  3       2055
# 대림 신선한콩나물         3       2046
#  쌈배추 알배기  1통      3       2031
# 국내산돈앞다리살          3       1973
# 처음처럼              3       1906
#  가지 5입 봉          3       1823
# 풀무원 씻어나온콩나물       3       1810
#  무우 1개 봉  투명비닐    3       1716
# ...

# %%
d4 = tmtest2.query('day == 4')

# %%
d4.value_counts().head(100)
# Out:
# GDS_NM            day
# 재사용봉투 20L         4      14929
#  대파 1단            4       8886
# 배달봉투              4       8102
#  깻잎 4묶음  봉        4       5321
#  백오이 1개           4       4276
# 흙당근               4       4227
# 서울 우유             4       3724
# 적상추 1봉 비닐         4       3636
#  느타리버섯 1팩         4       3598
#  인큐애호박 2개 행사      4       3591
#  청양고추 소           4       3476
# 감자                4       3077
# 토속대란 1판           4       2931
# 처음처럼              4       2721
#  청상추 1봉           4       2654
#  양파 중  1망         4       2573
# 팽이버섯 1봉           4       2488
# CJ 양념이잘배는찌개두부     4       2459
#  새송이버섯 1봉         4       2448
#  쌈배추 알배기  1통      4       2413
# 국내산돈앞다리살          4       2405
# 남양 맛있는우유GT기획      4       2384
#  새송이버섯 2봉 1인2봉한정  4       2321
#  추부깻잎 1봉          4       2312
# 대림 신선한콩나물         4       2222
#  부추 1단            4       2196
#  부사사과 6개          4       2122
#  가지 5입 봉          4       2069
#  시금치 1단           4       2056
# ...

# %%
d5 = tmtest2.query('day == 5')

# %%
d5.value_counts().head(100)
# Out:
# GDS_NM            day
# 재사용봉투 20L         5      16600
#  대파 1단            5       8763
# 배달봉투              5       8479
#  깻잎 4묶음  봉        5       6322
#  백오이 1개           5       5802
# 흙당근               5       4821
# 적상추 1봉 비닐         5       4611
#  청양고추 소           5       4274
#  느타리버섯 1팩         5       4154
# 서울 우유             5       4099
#  인큐애호박 2개 행사      5       3682
# 토속대란 1판           5       3650
# 처음처럼              5       3389
# 감자                5       3170
# 팽이버섯 1봉           5       3153
#  새송이버섯 1봉         5       2931
#  부사사과 6개          5       2893
#  추부깻잎 1봉          5       2883
#  양파 중  1망         5       2868
#  청상추 1봉           5       2826
# 국내산돈앞다리살          5       2809
# 남양 맛있는우유GT기획      5       2803
#  새송이버섯 2봉 1인2봉한정  5       2613
#  가지 5입 봉          5       2508
#  쌈배추 알배기  1통      5       2501
#  양파 특대  1망        5       2477
# CJ 양념이잘배는찌개두부     5       2469
#  파프리카 1개          5       2461
# 참이슬후레쉬            5       2450
# ...

# %%
d6 = tmtest2.query('day == 6')

# %%
d6.value_counts().head(100)
# Out:
# GDS_NM                  day
# 재사용봉투 20L               6      16416
#  대파 1단                  6       9572
# 배달봉투                    6       7465
#  깻잎 4묶음  봉              6       5458
#  백오이 1개                 6       4975
# 흙당근                     6       4755
# 서울 우유                   6       4427
# 토속대란 1판                 6       4254
#  청양고추 소                 6       4140
# 적상추 1봉 비닐               6       4103
#  인큐애호박 2개 행사            6       4034
#  느타리버섯 1팩               6       3850
# 감자                      6       3652
# 남양 맛있는우유GT기획            6       3213
# 팽이버섯 1봉                 6       3008
#  부사사과 6개                6       2934
#  양파 중  1망               6       2897
#  새송이버섯 1봉               6       2891
# 처음처럼                    6       2694
# CJ 양념이잘배는찌개두부           6       2668
# 농심 신라면 멀티               6       2643
# 국내산돈앞다리살                6       2504
#  파프리카 1개                6       2483
#  청상추 1봉                 6       2475
# ...
