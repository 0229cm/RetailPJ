# %% [markdown]
# ## 월

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'foruntitled65_1.csv')
df
# Out:
#              SAL_DT         PLU_CD    GDS_NM  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0        2021-09-04       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# 1        2021-09-07       93682091  스니커즈피넛싱글        11509       2.0    1100.0
# 2        2021-09-10       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# 3        2021-09-10       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# 4        2021-09-10       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# ...             ...            ...       ...          ...       ...       ...
# 2196143  2021-10-07  9803340000003       갈대비       999999       1.0    4200.0
# 2196144  2021-11-02  9803340000003       갈대비       999999       1.0    4200.0
# 2196145  2022-01-18  9803340000003       갈대비       999999       1.0    4200.0
# 2196146  2022-01-18  9803340000003       갈대비       999999       1.0    4200.0
# 2196147  2022-03-16  9803340000003       갈대비       999999       1.0    4200.0
#
# ...

# %%
dfm = df[['PLU_CD', 'GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
dfm
# Out:
#                 PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 0             93682091  스니커즈피넛싱글      9       1.0    1100.0
# 1             93682091  스니커즈피넛싱글      9       2.0    2200.0
# 2             93682091  스니커즈피넛싱글      9       1.0    1100.0
# 3             93682091  스니커즈피넛싱글      9       1.0    1100.0
# 4             93682091  스니커즈피넛싱글      9       1.0    1100.0
# ...                ...       ...    ...       ...       ...
# 2196143  9803340000003       갈대비     10       1.0    4200.0
# 2196144  9803340000003       갈대비     11       1.0    4200.0
# 2196145  9803340000003       갈대비      1       1.0    4200.0
# 2196146  9803340000003       갈대비      1       1.0    4200.0
# 2196147  9803340000003       갈대비      3       1.0    4200.0
#
# [2196148 rows x 5 columns]

# %% [markdown]
# ---

# %%
dfm1  = dfm.query('month == 1')
dfm1
# Out:
#                 PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 52            93682091  스니커즈피넛싱글      1       1.0    1100.0
# 53            93682091  스니커즈피넛싱글      1       1.0    1100.0
# 54            93682091  스니커즈피넛싱글      1       1.0    1100.0
# 55            93682091  스니커즈피넛싱글      1       4.0    4400.0
# 56            93682091  스니커즈피넛싱글      1       1.0    1100.0
# ...                ...       ...    ...       ...       ...
# 2196047       93682091   스니커즈55g      1       2.0    2000.0
# 2196048       93682091   스니커즈55g      1       1.0    1000.0
# 2196049       93682091   스니커즈55g      1       2.0    2000.0
# 2196145  9803340000003       갈대비      1       1.0    4200.0
# 2196146  9803340000003       갈대비      1       1.0    4200.0
#
# [209333 rows x 5 columns]

# %%
dfm2  = dfm.query('month == 2')
dfm2
# Out:
#            PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 68       93682091  스니커즈피넛싱글      2       1.0    1100.0
# 69       93682091  스니커즈피넛싱글      2       1.0    1100.0
# 70       93682091  스니커즈피넛싱글      2       2.0    2200.0
# 71       93682091  스니커즈피넛싱글      2       1.0    1100.0
# 72       93682091  스니커즈피넛싱글      2       2.0    2200.0
# ...           ...       ...    ...       ...       ...
# 2196053  93682091   스니커즈55g      2       1.0    1000.0
# 2196054  93682091   스니커즈55g      2       1.0    1000.0
# 2196055  93682091   스니커즈55g      2       2.0    2000.0
# 2196056  93682091   스니커즈55g      2       1.0    1000.0
# 2196057  93682091   스니커즈55g      2       3.0    3000.0
#
# [163836 rows x 5 columns]

# %%
dfm3  = dfm.query('month == 3')
dfm3
# Out:
#                 PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 79            93682091  스니커즈피넛싱글      3       1.0    1100.0
# 80            93682091  스니커즈피넛싱글      3       1.0    1100.0
# 81            93682091  스니커즈피넛싱글      3       2.0    2200.0
# 82            93682091  스니커즈피넛싱글      3       2.0    2200.0
# 83            93682091  스니커즈피넛싱글      3       1.0    1100.0
# ...                ...       ...    ...       ...       ...
# 2196063       93682091   스니커즈55g      3       1.0    1000.0
# 2196064       93682091   스니커즈55g      3       1.0    1000.0
# 2196065       93682091   스니커즈55g      3       2.0    2000.0
# 2196066       93682091   스니커즈55g      3       2.0    2000.0
# 2196147  9803340000003       갈대비      3       1.0    4200.0
#
# [195720 rows x 5 columns]

# %%
dfm4  = dfm.query('month == 4')
dfm4
# Out:
#            PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 95       93682091  스니커즈피넛싱글      4       2.0    2200.0
# 96       93682091  스니커즈피넛싱글      4       3.0    3300.0
# 97       93682091  스니커즈피넛싱글      4       3.0    3300.0
# 98       93682091  스니커즈피넛싱글      4       1.0    1100.0
# 99       93682091  스니커즈피넛싱글      4      24.0   26400.0
# ...           ...       ...    ...       ...       ...
# 2196077  93682091   스니커즈55g      4       3.0    3000.0
# 2196078  93682091   스니커즈55g      4       2.0    2000.0
# 2196079  93682091   스니커즈55g      4       2.0    2000.0
# 2196080  93682091   스니커즈55g      4       1.0    1000.0
# 2196081  93682091   스니커즈55g      4       3.0    3000.0
#
# [189877 rows x 5 columns]

# %%
dfm5  = dfm.query('month == 5')
dfm5
# Out:
#            PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 103      93682091  스니커즈피넛싱글      5       1.0    1100.0
# 104      93682091  스니커즈피넛싱글      5       1.0    1100.0
# 105      93682091  스니커즈피넛싱글      5       1.0    1100.0
# 106      93682091  스니커즈피넛싱글      5       1.0    1100.0
# 107      93682091  스니커즈피넛싱글      5       1.0    1100.0
# ...           ...       ...    ...       ...       ...
# 2196090  93682091   스니커즈55g      5       2.0    2000.0
# 2196091  93682091   스니커즈55g      5       3.0    3000.0
# 2196092  93682091   스니커즈55g      5       4.0    4000.0
# 2196093  93682091   스니커즈55g      5       2.0    2000.0
# 2196094  93682091   스니커즈55g      5       2.0    2000.0
#
# [187255 rows x 5 columns]

# %%
dfm6  = dfm.query('month == 6')
dfm6
# Out:
#                 PLU_CD           GDS_NM  month  SALE_QTY  SALE_AMT
# 112           93682091         스니커즈피넛싱글      6       3.0    3300.0
# 113           93682091         스니커즈피넛싱글      6       3.0    3300.0
# 114           93682091         스니커즈피넛싱글      6       2.0    2200.0
# 115           93682091         스니커즈피넛싱글      6       5.0    5500.0
# 116           93682091         스니커즈피넛싱글      6       3.0    3300.0
# ...                ...              ...    ...       ...       ...
# 2196119  9555319109186  포테이토크리스프바베큐맛90g      6       1.0    1000.0
# 2196120  9555319109186  포테이토크리스프바베큐맛90g      6       1.0    1000.0
# 2196121  9555319109186  포테이토크리스프바베큐맛90g      6       2.0    2000.0
# 2196136  9557240214052         피쉬바비스파이스      6       5.0    2500.0
# 2196137  9557240214052         피쉬바비스파이스      6       1.0     500.0
#
# [179572 rows x 5 columns]

# %%
dfm7  = dfm.query('month == 7')
dfm7
# Out:
#                 PLU_CD           GDS_NM  month  SALE_QTY  SALE_AMT
# 125           93682091         스니커즈피넛싱글      7       1.0    1100.0
# 126           93682091         스니커즈피넛싱글      7       1.0    1100.0
# 127           93682091         스니커즈피넛싱글      7       2.0    2200.0
# 128           93682091         스니커즈피넛싱글      7       4.0    4400.0
# 129           93682091         스니커즈피넛싱글      7       1.0    1100.0
# ...                ...              ...    ...       ...       ...
# 2196109       93682091          스니커즈55g      7       2.0    2000.0
# 2196110       93682091          스니커즈55g      7       1.0    1000.0
# 2196122  9555319109186  포테이토크리스프바베큐맛90g      7       1.0    1000.0
# 2196123  9555319109186  포테이토크리스프바베큐맛90g      7       1.0    1000.0
# 2196142  9801050000009            수수마당비      7       1.0    4000.0
#
# [174596 rows x 5 columns]

# %%
dfm8  = dfm.query('month == 8')
dfm8
# Out:
#                 PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 133           93682091  스니커즈피넛싱글      8       2.0    2200.0
# 134           93682091  스니커즈피넛싱글      8       3.0    3300.0
# 135           93682091  스니커즈피넛싱글      8       1.0    1100.0
# 136           93682091  스니커즈피넛싱글      8       1.0    1100.0
# 137           93682091  스니커즈피넛싱글      8       1.0    1100.0
# ...                ...       ...    ...       ...       ...
# 2196117       93682091   스니커즈55g      8       1.0    1000.0
# 2196138  9557240214052  피쉬바비스파이스      8       1.0     500.0
# 2196139  9557240214052  피쉬바비스파이스      8       1.0     500.0
# 2196140  9557240214052  피쉬바비스파이스      8       2.0    1000.0
# 2196141  9557240214052  피쉬바비스파이스      8       2.0    1000.0
#
# [161486 rows x 5 columns]

# %%
dfm9  = dfm.query('month == 9')
dfm9
# Out:
#            PLU_CD    GDS_NM  month  SALE_QTY  SALE_AMT
# 0        93682091  스니커즈피넛싱글      9       1.0    1100.0
# 1        93682091  스니커즈피넛싱글      9       2.0    2200.0
# 2        93682091  스니커즈피넛싱글      9       1.0    1100.0
# 3        93682091  스니커즈피넛싱글      9       1.0    1100.0
# 4        93682091  스니커즈피넛싱글      9       1.0    1100.0
# ...           ...       ...    ...       ...       ...
# 2196005  93682091   스니커즈55g      9       2.0    2000.0
# 2196006  93682091   스니커즈55g      9       1.0    1000.0
# 2196007  93682091   스니커즈55g      9       1.0    1000.0
# 2196008  93682091   스니커즈55g      9       1.0    1000.0
# 2196009  93682091   스니커즈55g      9       1.0    1000.0
#
# [197945 rows x 5 columns]

# %%
dfm10  = dfm.query('month == 10')
dfm10
# Out:
#                 PLU_CD     GDS_NM  month  SALE_QTY  SALE_AMT
# 18            93682091   스니커즈피넛싱글     10       1.0    1100.0
# 19            93682091   스니커즈피넛싱글     10       1.0    1100.0
# 20            93682091   스니커즈피넛싱글     10       1.0    1100.0
# 21            93682091   스니커즈피넛싱글     10       1.0    1100.0
# 22            93682091   스니커즈피넛싱글     10       2.0    2200.0
# ...                ...        ...    ...       ...       ...
# 2196126  9557240204305  서피시스넥스파이스     10       1.0    1200.0
# 2196127  9557240204305  서피시스넥스파이스     10       1.0    1200.0
# 2196128  9557240204305  서피시스넥스파이스     10       1.0    1200.0
# 2196129  9557240204305  서피시스넥스파이스     10       1.0    1200.0
# 2196143  9803340000003        갈대비     10       1.0    4200.0
#
# [182367 rows x 5 columns]

# %%
dfm11  = dfm.query('month == 11')
dfm11
# Out:
#                 PLU_CD     GDS_NM  month  SALE_QTY  SALE_AMT
# 36            93682091   스니커즈피넛싱글     11       2.0    2200.0
# 37            93682091   스니커즈피넛싱글     11       1.0    1100.0
# 38            93682091   스니커즈피넛싱글     11       2.0    2200.0
# 39            93682091   스니커즈피넛싱글     11       1.0    1100.0
# 40            93682091   스니커즈피넛싱글     11       1.0    1100.0
# ...                ...        ...    ...       ...       ...
# 2196028       93682091    스니커즈55g     11       1.0    1000.0
# 2196029       93682091    스니커즈55g     11       1.0    1000.0
# 2196030       93682091    스니커즈55g     11       2.0    2000.0
# 2196130  9557240204305  서피시스넥스파이스     11       1.0    1200.0
# 2196144  9803340000003        갈대비     11       1.0    4200.0
#
# [175651 rows x 5 columns]

# %%
dfm12  = dfm.query('month == 12')
dfm12
# Out:
#                 PLU_CD     GDS_NM  month  SALE_QTY  SALE_AMT
# 48            93682091   스니커즈피넛싱글     12       2.0    2200.0
# 49            93682091   스니커즈피넛싱글     12       1.0    1100.0
# 50            93682091   스니커즈피넛싱글     12       2.0    2200.0
# 51            93682091   스니커즈피넛싱글     12       1.0    1100.0
# 196           93682091   스니커즈피넛싱글     12       2.0    2200.0
# ...                ...        ...    ...       ...       ...
# 2196131  9557240204305  서피시스넥스파이스     12       2.0    2400.0
# 2196132  9557240204305  서피시스넥스파이스     12       2.0    2400.0
# 2196133  9557240204305  서피시스넥스파이스     12       2.0    2400.0
# 2196134  9557240204305  서피시스넥스파이스     12       3.0    3600.0
# 2196135  9557240204305  서피시스넥스파이스     12       2.0    2400.0
#
# [178510 rows x 5 columns]

# %% [markdown]
# ----

# %%
dfm1_1 = dfm1.groupby(['GDS_NM', 'month']).sum()
dfm1_1
# Out:
#                                 PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM         month
# 0000           1         8691216095557       1.0     1800.0
# 10001200청량초    1        14366450070056       8.0     8000.0
# 1000cc뚜껑       1         6600237568836       2.0     8400.0
# 1664블랑캔        1        21561512222677      12.0    42000.0
# 1664블랑캔500ml6입 1        30802160456270      12.0   180000.0
# ...                                ...       ...        ...
# 흑토마토           1              11685086      61.0   271000.0
# 흑토마토1팩행사       1       378168700976560     134.0   692600.0
# 흙당근            1             765468928    3820.0  4203870.0
# 흙당근1봉비닐        1      1391536000200448     503.0   774180.0
# 흙대파            1       105047460026964      43.0   107500.0
#
# [1750 rows x 3 columns]

# %%
dfm2_1 = dfm2.groupby(['GDS_NM', 'month']).sum()
dfm2_1
# Out:
#                                 PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM         month
# 0000           2        34764864382228       4.0     7200.0
# 10001200청량초    2         2052350010008       1.0     1000.0
# 1000cc뚜껑       2         3300118784418       1.0     4200.0
# 1664블랑캔        2        15401080159055       9.0    31500.0
# 1664블랑캔500ml6입 2        24641728365016      14.0   210000.0
# ...                                ...       ...        ...
# 흑토마토           2               1007015       5.0    19900.0
# 흑토마토1팩행사       2       421803551089240     153.0   914940.0
# 흙당근            2             432787448    2157.0  2394380.0
# 흙당근1봉비닐        2      1439520000207360     535.0   964260.0
# 흙대파            2       110049720229286      45.0   113970.0
#
# [1706 rows x 3 columns]

# %%
dfm3_1 = dfm3.groupby(['GDS_NM', 'month']).sum()
dfm3_1
# Out:
#                                 PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM         month
# 0000           3        17382432191114       2.0     3600.0
# 10001200청량초    3        14366450070056       9.0     9000.0
# 1300오이고추       3        16416400096040      11.0    14300.0
# 1664블랑캔        3        15401080159055      12.0    42000.0
# 1664블랑캔500ml6입 3        33882376501897      21.0   339000.0
# ...                                ...       ...        ...
# 흑토마토1팩행사       3       445075471149336     159.0  1090820.0
# 흙당근            3             546160472    2720.0  3240430.0
# 흙당근100g특품      3        32989000373967      54.0     9560.0
# 흙당근1봉비닐        3      1964345000282960     718.0  1421640.0
# 흙대파            3       122555370031458      51.0   139100.0
#
# [1692 rows x 3 columns]

# %%
dfm4_1 = dfm4.groupby(['GDS_NM', 'month']).sum()
dfm4_1
# Out:
#                                PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM        month
# 10001200청량초   4        30785250150120      16.0    16000.0
# 1300오이고추      4        18468450108045      10.0    13000.0
# 1664블랑캔       4        18481296190866       8.0    28000.0
# 2050780005007 4         4101560010014       4.0     2000.0
# 20kg천일염       4        58188828554720      21.0   619500.0
# ...                               ...       ...        ...
# 흙당근           4             565659024    2823.0  3907610.0
# 흙당근100g특품     4        89970001019910     156.0    36200.0
# 흙당근1봉비닐       4      1493502000215136     526.0  1041480.0
# 흙대파           4        65029380016692      26.0    74200.0
# 히말라야암염88g     4        18002828176988       2.0    23800.0
#
# [1673 rows x 3 columns]

# %%
dfm5_1 = dfm5.groupby(['GDS_NM', 'month']).sum()
dfm5_1
# Out:
#                              PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM      month
# 0000        5        43456080477785       5.0     9000.0
# 10001200청량초 5        20523500100080      11.0    11000.0
# 1000cc뚜껑    5         3300118784418       1.0     4200.0
# 1300오이고추    5        12312300072030       8.0    10400.0
# 15kg꽃소금     5          290200000299       1.0    12500.0
# ...                             ...       ...        ...
# 흙당근         5             527667000    2628.0  4629110.0
# 흙당근100g특품   5        86971000985913     244.0    79156.0
# 흙당근1봉비닐     5      1985338000285984     716.0  1417680.0
# 흙대파         5       122555370031458      49.0   122500.0
# 흙생강         5                201021       1.0     7960.0
#
# [1663 rows x 3 columns]

# %%
dfm6_1 = dfm6.groupby(['GDS_NM', 'month']).sum()
dfm6_1
# Out:
#                                PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM        month
# 0000          6         8691216095557       1.0     1800.0
# 0241405572666 6          482811145332       3.0     2700.0
# 10001200청량초   6        18471150090072       9.0     9000.0
# 1300오이고추      6        14364350084035       7.0     9100.0
# 1664블랑        6         3080216031811       1.0     3600.0
# ...                               ...       ...        ...
# 흑토마토2kg1박스행사  6        75436767792698      26.0   155480.0
# 흙당근           6             531687320    2649.0  4880410.0
# 흙당근100g특품     6       110963001257889     197.0    72390.0
# 흙당근1봉비닐       6      2027324000292032     729.0  1579140.0
# 흙대파           6       123909780029469      48.0   132100.0
#
# [1695 rows x 3 columns]

# %%
dfm7_1 = dfm7.groupby(['GDS_NM', 'month']).sum()
dfm7_1
# Out:
#                               PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM       month
# 0000         7        26073648286671       4.0     7200.0
# 10001200청량초  7        28732900140112      15.0    15000.0
# 1300오이고추     7        10260250060025       7.0     9100.0
# 1664블랑       7         3080216031811       1.0     3600.0
# 1664블랑캔      7        30802160318110      24.0    84000.0
# ...                              ...       ...        ...
# 흑토마토2kg1박스행사 7       142169293147777      48.0   210060.0
# 흙당근          7             509173528    2538.0  4931600.0
# 흙당근100g특품    7       128957001461871     222.0    80340.0
# 흙당근1봉비닐      7      1478507000212976     537.0  1281500.0
# 흙대파          7       109199580028875      44.0   106200.0
#
# [1706 rows x 3 columns]

# %%
dfm8_1 = dfm8.groupby(['GDS_NM', 'month']).sum()
dfm8_1
# Out:
#                              PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM      month
# 0000        8        17382432191114       3.0     5400.0
# 10001200청량초 8        10261750050040       6.0     6000.0
# 1300오이고추    8        14364350084035       7.0     9100.0
# 1664블랑      8         3080216031811       1.0     3600.0
# 1664블랑캔     8         9240648095433       4.0    14000.0
# ...                             ...       ...        ...
# 흙당근100g특품   8       128957001461871     174.0    71880.0
# 흙당근1봉비닐     8      3196934000460512    1101.0  3244050.0
# 흙대파         8       140399460040068      55.0   188000.0
# 흙생강         8               1005105       5.0     6430.0
# 히말라야암염88g   8         9001414088494       1.0     7900.0
#
# [1653 rows x 3 columns]

# %%
dfm9_1 = dfm9.groupby(['GDS_NM', 'month']).sum()
dfm9_1
# Out:
#                                 PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM         month
# 0000           9        17382432191114       4.0     7200.0
# 12곡플러스그레인      9       659601157605880     177.0   284910.0
# 1300오이고추       9         4104100024010       3.0     3900.0
# 1664블랑캔        9        24641728254488      42.0   180600.0
# 1664블랑캔500ml6입 9        15401080228135       8.0   120000.0
# ...                                ...       ...        ...
# 흙당근            9             744161232    3703.0  6624190.0
# 흙당근100g특품      9         2999000033997      10.0     4500.0
# 흙당근1봉비닐        9      1256581000181008     439.0   911780.0
# 흙대파            9        97544070025038      39.0    97500.0
# 히츨러수수깡캔디       9        53303250084630      13.0    45500.0
#
# [1850 rows x 3 columns]

# %%
dfm10_1 = dfm10.groupby(['GDS_NM', 'month']).sum()
dfm10_1
# Out:
#                                 PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM         month
# 1000cc뚜껑       10        9900356353254       3.0    12600.0
# 12곡플러스그레인      10      560660983964998     146.0   219000.0
# 1300오이고추       10        4104100024010       3.0     3900.0
# 1664블랑캔        10        3080216031811       2.0     8600.0
# 1664블랑캔500ml6입 10       33882376501897      13.0   195000.0
# ...                                ...       ...        ...
# 흙당근            10            544954376    2715.0  4284940.0
# 흙당근1개          10      569810000421990     415.0   207500.0
# 흙당근1봉비닐        10     1196601000172368     430.0   824040.0
# 흙대파            10      142564410036594      57.0   142500.0
# 히츨러수수깡캔디       10        8200500013020       2.0     7000.0
#
# [1718 rows x 3 columns]

# %%
dfm11_1 = dfm11.groupby(['GDS_NM', 'month']).sum()
dfm11_1
# Out:
#                              PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM       month
# 10001200청량초  11      28732900140112      18.0    18000.0
# 1000cc뚜껑     11       3300118784418       1.0     4200.0
# 11           11       2750000013224       1.0     5000.0
# 12곡플러스그레인    11      65960115760588      19.0    28500.0
# 1300오이고추     11       2052050012005       1.0     1300.0
# ...                             ...       ...        ...
# 흑토마토1팩행사     11     477074361231968     172.0   946560.0
# 흑토마토2kg1박스행사 11      72535353646825      28.0   330400.0
# 흙당근          11           532491384    2650.0  4173540.0
# 흙당근1개        11       5998000004442       4.0     2000.0
# 흙대파          11     130058760033384      52.0   130000.0
#
# [1696 rows x 3 columns]

# %%
dfm12_1 = dfm12.groupby(['GDS_NM', 'month']).sum()
dfm12_1
# Out:
#                                PLU_CD  SALE_QTY   SALE_AMT
# GDS_NM         month
# 0000           12      17382432191114       2.0     3600.0
# 10001200청량초    12      36942300180144      18.0    18000.0
# 1000cc뚜껑       12       3300118784418       1.0     4200.0
# 1664블랑캔        12      21561512222677       8.0    28000.0
# 1664블랑캔500ml6입 12      15401080228135       9.0   189000.0
# ...                               ...       ...        ...
# 흙달래            12             4829592      24.0    61400.0
# 흙당근            12           564251912    2807.0  4215530.0
# 흙당근1봉비닐        12     899700000129600     325.0   643500.0
# 흙대파            12      72532770018618      29.0    72500.0
# 히츨러수수깡캔디       12       8200500013020       4.0    14000.0
#
# [1732 rows x 3 columns]

# %% [markdown]
# ---

# %%
dfm1_2 = dfm1_1.reset_index() 
dfm1_2
# Out:
#               GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0               0000      1     8691216095557       1.0     1800.0
# 1        10001200청량초      1    14366450070056       8.0     8000.0
# 2           1000cc뚜껑      1     6600237568836       2.0     8400.0
# 3            1664블랑캔      1    21561512222677      12.0    42000.0
# 4     1664블랑캔500ml6입      1    30802160456270      12.0   180000.0
# ...              ...    ...               ...       ...        ...
# 1745            흑토마토      1          11685086      61.0   271000.0
# 1746        흑토마토1팩행사      1   378168700976560     134.0   692600.0
# 1747             흙당근      1         765468928    3820.0  4203870.0
# 1748         흙당근1봉비닐      1  1391536000200448     503.0   774180.0
# 1749             흙대파      1   105047460026964      43.0   107500.0
#
# [1750 rows x 5 columns]

# %%
dfm2_2 = dfm2_1.reset_index() 
dfm2_2
# Out:
#               GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0               0000      2    34764864382228       4.0     7200.0
# 1        10001200청량초      2     2052350010008       1.0     1000.0
# 2           1000cc뚜껑      2     3300118784418       1.0     4200.0
# 3            1664블랑캔      2    15401080159055       9.0    31500.0
# 4     1664블랑캔500ml6입      2    24641728365016      14.0   210000.0
# ...              ...    ...               ...       ...        ...
# 1701            흑토마토      2           1007015       5.0    19900.0
# 1702        흑토마토1팩행사      2   421803551089240     153.0   914940.0
# 1703             흙당근      2         432787448    2157.0  2394380.0
# 1704         흙당근1봉비닐      2  1439520000207360     535.0   964260.0
# 1705             흙대파      2   110049720229286      45.0   113970.0
#
# [1706 rows x 5 columns]

# %%
dfm3_2 = dfm3_1.reset_index() 
dfm3_2
# Out:
#               GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0               0000      3    17382432191114       2.0     3600.0
# 1        10001200청량초      3    14366450070056       9.0     9000.0
# 2           1300오이고추      3    16416400096040      11.0    14300.0
# 3            1664블랑캔      3    15401080159055      12.0    42000.0
# 4     1664블랑캔500ml6입      3    33882376501897      21.0   339000.0
# ...              ...    ...               ...       ...        ...
# 1687        흑토마토1팩행사      3   445075471149336     159.0  1090820.0
# 1688             흙당근      3         546160472    2720.0  3240430.0
# 1689       흙당근100g특품      3    32989000373967      54.0     9560.0
# 1690         흙당근1봉비닐      3  1964345000282960     718.0  1421640.0
# 1691             흙대파      3   122555370031458      51.0   139100.0
#
# [1692 rows x 5 columns]

# %%
dfm4_2 = dfm4_1.reset_index() 
dfm4_2
# Out:
#              GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0       10001200청량초      4    30785250150120      16.0    16000.0
# 1          1300오이고추      4    18468450108045      10.0    13000.0
# 2           1664블랑캔      4    18481296190866       8.0    28000.0
# 3     2050780005007      4     4101560010014       4.0     2000.0
# 4           20kg천일염      4    58188828554720      21.0   619500.0
# ...             ...    ...               ...       ...        ...
# 1668            흙당근      4         565659024    2823.0  3907610.0
# 1669      흙당근100g특품      4    89970001019910     156.0    36200.0
# 1670        흙당근1봉비닐      4  1493502000215136     526.0  1041480.0
# 1671            흙대파      4    65029380016692      26.0    74200.0
# 1672      히말라야암염88g      4    18002828176988       2.0    23800.0
#
# [1673 rows x 5 columns]

# %%
dfm5_2 = dfm5_1.reset_index() 
dfm5_2
# Out:
#            GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0            0000      5    43456080477785       5.0     9000.0
# 1     10001200청량초      5    20523500100080      11.0    11000.0
# 2        1000cc뚜껑      5     3300118784418       1.0     4200.0
# 3        1300오이고추      5    12312300072030       8.0    10400.0
# 4         15kg꽃소금      5      290200000299       1.0    12500.0
# ...           ...    ...               ...       ...        ...
# 1658          흙당근      5         527667000    2628.0  4629110.0
# 1659    흙당근100g특품      5    86971000985913     244.0    79156.0
# 1660      흙당근1봉비닐      5  1985338000285984     716.0  1417680.0
# 1661          흙대파      5   122555370031458      49.0   122500.0
# 1662          흙생강      5            201021       1.0     7960.0
#
# [1663 rows x 5 columns]

# %%
dfm6_2 = dfm6_1.reset_index() 
dfm6_2
# Out:
#              GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0              0000      6     8691216095557       1.0     1800.0
# 1     0241405572666      6      482811145332       3.0     2700.0
# 2       10001200청량초      6    18471150090072       9.0     9000.0
# 3          1300오이고추      6    14364350084035       7.0     9100.0
# 4            1664블랑      6     3080216031811       1.0     3600.0
# ...             ...    ...               ...       ...        ...
# 1690   흑토마토2kg1박스행사      6    75436767792698      26.0   155480.0
# 1691            흙당근      6         531687320    2649.0  4880410.0
# 1692      흙당근100g특품      6   110963001257889     197.0    72390.0
# 1693        흙당근1봉비닐      6  2027324000292032     729.0  1579140.0
# 1694            흙대파      6   123909780029469      48.0   132100.0
#
# [1695 rows x 5 columns]

# %%
dfm7_2 = dfm7_1.reset_index() 
dfm7_2
# Out:
#             GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0             0000      7    26073648286671       4.0     7200.0
# 1      10001200청량초      7    28732900140112      15.0    15000.0
# 2         1300오이고추      7    10260250060025       7.0     9100.0
# 3           1664블랑      7     3080216031811       1.0     3600.0
# 4          1664블랑캔      7    30802160318110      24.0    84000.0
# ...            ...    ...               ...       ...        ...
# 1701  흑토마토2kg1박스행사      7   142169293147777      48.0   210060.0
# 1702           흙당근      7         509173528    2538.0  4931600.0
# 1703     흙당근100g특품      7   128957001461871     222.0    80340.0
# 1704       흙당근1봉비닐      7  1478507000212976     537.0  1281500.0
# 1705           흙대파      7   109199580028875      44.0   106200.0
#
# [1706 rows x 5 columns]

# %%
dfm8_2 = dfm8_1.reset_index() 
dfm8_2
# Out:
#            GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0            0000      8    17382432191114       3.0     5400.0
# 1     10001200청량초      8    10261750050040       6.0     6000.0
# 2        1300오이고추      8    14364350084035       7.0     9100.0
# 3          1664블랑      8     3080216031811       1.0     3600.0
# 4         1664블랑캔      8     9240648095433       4.0    14000.0
# ...           ...    ...               ...       ...        ...
# 1648    흙당근100g특품      8   128957001461871     174.0    71880.0
# 1649      흙당근1봉비닐      8  3196934000460512    1101.0  3244050.0
# 1650          흙대파      8   140399460040068      55.0   188000.0
# 1651          흙생강      8           1005105       5.0     6430.0
# 1652    히말라야암염88g      8     9001414088494       1.0     7900.0
#
# [1653 rows x 5 columns]

# %%
dfm9_2 = dfm9_1.reset_index() 
dfm9_2
# Out:
#               GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0               0000      9    17382432191114       4.0     7200.0
# 1          12곡플러스그레인      9   659601157605880     177.0   284910.0
# 2           1300오이고추      9     4104100024010       3.0     3900.0
# 3            1664블랑캔      9    24641728254488      42.0   180600.0
# 4     1664블랑캔500ml6입      9    15401080228135       8.0   120000.0
# ...              ...    ...               ...       ...        ...
# 1845             흙당근      9         744161232    3703.0  6624190.0
# 1846       흙당근100g특품      9     2999000033997      10.0     4500.0
# 1847         흙당근1봉비닐      9  1256581000181008     439.0   911780.0
# 1848             흙대파      9    97544070025038      39.0    97500.0
# 1849        히츨러수수깡캔디      9    53303250084630      13.0    45500.0
#
# [1850 rows x 5 columns]

# %%
dfm10_2 = dfm10_1.reset_index() 
dfm10_2
# Out:
#               GDS_NM  month            PLU_CD  SALE_QTY   SALE_AMT
# 0           1000cc뚜껑     10     9900356353254       3.0    12600.0
# 1          12곡플러스그레인     10   560660983964998     146.0   219000.0
# 2           1300오이고추     10     4104100024010       3.0     3900.0
# 3            1664블랑캔     10     3080216031811       2.0     8600.0
# 4     1664블랑캔500ml6입     10    33882376501897      13.0   195000.0
# ...              ...    ...               ...       ...        ...
# 1713             흙당근     10         544954376    2715.0  4284940.0
# 1714           흙당근1개     10   569810000421990     415.0   207500.0
# 1715         흙당근1봉비닐     10  1196601000172368     430.0   824040.0
# 1716             흙대파     10   142564410036594      57.0   142500.0
# 1717        히츨러수수깡캔디     10     8200500013020       2.0     7000.0
#
# [1718 rows x 5 columns]

# %%
dfm11_2 = dfm11_1.reset_index() 
dfm11_2
# Out:
#             GDS_NM  month           PLU_CD  SALE_QTY   SALE_AMT
# 0      10001200청량초     11   28732900140112      18.0    18000.0
# 1         1000cc뚜껑     11    3300118784418       1.0     4200.0
# 2               11     11    2750000013224       1.0     5000.0
# 3        12곡플러스그레인     11   65960115760588      19.0    28500.0
# 4         1300오이고추     11    2052050012005       1.0     1300.0
# ...            ...    ...              ...       ...        ...
# 1691      흑토마토1팩행사     11  477074361231968     172.0   946560.0
# 1692  흑토마토2kg1박스행사     11   72535353646825      28.0   330400.0
# 1693           흙당근     11        532491384    2650.0  4173540.0
# 1694         흙당근1개     11    5998000004442       4.0     2000.0
# 1695           흙대파     11  130058760033384      52.0   130000.0
#
# [1696 rows x 5 columns]

# %%
dfm12_2 = dfm12_1.reset_index() 
dfm12_2
# Out:
#               GDS_NM  month           PLU_CD  SALE_QTY   SALE_AMT
# 0               0000     12   17382432191114       2.0     3600.0
# 1        10001200청량초     12   36942300180144      18.0    18000.0
# 2           1000cc뚜껑     12    3300118784418       1.0     4200.0
# 3            1664블랑캔     12   21561512222677       8.0    28000.0
# 4     1664블랑캔500ml6입     12   15401080228135       9.0   189000.0
# ...              ...    ...              ...       ...        ...
# 1727             흙달래     12          4829592      24.0    61400.0
# 1728             흙당근     12        564251912    2807.0  4215530.0
# 1729         흙당근1봉비닐     12  899700000129600     325.0   643500.0
# 1730             흙대파     12   72532770018618      29.0    72500.0
# 1731        히츨러수수깡캔디     12    8200500013020       4.0    14000.0
#
# [1732 rows x 5 columns]

# %% [markdown]
# ---

# %%
dfm1_3 = dfm1_2[dfm1_2.SALE_QTY > 29]

# %%
dfm2_3 = dfm2_2[dfm2_2.SALE_QTY > 29]

# %%
dfm3_3 = dfm3_2[dfm3_2.SALE_QTY > 29]

# %%
dfm4_3 = dfm4_2[dfm4_2.SALE_QTY > 29]

# %%
dfm5_3 = dfm5_2[dfm5_2.SALE_QTY > 29]

# %%
dfm6_3 = dfm6_2[dfm6_2.SALE_QTY > 29]

# %%
dfm7_3 = dfm7_2[dfm7_2.SALE_QTY > 29]

# %%
dfm8_3 = dfm8_2[dfm8_2.SALE_QTY > 29]

# %%
dfm9_3 = dfm9_2[dfm9_2.SALE_QTY > 29]

# %%
dfm10_3 = dfm10_2[dfm10_2.SALE_QTY > 29]

# %%
dfm11_3 = dfm11_2[dfm11_2.SALE_QTY > 29]

# %%
dfm12_3 = dfm12_2[dfm12_2.SALE_QTY > 29]

# %% [markdown]
# ---

# %%
dfm1_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#                GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 359              대파1단      1  22067598188031456    9096.0  12947560.0
# 826              소주공병      1    397718648937789    7396.0    739540.0
# 254           느타리버섯1팩      1  12816089487194830    6224.0   8125820.0
# 213           남해초1단행사      1  11490510525856700    5588.0  12100780.0
# 1155        인큐애호박2개행사      1  11687226220373340    5250.0  11489320.0
# 621         무우1개봉투명비닐      1  10844714744261824    5105.0   6606720.0
# 192            깻잎4묶음봉      1  10670175335819512    4652.0   6900740.0
# 1472           팽이버섯1봉      1   8325529389510426    4614.0   2576770.0
# 699             백오이1개      1  11437014250779196    4537.0  14801900.0
# 1457           파프리카1개      1   6254328593436850    4296.0   7405130.0
# 779           새송이버섯1봉      1  10033106533811896    4132.0   7959240.0
# 1747              흙당근      1          765468928    3820.0   4203870.0
# ...

# %%
dfm2_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#                GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 318              달래1단      2   3258068806792800    8702.0   9174240.0
# 344              대파1단      2  14885301862397748    6385.0   8299290.0
# 662             백오이1개      2  12597881380278280    5092.0  13136680.0
# 786              소주공병      2    386395860844937    4343.0    430700.0
# 1118        인큐애호박2개행사      2   9572062301475800    4204.0   7472940.0
# 1431          팩딸기3팩전단      2   8241252008035152    3829.0  22008580.0
# 174            깻잎4묶음봉      2   8255713632240294    3446.0   3945220.0
# 1153          적상추1봉비닐      2   9265133163813256    3440.0   3764800.0
# 235           느타리버섯1팩      2   6764451318439950    2990.0   3020920.0
# 856             시금치1단      2   5930923234909344    2901.0   3836900.0
# 1259            청양고추소      2   7476104313104430    2734.0   6060680.0
# 1442           팽이버섯1봉      2   5099459475825219    2723.0   1368900.0
# ...

# %%
dfm3_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 1101      인큐애호박2개행사      3  16674008829713620    8051.0  10394480.0
# 638             배송비      3                  4    8000.0      8000.0
# 322            대파1단      3  17675023278470136    7475.0  10801200.0
# 642           백오이1개      3  15390945150501640    6370.0  20890280.0
# 575         무우1개행사용      3  10134921181106072    5144.0   6057140.0
# 166          깻잎4묶음봉      3  10579996645685840    4668.0   4756120.0
# 1401         파프리카1개      3   6402687085653259    4309.0   6333440.0
# 1418         팽이버섯1봉      3   7697187548792658    4284.0   2262920.0
# 228         느타리버섯1팩      3   9647707772880376    4281.0   3784340.0
# 1132        적상추1봉비닐      3   9972017734866904    3702.0   4278810.0
# 721   새송이버섯2봉1인2봉한정      3   9198226398051792    3648.0   5202800.0
# 766            소주공병      3    452556460033868    3587.0    358700.0
# 829           시금치1단      3   6027427293548808    2935.0   3907780.0
# ...

# %%
dfm4_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 636           백오이1개      4  25931851441667508   11394.0  25873560.0
# 1088      인큐애호박2개행사      4  20229346255976060   10797.0  11514300.0
# 309            대파1단      4  13375536049111440    5599.0   6815480.0
# 1386         파프리카1개      4   6364870215088292    4465.0   5730940.0
# 147          깻잎4묶음봉      4   9797478334525912    4326.0   4326000.0
# 1402         팽이버섯1봉      4   7193932278217779    4162.0   2236910.0
# 719   새송이버섯2봉1인2봉한정      4  10041833499707112    4107.0   5103360.0
# 1115        적상추1봉비닐      4  10094195315049016    3818.0   4677940.0
# 570         무우1개행사용      4   7249203095096536    3293.0   3899680.0
# 938             양파소      4   2987532734689282    3028.0   7369280.0
# 755            소주공병      4    368427575027851    2921.0    292100.0
# 1668            흙당근      4          565659024    2823.0   3907610.0
# 1223          청양고추소      4   7560465023252301    2712.0   4481490.0
# ...

# %%
dfm5_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 1088        인큐애호박1개      5  17002195977293456    7290.0   8172220.0
# 644           백오이3개      5  11346821573685000    6509.0   9136720.0
# 325            대파1단      5  13605346259611668    5466.0   7905960.0
# 642           백오이1개      5   9793179844345656    4374.0   8542680.0
# 758            소주공병      5    519477503647907    4117.0    409180.0
# 741         성주참외10개      5  11153067676041456    3965.0  38893600.0
# 1113        적상추1봉비닐      5   9573486104272872    3731.0   4137000.0
# 160          깻잎4묶음봉      5   7950269681787429    3633.0   3936800.0
# 711     빨강대추방울토마토1팩      5   8569884551227206    3578.0  12285560.0
# 849        쌈배추알배기1통      5   6616069809630138    3448.0   6238560.0
# 728   새송이버섯2봉1인2봉한정      5   8133536055962364    3253.0   4739380.0
# 683            부추1단      5   7314335752616616    3120.0   5486380.0
# 826           시금치1단      5   6719766915105090    3116.0   5270000.0
# ...

# %%
dfm6_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 870       아이스크림바10개      6   1104995750039950    9033.0   5866740.0
# 648           백오이3개      6  17939615852138900    8150.0  13711620.0
# 1404       파프리카2개행사      6  11897033135309440    6247.0   7651330.0
# 326            대파1단      6  12910097648098320    5055.0   7847000.0
# 1115        인큐애호박1개      6   9869333074912244    4699.0   5383900.0
# 173          깻잎4묶음봉      6   9023686993378920    4370.0   4370000.0
# 750         성주참외10개      6  10251280774744416    3714.0  31379000.0
# 738   새송이버섯2봉1인2봉한정      6   8811330727292561    3709.0   4668390.0
# 716     빨강대추방울토마토1팩      6   8566975561223395    3638.0  10748680.0
# 231         느타리버섯1팩      6   7023391605468404    3443.0   2210290.0
# 47            가지5입봉      6   7938633829093560    3295.0   5800160.0
# 689            부추1단      6   7203776978312944    3218.0   4368720.0
# 764            소주공병      6    380213914632341    3186.0    318600.0
# ...

# %%
dfm7_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 175          깻잎4묶음봉      7  11618506077225224    5709.0   6102570.0
# 670         백오이3입1봉      7  13357546156059252    5232.0  12622200.0
# 338            대파1단      7  12956641488199632    5219.0   9003660.0
# 1126        인큐애호박1개      7  10388704139679016    4874.0   6205600.0
# 763   새송이버섯2봉1인2봉한정      7   9588031058816664    4224.0   4785980.0
# 1128        일반애호박2개      7   7508103210376995    3683.0   4074560.0
# 1413       파프리카2개행사      7   7770409088376419    3536.0   4568500.0
# 881        쌈배추알배기1통      7   5493025418021856    3083.0   6114940.0
# 44            가지5입봉      7   7769912406562440    3063.0   6560540.0
# 794            소주공병      7    351029519029452    2920.0    291940.0
# 1235      천도복숭아특10개      7   6879761368508490    2612.0  14982560.0
# 240         느타리버섯1팩      7   5239904010542086    2586.0   1691570.0
# 1702            흙당근      7          509173528    2538.0   4931600.0
# ...

# %%
dfm8_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#           GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 314         대파1단      8  15615458353987080    6396.0  11725060.0
# 158       깻잎4묶음봉      8   9573486104193888    4362.0   6986230.0
# 1388      팽이버섯1봉      8   6603407307543210    3901.0   2069250.0
# 642      백오이3입1봉      8   9116960106515520    3483.0  12996340.0
# 845     쌈배추알배기1통      8   5501753742308967    3373.0   7259550.0
# 564         무우1개      8   6441852074623668    2891.0   6431900.0
# 874    아이스크림바10개      8   1710793420061852    2835.0  11283300.0
# 727      새송이버섯1봉      8   6824490556196784    2773.0   4039550.0
# 223      느타리버섯1팩      8   5615221954661980    2638.0   2025220.0
# 759         소주공병      8    333615414025071    2626.0    262600.0
# 862      아삭이고추1팩      8   6453848003882208    2579.0   3472900.0
# 1193   천도복숭아특10개      8   6379415087162418    2539.0  14274200.0
# 1647         흙당근      8          494097328    2461.0   5147600.0
# ...

# %%
dfm9_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#                GDS_NM  month             PLU_CD  SALE_QTY     SALE_AMT
# 836            소금20kg      9      5002260001420   10000.0  270000000.0
# 337              대파1단      9  16581243036089304    6586.0   12939950.0
# 954            아보카도1개      9   5812746311320416    5201.0    5212760.0
# 1218          일반애호박1개      9   9355311857276352    5183.0    6465850.0
# 782           새송이버섯1봉      9  11662140937678136    5103.0    9594380.0
# 623         무우1개봉투명비닐      9  10943620404483096    4581.0    6118300.0
# 1216          인큐애호박1개      9   8810672099175280    4380.0    6829920.0
# 1559           팽이버섯2봉      9   7752458359793875    4249.0    2819990.0
# 242           느타리버섯2팩      9   8616428396587200    4152.0    6139360.0
# 185            깻잎4묶음봉      9   9558941154172328    4050.0    8401250.0
# 704             백오이1개      9   9196744351745876    3763.0    9673220.0
# 1845              흙당근      9          744161232    3703.0    6624190.0
# ...

# %%
dfm10_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#            GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 319          대파1단     10  16034352914898888    6307.0   9163280.0
# 286          단감5개     10        90894434310    4731.0  32996318.0
# 170        깻잎4묶음봉     10   9393128723926544    3900.0   5883450.0
# 591     무우1개봉투명비닐     10   8846238609790828    3617.0   4393020.0
# 750       새송이버섯1봉     10   8985870131326456    3611.0   5674750.0
# 222       느타리버섯1팩     10   7279422451069572    3300.0   2791590.0
# 805          소주공병     10    371328391027808    3056.0    305600.0
# 1713          흙당근     10          544954376    2715.0   4284940.0
# 732   빨강대추방울토마토1팩     10   6175221047840087    2578.0   8682330.0
# 669         백오이1개     10   6153468618773340    2414.0   7270940.0
# 330     델몬트바나나1송이     10   6807036609860760    2409.0   8545420.0
# 1142    인큐애호박2개행사     10   5626859723724680    2349.0   3681560.0
# 1277        청양고추소     10   6149604870779286    2294.0   3767720.0
# ...

# %%
dfm11_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#          GDS_NM  month             PLU_CD  SALE_QTY      SALE_AMT
# 904      아이스콘1개     11     10399960000400   11001.0  9.900900e+06
# 1132         잡화     11    301598840013572   10135.0  3.999925e+09
# 334        대파1단     11  17677932268476468    7517.0  1.174678e+07
# 1111  인큐애호박2개행사     11  11524297500348220    5532.0  7.456900e+06
# 928          야채     11   3709257286299259    5415.0  1.371450e+07
# 1203      쪽파대1단     11   7918270794973722    4556.0  2.848208e+07
# 178      깻잎4묶음봉     11   9430945593982600    4112.0  4.605700e+06
# 797        소주공병     11    446786443045246    3874.0  3.838000e+05
# 232     느타리버섯1팩     11   7596551566643746    3622.0  2.873470e+06
# 743     새송이버섯1봉     11   8278985559648784    3589.0  5.036240e+06
# 1433     팽이버섯1봉     11   6073971126938424    3573.0  1.858680e+06
# 304        단감5개     11        62642569470    3358.0  2.646110e+07
# 663       백오이1개     11   7919499565154152    3153.0  9.779020e+06
# ...

# %%
dfm12_3.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#                GDS_NM  month             PLU_CD  SALE_QTY    SALE_AMT
# 348              대파1단     12  15109294092885312    6122.0   8896540.0
# 195           남해초1단행사     12  12377752477853230    5678.0  10147120.0
# 1442           파프리카1개     12   6481229816826652    4696.0   5453160.0
# 235           느타리버섯1팩     12   8542120030511696    4038.0   3995190.0
# 1133        인큐애호박2개행사     12   9121098879977700    3979.0   7224420.0
# 1461           팽이버섯1봉     12   6937941157925355    3866.0   1883300.0
# 177            깻잎4묶음봉     12   9244770233706632    3807.0   5010830.0
# 686             백오이1개     12   8835973614758692    3536.0   9881740.0
# 760           새송이버섯1봉     12   8526249710235624    3421.0   5517580.0
# 810              소주공병     12    394718592632958    3370.0    337000.0
# 106           구호물품택배비     12     34907880518028    3359.0  13436000.0
# 881             시금치1단     12   6207784673954226    3178.0   3534470.0
# ...

# %% [markdown]
# ---

# %%
testing1 = dfm1_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing1
# Out:
#         GDS_NM  month  SALE_QTY    SALE_AMT
# 26     HS쿨맨솔샴푸      1      30.0    227370.0
# 31        LA갈비      1     308.0  23987070.0
# 34      SB생와사비      1      89.0    289250.0
# 46          가지      1     146.0    305640.0
# 48        가지2입      1      71.0    161880.0
# ...        ...    ...       ...         ...
# 1745      흑토마토      1      61.0    271000.0
# 1746  흑토마토1팩행사      1     134.0    692600.0
# 1747       흙당근      1    3820.0   4203870.0
# 1748   흙당근1봉비닐      1     503.0    774180.0
# 1749       흙대파      1      43.0    107500.0
#
# [583 rows x 4 columns]

# %%
testing2 = dfm2_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing2
# Out:
#                 GDS_NM  month  SALE_QTY   SALE_AMT
# 31                LA갈비      2      38.0  3051340.0
# 33              SB생와사비      2      66.0   214500.0
# 43                  가지      2     102.0   232300.0
# 46               가지5입봉      2     702.0  1400700.0
# 49            감귤800g1팩      2     138.0   411240.0
# ...                ...    ...       ...        ...
# 1700  흑대추방울토마토500g1팩행사      2    1188.0  4297240.0
# 1702          흑토마토1팩행사      2     153.0   914940.0
# 1703               흙당근      2    2157.0  2394380.0
# 1704           흙당근1봉비닐      2     535.0   964260.0
# 1705               흙대파      2      45.0   113970.0
#
# [550 rows x 4 columns]

# %%
testing3 = dfm3_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing3
# Out:
#          GDS_NM  month  SALE_QTY   SALE_AMT
# 27       SB생와사비      3      43.0   139750.0
# 37           가지      3     156.0   364200.0
# 38        가지5입봉      3    1130.0  2995920.0
# 42     감귤800g1팩      3     237.0  1109540.0
# 43       감귤L1상자      3      69.0   559400.0
# ...         ...    ...       ...        ...
# 1687   흑토마토1팩행사      3     159.0  1090820.0
# 1688        흙당근      3    2720.0  3240430.0
# 1689  흙당근100g특품      3      54.0     9560.0
# 1690    흙당근1봉비닐      3     718.0  1421640.0
# 1691        흙대파      3      51.0   139100.0
#
# [576 rows x 4 columns]

# %%
testing4 = dfm4_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing4
# Out:
#                 GDS_NM  month  SALE_QTY   SALE_AMT
# 5               4D후르츠향      4     350.0   182700.0
# 20                LA갈비      4      35.0  2264660.0
# 22              SB생와사비      4      43.0   139750.0
# 31                가시오이      4      73.0   108700.0
# 34                  가지      4     127.0   293660.0
# ...                ...    ...       ...        ...
# 1665  흑대추방울토마토750g1팩행사      4     381.0  1350380.0
# 1667          흑토마토1팩행사      4     184.0  1166320.0
# 1668               흙당근      4    2823.0  3907610.0
# 1669         흙당근100g특품      4     156.0    36200.0
# 1670           흙당근1봉비닐      4     526.0  1041480.0
#
# [552 rows x 4 columns]

# %%
testing5 = dfm5_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing5
# Out:
#          GDS_NM  month  SALE_QTY   SALE_AMT
# 7       20kg천일염      5      49.0  1445500.0
# 10       4D후르츠향      5     228.0   116100.0
# 32         LA갈비      5      31.0  1702420.0
# 34       SB생와사비      5      47.0   152750.0
# 43         가시오이      5      33.0   180700.0
# ...         ...    ...       ...        ...
# 1657   흑토마토1팩행사      5     153.0   774140.0
# 1658        흙당근      5    2628.0  4629110.0
# 1659  흙당근100g특품      5     244.0    79156.0
# 1660    흙당근1봉비닐      5     716.0  1417680.0
# 1661        흙대파      5      49.0   122500.0
#
# [543 rows x 4 columns]

# %%
testing6 = dfm6_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing6
# Out:
#          GDS_NM  month  SALE_QTY   SALE_AMT
# 7       20kg천일염      6      40.0  1180000.0
# 14    4개_젤리스트로우      6      32.0     6400.0
# 19       G7순수블랙      6      31.0    83700.0
# 32         LA갈비      6      39.0  1812230.0
# 35       SB생와사비      6      40.0   130000.0
# ...         ...    ...       ...        ...
# 1689   흑토마토1팩행사      6     148.0   510920.0
# 1691        흙당근      6    2649.0  4880410.0
# 1692  흙당근100g특품      6     197.0    72390.0
# 1693    흙당근1봉비닐      6     729.0  1579140.0
# 1694        흙대파      6      48.0   132100.0
#
# [565 rows x 4 columns]

# %%
testing7 = dfm7_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing7
# Out:
#             GDS_NM  month  SALE_QTY   SALE_AMT
# 33          SB생와사비      7      45.0   146250.0
# 42       가시오이2개입1팩      7     213.0   593940.0
# 43              가지      7     345.0   666820.0
# 44           가지5입봉      7    3063.0  6560540.0
# 49       감숙왕마운틴바나나      7     143.0   469500.0
# ...            ...    ...       ...        ...
# 1701  흑토마토2kg1박스행사      7      48.0   210060.0
# 1702           흙당근      7    2538.0  4931600.0
# 1703     흙당근100g특품      7     222.0    80340.0
# 1704       흙당근1봉비닐      7     537.0  1281500.0
# 1705           흙대파      7      44.0   106200.0
#
# [575 rows x 4 columns]

# %%
testing8 = dfm8_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing8
# Out:
#          GDS_NM  month  SALE_QTY   SALE_AMT
# 28         LA갈비      8      70.0  4023100.0
# 30       SB생와사비      8      33.0   107250.0
# 38         가시오이      8      55.0    86080.0
# 39    가시오이2개입1팩      8     108.0   366470.0
# 40           가지      8     445.0   855560.0
# ...         ...    ...       ...        ...
# 1640      황도복숭아      8     315.0  4178000.0
# 1647        흙당근      8    2461.0  5147600.0
# 1648  흙당근100g특품      8     174.0    71880.0
# 1649    흙당근1봉비닐      8    1101.0  3244050.0
# 1650        흙대파      8      55.0   188000.0
#
# [542 rows x 4 columns]

# %%
testing9 = dfm9_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing9
# Out:
#          GDS_NM  month  SALE_QTY    SALE_AMT
# 1     12곡플러스그레인      9     177.0    284910.0
# 3       1664블랑캔      9      42.0    180600.0
# 34         LA갈비      9     448.0  26669290.0
# 37       SB생와사비      9      65.0    211250.0
# 44         가시오이      9     269.0    513520.0
# ...         ...    ...       ...         ...
# 1833      황도복숭아      9      42.0    847800.0
# 1843       흑토마토      9      77.0    384140.0
# 1845        흙당근      9    3703.0   6624190.0
# 1847    흙당근1봉비닐      9     439.0    911780.0
# 1848        흙대파      9      39.0     97500.0
#
# [580 rows x 4 columns]

# %%
testing10 = dfm10_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing10
# Out:
#          GDS_NM  month  SALE_QTY   SALE_AMT
# 1     12곡플러스그레인     10     146.0   219000.0
# 6       20kg천일염     10      62.0  1753800.0
# 21       G7순수블랙     10      35.0    80000.0
# 30         LA갈비     10      77.0  3247240.0
# 32       SB생와사비     10      74.0   240500.0
# ...         ...    ...       ...        ...
# 1711       흑토마토     10      68.0   282500.0
# 1713        흙당근     10    2715.0  4284940.0
# 1714      흙당근1개     10     415.0   207500.0
# 1715    흙당근1봉비닐     10     430.0   824040.0
# 1716        흙대파     10      57.0   142500.0
#
# [584 rows x 4 columns]

# %%
testing11 = dfm11_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing11
# Out:
#              GDS_NM  month  SALE_QTY   SALE_AMT
# 9     2050780005007     11      36.0    17900.0
# 10          20kg천일염     11      69.0  2035500.0
# 36             LA갈비     11      53.0  2185210.0
# 39           SB생와사비     11      65.0   211250.0
# 47             가시오이     11     112.0   245100.0
# ...             ...    ...       ...        ...
# 1675            홍피망     11     102.0   142510.0
# 1682        황금향특10개     11     201.0  1009600.0
# 1691       흑토마토1팩행사     11     172.0   946560.0
# 1693            흙당근     11    2650.0  4173540.0
# 1695            흙대파     11      52.0   130000.0
#
# [550 rows x 4 columns]

# %%
testing12 = dfm12_3[['GDS_NM', 'month', 'SALE_QTY', 'SALE_AMT']]
testing12
# Out:
#         GDS_NM  month  SALE_QTY   SALE_AMT
# 15      G7순수블랙     12      37.0    99900.0
# 28        LA갈비     12     111.0  4634460.0
# 31      SB생와사비     12      90.0   292500.0
# 45          가지     12     177.0   550390.0
# 47        가지2입     12      33.0    98340.0
# ...        ...    ...       ...        ...
# 1718   황금향특10개     12      52.0   514800.0
# 1721     후르츠텔라     12      38.0    79800.0
# 1725  흑토마토1팩행사     12     800.0  2787640.0
# 1728       흙당근     12    2807.0  4215530.0
# 1729   흙당근1봉비닐     12     325.0   643500.0
#
# [558 rows x 4 columns]

# %% [markdown]
# ---

# %%
testing1_1 = testing1[testing1.SALE_QTY > 1724.0]
testing1_1
# Out:
#                GDS_NM  month  SALE_QTY    SALE_AMT
# 69                 감자      1    2466.0   7527700.0
# 118           구호물품택배비      1    3015.0  12060000.0
# 149          국내산한돈다짐육      1    1749.0   9108680.0
# 192            깻잎4묶음봉      1    4652.0   6900740.0
# 213           남해초1단행사      1    5588.0  12100780.0
# 254           느타리버섯1팩      1    6224.0   8125820.0
# 359              대파1단      1    9096.0  12947560.0
# 373         델몬트바나나1송이      1    1950.0   7295120.0
# 621         무우1개봉투명비닐      1    5105.0   6606720.0
# 699             백오이1개      1    4537.0  14801900.0
# 731                봄동      1    1926.0   4715070.0
# 736            부사사과6개      1    2552.0  25093800.0
# 779           새송이버섯1봉      1    4132.0   7959240.0
# 826              소주공병      1    7396.0    739540.0
# 847   수입산브로컬리2송이구입시행사      1    2126.0   2281740.0
# 854                숙주      1    1840.0   3068810.0
# 893             시금치1단      1    2756.0   4422640.0
# ...

# %%
testing2_1 = testing2[testing2.SALE_QTY > 1239.0]
testing2_1
# Out:
#                GDS_NM  month  SALE_QTY    SALE_AMT
# 59                 감자      2    2049.0   8437700.0
# 104           구호물품택배비      2    1900.0   7600000.0
# 130   국내산브로컬리2송이구입시행사      2    1277.0   1472560.0
# 174            깻잎4묶음봉      2    3446.0   3945220.0
# 235           느타리버섯1팩      2    2990.0   3020920.0
# 241         다라딸기1다라행사      2    2538.0  20635800.0
# 318              달래1단      2    8702.0   9174240.0
# 344              대파1단      2    6385.0   8299290.0
# 419                딸기      2    1449.0  14795740.0
# 591         무우1개봉투명비닐      2    2692.0   3156500.0
# 662             백오이1개      2    5092.0  13136680.0
# 689                봄동      2    1528.0   4786660.0
# 694            부사사과6개      2    1647.0  16140600.0
# 709         블루베리특3팩행사      2    2008.0   3967720.0
# 737           새송이버섯1봉      2    1423.0   2176800.0
# 738     새송이버섯2봉1인2봉한정      2    1666.0   2492260.0
# 786              소주공병      2    4343.0    430700.0
# ...

# %%
testing3_1 = testing3[testing3.SALE_QTY > 1537.0]
testing3_1
# Out:
#              GDS_NM  month  SALE_QTY    SALE_AMT
# 46               감자      3    2718.0  11702410.0
# 119        국내산양상추1통      3    1544.0   2981380.0
# 166          깻잎4묶음봉      3    4668.0   4756120.0
# 228         느타리버섯1팩      3    4281.0   3784340.0
# 233       다라딸기1다라행사      3    1663.0  14659200.0
# 322            대파1단      3    7475.0  10801200.0
# 401              딸기      3    2167.0  20944900.0
# 575         무우1개행사용      3    5144.0   6057140.0
# 638             배송비      3    8000.0      8000.0
# 642           백오이1개      3    6370.0  20890280.0
# 679          부사사과6개      3    2415.0  23667000.0
# 682            부추1단      3    2391.0   5485200.0
# 721   새송이버섯2봉1인2봉한정      3    3648.0   5202800.0
# 766            소주공병      3    3587.0    358700.0
# 829           시금치1단      3    2935.0   3907780.0
# 867          아보카도1개      3    1564.0   1700920.0
# 908              야채      3    1906.0   4587040.0
# 950           양파중1망      3    1740.0   5140200.0
# ...

# %%
testing4_1 = testing4[testing4.SALE_QTY > 1581.0]
testing4_1
# Out:
#              GDS_NM  month  SALE_QTY    SALE_AMT
# 38               감자      4    2446.0  11300580.0
# 147          깻잎4묶음봉      4    4326.0   4326000.0
# 216         느타리버섯1팩      4    1724.0   1616220.0
# 218      느타리버섯2팩구입시      4    2347.0   1696420.0
# 309            대파1단      4    5599.0   6815480.0
# 393              딸기      4    1872.0  16757920.0
# 570         무우1개행사용      4    3293.0   3899680.0
# 591             바나나      4    1712.0   7852000.0
# 636           백오이1개      4   11394.0  25873560.0
# 672          부사사과6개      4    2027.0  19864600.0
# 676            부추1단      4    2646.0   6376160.0
# 700     빨강대추방울토마토1팩      4    2019.0   7340960.0
# 719   새송이버섯2봉1인2봉한정      4    4107.0   5103360.0
# 755            소주공병      4    2921.0    292100.0
# 818           시금치1단      4    2366.0   3509440.0
# 899              야채      4    1733.0   4067900.0
# 938             양파소      4    3028.0   7369280.0
# 940           양파중1망      4    2268.0   6713420.0
# ...

# %%
testing5_1 = testing5[testing5.SALE_QTY > 1756.0]
testing5_1
# Out:
#              GDS_NM  month  SALE_QTY    SALE_AMT
# 46            가지5입봉      5    2540.0   4987900.0
# 52               감자      5    2620.0  10045420.0
# 119        국내산양상추1통      5    2050.0   2538880.0
# 160          깻잎4묶음봉      5    3633.0   3936800.0
# 224         느타리버섯1팩      5    2605.0   2017470.0
# 325            대파1단      5    5466.0   7905960.0
# 581         무우1개행사용      5    2250.0   3293580.0
# 642           백오이1개      5    4374.0   8542680.0
# 644           백오이3개      5    6509.0   9136720.0
# 679          부사사과6개      5    2347.0  23000600.0
# 683            부추1단      5    3120.0   5486380.0
# 711     빨강대추방울토마토1팩      5    3578.0  12285560.0
# 728   새송이버섯2봉1인2봉한정      5    3253.0   4739380.0
# 741         성주참외10개      5    3965.0  38893600.0
# 758            소주공병      5    4117.0    409180.0
# 826           시금치1단      5    3116.0   5270000.0
# 849        쌈배추알배기1통      5    3448.0   6238560.0
# 901              야채      5    1799.0   4297120.0
# ...

# %%
testing6_1 = testing6[testing6.SALE_QTY > 1455.0]
testing6_1
# Out:
#              GDS_NM  month  SALE_QTY    SALE_AMT
# 47            가지5입봉      6    3295.0   5800160.0
# 54               감자      6    2745.0   8169830.0
# 173          깻잎4묶음봉      6    4370.0   4370000.0
# 231         느타리버섯1팩      6    3443.0   2210290.0
# 326            대파1단      6    5055.0   7847000.0
# 582            무우1개      6    2240.0   3613880.0
# 648           백오이3개      6    8150.0  13711620.0
# 686          부사사과6개      6    1723.0  16885400.0
# 689            부추1단      6    3218.0   4368720.0
# 716     빨강대추방울토마토1팩      6    3638.0  10748680.0
# 738   새송이버섯2봉1인2봉한정      6    3709.0   4668390.0
# 750         성주참외10개      6    3714.0  31379000.0
# 764            소주공병      6    3186.0    318600.0
# 824           시금치1단      6    1879.0   3402040.0
# 846        쌈배추알배기1통      6    2066.0   4204440.0
# 859          아보카도1개      6    2438.0   2538000.0
# 870       아이스크림바10개      6    9033.0   5866740.0
# 909              야채      6    1917.0   4322930.0
# ...

# %%
testing7_1 = testing7[testing7.SALE_QTY > 1538.0]
testing7_1
# Out:
#              GDS_NM  month  SALE_QTY    SALE_AMT
# 44            가지5입봉      7    3063.0   6560540.0
# 51               감자      7    1692.0   4039610.0
# 122        국내산돈앞다리살      7    1842.0  14378470.0
# 175          깻잎4묶음봉      7    5709.0   6102570.0
# 187   꿀수박59kg이상1통행사      7    2478.0  39996400.0
# 240         느타리버섯1팩      7    2586.0   1691570.0
# 338            대파1단      7    5219.0   9003660.0
# 593            무우1개      7    2372.0   3628400.0
# 670         백오이3입1봉      7    5232.0  12622200.0
# 720            부추1단      7    1748.0   3830980.0
# 742     빨강대추방울토마토1팩      7    2212.0   7583800.0
# 763   새송이버섯2봉1인2봉한정      7    4224.0   4785980.0
# 794            소주공병      7    2920.0    291940.0
# 881        쌈배추알배기1통      7    3083.0   6114940.0
# 893          아보카도1개      7    2076.0   2383500.0
# 897         아삭이고추1팩      7    1574.0   2710920.0
# 935              야채      7    1921.0   4551720.0
# 976           양파중1망      7    1580.0   5464040.0
# ...

# %%
testing8_1 = testing8[testing8.SALE_QTY > 1514.0]
testing8_1
# Out:
#           GDS_NM  month  SALE_QTY    SALE_AMT
# 41      가지5개벌크행사      8    2030.0   3193300.0
# 42         가지5입봉      8    2003.0   4269590.0
# 50            감자      8    1769.0   5083530.0
# 111     국내산돈앞다리살      8    1870.0  14531870.0
# 158       깻잎4묶음봉      8    4362.0   6986230.0
# 223      느타리버섯1팩      8    2638.0   2025220.0
# 224      느타리버섯2팩      8    2040.0   1926060.0
# 314         대파1단      8    6396.0  11725060.0
# 564         무우1개      8    2891.0   6431900.0
# 600     바나나1송이행사      8    1907.0   3770430.0
# 641        백오이3개      8    1877.0   4646820.0
# 642      백오이3입1봉      8    3483.0  12996340.0
# 681         부추1단      8    1954.0   4302930.0
# 727      새송이버섯1봉      8    2773.0   4039550.0
# 759         소주공병      8    2626.0    262600.0
# 785   수입산브로컬리1송이      8    1599.0   1745790.0
# 845     쌈배추알배기1통      8    3373.0   7259550.0
# 862      아삭이고추1팩      8    2579.0   3472900.0
# 867    아오리사과5개행사      8    1805.0  15558600.0
# ...

# %%
testing9_1 = testing9[testing9.SALE_QTY > 1647.0]
testing9_1
# Out:
#                GDS_NM  month  SALE_QTY     SALE_AMT
# 49              가지5입봉      9    2995.0    6466040.0
# 185            깻잎4묶음봉      9    4050.0    8401250.0
# 242           느타리버섯2팩      9    4152.0    6139360.0
# 337              대파1단      9    6586.0   12939950.0
# 623         무우1개봉투명비닐      9    4581.0    6118300.0
# 661               바나나      9    1694.0    4311400.0
# 662         바나나1봉송이행사      9    1823.0    3344820.0
# 704             백오이1개      9    3763.0    9673220.0
# 706             백오이3개      9    2957.0    6472100.0
# 782           새송이버섯1봉      9    5103.0    9594380.0
# 836            소금20kg      9   10000.0  270000000.0
# 839              소주공병      9    2727.0     271200.0
# 861   수입산브로컬리2송이구입시행사      9    1751.0    1690820.0
# 913         시금치2단어플행사      9    2978.0   10365960.0
# 941           쌈배추벌크1통      9    1681.0    3993100.0
# 954            아보카도1개      9    5201.0    5212760.0
# 969         아이스크림바10개      9    2804.0    1193200.0
# ...

# %%
testing10_1 = testing10[testing10.SALE_QTY > 1587.0]
testing10_1
# Out:
#            GDS_NM  month  SALE_QTY    SALE_AMT
# 43          가지5입봉     10    1783.0   3967300.0
# 58             감자     10    2043.0   5049150.0
# 106       구호물품택배비     10    2000.0   8000000.0
# 170        깻잎4묶음봉     10    3900.0   5883450.0
# 222       느타리버섯1팩     10    3300.0   2791590.0
# 286          단감5개     10    4731.0  32996318.0
# 319          대파1단     10    6307.0   9163280.0
# 330     델몬트바나나1송이     10    2409.0   8545420.0
# 591     무우1개봉투명비닐     10    3617.0   4393020.0
# 669         백오이1개     10    2414.0   7270940.0
# 671         백오이3개     10    1901.0   3234660.0
# 707          부추1단     10    1895.0   3045720.0
# 732   빨강대추방울토마토1팩     10    2578.0   8682330.0
# 739        사과대추1팩     10    2268.0  10451980.0
# 750       새송이버섯1봉     10    3611.0   5674750.0
# 760          생강1봉     10    1967.0   9286660.0
# 805          소주공병     10    3056.0    305600.0
# 867         시금치1단     10    2085.0   4971780.0
# 894      쌈배추알배기1통     10    2209.0   3394080.0
# ...

# %%
testing11_1 = testing11[testing11.SALE_QTY > 1736.0]
testing11_1
# Out:
#          GDS_NM  month  SALE_QTY      SALE_AMT
# 69           감자     11    1861.0  5.108600e+06
# 135    국내산돈앞다리살     11    1844.0  3.333790e+07
# 178      깻잎4묶음봉     11    4112.0  4.605700e+06
# 190       남해초1단     11    1745.0  4.430960e+06
# 232     느타리버섯1팩     11    3622.0  2.873470e+06
# 241       다발무1단     11    2993.0  1.978860e+07
# 304        단감5개     11    3358.0  2.646110e+07
# 334        대파1단     11    7517.0  1.174678e+07
# 344   델몬트바나나1송이     11    2826.0  9.228960e+06
# 593   무우1개봉투명비닐     11    2442.0  3.954840e+06
# 663       백오이1개     11    3153.0  9.779020e+06
# 695      부사사과6개     11    2008.0  1.660130e+07
# 743     새송이버섯1봉     11    3589.0  5.036240e+06
# 754        생강1봉     11    2143.0  7.956460e+06
# 797        소주공병     11    3874.0  3.838000e+05
# 861       시금치1단     11    2116.0  3.089700e+06
# 893      아보카도1개     11    2338.0  2.378300e+06
# 904      아이스콘1개     11   11001.0  9.900900e+06
# 928          야채     11    5415.0  1.371450e+07
# ...

# %%
testing12_1 = testing12[testing12.SALE_QTY > 1319.0]
testing12_1
# Out:
#                GDS_NM  month  SALE_QTY    SALE_AMT
# 63                 감자     12    2099.0   7936060.0
# 106           구호물품택배비     12    3359.0  13436000.0
# 127          국내산돈앞다리살     12    1625.0  26320830.0
# 177            깻잎4묶음봉     12    3807.0   5010830.0
# 195           남해초1단행사     12    5678.0  10147120.0
# 235           느타리버섯1팩     12    4038.0   3995190.0
# 314              단감5개     12    1412.0  12578500.0
# 348              대파1단     12    6122.0   8896540.0
# 362         델몬트바나나1송이     12    2397.0   7366100.0
# 620         무우1개봉투명비닐     12    2335.0   3198460.0
# 686             백오이1개     12    3536.0   9881740.0
# 712                봄동     12    1373.0   2378330.0
# 718            부사사과6개     12    2023.0  18465700.0
# 760           새송이버섯1봉     12    3421.0   5517580.0
# 810              소주공병     12    3370.0    337000.0
# 829   수입산브로컬리2송이구입시행사     12    1862.0   1932810.0
# 881             시금치1단     12    3178.0   3534470.0
# ...

# %% [markdown]
# ---

# %%
testing1_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing2_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing3_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing4_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing5_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing6_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing7_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing8_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing9_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing10_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing11_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing12_1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %% [markdown]
# ---

# %%
testing1_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing2_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing3_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing4_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing5_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing6_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing7_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing8_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing9_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing10_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing11_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
testing12_1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>
