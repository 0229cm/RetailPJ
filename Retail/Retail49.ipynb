# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'newdf1007-2.csv')

# %%
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
#  대파 1단           64792
#  깻잎 4묶음  봉       39561
#  백오이 1개          38042
# 흙당근              33614
# 적상추 1봉 비닐        30120
#                  ...
# 탐스제로 오렌지600 6        1
# 아스파라거스 1묶음           1
# 팔라라이트 트위스트           1
# 도루묵                  1
# 던힐 파인컷 멘솔 1mg        1
# Name: GDS_NM, Length: 3087, dtype: int64

# %%
pd.set_option('display.max_rows', 3100)

# %%
df['GDS_NM'].value_counts()
# Out:
#  대파 1단                                  64792
#  깻잎 4묶음  봉                              39561
#  백오이 1개                                 38042
# 흙당근                                     33614
# 적상추 1봉 비닐                               30120
#  청양고추 소                                 29863
#  인큐애호박 2개 행사                            29190
#  느타리버섯 1팩                               27791
# 감자                                      25492
# 팽이버섯 1봉                                 21808
#  양파 중  1망                               20830
#  새송이버섯 1봉                               19871
#  청상추 1봉                                 19475
#  쌈배추 알배기  1통                            18446
#  가지 5입 봉                                18322
#  새송이버섯 2봉 1인2봉한정                        18111
#  부추 1단                                  17918
# 국내산돈앞다리살                                17692
#  시금치 1단                                 17362
#  부사사과 6개                                16908
# ...

# %%
df['GDS_NM'].nunique()
# Out:
# 3087

# %% [markdown]
# 디스 플러스
# 버지니아 슬림 골드
# 필라멘트수퍼슬림레드
# 에쎄 원
# 버지니아 슬림 1mg
# 던힐1
# 히츠

# %%
drap = df[df['GDS_NM'].str.contains('비식품')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('디스')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('버지니아')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('필라멘트')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('에쎄')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('던힐')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('히츠')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('장마')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('장마')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('썬부탄가스')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('밥용기')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('접석쇠')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('국용기')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('매직스폰지')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('마대')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('노끈')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('썬랩')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('종이용기')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('암앤해머')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('맑은하늘')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('그레이드')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('헨켈')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('칫솔')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('멜라민옥돌컵')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('이그젝타')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('화장실용')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('센서티브젤')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('은은한향')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('POS신규등록상품')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('봄의소생')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('스텐양푼')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('상쾌향')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('반야양초')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('도브핑크')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('에코라믹')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('정육plu')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('리필320')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('차량용')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('종이용기')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('절약')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('0000')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('생선plu')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('실링용기')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('마스크')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('5000394131378')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('5000394131361')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('2000420020006')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('스텐들통')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('유리닦기')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('정종공병')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('63864564')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('3864104666527')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('2050780005007')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('37793025127')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('니베아')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('감사합니다')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('3862004642085')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('USB충전랜턴')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('88023755')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('7897446693339')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('립케어')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
#  대파 1단                                  64792
#  깻잎 4묶음  봉                              39561
#  백오이 1개                                 38042
# 흙당근                                     33614
# 적상추 1봉 비닐                               30120
#  청양고추 소                                 29863
#  인큐애호박 2개 행사                            29190
#  느타리버섯 1팩                               27791
# 감자                                      25492
# 팽이버섯 1봉                                 21808
#  양파 중  1망                               20830
#  새송이버섯 1봉                               19871
#  청상추 1봉                                 19475
#  쌈배추 알배기  1통                            18446
#  가지 5입 봉                                18322
#  새송이버섯 2봉 1인2봉한정                        18111
#  부추 1단                                  17918
# 국내산돈앞다리살                                17692
#  시금치 1단                                 17362
#  부사사과 6개                                16908
# ...

# %%
drap = df[df['GDS_NM'].str.contains('오징어게임레고')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('말보로')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('깨끗한나라')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('버지 에스골드')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('메비우스')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('팔라라이트')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('말보로')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('말보루')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('로스만')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('켄트')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('3000 마인블럭')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('네오')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('퓨전')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('카멜')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('존슨 향기걸이')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('부탄가스plu')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('삼성경질냄비')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('택배비')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('종이컵')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('35104002974014091')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('레고 히어로우')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('쉐이브폼')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('쿨토시')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('봉투')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('지포라이타')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('쉬크 쿼트로4티타늄')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('고무장갑')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('면도날')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('팔리아')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('전자식PL등기구')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('soft 갑')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
drap = df[df['GDS_NM'].str.contains('쿠진글라스실버락')].index
df.drop(drap, inplace=True)
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
#  대파 1단                                  64792
#  깻잎 4묶음  봉                              39561
#  백오이 1개                                 38042
# 흙당근                                     33614
# 적상추 1봉 비닐                               30120
#  청양고추 소                                 29863
#  인큐애호박 2개 행사                            29190
#  느타리버섯 1팩                               27791
# 감자                                      25492
# 팽이버섯 1봉                                 21808
#  양파 중  1망                               20830
#  새송이버섯 1봉                               19871
#  청상추 1봉                                 19475
#  쌈배추 알배기  1통                            18446
#  가지 5입 봉                                18322
#  새송이버섯 2봉 1인2봉한정                        18111
#  부추 1단                                  17918
# 국내산돈앞다리살                                17692
#  시금치 1단                                 17362
#  부사사과 6개                                16908
# ...

# %%
# df.to_csv('df1007.csv', index=False)

# %%
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD           GDS_NM  \
# 0        2021-09-02        185158  2999000001262     의성햇사과 8입 1봉
# 1        2021-09-02        185158  2908990004443        쌈배추 벌크 1통
# 2        2021-09-02        185158  2908990003866   성주꿀참외 특  6입 1봉
# 3        2021-09-02        185158         351060        대패삼겹살 수입
# 4        2021-09-02        185158         201447             거봉포도
# ...             ...           ...            ...              ...
# 2088623  2022-04-29        202815  8800789888880               찹쌀
# 2088624  2022-07-13        152301  8800789888880               찹쌀
# 2088625  2021-11-21        143020  8800789080000              늘보리
# 2088626  2022-03-03        165411  8800789080000              늘보리
# 2088627  2022-06-17        140922  8800789080000              늘보리
#
#          GDS_CLSS_CD  SALE_AMT
# 0            40601.0      9960
# 1            30101.0      1980
# 2            40101.0      9800
# 3            52599.0     13060
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2079024 entries, 0 to 2088627
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   SAL_DT        object
#  1   REAL_SAL_TTM  int64
#  2   PLU_CD        int64
#  3   GDS_NM        object
#  4   GDS_CLSS_CD   float64
#  5   SALE_AMT      int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 111.0+ MB

# %%
df['GDS_NM'] = df['GDS_NM'].str.replace(" ", "")

# %%
df
# Out:
#              SAL_DT  REAL_SAL_TTM         PLU_CD      GDS_NM  GDS_CLSS_CD  \
# 0        2021-09-02        185158  2999000001262   의성햇사과8입1봉      40601.0
# 1        2021-09-02        185158  2908990004443     쌈배추벌크1통      30101.0
# 2        2021-09-02        185158  2908990003866  성주꿀참외특6입1봉      40101.0
# 3        2021-09-02        185158         351060     대패삼겹살수입      52599.0
# 4        2021-09-02        185158         201447        거봉포도      40702.0
# ...             ...           ...            ...         ...          ...
# 2088623  2022-04-29        202815  8800789888880          찹쌀     105152.0
# 2088624  2022-07-13        152301  8800789888880          찹쌀     105152.0
# 2088625  2021-11-21        143020  8800789080000         늘보리     105152.0
# 2088626  2022-03-03        165411  8800789080000         늘보리     105152.0
# 2088627  2022-06-17        140922  8800789080000         늘보리     105152.0
#
#          SALE_AMT
# 0            9960
# 1            1980
# 2            9800
# ...

# %%
df['GDS_NM'].value_counts()
# Out:
# 대파1단                        64792
# 깻잎4묶음봉                      39561
# 백오이1개                       38042
# 흙당근                         33614
# 적상추1봉비닐                     30120
# 청양고추소                       29863
# 인큐애호박2개행사                   29190
# 느타리버섯1팩                     27791
# 감자                          25492
# 팽이버섯1봉                      21808
# 양파중1망                       20830
# 새송이버섯1봉                     19871
# 인큐애호박1개                     19729
# 청상추1봉                       19475
# 쌈배추알배기1통                    18446
# 가지5입봉                       18322
# 새송이버섯2봉1인2봉한정               18111
# 부추1단                        17918
# 국내산돈앞다리살                    17692
# 시금치1단                       17421
# 부사사과6개                      16908
# 백오이3개                       16698
# 추부깻잎1봉                      16638
# 무우1개봉투명비닐                   16446
# 파프리카1개                      14916
# 야채                          14441
# 양파특대1망                      14141
# ...

# %%
df.to_csv('df1007.csv', index=False)
