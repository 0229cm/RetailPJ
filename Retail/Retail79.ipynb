# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\min\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\min\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
gds = pd.read_csv(base_path + 'gds.csv')

gdsclss = pd.read_csv(base_path + 'gdsclss.csv')

trlist = pd.read_csv(base_path + 'trlist.csv')

trdtl = pd.read_csv(base_path + 'trdtl.csv')
# Out:
# <ipython-input-2-9df49ae41411>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   gds = pd.read_csv(base_path + 'gds.csv')
# <ipython-input-2-9df49ae41411>:5: DtypeWarning: Columns (2,9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   trlist = pd.read_csv(base_path + 'trlist.csv')
# <ipython-input-2-9df49ae41411>:7: DtypeWarning: Columns (2,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   trdtl = pd.read_csv(base_path + 'trdtl.csv')

# %%
drap = gds[gds['GDS_TP_NM'].str.contains('배송료')].index
gds.drop(drap, inplace=True)

# %%
drap = gds[gds['GDS_TP_NM'].str.contains('공병')].index
gds.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('로그인')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('캐셔정산')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('영업개시')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('영업종료')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('POS정산')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('로그오프')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('준비금')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('거래후현영')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('사내소비')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('중간출금')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('외상입금')].index
trlist.drop(drap, inplace=True)

# %%
drap = trlist[trlist['SALE_KIND_TP_NM'].str.contains('공병회수')].index
trlist.drop(drap, inplace=True)

# %%
trlist = trlist[trlist.SALE_RTN_SGN != -1]
trlist
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO SALE_KIND_TP_NM  SALE_RTN_SGN  \
# 0        20201220   12018      1       25              매출             1
# 2        20201220   12018      1       27              매출             1
# 4        20201220   12018      1       34              매출             1
# 5        20201220   12018      1       35              매출             1
# 6        20201220   12018      1       36              매출             1
# ...           ...     ...    ...      ...             ...           ...
# 7766640  20220901  168009      1      280              매출             1
# 7766641  20220901  168009      1      281              매출             1
# 7766642  20220901  168009      1      282              매출             1
# 7766643  20220901  168009      1      283              매출             1
# 7766644  20220901  168009      1      284              매출             1
#
#          REAL_SAL_DT  REAL_SAL_TTM  PAY_AMT   MSHP_ID  ORN_SAL_DT ORN_POS_NO  \
# 0           20201220      105406.0  21880.0       NaN         NaN        NaN
# 2           20201220      105703.0  21880.0  012018_0         NaN        NaN
# 4           20201220      110647.0  20300.0       NaN         NaN        NaN
# 5           20201220      110935.0  19380.0       NaN         NaN        NaN
# 6           20201220      111357.0  15960.0  012018_1         NaN        NaN
# ...              ...           ...      ...       ...         ...        ...
# 7766640     20220901      142845.0   7400.0       NaN         NaN        NaN
# 7766641     20220901      143105.0   9000.0       NaN         NaN        NaN
# 7766642     20220901      143132.0  11000.0       NaN         NaN        NaN
# 7766643     20220901      143433.0    500.0       NaN         NaN        NaN
# 7766644     20220901      143610.0   1900.0       NaN         NaN        NaN
#
#          ORN_TRAN_NO
# 0                NaN
# 2                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# ...              ...
# 7766640          NaN
# 7766641          NaN
# 7766642          NaN
# 7766643          NaN
# 7766644          NaN
#
# [7483751 rows x 13 columns]

# %%
drap = trdtl[trdtl['DESI_CNCL_TP_NM'].str.contains('지정취소')].index
trdtl.drop(drap, inplace=True)

# %%
drap = trdtl[trdtl['DESI_CNCL_TP_NM'].str.contains('전체취소')].index
trdtl.drop(drap, inplace=True)

# %%
trdtl = trdtl[trdtl.SALE_RTN_SGN != -1]
trdtl
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 1         20201220   12018      1       25       1            정상판매
# 2         20201220   12018      1       25       2            정상판매
# 5         20201220   12018      1       27       1            정상판매
# 6         20201220   12018      1       27       2            정상판매
# 9         20201220   12018      1       34       1            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 31498430  20220901  168009      1      282       4            정상판매
# 31498431  20220901  168009      1      282       5            정상판매
# 31498432  20220901  168009      1      283       1            정상판매
# 31498433  20220901  168009      1      284       1            정상판매
# 31498434  20220901  168009      1      284       2            정상판매
#
#           SALE_RTN_SGN         PLU_CD GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 1                    1  2908990003422     30499.0       1.0   18900.0
# 2                    1  2908990008472     30702.0       1.0    2980.0
# 5                    1  2908990003422     30499.0       1.0   18900.0
# 6                    1  2908990008472     30702.0       1.0    2980.0
# 9                    1  8809522421100     10303.0       1.0    5600.0
# ...                ...            ...         ...       ...       ...
# 31498430             1  2504010000015     40101.0       1.0    3000.0
# 31498431             1  8809730783199    999999.0       1.0    1000.0
# 31498432             1  8801056020026    898989.0       1.0     500.0
# 31498433             1  4711269689931    999999.0       6.0     200.0
# 31498434             1  8801045520117    999999.0       1.0     700.0
#
#           SALE_AMT SGDS_DC_TP_NM  SGDS_DC_PRC  SUBTOT_DC_AMT  EVT_DC_AMT  \
# 1          18900.0            정상          0.0            0.0         0.0
# 2           2980.0            정상          0.0            0.0         0.0
# 5          18900.0            정상          0.0            0.0         0.0
# 6           2980.0            정상          0.0            0.0         0.0
# 9           5600.0            정상          0.0            0.0         0.0
# ...            ...           ...          ...            ...         ...
# 31498430    3000.0            정상          0.0            0.0         0.0
# 31498431    1000.0            정상          0.0            0.0         0.0
# 31498432     500.0            정상          0.0            0.0         0.0
# 31498433    1200.0            정상          0.0            0.0         0.0
# 31498434     700.0            정상          0.0            0.0         0.0
#
#           CPON_DC_AMT SCALES_GDS_TP_NM  GDS_CPON_DC_AMT  BASKET_CPON_DC_AMT
# 1                 0.0               일반              0.0                 0.0
# 2                 0.0               일반              0.0                 0.0
# 5                 0.0               일반              0.0                 0.0
# 6                 0.0               일반              0.0                 0.0
# 9                 0.0               일반              0.0                 0.0
# ...               ...              ...              ...                 ...
# 31498430          0.0               일반              0.0                 0.0
# 31498431          0.0               일반              0.0                 0.0
# 31498432          0.0               일반              0.0                 0.0
# 31498433          0.0               일반              0.0                 0.0
# 31498434          0.0               일반              0.0                 0.0
#
# [30716454 rows x 20 columns]

# %%
trdtl = trdtl[trdtl.SALE_RTN_SGN != 0]
trdtl
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 1         20201220   12018      1       25       1            정상판매
# 2         20201220   12018      1       25       2            정상판매
# 5         20201220   12018      1       27       1            정상판매
# 6         20201220   12018      1       27       2            정상판매
# 9         20201220   12018      1       34       1            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 31498430  20220901  168009      1      282       4            정상판매
# 31498431  20220901  168009      1      282       5            정상판매
# 31498432  20220901  168009      1      283       1            정상판매
# 31498433  20220901  168009      1      284       1            정상판매
# 31498434  20220901  168009      1      284       2            정상판매
#
#           SALE_RTN_SGN         PLU_CD GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 1                    1  2908990003422     30499.0       1.0   18900.0
# 2                    1  2908990008472     30702.0       1.0    2980.0
# 5                    1  2908990003422     30499.0       1.0   18900.0
# 6                    1  2908990008472     30702.0       1.0    2980.0
# 9                    1  8809522421100     10303.0       1.0    5600.0
# ...                ...            ...         ...       ...       ...
# 31498430             1  2504010000015     40101.0       1.0    3000.0
# 31498431             1  8809730783199    999999.0       1.0    1000.0
# 31498432             1  8801056020026    898989.0       1.0     500.0
# 31498433             1  4711269689931    999999.0       6.0     200.0
# 31498434             1  8801045520117    999999.0       1.0     700.0
#
#           SALE_AMT SGDS_DC_TP_NM  SGDS_DC_PRC  SUBTOT_DC_AMT  EVT_DC_AMT  \
# 1          18900.0            정상          0.0            0.0         0.0
# 2           2980.0            정상          0.0            0.0         0.0
# 5          18900.0            정상          0.0            0.0         0.0
# 6           2980.0            정상          0.0            0.0         0.0
# 9           5600.0            정상          0.0            0.0         0.0
# ...            ...           ...          ...            ...         ...
# 31498430    3000.0            정상          0.0            0.0         0.0
# 31498431    1000.0            정상          0.0            0.0         0.0
# 31498432     500.0            정상          0.0            0.0         0.0
# 31498433    1200.0            정상          0.0            0.0         0.0
# 31498434     700.0            정상          0.0            0.0         0.0
#
#           CPON_DC_AMT SCALES_GDS_TP_NM  GDS_CPON_DC_AMT  BASKET_CPON_DC_AMT
# 1                 0.0               일반              0.0                 0.0
# 2                 0.0               일반              0.0                 0.0
# 5                 0.0               일반              0.0                 0.0
# 6                 0.0               일반              0.0                 0.0
# 9                 0.0               일반              0.0                 0.0
# ...               ...              ...              ...                 ...
# 31498430          0.0               일반              0.0                 0.0
# 31498431          0.0               일반              0.0                 0.0
# 31498432          0.0               일반              0.0                 0.0
# 31498433          0.0               일반              0.0                 0.0
# 31498434          0.0               일반              0.0                 0.0
#
# [30716446 rows x 20 columns]

# %%
gds
# Out:
#           CO_CD  STR_CD         PLU_CD     GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0       1001294   12018              1        배송비     809999.0        일반
# 2       1001294   12018          91770     코지유리물병      93331.0        일반
# 3       1001294   12018          91770       크지물병      91701.0        일반
# 4       1001294   12018       50390427      POM석류      12579.0        일반
# 5       1001294   12018       50430048    POM블루베리      12579.0        일반
# ...         ...     ...            ...        ...          ...       ...
# 744362  1002056  168009  9805817760205        포카칩     898989.0        일반
# 744363  1002056  168009  9808205106111  매입에서등록한상품     997979.0        일반
# 744364  1002056  168009  9808862878406        월드콘     898989.0        일반
# 744365  1002056  168009  9880913160015  매입에서등록한상품     997979.0        일반
# 744366  1002056  168009       99889906     버디 토스트     898989.0        일반
#
#         VEN_CD
# 0            0
# 2            0
# 3            0
# 4            0
# 5            0
# ...        ...
# 744362      46
# 744363      30
# 744364       9
# 744365      34
# 744366    8989
#
# [744320 rows x 7 columns]

# %%
trdtl
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 1         20201220   12018      1       25       1            정상판매
# 2         20201220   12018      1       25       2            정상판매
# 5         20201220   12018      1       27       1            정상판매
# 6         20201220   12018      1       27       2            정상판매
# 9         20201220   12018      1       34       1            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 31498430  20220901  168009      1      282       4            정상판매
# 31498431  20220901  168009      1      282       5            정상판매
# 31498432  20220901  168009      1      283       1            정상판매
# 31498433  20220901  168009      1      284       1            정상판매
# 31498434  20220901  168009      1      284       2            정상판매
#
#           SALE_RTN_SGN         PLU_CD GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 1                    1  2908990003422     30499.0       1.0   18900.0
# 2                    1  2908990008472     30702.0       1.0    2980.0
# 5                    1  2908990003422     30499.0       1.0   18900.0
# 6                    1  2908990008472     30702.0       1.0    2980.0
# 9                    1  8809522421100     10303.0       1.0    5600.0
# ...                ...            ...         ...       ...       ...
# 31498430             1  2504010000015     40101.0       1.0    3000.0
# 31498431             1  8809730783199    999999.0       1.0    1000.0
# 31498432             1  8801056020026    898989.0       1.0     500.0
# 31498433             1  4711269689931    999999.0       6.0     200.0
# 31498434             1  8801045520117    999999.0       1.0     700.0
#
#           SALE_AMT SGDS_DC_TP_NM  SGDS_DC_PRC  SUBTOT_DC_AMT  EVT_DC_AMT  \
# 1          18900.0            정상          0.0            0.0         0.0
# 2           2980.0            정상          0.0            0.0         0.0
# 5          18900.0            정상          0.0            0.0         0.0
# 6           2980.0            정상          0.0            0.0         0.0
# 9           5600.0            정상          0.0            0.0         0.0
# ...            ...           ...          ...            ...         ...
# 31498430    3000.0            정상          0.0            0.0         0.0
# 31498431    1000.0            정상          0.0            0.0         0.0
# 31498432     500.0            정상          0.0            0.0         0.0
# 31498433    1200.0            정상          0.0            0.0         0.0
# 31498434     700.0            정상          0.0            0.0         0.0
#
#           CPON_DC_AMT SCALES_GDS_TP_NM  GDS_CPON_DC_AMT  BASKET_CPON_DC_AMT
# 1                 0.0               일반              0.0                 0.0
# 2                 0.0               일반              0.0                 0.0
# 5                 0.0               일반              0.0                 0.0
# 6                 0.0               일반              0.0                 0.0
# 9                 0.0               일반              0.0                 0.0
# ...               ...              ...              ...                 ...
# 31498430          0.0               일반              0.0                 0.0
# 31498431          0.0               일반              0.0                 0.0
# 31498432          0.0               일반              0.0                 0.0
# 31498433          0.0               일반              0.0                 0.0
# 31498434          0.0               일반              0.0                 0.0
#
# [30716446 rows x 20 columns]

# %%
#mer = pd.merge(gds, trdtl, on='GDS_CLSS_CD', how='inner')
#mer

# %%
#mer1 = pd.merge(gds, trdtl, on='GDS_CLSS_CD', how='outer')
#mer1

# %%
#mer2 = pd.merge(gds, trdtl, on='PLU_CD', how='inner')
#mer2

# %%
#mer3 = pd.merge(gds, trdtl, on='PLU_CD', how='outer')
#mer3

# %%
#mer4 = pd.merge(gds, trdtl, on='STR_CD', how='inner')
#mer4

# %%
#mer5 = pd.merge(gds, trdtl, on='STR_CD', how='outer')
#mer5

# %%
mer6 = pd.merge(gds, trdtl, on='PLU_CD', how='left')
mer6
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-30-c273ee318bc8> in <module>
# ----> 1 mer6 = pd.merge(gds, trdtl, on='PLU_CD', how='left')
#       2 mer6
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     123         validate=validate,
#     124     )
# --> 125     return op.get_result(copy=copy)
#     126
#     127
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self, copy)
#     776         join_index, left_indexer, right_indexer = self._get_join_info()
#     777
# --> 778         result = self._reindex_and_concat(
#     779             join_index, left_indexer, right_indexer, copy=copy
#     780         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     767         left.columns = llabels
#     768         right.columns = rlabels
# --> 769         result = concat([left, right], axis=1, copy=copy)
#     770         return result
#     771
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#     318
#     319         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     )
#     381
# --> 382     return op.get_result()
#     383
#     384
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     615                 mgrs_indexers.append((obj._mgr, indexers))
#     616
# --> 617             new_data = concatenate_managers(
#     618                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     619             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     231             fastpath = blk.values.dtype == values.dtype
#     232         else:
# --> 233             values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     234             fastpath = False
#     235
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     540     upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)
#     541
# --> 542     to_concat = [
#     543         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     544         for ju in join_units
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in <listcomp>(.0)
#     541
#     542     to_concat = [
# --> 543         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     544         for ju in join_units
#     545     ]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     520         else:
#     521             for ax, indexer in self.indexers.items():
# --> 522                 values = algos.take_nd(values, indexer, axis=ax)
#     523
#     524         return values
#
# ~\Anaconda3\lib\site-packages\pandas\core\array_algos\take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115
#     116     arr = np.asarray(arr)
# --> 117     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     118
#     119
#
# ~\Anaconda3\lib\site-packages\pandas\core\array_algos\take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     156         out = np.empty(out_shape, dtype=dtype, order="F")
#     157     else:
# --> 158         out = np.empty(out_shape, dtype=dtype)
#     159
#     160     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 6.00 GiB for an array with shape (4, 201214079) and data type float64

# %%
# mer = pd.merge(gds, trdtl)

# %%
mer

# %%
mer.columns

# %%
mer1 = mer[['CO_CD', 'STR_CD', 'PLU_CD', 'GDS_NM', 'GDS_CLSS_CD', 'GDS_TP_NM',
       'VEN_CD', 'SAL_DT', 'POS_NO', 'TRAN_NO', 'SEQ_NO', 'DESI_CNCL_TP_NM',
       'SALE_RTN_SGN', 'SALE_QTY', 'SALE_PRC', 'SALE_AMT']]

# %%
mer1

# %%
# mer1.to_csv('mer1014.csv', index=False)
