# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# a 마트 gds+list+dtl
amartsum = pd.read_csv(base_path + 'amartsum.csv')
amartsum
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# ...

# %%
amartsum.SAL_DT = amartsum.SAL_DT.astype('str')
amartsum.SAL_DT
# Out:
# 0          20210901
# 1          20210901
# 2          20210901
# 3          20210901
# 4          20210901
#              ...
# 4968529    20220901
# 4968530    20220901
# 4968531    20220901
# 4968532    20220901
# 4968533    20220901
# Name: SAL_DT, Length: 4968534, dtype: object

# %%
amartsum.REAL_SAL_DT = amartsum.REAL_SAL_DT.astype('str')
amartsum.REAL_SAL_DT
# Out:
# 0          20210901
# 1          20210901
# 2          20210901
# 3          20210901
# 4          20210901
#              ...
# 4968529    20220901
# 4968530    20220901
# 4968531    20220901
# 4968532    20220901
# 4968533    20220901
# Name: REAL_SAL_DT, Length: 4968534, dtype: object

# %%
amartsum.REAL_SAL_TTM = amartsum.REAL_SAL_TTM.astype('str')
amartsum.REAL_SAL_TTM
# Out:
# 0           71138
# 1           71138
# 2           71138
# 3           71138
# 4           71138
#             ...
# 4968529    125736
# 4968530    142401
# 4968531    142602
# 4968532    162924
# 4968533    162937
# Name: REAL_SAL_TTM, Length: 4968534, dtype: object

# %%
amartsum.SAL_DT = pd.to_datetime(amartsum.SAL_DT)

# %%
amartsum.REAL_SAL_DT = pd.to_datetime(amartsum.REAL_SAL_DT)

# %%
amartsum.REAL_SAL_TTM = pd.to_datetime(amartsum.REAL_SAL_TTM, format='%H%M%S')

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     datetime64[ns]
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: datetime64[ns](1), float64(5), int64(7), object(5)
# memory usage: 682.3+ MB

# %%
amartsum
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
amartsum['REAL_SAL_TTM'] = amartsum['REAL_SAL_TTM'].replace('1900-01-01','', inplace=True)

# %%
amartsum
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
cols = ['REAL_SAL_DT', 'REAL_SAL_TTM']
amartsum['DTT'] =amartsum[cols].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
amartsum
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
amartsum.DTT = pd.to_datetime(amartsum.DTT)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# OverflowError: Python int too large to convert to C long
#
# ...

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 19 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     int64
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
#  18  DTT              object
# dtypes: float64(5), int64(8), object(6)
# memory usage: 720.2+ MB

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 19 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     int64
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
#  18  DTT              object
# dtypes: float64(5), int64(8), object(6)
# memory usage: 720.2+ MB

# %%
amartsum.DTT = pd.to_datetime(amartsum.DTT)

amartsum
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# OverflowError: Python int too large to convert to C long
#
# ...

# %%
# a 마트 gds+list+dtl
df = pd.read_csv(base_path + 'amartsum.csv')
df
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# ...

# %%
# REAL_SAL_TTM 부분 시간으로 바꿈

t1 = df['REAL_SAL_TTM'].astype(str).str.zfill(6)
df['REAL_SAL_TTM'] = pd.to_datetime(t1, format='%H%M%S').dt.time

print (df)
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
df['REAL_SAL_TTM'] = pd.to_datetime(df['REAL_SAL_TTM'], format='%H:%M:%S').dt.time

# %%
df
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 682.3+ MB

# %%
df['REAL_SAL_TTM'] = pd.to_datetime(df['REAL_SAL_TTM'], format='%H:%M:%S', errors='raise')

# %%
df
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# ...
