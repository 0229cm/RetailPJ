# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\min\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\min\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\min\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# 제품목록 gds_list_0, gds_list_1
gds_0 = pd.read_csv(base_path + 'gds_list_0_ansi.csv', encoding='ANSI')
gds_1 = pd.read_csv(base_path + 'gds_list_1_ansi.csv', encoding='ANSI')


# 매출 제품 데이터 상세: tr_dtl_list_0, tr_dtl_list_1
tr_dtl_list_0 = pd.read_csv(base_path + 'tr_dtl_list_0_ansi.csv', encoding='ANSI')
tr_dtl_list_1 = pd.read_csv(base_path + 'tr_dtl_list_1_ansi.csv', encoding='ANSI')
# Out:
# <ipython-input-2-bcd6243acd39>:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   gds_0 = pd.read_csv(base_path + 'gds_list_0_ansi.csv', encoding='ANSI')
# <ipython-input-2-bcd6243acd39>:7: DtypeWarning: Columns (2,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   tr_dtl_list_0 = pd.read_csv(base_path + 'tr_dtl_list_0_ansi.csv', encoding='ANSI')
# <ipython-input-2-bcd6243acd39>:8: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   tr_dtl_list_1 = pd.read_csv(base_path + 'tr_dtl_list_1_ansi.csv', encoding='ANSI')

# %%
gds_0
# Out:
#           CO_CD  STR_CD         PLU_CD     GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0       1001294   12018              1        배송비     809999.0        일반
# 1       1001294   12018              2     사은행사쿠폰     999999.0       배송료
# 2       1001294   12018          91770     코지유리물병      93331.0        일반
# 3       1001294   12018          91770       크지물병      91701.0        일반
# 4       1001294   12018       50390427      POM석류      12579.0        일반
# ...         ...     ...            ...        ...          ...       ...
# 457561  1002117  363004  9556437014116       망고푸딩      22799.0        일반
# 457562  1002117  363004  9556995200068  매직쿠키/블루베리      22799.0        일반
# 457563  1002117  363004  9556995200075   매직쿠키/딸기잼      22799.0        일반
# 457564  1002117  363004     9654955092   돌)황도슬라이스      20599.0        일반
# 457565  1002117  363004  9788087049099  탑쿨토시(일반형)     110499.0        일반
#
#         VEN_CD
# 0            0
# 1            0
# 2            0
# 3            0
# ...

# %%
gds_1
# Out:
#           CO_CD  STR_CD         PLU_CD       GDS_NM  GDS_CLSS_CD GDS_TP_NM  \
# 0       1001993  142011              0       종랑제75ㄴ       999999        일반
# 1       1001993  142011              1          배송비       999999       배송료
# 2       1001993  142011              2       사은행사쿠폰       999999       배송료
# 3       1001993  142011          12003          얼음물       999999        일반
# 4       1001993  142011          22002      써니텐=사이다       999999        일반
# ...         ...     ...            ...          ...          ...       ...
# 114061  1002150  216008  9800412000541      보리건빵3번들       999999        일반
# 114062  1002150  216008  9804964550028     강력방글집게2호       999999        일반
# 114063  1002150  216008  9900000002091     노끈 동태(대)       999999        일반
# 114064  1002150  216008  9900000002107     노끈 동태(소)       999999        일반
# 114065  1002150  216008  9900000003401  로얄카드 인지(녹색)       999999        일반
#
#         VEN_CD
# 0            0
# 1            0
# 2            0
# ...

# %%
tr_dtl_list_0
# Out:
#             SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0         20201220   12018      1       24       1            전체취소
# 1         20201220   12018      1       25       1            정상판매
# 2         20201220   12018      1       25       2            정상판매
# 3         20201220   12018      1       26       1            정상판매
# 4         20201220   12018      1       26       2            정상판매
# ...            ...     ...    ...      ...     ...             ...
# 24084721  20220930  363004     R1        1       2            정상판매
# 24084722  20220930  363004     R1        1       3            정상판매
# 24084723  20220930  363004     R1        1       4            정상판매
# 24084724  20220930  363004     R1        1       5            정상판매
# 24084725  20220930  363004     R1        1   10001            정상판매
#
#           SALE_RTN_SGN         PLU_CD GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                    1  2908990004313     30101.0       1.0    1500.0
# ...

# %%
tr_dtl_list_1
# Out:
#           SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0       20210805  142011      1        4       1            전체취소
# 1       20210805  142011      1        5       1            전체취소
# 2       20210805  142011      1        8       1            전체취소
# 3       20210805  142011      1        9       1            정상판매
# 4       20210805  142011      1        9       2            정상판매
# ...          ...     ...    ...      ...     ...             ...
# 891789  20220930  216008     R1        1       6            정상판매
# 891790  20220930  216008     R1        1       7            지정취소
# 891791  20220930  216008     R1        1       8            정상판매
# 891792  20220930  216008     R1        1       9            정상판매
# 891793  20220930  216008     R1        1      10            정상판매
#
#         SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                  1  8801007792316     999999.0       1.0    1400.0
# ...

# %%
mer6 = pd.merge(gds_1, tr_dtl_list_1, on='PLU_CD', how='left')
mer6
# Out:
#            CO_CD  STR_CD_x         PLU_CD       GDS_NM  GDS_CLSS_CD_x  \
# 0        1001993    142011              0       종랑제75ㄴ         999999
# 1        1001993    142011              0       종랑제75ㄴ         999999
# 2        1001993    142011              1          배송비         999999
# 3        1001993    142011              1          배송비         999999
# 4        1001993    142011              1          배송비         999999
# ...          ...       ...            ...          ...            ...
# 1919065  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1919066  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1919067  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1919068  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1919069  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
#
#         GDS_TP_NM  VEN_CD      SAL_DT  STR_CD_y POS_NO  ...  SALE_PRC  \
# ...

# %%
mer6.isnull().sum()
# Out:
# CO_CD                     0
# STR_CD_x                  0
# PLU_CD                    0
# GDS_NM                    0
# GDS_CLSS_CD_x             0
# GDS_TP_NM                 0
# VEN_CD                    0
# SAL_DT                88537
# STR_CD_y              88537
# POS_NO                88537
# TRAN_NO               88537
# SEQ_NO                88537
# DESI_CNCL_TP_NM       88537
# SALE_RTN_SGN          88537
# GDS_CLSS_CD_y         88537
# SALE_QTY              88537
# SALE_PRC              88537
# SALE_AMT              88537
# SGDS_DC_TP_NM         88537
# SGDS_DC_PRC           88537
# SUBTOT_DC_AMT         88537
# EVT_DC_AMT            88537
# CPON_DC_AMT           88537
# SCALES_GDS_TP_NM      88537
# GDS_CPON_DC_AMT       88537
# BASKET_CPON_DC_AMT    88537
# dtype: int64

# %%
mer1 = pd.merge(gds_1, tr_dtl_list_1, on='PLU_CD', how='inner')
mer1
# Out:
#            CO_CD  STR_CD_x         PLU_CD       GDS_NM  GDS_CLSS_CD_x  \
# 0        1001993    142011              0       종랑제75ㄴ         999999
# 1        1001993    142011              0       종랑제75ㄴ         999999
# 2        1002056    168009              0           동태         898989
# 3        1002056    168009              0           동태         898989
# 4        1002056    168009              0         간고등어         898989
# ...          ...       ...            ...          ...            ...
# 1830528  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1830529  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1830530  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1830531  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
# 1830532  1002150    216008  9900000003401  로얄카드 인지(녹색)         999999
#
#         GDS_TP_NM  VEN_CD    SAL_DT  STR_CD_y POS_NO  ...  SALE_PRC  SALE_AMT  \
# ...

# %%
mer1.isnull().sum()
# Out:
# CO_CD                 0
# STR_CD_x              0
# PLU_CD                0
# GDS_NM                0
# GDS_CLSS_CD_x         0
# GDS_TP_NM             0
# VEN_CD                0
# SAL_DT                0
# STR_CD_y              0
# POS_NO                0
# TRAN_NO               0
# SEQ_NO                0
# DESI_CNCL_TP_NM       0
# SALE_RTN_SGN          0
# GDS_CLSS_CD_y         0
# SALE_QTY              0
# SALE_PRC              0
# SALE_AMT              0
# SGDS_DC_TP_NM         0
# SGDS_DC_PRC           0
# SUBTOT_DC_AMT         0
# EVT_DC_AMT            0
# CPON_DC_AMT           0
# SCALES_GDS_TP_NM      0
# GDS_CPON_DC_AMT       0
# BASKET_CPON_DC_AMT    0
# dtype: int64

# %%
mer2 = pd.merge(gds_1, tr_dtl_list_1, on='PLU_CD', how='outer')
mer2
# Out:
#              CO_CD  STR_CD_x         PLU_CD  GDS_NM  GDS_CLSS_CD_x GDS_TP_NM  \
# 0        1001993.0  142011.0              0  종랑제75ㄴ       999999.0        일반
# 1        1001993.0  142011.0              0  종랑제75ㄴ       999999.0        일반
# 2        1002056.0  168009.0              0      동태       898989.0        일반
# 3        1002056.0  168009.0              0      동태       898989.0        일반
# 4        1002056.0  168009.0              0    간고등어       898989.0        일반
# ...            ...       ...            ...     ...            ...       ...
# 1919803        NaN       NaN  8806396285029     NaN            NaN       NaN
# 1919804        NaN       NaN   499800000001     NaN            NaN       NaN
# 1919805        NaN       NaN   499800000001     NaN            NaN       NaN
# 1919806        NaN       NaN   499800000001     NaN            NaN       NaN
# 1919807        NaN       NaN   499800000001     NaN            NaN       NaN
#
# ...

# %%
mer2.isnull().sum()
# Out:
# CO_CD                   738
# STR_CD_x                738
# PLU_CD                    0
# GDS_NM                  738
# GDS_CLSS_CD_x           738
# GDS_TP_NM               738
# VEN_CD                  738
# SAL_DT                88537
# STR_CD_y              88537
# POS_NO                88537
# TRAN_NO               88537
# SEQ_NO                88537
# DESI_CNCL_TP_NM       88537
# SALE_RTN_SGN          88537
# GDS_CLSS_CD_y         89275
# SALE_QTY              88537
# SALE_PRC              88537
# SALE_AMT              88537
# SGDS_DC_TP_NM         88537
# SGDS_DC_PRC           88537
# SUBTOT_DC_AMT         88537
# EVT_DC_AMT            88537
# CPON_DC_AMT           88537
# SCALES_GDS_TP_NM      88537
# GDS_CPON_DC_AMT       88537
# BASKET_CPON_DC_AMT    88537
# dtype: int64

# %%
gds_0['STR_CD'].value_counts()
# Out:
# 12018     72308
# 145002    51695
# 164050    48370
# 75008     40425
# 156013    38382
# 150009    33949
# 72005     30602
# 194001    30400
# 201001    26825
# 156011    26657
# 363004    24897
# 156012    22331
# 227003    10725
# Name: STR_CD, dtype: int64

# %%
gds_1['STR_CD'].value_counts()
# Out:
# 142011    48700
# 216008    43885
# 168009    21481
# Name: STR_CD, dtype: int64

# %%
gds_1.STR_CD = gds_1.STR_CD.astype('str')

# %%
gds142011 = gds_1[gds_1.STR_CD == '142011']

# %%
gds142011
# Out:
#          CO_CD  STR_CD         PLU_CD    GDS_NM  GDS_CLSS_CD GDS_TP_NM  VEN_CD
# 0      1001993  142011              0    종랑제75ㄴ       999999        일반       0
# 1      1001993  142011              1       배송비       999999       배송료       0
# 2      1001993  142011              2    사은행사쿠폰       999999       배송료       0
# 3      1001993  142011          12003       얼음물       999999        일반       0
# 4      1001993  142011          22002   써니텐=사이다       999999        일반       0
# ...        ...     ...            ...       ...          ...       ...     ...
# 48695  1001993  142011       97059582      약초갱이       999999        일반    9999
# 48696  1001993  142011       97059585      약초갱이       999999        일반    9999
# 48697  1001993  142011       97159490      약초갱이       999999        일반    9999
# 48698  1001993  142011       97159599  약초갱이(3발)       999999        일반    9999
# 48699  1001993  142011  9788087049099  쿨토시(국방색)        20101        일반    9094
#
# ...

# %%
gds142011['STR_CD'].value_counts()
# Out:
# 142011    48700
# Name: STR_CD, dtype: int64

# %%
tr_dtl_list_1.STR_CD = tr_dtl_list_1.STR_CD.astype('str')

# %%
tdtl42011 = tr_dtl_list_1[tr_dtl_list_1.STR_CD == '142011']

# %%
tdtl42011
# Out:
#           SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0       20210805  142011      1        4       1            전체취소
# 1       20210805  142011      1        5       1            전체취소
# 2       20210805  142011      1        8       1            전체취소
# 3       20210805  142011      1        9       1            정상판매
# 4       20210805  142011      1        9       2            정상판매
# ...          ...     ...    ...      ...     ...             ...
# 106602  20220930  142011      1       84       2            정상판매
# 106603  20220930  142011      1       85       1            정상판매
# 106604  20220930  142011      1       85       2            정상판매
# 106605  20220930  142011      1       85       3            정상판매
# 106606  20220930  142011      1       86       1            정상판매
#
#         SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                  1  8801007792316     999999.0       1.0    1400.0
# ...

# %%
mer43 = pd.merge(gds142011, tdtl42011, on='PLU_CD', how='inner')
mer43
# Out:
#           CO_CD STR_CD_x         PLU_CD GDS_NM  GDS_CLSS_CD_x GDS_TP_NM  \
# 0       1001993   142011          12003    얼음물         999999        일반
# 1       1001993   142011          12003    얼음물         999999        일반
# 2       1001993   142011          12003    얼음물         999999        일반
# 3       1001993   142011          12003    얼음물         999999        일반
# 4       1001993   142011          12003    얼음물         999999        일반
# ...         ...      ...            ...    ...            ...       ...
# 106662  1001993   142011  9556486800210   망고푸딩         999999        일반
# 106663  1001993   142011  9556486800210   망고푸딩         999999        일반
# 106664  1001993   142011  9556486800210   망고푸딩         999999        일반
# 106665  1001993   142011  9556486800210   망고푸딩         999999        일반
# 106666  1001993   142011  9556486800210   망고푸딩         999999        일반
#
#         VEN_CD    SAL_DT STR_CD_y POS_NO  ...  SALE_PRC  SALE_AMT  \
# ...

# %%
mer43.isnull().sum()
# Out:
# CO_CD                 0
# STR_CD_x              0
# PLU_CD                0
# GDS_NM                0
# GDS_CLSS_CD_x         0
# GDS_TP_NM             0
# VEN_CD                0
# SAL_DT                0
# STR_CD_y              0
# POS_NO                0
# TRAN_NO               0
# SEQ_NO                0
# DESI_CNCL_TP_NM       0
# SALE_RTN_SGN          0
# GDS_CLSS_CD_y         0
# SALE_QTY              0
# SALE_PRC              0
# SALE_AMT              0
# SGDS_DC_TP_NM         0
# SGDS_DC_PRC           0
# SUBTOT_DC_AMT         0
# EVT_DC_AMT            0
# CPON_DC_AMT           0
# SCALES_GDS_TP_NM      0
# GDS_CPON_DC_AMT       0
# BASKET_CPON_DC_AMT    0
# dtype: int64

# %%
mer44 = pd.merge(gds142011, tdtl42011, on='PLU_CD', how='outer')
mer44
# Out:
#           CO_CD STR_CD_x         PLU_CD    GDS_NM  GDS_CLSS_CD_x GDS_TP_NM  \
# 0       1001993   142011              0    종랑제75ㄴ         999999        일반
# 1       1001993   142011              1       배송비         999999       배송료
# 2       1001993   142011              2    사은행사쿠폰         999999       배송료
# 3       1001993   142011          12003       얼음물         999999        일반
# 4       1001993   142011          12003       얼음물         999999        일반
# ...         ...      ...            ...       ...            ...       ...
# 151549  1001993   142011       97059582      약초갱이         999999        일반
# 151550  1001993   142011       97059585      약초갱이         999999        일반
# 151551  1001993   142011       97159490      약초갱이         999999        일반
# 151552  1001993   142011       97159599  약초갱이(3발)         999999        일반
# 151553  1001993   142011  9788087049099  쿨토시(국방색)          20101        일반
#
# ...

# %%
mer44.isnull().sum()
# Out:
# CO_CD                     0
# STR_CD_x                  0
# PLU_CD                    0
# GDS_NM                    0
# GDS_CLSS_CD_x             0
# GDS_TP_NM                 0
# VEN_CD                    0
# SAL_DT                44887
# STR_CD_y              44887
# POS_NO                44887
# TRAN_NO               44887
# SEQ_NO                44887
# DESI_CNCL_TP_NM       44887
# SALE_RTN_SGN          44887
# GDS_CLSS_CD_y         44887
# SALE_QTY              44887
# SALE_PRC              44887
# SALE_AMT              44887
# SGDS_DC_TP_NM         44887
# SGDS_DC_PRC           44887
# SUBTOT_DC_AMT         44887
# EVT_DC_AMT            44887
# CPON_DC_AMT           44887
# SCALES_GDS_TP_NM      44887
# GDS_CPON_DC_AMT       44887
# BASKET_CPON_DC_AMT    44887
# dtype: int64

# %%
test1 = mer44[['SAL_DT', 'PLU_CD', 'GDS_NM', 'SALE_QTY', 'SALE_PRC', 'SALE_AMT', 'STR_CD_x', 'STR_CD_y']]
test1
# Out:
#             SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0              NaN              0    종랑제75ㄴ       NaN       NaN       NaN
# 1              NaN              1       배송비       NaN       NaN       NaN
# 2              NaN              2    사은행사쿠폰       NaN       NaN       NaN
# 3       20210805.0          12003       얼음물       1.0    1200.0    1200.0
# 4       20210806.0          12003       얼음물       2.0    1200.0    2400.0
# ...            ...            ...       ...       ...       ...       ...
# 151549         NaN       97059582      약초갱이       NaN       NaN       NaN
# 151550         NaN       97059585      약초갱이       NaN       NaN       NaN
# 151551         NaN       97159490      약초갱이       NaN       NaN       NaN
# 151552         NaN       97159599  약초갱이(3발)       NaN       NaN       NaN
# 151553         NaN  9788087049099  쿨토시(국방색)       NaN       NaN       NaN
#
#        STR_CD_x STR_CD_y
# 0        142011      NaN
# 1        142011      NaN
# ...

# %%
test1['SAL_DT'].isnull().sum()
# Out:
# 44887

# %%
test1 = test1.dropna(how='any',axis=0)

# %%
test1
# Out:
#             SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 3       20210805.0          12003    얼음물       1.0    1200.0    1200.0
# 4       20210806.0          12003    얼음물       2.0    1200.0    2400.0
# 5       20210808.0          12003    얼음물       1.0    1200.0    1200.0
# 6       20210810.0          12003    얼음물       1.0    1200.0    1200.0
# 7       20210812.0          12003    얼음물       1.0    1200.0    1200.0
# ...            ...            ...    ...       ...       ...       ...
# 151538  20220827.0  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 151539  20220828.0  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 151540  20220913.0  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 151541  20220920.0  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 151542  20220922.0  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
#        STR_CD_x STR_CD_y
# 3        142011   142011
# 4        142011   142011
# 5        142011   142011
# ...

# %%
check = pd.read_csv(base_path + 'df1014.csv')

# %%
check
# Out:
#           STR_CD         PLU_CD         GDS_NM  GDS_CLSS_CD      SAL_DT  \
# 0          12018              1            배송비     809999.0  2022-09-29
# 1          12018       93682091       스니커즈피넛싱글      11509.0  2020-12-22
# 2          12018       93682091       스니커즈피넛싱글      11509.0  2020-12-22
# 3          12018       93682091       스니커즈피넛싱글      11509.0  2020-12-23
# 4          12018       93682091       스니커즈피넛싱글      11509.0  2020-12-23
# ...          ...            ...            ...          ...         ...
# 41369777  168009  8809071466140  코텍에스(S)자고리10P     997979.0  2022-02-28
# 41369778  168009  8809071466140  코텍에스(S)자고리10P     997979.0  2022-09-21
# 41369779  168009  8809071466140  코텍에스(S)자고리10P     997979.0  2021-11-11
# 41369780  168009  8809071466140  코텍에스(S)자고리10P     997979.0  2021-12-21
# 41369781  168009  8809071466140  코텍에스(S)자고리10P     997979.0  2022-02-28
#
#           SALE_QTY  SALE_PRC  SALE_AMT
# 0           5000.0       1.0    5000.0
# ...

# %%
check.STR_CD = check.STR_CD.astype('str')

# %%
gds142012 = check[check.STR_CD == '142011']

# %%
gds142012
# Out:
#           STR_CD         PLU_CD GDS_NM  GDS_CLSS_CD      SAL_DT  SALE_QTY  \
# 40664356  142011          12003    얼음물     999999.0  2021-08-05       1.0
# 40664357  142011          12003    얼음물     999999.0  2021-08-06       2.0
# 40664358  142011          12003    얼음물     999999.0  2021-08-08       1.0
# 40664359  142011          12003    얼음물     999999.0  2021-08-10       1.0
# 40664360  142011          12003    얼음물     999999.0  2021-08-12       1.0
# ...          ...            ...    ...          ...         ...       ...
# 40859682  142011  9556486800210   망고푸딩     999999.0  2022-08-09       1.0
# 40859683  142011  9556486800210   망고푸딩     999999.0  2022-08-10       1.0
# 40859684  142011  9556486800210   망고푸딩     999999.0  2022-08-12       1.0
# 40859685  142011  9556486800210   망고푸딩     999999.0  2022-08-27       1.0
# 40859686  142011  9556486800210   망고푸딩     999999.0  2022-08-28       1.0
#
#           SALE_PRC  SALE_AMT
# 40664356    1200.0    1200.0
# ...
