# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'cat1014.csv')
df
# Out:
#             SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         20210527  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 1         20210529  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 2         20210529  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 3         20210530  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 4         20210531  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# ...            ...            ...    ...       ...       ...       ...
# 24805738  20220827  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805739  20220828  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805740  20220913  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805741  20220920  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 24805742  20220922  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
# [24805743 rows x 6 columns]

# %%
df['GDS_NM'].value_counts()
# Out:
# 재사용봉투20L               375557
# 재사용봉투                  251539
# 대파1단                   127103
# 배달봉투                   105428
# 흙당근                    102456
#                         ...
# 충화반점라구짜장350g                1
# 피코크툭툭누들타이새우팟퐁커리600g         1
# 청정원양조진간장플러스                 1
# 화이트캄파10p                    1
# 루카스나인라떼더블샷                  1
# Name: GDS_NM, Length: 95457, dtype: int64

# %%
df['GDS_NM'].value_counts().head(50)
# Out:
# 재사용봉투20L        375557
# 재사용봉투           251539
# 대파1단            127103
# 배달봉투            105428
# 흙당근             102456
# 서울우유             93327
# 감자               86819
# 종량제재사용봉투20L      78606
# 대파               77448
# 깻잎5묶음봉           70839
# 백오이              70753
# 백오이1개            67155
# 인큐애호박            65423
# 참이슬후레쉬           65169
# 청양고추             61247
# 양배추              59195
# 청양고추소            57384
# 인큐애호박2개행사        56224
# 적상추1봉비닐          55414
# 팽이버섯             53815
# 종량제봉투20L         52939
# 처음처럼             52700
# 야채               52626
# 깐마늘              51896
# 새송이버섯1봉          51630
# 바나나              50927
# 남양맛있는우유GT기획      50727
# 느타리버섯1팩          49495
# 시금치              48458
# 인큐애호박1개          47773
# 깻잎               47057
# 청상추1봉            45077
# 토속대란1판           45010
# 양파중1망            44121
# 새송이버섯            43385
# CJ양념이잘배는찌개두부     42433
# 딸기               41741
# 추부깻잎1봉           41714
# 농심신라면멀티          41604
# 양파소              40993
# ...

# %%
df = df.astype({'SALE_QTY' : 'int'})

# %%
df = df.astype({'SALE_AMT' : 'int'})

# %%
df = df.astype({'SAL_DT' : 'str'})

# %%
df
# Out:
#             SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         20210527  8801068097474   땅콩샌드         1    1100.0      1100
# 1         20210529  8801068097474   땅콩샌드         1    1100.0      1100
# 2         20210529  8801068097474   땅콩샌드         1    1100.0      1100
# 3         20210530  8801068097474   땅콩샌드         1    1100.0      1100
# 4         20210531  8801068097474   땅콩샌드         1    1100.0      1100
# ...            ...            ...    ...       ...       ...       ...
# 24805738  20220827  9556486800210   망고푸딩         1    3500.0      3500
# 24805739  20220828  9556486800210   망고푸딩         1    3500.0      3500
# 24805740  20220913  9556486800210   망고푸딩         1    3500.0      3500
# 24805741  20220920  9556486800210   망고푸딩         1    3500.0      3500
# 24805742  20220922  9556486800210   망고푸딩         1    3500.0      3500
#
# [24805743 rows x 6 columns]

# %%
test = df.sort_values('SALE_QTY', ascending=False).head(50)
test
# Out:
#             SAL_DT         PLU_CD          GDS_NM  SALE_QTY  SALE_PRC  \
# 24399828  20210919  2501130000710          소금20kg      9999   27000.0
# 24446362  20211106  2599990000117              잡화      9999  400000.0
# 24651563  20210919  8802521125819        국순당대박막걸리      9999    1000.0
# 24445947  20211106  2599990000100          아이스콘1개      9999     900.0
# 24688659  20210919  8809440820009           종이컵박스      9999    9900.0
# 8035492   20220317         202024              딸기      9999   10000.0
# 9579528   20220421  8809517210078           에그탑특란      9999   10000.0
# 6974919   20220524  8801045420042  오뚜기바삭하고고소한튀김가루      9999    3900.0
# 965765    20220124  8801045299419         오옛날사골곰탕      9999    1000.0
# 6163296   20220402         200131           모듬쌈채류      9999  172720.0
# 6163297   20220402         200131           모듬쌈채류      9999  170210.0
# 6169620   20220114         200160             백오이      9999    2480.0
# ...
