# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'df1005.csv')
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 1         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 2         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 3         2021-05-30  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# 4         2021-05-31  8801068097474   땅콩샌드       1.0    1100.0    1100.0
# ...              ...            ...    ...       ...       ...       ...
# 23660707  2022-08-27  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660708  2022-08-28  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660709  2022-09-13  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660710  2022-09-20  9556486800210   망고푸딩       1.0    3500.0    3500.0
# 23660711  2022-09-22  9556486800210   망고푸딩       1.0    3500.0    3500.0
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df = df.astype({'SALE_AMT' : 'int'})

# %%
q1=df['SALE_AMT'].quantile(0.25)
q2=df['SALE_AMT'].quantile(0.5)
q3=df['SALE_AMT'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 3420.0

# %%
q3
# Out:
# 5100.0

# %%
q1
# Out:
# 1680.0

# %%
df.sort_values('SALE_AMT', ascending=False).head(50)
# Out:
#               SAL_DT         PLU_CD           GDS_NM  SALE_QTY     SALE_PRC  \
# 13953223  2022-03-23         201044               딸기       2.0  880491120.0
# 5867761   2022-04-02         200131            모듬쌈채류    9999.0     172720.0
# 5867762   2022-04-02         200131            모듬쌈채류    9999.0     170210.0
# 5867760   2022-04-02         200131            모듬쌈채류    9000.0     176650.0
# 2663438   2021-09-26      520000009             망고스틴       1.0  941181000.0
# 2086866   2022-02-10         200000             청량고추       1.0  930144000.0
# 2326423   2022-01-10       22000033               식품    3000.0     300000.0
# 77228     2021-10-18         200047            청상추1봉       1.0  880306000.0
# 985165    2022-08-13  8801051088151    엘자연퐁용기베이킹소다레몬       1.0  880109440.0
# 1074764   2022-07-22  8801056227708  롯데칠성사이다플러스500ml       1.0  880104890.0
# 10730020  2022-01-22  8801045442723            오옥수수유       1.0  880100780.0
# ...

# %%
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드       1.0    1100.0      1100
# 1         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0      1100
# 2         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0      1100
# 3         2021-05-30  8801068097474   땅콩샌드       1.0    1100.0      1100
# 4         2021-05-31  8801068097474   땅콩샌드       1.0    1100.0      1100
# ...              ...            ...    ...       ...       ...       ...
# 23660707  2022-08-27  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660708  2022-08-28  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660709  2022-09-13  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660710  2022-09-20  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660711  2022-09-22  9556486800210   망고푸딩       1.0    3500.0      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23660712 entries, 0 to 23660711
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    object
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  float64
#  4   SALE_PRC  float64
#  5   SALE_AMT  int32
#  6   month     int64
#  7   weekday   int64
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 1.3+ GB

# %%
df.isnull().sum()
# Out:
# SAL_DT      0
# PLU_CD      0
# GDS_NM      0
# SALE_QTY    0
# SALE_PRC    0
# SALE_AMT    0
# month       0
# weekday     0
# dtype: int64

# %%
condition=df['SALE_AMT']>q3+1.5*iqr
df[condition]
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 1456      2021-08-27              0     황도복숭아       1.0   25900.0     25900
# 1457      2021-08-27              0     황도복숭아       1.0   25900.0     25900
# 1461      2022-01-24             13      딸기1팩       2.0    7900.0     15800
# 1466      2022-01-24             13      딸기1팩       2.0    7900.0     15800
# 1470      2022-01-24             13      딸기1팩       2.0    7900.0     15800
# ...              ...            ...       ...       ...       ...       ...
# 23660154  2022-07-27  8809772191617  코디순수3겹데코       1.0   17000.0     17000
# 23660155  2022-08-26  8809772191617  코디순수3겹데코       1.0   16000.0     16000
# 23660156  2022-08-28  8809772191617  코디순수3겹데코       1.0   16000.0     16000
# 23660157  2022-09-14  8809772191617  코디순수3겹데코       1.0   17000.0     17000
# 23660640  2022-08-13  9002490100070    동서레드블캔       7.0    2300.0     16100
#
#           month  weekday
# 1456          8        4
# ...

# %%
a=df[condition].index
df.drop(a,inplace=True)

# %%
df
# Out:
#               SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474   땅콩샌드       1.0    1100.0      1100
# 1         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0      1100
# 2         2021-05-29  8801068097474   땅콩샌드       1.0    1100.0      1100
# 3         2021-05-30  8801068097474   땅콩샌드       1.0    1100.0      1100
# 4         2021-05-31  8801068097474   땅콩샌드       1.0    1100.0      1100
# ...              ...            ...    ...       ...       ...       ...
# 23660707  2022-08-27  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660708  2022-08-28  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660709  2022-09-13  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660710  2022-09-20  9556486800210   망고푸딩       1.0    3500.0      3500
# 23660711  2022-09-22  9556486800210   망고푸딩       1.0    3500.0      3500
#
#           month  weekday
# 0             5        3
# 1             5        5
# ...

# %%
df.sort_values('SALE_AMT', ascending=False).head(50)
# Out:
#               SAL_DT   PLU_CD       GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 17577687  2021-04-10   461019        냉장부채살       1.0   10230.0     10230
# 5945845   2022-01-31   201034      한우양지국거리       1.0   10230.0     10230
# 5945777   2022-01-29   201034      한우양지국거리       1.0   10230.0     10230
# 17685858  2022-05-13   521001       양념소불고기       1.0   10230.0     10230
# 5945769   2022-01-28   201034      한우양지국거리       1.0   10230.0     10230
# 5945546   2022-01-20   201034      한우양지국거리       1.0   10230.0     10230
# 5954013   2022-04-19   201048       한우다짐육1       1.0   10230.0     10230
# 5954018   2022-04-19   201048       한우다짐육1       1.0   10230.0     10230
# 5945520   2022-01-20   201034      한우양지국거리       1.0   10230.0     10230
# 17540252  2021-09-19   461004      냉장등심국거리       1.0   10230.0     10230
# 9325300   2022-02-16   202313          연어회       1.0   10230.0     10230
# 13631084  2022-05-13   209104       수입설도호주       1.0   10230.0     10230
# ...

# %%
df.sort_values('SALE_QTY', ascending=False).head(50)
# Out:
#               SAL_DT         PLU_CD   GDS_NM  SALE_QTY  SALE_PRC    SALE_AMT  \
# 23304225  2021-11-06  2599990000117       잡화    9999.0  400000.0 -2147483648
# 14026309  2021-11-25   290000001480    조이사시장     656.0      10.0        6560
# 14025758  2021-11-22   290000001480    조이사시장     333.0      10.0        3330
# 14027292  2021-12-05   290000001480    조이사시장     333.0      10.0        3330
# 14027293  2021-12-05   290000001480    조이사시장     333.0      10.0        3330
# 14027291  2021-12-05   290000001480    조이사시장     333.0      10.0        3330
# 23306786  2022-05-29  2599990000247   공병100원     102.0     100.0       10200
# 23306970  2022-08-12  2599990000247   공병100원     102.0     100.0       10200
# 23306825  2022-06-12  2599990000247   공병100원     101.0     100.0       10100
# 23306619  2022-04-04  2599990000247   공병100원     101.0     100.0       10100
# 23306061  2021-10-21  2599990000247   공병100원     100.0     100.0       10000
# ...
