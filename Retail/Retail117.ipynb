# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'df1018.csv')

# %%
df1 = pd.read_excel(base_path + 'gds1018 (3).xlsx')

# %%
df2 = pd.merge(df, df1)

# %%
df2
# Out:
#               SAL_DT         PLU_CD      GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0         2021-05-27  8801068097474        땅콩샌드         1      1100      1100
# 1         2021-05-29  8801068097474        땅콩샌드         1      1100      1100
# 2         2021-05-29  8801068097474        땅콩샌드         1      1100      1100
# 3         2021-05-30  8801068097474        땅콩샌드         1      1100      1100
# 4         2021-05-31  8801068097474        땅콩샌드         1      1100      1100
# ...              ...            ...         ...       ...       ...       ...
# 18256528  2022-09-27  8809359010232  650별애별란30구         1      8000      8000
# 18256529  2022-09-28  8809359010232  650별애별란30구         1      8000      8000
# 18256530  2022-09-28  8809359010232  650별애별란30구         1      8000      8000
# 18256531  2022-09-28  8809359010232  650별애별란30구         1      8000      8000
# 18256532  2022-09-30  8809359010232  650별애별란30구         1      8000      8000
#
# ...

# %%
df3 = df2.dropna()

# %%
df3
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 1175      2021-07-24              0     황도복숭아         1      5980      5980
# 1176      2021-07-24              0     황도복숭아         1      5980      5980
# 1177      2021-07-24              0     황도복숭아         1      5980      5980
# 1178      2021-07-24              0     황도복숭아         1      5980      5980
# 1179      2021-07-24              0     황도복숭아         1      5980      5980
# ...              ...            ...       ...       ...       ...       ...
# 18248318  2022-09-29  8809267390136  서라벌특란30구         1      7800      7800
# 18248319  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 18248320  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 18248321  2022-09-30  8809267390136  서라벌특란30구         2      7800     15600
# 18248322  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
#
#           month  weekday        대분류   소분류
# ...

# %%
data = df3.copy()
data
# Out:
#               SAL_DT         PLU_CD    GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 1175      2021-07-24              0     황도복숭아         1      5980      5980
# 1176      2021-07-24              0     황도복숭아         1      5980      5980
# 1177      2021-07-24              0     황도복숭아         1      5980      5980
# 1178      2021-07-24              0     황도복숭아         1      5980      5980
# 1179      2021-07-24              0     황도복숭아         1      5980      5980
# ...              ...            ...       ...       ...       ...       ...
# 18248318  2022-09-29  8809267390136  서라벌특란30구         1      7800      7800
# 18248319  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 18248320  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
# 18248321  2022-09-30  8809267390136  서라벌특란30구         2      7800     15600
# 18248322  2022-09-30  8809267390136  서라벌특란30구         1      7800      7800
#
#           month  weekday        대분류   소분류
# ...

# %%
# data.to_csv('data1019.csv', index=False)

# %%
data['GDS_NM'].value_counts()
# Out:
# 대파1단              127103
# 흙당근               102456
# 서울우유               93327
# 감자                 86819
# 대파                 77448
#                    ...
# 일미우엉플러스단무지250g         7
# 청정원현미식초900ml           5
# 과자묶음                   4
# 처음처럼페트18L              4
# 크롬바커수입맥주               3
# Name: GDS_NM, Length: 2834, dtype: int64

# %%
data.isnull().sum()
# Out:
# SAL_DT      0
# PLU_CD      0
# GDS_NM      0
# SALE_QTY    0
# SALE_PRC    0
# SALE_AMT    0
# month       0
# weekday     0
# 대분류         0
# 소분류         0
# dtype: int64

# %%
df1 = data[data['GDS_NM'] == '대파1단']
df1
# Out:
#             SAL_DT         PLU_CD GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  month  \
# 9670    2021-07-04            101   대파1단         1       900       900      7
# 9671    2021-07-04            101   대파1단         1       900       900      7
# 9672    2021-07-04            101   대파1단         1       900       900      7
# 9673    2021-07-04            101   대파1단         1       900       900      7
# 9674    2021-07-04            101   대파1단         1       900       900      7
# ...            ...            ...    ...       ...       ...       ...    ...
# 136768  2022-09-30  2908990006331   대파1단         1      1950      1950      9
# 136769  2022-09-30  2908990006331   대파1단         1      1950      1950      9
# 136770  2022-09-30  2908990006331   대파1단         1      1950      1950      9
# 136771  2022-09-30  2908990006331   대파1단         2      1950      3900      9
# 136772  2022-09-30  2908990006331   대파1단         2      1950      3900      9
#
#         weekday 대분류 소분류
# ...

# %%
df1['SALE_QTY'].sum()
# Out:
# 152967
