# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

base_path = ''

# %%
df = pd.read_csv(base_path + 'cat1017.csv')
df
# Out:
#             SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0         20201222       93682091   스니커즈피넛싱글         1       990       990
# 1         20201223       93682091   스니커즈피넛싱글         1       990       990
# 2         20210102       93682091   스니커즈피넛싱글         1       990       990
# 3         20210111       93682091   스니커즈피넛싱글         5       990      4950
# 4         20210113       93682091   스니커즈피넛싱글         6       990      5940
# ...            ...            ...        ...       ...       ...       ...
# 15975942  20220921  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975943  20220924  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975944  20220927  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975945  20220929  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975946  20220325  8888021200164   에너자이저AAA         1      2700      2700
#
# [15975947 rows x 6 columns]

# %%
df['GDS_NM'].value_counts() # 66324 개의 상품.
# Out:
# 재사용봉투20L             329589
# 재사용봉투                113511
# 대파1단                  92565
# 서울우유                  84293
# 배달봉투                  72602
#                       ...
# 동원양반우리아이주먹밥김자반30g         1
# 동원양반한식김자반전복간장50g2         1
# 동원양반한식김자반전복간장50g          1
# 육개장300g                   1
# 기능성수면양말                   1
# Name: GDS_NM, Length: 66324, dtype: int64

# %%
df['GDS_NM'].value_counts().head(50)
# Out:
# 재사용봉투20L        329589
# 재사용봉투           113511
# 대파1단             92565
# 서울우유             84293
# 배달봉투             72602
# 백오이1개            66353
# 깻잎5묶음봉           58581
# 인큐애호박2개행사        56061
# 처음처럼             49388
# 느타리버섯1팩          49326
# 참이슬후레쉬           48123
# 새송이버섯1봉          47917
# 남양맛있는우유GT기획      46758
# 적상추1봉비닐          44623
# 인큐애호박1개          42859
# 감자               42769
# 토속대란1판           41765
# 청양고추소            40398
# 대파               40099
# 백오이5개            39953
# CJ양념이잘배는찌개두부     37686
# 백오이              37066
# 농심신라면멀티          37035
# 부추1단             35409
# 추부깻잎1봉           35060
# 대림신선한콩나물         33786
# 종량제재사용봉투20L      33608
# 양파중1망            32793
# 쌀소성주             32038
# 풀무원소가찌개두부        31621
# CJ삼호부산어묵바른사각     30644
# 코카콜라             30275
# 청상추1봉            29645
# 서울장수막걸리          28470
# 인큐애호박            28468
# 양배추              28299
# 팽이버섯             28104
# 풀무원씻어나온콩나물       28088
# 토속특란1판           28044
# 가지3입봉            27690
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15975947 entries, 0 to 15975946
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    int64
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  int64
#  4   SALE_PRC  int64
#  5   SALE_AMT  int64
# dtypes: int64(5), object(1)
# memory usage: 731.3+ MB

# %% [markdown]
# # 우선 6만개에서 그대로 돌려보는걸로

# %% [markdown]
# # 이 파일은 16개의 마트를 다 합한것 지울 항목이나 판매량 등 기준 세워서 다시 돌리는것도 생각

# %%
df.SAL_DT = df.SAL_DT.astype('str')
df.SAL_DT
# Out:
# 0           20201222
# 1           20201223
# 2           20210102
# 3           20210111
# 4           20210113
#               ...
# 15975942    20220921
# 15975943    20220924
# 15975944    20220927
# 15975945    20220929
# 15975946    20220325
# Name: SAL_DT, Length: 15975947, dtype: object

# %%
df.SAL_DT = pd.to_datetime(df.SAL_DT)

df
# Out:
#              SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT
# 0        2020-12-22       93682091   스니커즈피넛싱글         1       990       990
# 1        2020-12-23       93682091   스니커즈피넛싱글         1       990       990
# 2        2021-01-02       93682091   스니커즈피넛싱글         1       990       990
# 3        2021-01-11       93682091   스니커즈피넛싱글         5       990      4950
# 4        2021-01-13       93682091   스니커즈피넛싱글         6       990      5940
# ...             ...            ...        ...       ...       ...       ...
# 15975942 2022-09-21  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975943 2022-09-24  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975944 2022-09-27  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975945 2022-09-29  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975946 2022-03-25  8888021200164   에너자이저AAA         1      2700      2700
#
# [15975947 rows x 6 columns]

# %%
df['month'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.month
df
# Out:
#              SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2020-12-22       93682091   스니커즈피넛싱글         1       990       990
# 1        2020-12-23       93682091   스니커즈피넛싱글         1       990       990
# 2        2021-01-02       93682091   스니커즈피넛싱글         1       990       990
# 3        2021-01-11       93682091   스니커즈피넛싱글         5       990      4950
# 4        2021-01-13       93682091   스니커즈피넛싱글         6       990      5940
# ...             ...            ...        ...       ...       ...       ...
# 15975942 2022-09-21  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975943 2022-09-24  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975944 2022-09-27  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975945 2022-09-29  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975946 2022-03-25  8888021200164   에너자이저AAA         1      2700      2700
#
#           month
# 0            12
# 1            12
# ...

# %%
df['weekday'] = pd.to_datetime(df['SAL_DT'], format='%Y-%m-%d').dt.weekday
df
# Out:
#              SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2020-12-22       93682091   스니커즈피넛싱글         1       990       990
# 1        2020-12-23       93682091   스니커즈피넛싱글         1       990       990
# 2        2021-01-02       93682091   스니커즈피넛싱글         1       990       990
# 3        2021-01-11       93682091   스니커즈피넛싱글         5       990      4950
# 4        2021-01-13       93682091   스니커즈피넛싱글         6       990      5940
# ...             ...            ...        ...       ...       ...       ...
# 15975942 2022-09-21  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975943 2022-09-24  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975944 2022-09-27  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975945 2022-09-29  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975946 2022-03-25  8888021200164   에너자이저AAA         1      2700      2700
#
#           month  weekday
# 0            12        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15975947 entries, 0 to 15975946
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   SAL_DT    datetime64[ns]
#  1   PLU_CD    int64
#  2   GDS_NM    object
#  3   SALE_QTY  int64
#  4   SALE_PRC  int64
#  5   SALE_AMT  int64
#  6   month     int64
#  7   weekday   int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 975.1+ MB

# %%
#df.to_csv('cat1017_1.csv',index=False)

# %% [markdown]
# # 결과 보고 나니 역시 지워야겠음.

# %%
pd.set_option('display.max_rows', 300)

# %%
df['GDS_NM'].value_counts()
# Out:
# 재사용봉투20L             329589
# 재사용봉투                113511
# 대파1단                  92565
# 서울우유                  84293
# 배달봉투                  72602
#                       ...
# 동원양반우리아이주먹밥김자반30g         1
# 동원양반한식김자반전복간장50g2         1
# 동원양반한식김자반전복간장50g          1
# 육개장300g                   1
# 기능성수면양말                   1
# Name: GDS_NM, Length: 66324, dtype: int64

# %%
df['GDS_NM'].value_counts().head(300)
# Out:
# 재사용봉투20L            329589
# 재사용봉투               113511
# 대파1단                 92565
# 서울우유                 84293
# 배달봉투                 72602
# 백오이1개                66353
# 깻잎5묶음봉               58581
# 인큐애호박2개행사            56061
# 처음처럼                 49388
# 느타리버섯1팩              49326
# 참이슬후레쉬               48123
# 새송이버섯1봉              47917
# 남양맛있는우유GT기획          46758
# 적상추1봉비닐              44623
# 인큐애호박1개              42859
# 감자                   42769
# 토속대란1판               41765
# 청양고추소                40398
# 대파                   40099
# 백오이5개                39953
# CJ양념이잘배는찌개두부         37686
# 백오이                  37066
# 농심신라면멀티              37035
# 부추1단                 35409
# 추부깻잎1봉               35060
# 대림신선한콩나물             33786
# 종량제재사용봉투20L          33608
# 양파중1망                32793
# 쌀소성주                 32038
# 풀무원소가찌개두부            31621
# CJ삼호부산어묵바른사각         30644
# 코카콜라                 30275
# 청상추1봉                29645
# 서울장수막걸리              28470
# ...

# %%
df.isnull().sum()
# Out:
# SAL_DT         0
# PLU_CD         0
# GDS_NM      3158
# SALE_QTY       0
# SALE_PRC       0
# SALE_AMT       0
# month          0
# weekday        0
# dtype: int64

# %%
df = df.dropna(how='any',axis=0)

# %%
df.isnull().sum()
# Out:
# SAL_DT      0
# PLU_CD      0
# GDS_NM      0
# SALE_QTY    0
# SALE_PRC    0
# SALE_AMT    0
# month       0
# weekday     0
# dtype: int64

# %%
drap = df[df['GDS_NM'].str.contains('재사용')].index
df.drop(drap, inplace=True)
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_18128\2003546797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('배달봉투')].index
df.drop(drap, inplace=True)
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_18128\3912365714.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('종량제')].index
df.drop(drap, inplace=True)
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_18128\1150018821.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('음식물')].index
df.drop(drap, inplace=True)
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_18128\2939864518.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('소주공병')].index
df.drop(drap, inplace=True)
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_18128\3509199698.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
drap = df[df['GDS_NM'].str.contains('배송비')].index
df.drop(drap, inplace=True)
# Out:
# C:\Users\min\AppData\Local\Temp\ipykernel_18128\392919644.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drap, inplace=True)

# %%
df
# Out:
#              SAL_DT         PLU_CD     GDS_NM  SALE_QTY  SALE_PRC  SALE_AMT  \
# 0        2020-12-22       93682091   스니커즈피넛싱글         1       990       990
# 1        2020-12-23       93682091   스니커즈피넛싱글         1       990       990
# 2        2021-01-02       93682091   스니커즈피넛싱글         1       990       990
# 3        2021-01-11       93682091   스니커즈피넛싱글         5       990      4950
# 4        2021-01-13       93682091   스니커즈피넛싱글         6       990      5940
# ...             ...            ...        ...       ...       ...       ...
# 15975942 2022-09-21  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975943 2022-09-24  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975944 2022-09-27  8886467100055  프링글스핫스파이스         1      1980      1980
# 15975945 2022-09-29  8886467100055  프링글스핫스파이스         2      1980      3960
# 15975946 2022-03-25  8888021200164   에너자이저AAA         1      2700      2700
#
#           month  weekday
# 0            12        1
# ...

# %% [markdown]
# ## 대략 60만개정도 지워짐

# %%
df.to_csv('cat1017_2.csv',index=False)
