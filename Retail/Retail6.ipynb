# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
# 제품목록 gds_list_0, gds_list_1
gds_a = pd.read_csv(base_path + 'gds_a.csv')
gds_b = pd.read_csv(base_path + 'gds_b.csv')
gds_c = pd.read_csv(base_path + 'gds_c.csv')
gds_d = pd.read_csv(base_path + 'gds_d.csv')

# 제품 카테고리 목록: gdsclss_list_0, gdsclss_list_1
gdsclss_0 = pd.read_csv(base_path + 'gdsclss_list_0.csv')
gdsclss_1 = pd.read_csv(base_path + 'gdsclss_list_1.csv')

# 매출 데이터 마스터(장바구니 단위): tr_list_0, tr_list_1
tr_list_a = pd.read_csv(base_path + 'tr_list_a.csv')
tr_list_b = pd.read_csv(base_path + 'tr_list_b.csv')
tr_list_c = pd.read_csv(base_path + 'tr_list_c.csv')
tr_list_d = pd.read_csv(base_path + 'tr_list_d.csv')

# 매출 제품 데이터 상세: tr_dtl_list_0, tr_dtl_list_1
tr_dtl_list_a = pd.read_csv(base_path + 'tr_dtl_list_a.csv')
tr_dtl_list_b = pd.read_csv(base_path + 'tr_dtl_list_b.csv')
tr_dtl_list_c = pd.read_csv(base_path + 'tr_dtl_list_c.csv')
tr_dtl_list_d = pd.read_csv(base_path + 'tr_dtl_list_d.csv')
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# a 마트 gds+list+dtl 시간문제있는파일
amartsumtime = pd.read_csv(base_path + 'amartsumtimeproblem.csv')
amartsumtime
# Out:
#              SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        2021-09-01   12018     01        3       1            정상판매
# 1        2021-09-01   12018     01        3       2            정상판매
# 2        2021-09-01   12018     01        3       3            정상판매
# 3        2021-09-01   12018     01        3       4            정상판매
# 4        2021-09-01   12018     01        3       5            정상판매
# ...             ...     ...    ...      ...     ...             ...
# 4968529  2022-09-01   12018      7      175       1            정상판매
# 4968530  2022-09-01   12018      7      242       1            정상판매
# 4968531  2022-09-01   12018      7      245       1            정상판매
# 4968532  2022-09-01   12018      7      385       1            정상판매
# 4968533  2022-09-01   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM REAL_SAL_DT REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출  2021-09-01     07:11:38
# 1         360000.0   오뚜기 3분쇠고기카레              매출  2021-09-01     07:11:38
# 2         360000.0   오뚜기 3분쇠고기짜장              매출  2021-09-01     07:11:38
# 3         486000.0        목우촌 뚝심              매출  2021-09-01     07:11:38
# 4        1710000.0    오뚜기 맛있는밥기획              매출  2021-09-01     07:11:38
# ...            ...           ...             ...         ...          ...
# 4968529     5000.0      햇배 4개/행사              매출  2022-09-01     12:57:36
# 4968530     5000.0      햇배 4개/행사              매출  2022-09-01     14:24:01
# 4968531    10000.0      햇배 4개/행사              매출  2022-09-01     14:26:02
# 4968532     5000.0      햇배 4개/행사              매출  2022-09-01     16:29:24
# 4968533    22600.0  청정원 올리브유 재래김              매출  2022-09-01     16:29:37
#
#            PAY_AMT      MSHP_ID
# 0        9000000.0          NaN
# 1        9000000.0          NaN
# 2        9000000.0          NaN
# 3        9000000.0          NaN
# 4        9000000.0          NaN
# ...            ...          ...
# 4968529     5000.0  012018_1636
# 4968530     5000.0          NaN
# 4968531    10000.0  012018_6700
# 4968532     5000.0  012018_2764
# 4968533    22600.0  012018_4787
#
# [4968534 rows x 18 columns]

# %%
amartsumtime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           object
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      object
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: float64(5), int64(5), object(8)
# memory usage: 682.3+ MB

# %%
a = amartsumtime['REAL_SAL_TTM'].dt.strftime('%H:%M:%S')
a
# Out:
# 0          07:11:38
# 1          07:11:38
# 2          07:11:38
# 3          07:11:38
# 4          07:11:38
#              ...
# 4968529    12:57:36
# 4968530    14:24:01
# 4968531    14:26:02
# 4968532    16:29:24
# 4968533    16:29:37
# Name: REAL_SAL_TTM, Length: 4968534, dtype: object

# %%
amartsumtime
# Out:
#              SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        2021-09-01   12018     01        3       1            정상판매
# 1        2021-09-01   12018     01        3       2            정상판매
# 2        2021-09-01   12018     01        3       3            정상판매
# 3        2021-09-01   12018     01        3       4            정상판매
# 4        2021-09-01   12018     01        3       5            정상판매
# ...             ...     ...    ...      ...     ...             ...
# 4968529  2022-09-01   12018      7      175       1            정상판매
# 4968530  2022-09-01   12018      7      242       1            정상판매
# 4968531  2022-09-01   12018      7      245       1            정상판매
# 4968532  2022-09-01   12018      7      385       1            정상판매
# 4968533  2022-09-01   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM REAL_SAL_DT  \
# 0         540000.0   해표 더고소한 파래김              매출  2021-09-01
# 1         360000.0   오뚜기 3분쇠고기카레              매출  2021-09-01
# 2         360000.0   오뚜기 3분쇠고기짜장              매출  2021-09-01
# 3         486000.0        목우촌 뚝심              매출  2021-09-01
# 4        1710000.0    오뚜기 맛있는밥기획              매출  2021-09-01
# ...            ...           ...             ...         ...
# 4968529     5000.0      햇배 4개/행사              매출  2022-09-01
# 4968530     5000.0      햇배 4개/행사              매출  2022-09-01
# 4968531    10000.0      햇배 4개/행사              매출  2022-09-01
# 4968532     5000.0      햇배 4개/행사              매출  2022-09-01
# 4968533    22600.0  청정원 올리브유 재래김              매출  2022-09-01
#
#                REAL_SAL_TTM    PAY_AMT      MSHP_ID
# 0       2022-09-26 07:11:38  9000000.0          NaN
# 1       2022-09-26 07:11:38  9000000.0          NaN
# 2       2022-09-26 07:11:38  9000000.0          NaN
# 3       2022-09-26 07:11:38  9000000.0          NaN
# 4       2022-09-26 07:11:38  9000000.0          NaN
# ...                     ...        ...          ...
# 4968529 2022-09-26 12:57:36     5000.0  012018_1636
# 4968530 2022-09-26 14:24:01     5000.0          NaN
# 4968531 2022-09-26 14:26:02    10000.0  012018_6700
# 4968532 2022-09-26 16:29:24     5000.0  012018_2764
# 4968533 2022-09-26 16:29:37    22600.0  012018_4787
#
# [4968534 rows x 18 columns]

# %%
amartsumtime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           object
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      object
#  15  REAL_SAL_TTM     datetime64[ns]
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: datetime64[ns](1), float64(5), int64(5), object(7)
# memory usage: 682.3+ MB

# %%
# a 마트 gds+list+dtl 시간문제있는파일
a = pd.read_csv(base_path + 'amartsumtimeproblem.csv')
a
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        2021-09-01   12018     01        3       1            정상판매
# 1        2021-09-01   12018     01        3       2            정상판매
# 2        2021-09-01   12018     01        3       3            정상판매
# 3        2021-09-01   12018     01        3       4            정상판매
# 4        2021-09-01   12018     01        3       5            정상판매
# ...             ...     ...    ...      ...     ...             ...
# 4968529  2022-09-01   12018      7      175       1            정상판매
# 4968530  2022-09-01   12018      7      242       1            정상판매
# 4968531  2022-09-01   12018      7      245       1            정상판매
# 4968532  2022-09-01   12018      7      385       1            정상판매
# 4968533  2022-09-01   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM REAL_SAL_DT REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출  2021-09-01     07:11:38
# 1         360000.0   오뚜기 3분쇠고기카레              매출  2021-09-01     07:11:38
# 2         360000.0   오뚜기 3분쇠고기짜장              매출  2021-09-01     07:11:38
# 3         486000.0        목우촌 뚝심              매출  2021-09-01     07:11:38
# 4        1710000.0    오뚜기 맛있는밥기획              매출  2021-09-01     07:11:38
# ...            ...           ...             ...         ...          ...
# 4968529     5000.0      햇배 4개/행사              매출  2022-09-01     12:57:36
# 4968530     5000.0      햇배 4개/행사              매출  2022-09-01     14:24:01
# 4968531    10000.0      햇배 4개/행사              매출  2022-09-01     14:26:02
# 4968532     5000.0      햇배 4개/행사              매출  2022-09-01     16:29:24
# 4968533    22600.0  청정원 올리브유 재래김              매출  2022-09-01     16:29:37
#
#            PAY_AMT      MSHP_ID
# 0        9000000.0          NaN
# 1        9000000.0          NaN
# 2        9000000.0          NaN
# 3        9000000.0          NaN
# 4        9000000.0          NaN
# ...            ...          ...
# 4968529     5000.0  012018_1636
# 4968530     5000.0          NaN
# 4968531    10000.0  012018_6700
# 4968532     5000.0  012018_2764
# 4968533    22600.0  012018_4787
#
# [4968534 rows x 18 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           object
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      object
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: float64(5), int64(5), object(8)
# memory usage: 682.3+ MB

# %%
# a 마트 gds+list+dtl
amartsum = pd.read_csv(base_path + 'amartsum.csv')
amartsum
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM  REAL_SAL_DT  REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출     20210901         71138
# 1         360000.0   오뚜기 3분쇠고기카레              매출     20210901         71138
# 2         360000.0   오뚜기 3분쇠고기짜장              매출     20210901         71138
# 3         486000.0        목우촌 뚝심              매출     20210901         71138
# 4        1710000.0    오뚜기 맛있는밥기획              매출     20210901         71138
# ...            ...           ...             ...          ...           ...
# 4968529     5000.0      햇배 4개/행사              매출     20220901        125736
# 4968530     5000.0      햇배 4개/행사              매출     20220901        142401
# 4968531    10000.0      햇배 4개/행사              매출     20220901        142602
# 4968532     5000.0      햇배 4개/행사              매출     20220901        162924
# 4968533    22600.0  청정원 올리브유 재래김              매출     20220901        162937
#
#            PAY_AMT      MSHP_ID
# 0        9000000.0          NaN
# 1        9000000.0          NaN
# 2        9000000.0          NaN
# 3        9000000.0          NaN
# 4        9000000.0          NaN
# ...            ...          ...
# 4968529     5000.0  012018_1636
# 4968530     5000.0          NaN
# 4968531    10000.0  012018_6700
# 4968532     5000.0  012018_2764
# 4968533    22600.0  012018_4787
#
# [4968534 rows x 18 columns]

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     int64
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: float64(5), int64(8), object(5)
# memory usage: 682.3+ MB

# %%
amartsum.isnull().sum()
# Out:
# SAL_DT                  0
# STR_CD                  0
# POS_NO                  0
# TRAN_NO                 0
# SEQ_NO                  0
# DESI_CNCL_TP_NM         0
# SALE_RTN_SGN            0
# PLU_CD                  0
# GDS_CLSS_CD             0
# SALE_QTY                0
# SALE_PRC                0
# SALE_AMT                0
# GDS_NM                  0
# SALE_KIND_TP_NM         0
# REAL_SAL_DT             0
# REAL_SAL_TTM            0
# PAY_AMT                 0
# MSHP_ID            688555
# dtype: int64

# %%
cols = ['REAL_SAL_DT', 'REAL_SAL_TTM']
amartsum['DTT'] =amartsum[cols].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
amartsum
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM  REAL_SAL_DT  REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출     20210901         71138
# 1         360000.0   오뚜기 3분쇠고기카레              매출     20210901         71138
# 2         360000.0   오뚜기 3분쇠고기짜장              매출     20210901         71138
# 3         486000.0        목우촌 뚝심              매출     20210901         71138
# 4        1710000.0    오뚜기 맛있는밥기획              매출     20210901         71138
# ...            ...           ...             ...          ...           ...
# 4968529     5000.0      햇배 4개/행사              매출     20220901        125736
# 4968530     5000.0      햇배 4개/행사              매출     20220901        142401
# 4968531    10000.0      햇배 4개/행사              매출     20220901        142602
# 4968532     5000.0      햇배 4개/행사              매출     20220901        162924
# 4968533    22600.0  청정원 올리브유 재래김              매출     20220901        162937
#
#            PAY_AMT      MSHP_ID             DTT
# 0        9000000.0          NaN   2021090171138
# 1        9000000.0          NaN   2021090171138
# 2        9000000.0          NaN   2021090171138
# 3        9000000.0          NaN   2021090171138
# 4        9000000.0          NaN   2021090171138
# ...            ...          ...             ...
# 4968529     5000.0  012018_1636  20220901125736
# 4968530     5000.0          NaN  20220901142401
# 4968531    10000.0  012018_6700  20220901142602
# 4968532     5000.0  012018_2764  20220901162924
# 4968533    22600.0  012018_4787  20220901162937
#
# [4968534 rows x 19 columns]

# %%
amartsum
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM  REAL_SAL_DT  REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출     20210901         71138
# 1         360000.0   오뚜기 3분쇠고기카레              매출     20210901         71138
# 2         360000.0   오뚜기 3분쇠고기짜장              매출     20210901         71138
# 3         486000.0        목우촌 뚝심              매출     20210901         71138
# 4        1710000.0    오뚜기 맛있는밥기획              매출     20210901         71138
# ...            ...           ...             ...          ...           ...
# 4968529     5000.0      햇배 4개/행사              매출     20220901        125736
# 4968530     5000.0      햇배 4개/행사              매출     20220901        142401
# 4968531    10000.0      햇배 4개/행사              매출     20220901        142602
# 4968532     5000.0      햇배 4개/행사              매출     20220901        162924
# 4968533    22600.0  청정원 올리브유 재래김              매출     20220901        162937
#
#            PAY_AMT      MSHP_ID             DTT
# 0        9000000.0          NaN   2021090171138
# 1        9000000.0          NaN   2021090171138
# 2        9000000.0          NaN   2021090171138
# 3        9000000.0          NaN   2021090171138
# 4        9000000.0          NaN   2021090171138
# ...            ...          ...             ...
# 4968529     5000.0  012018_1636  20220901125736
# 4968530     5000.0          NaN  20220901142401
# 4968531    10000.0  012018_6700  20220901142602
# 4968532     5000.0  012018_2764  20220901162924
# 4968533    22600.0  012018_4787  20220901162937
#
# [4968534 rows x 19 columns]

# %%
# a 마트 gds+list+dtl
amartsum = pd.read_csv(base_path + 'amartsum.csv')
amartsum
# Out:
# C:\Users\min\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM  REAL_SAL_DT  REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출     20210901         71138
# 1         360000.0   오뚜기 3분쇠고기카레              매출     20210901         71138
# 2         360000.0   오뚜기 3분쇠고기짜장              매출     20210901         71138
# 3         486000.0        목우촌 뚝심              매출     20210901         71138
# 4        1710000.0    오뚜기 맛있는밥기획              매출     20210901         71138
# ...            ...           ...             ...          ...           ...
# 4968529     5000.0      햇배 4개/행사              매출     20220901        125736
# 4968530     5000.0      햇배 4개/행사              매출     20220901        142401
# 4968531    10000.0      햇배 4개/행사              매출     20220901        142602
# 4968532     5000.0      햇배 4개/행사              매출     20220901        162924
# 4968533    22600.0  청정원 올리브유 재래김              매출     20220901        162937
#
#            PAY_AMT      MSHP_ID
# 0        9000000.0          NaN
# 1        9000000.0          NaN
# 2        9000000.0          NaN
# 3        9000000.0          NaN
# 4        9000000.0          NaN
# ...            ...          ...
# 4968529     5000.0  012018_1636
# 4968530     5000.0          NaN
# 4968531    10000.0  012018_6700
# 4968532     5000.0  012018_2764
# 4968533    22600.0  012018_4787
#
# [4968534 rows x 18 columns]

# %%
amartsum['REAL_SAL_TTM'] = pd.to_datetime(t1, format='%H%M%S').dt.strftime('%H:%M:%S')

print (amartsum)
# Out:
#            SAL_DT  STR_CD POS_NO  TRAN_NO  SEQ_NO DESI_CNCL_TP_NM  \
# 0        20210901   12018     01        3       1            정상판매
# 1        20210901   12018     01        3       2            정상판매
# 2        20210901   12018     01        3       3            정상판매
# 3        20210901   12018     01        3       4            정상판매
# 4        20210901   12018     01        3       5            정상판매
# ...           ...     ...    ...      ...     ...             ...
# 4968529  20220901   12018      7      175       1            정상판매
# 4968530  20220901   12018      7      242       1            정상판매
# 4968531  20220901   12018      7      245       1            정상판매
# 4968532  20220901   12018      7      385       1            정상판매
# 4968533  20220901   12018      1      354       1            정상판매
#
#          SALE_RTN_SGN         PLU_CD  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0                   1  8801039939499      12301.0     180.0    3000.0
# 1                   1  8801045312316      12101.0     360.0    1000.0
# 2                   1  8801045291314      12101.0     360.0    1000.0
# 3                   1  8803712127018      11363.0     180.0    2700.0
# 4                   1  8801045890333      12102.0     180.0    9500.0
# ...               ...            ...          ...       ...       ...
# 4968529             1  2999000035403      40602.0       1.0    5000.0
# 4968530             1  2999000035403      40602.0       1.0    5000.0
# 4968531             1  2999000035403      40602.0       2.0    5000.0
# 4968532             1  2999000035403      40602.0       1.0    5000.0
# 4968533             1  8801052098746      12211.0       2.0   11300.0
#
#           SALE_AMT        GDS_NM SALE_KIND_TP_NM  REAL_SAL_DT REAL_SAL_TTM  \
# 0         540000.0   해표 더고소한 파래김              매출     20210901     07:11:38
# 1         360000.0   오뚜기 3분쇠고기카레              매출     20210901     07:11:38
# 2         360000.0   오뚜기 3분쇠고기짜장              매출     20210901     07:11:38
# 3         486000.0        목우촌 뚝심              매출     20210901     07:11:38
# 4        1710000.0    오뚜기 맛있는밥기획              매출     20210901     07:11:38
# ...            ...           ...             ...          ...          ...
# 4968529     5000.0      햇배 4개/행사              매출     20220901     12:57:36
# 4968530     5000.0      햇배 4개/행사              매출     20220901     14:24:01
# 4968531    10000.0      햇배 4개/행사              매출     20220901     14:26:02
# 4968532     5000.0      햇배 4개/행사              매출     20220901     16:29:24
# 4968533    22600.0  청정원 올리브유 재래김              매출     20220901     16:29:37
#
#            PAY_AMT      MSHP_ID
# 0        9000000.0          NaN
# 1        9000000.0          NaN
# 2        9000000.0          NaN
# 3        9000000.0          NaN
# 4        9000000.0          NaN
# ...            ...          ...
# 4968529     5000.0  012018_1636
# 4968530     5000.0          NaN
# 4968531    10000.0  012018_6700
# 4968532     5000.0  012018_2764
# 4968533    22600.0  012018_4787
#
# [4968534 rows x 18 columns]

# %%
amartsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968534 entries, 0 to 4968533
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   SAL_DT           int64
#  1   STR_CD           int64
#  2   POS_NO           object
#  3   TRAN_NO          int64
#  4   SEQ_NO           int64
#  5   DESI_CNCL_TP_NM  object
#  6   SALE_RTN_SGN     int64
#  7   PLU_CD           int64
#  8   GDS_CLSS_CD      float64
#  9   SALE_QTY         float64
#  10  SALE_PRC         float64
#  11  SALE_AMT         float64
#  12  GDS_NM           object
#  13  SALE_KIND_TP_NM  object
#  14  REAL_SAL_DT      int64
#  15  REAL_SAL_TTM     object
#  16  PAY_AMT          float64
#  17  MSHP_ID          object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 682.3+ MB

# %%
amartsum['REAL_SAL_TTM'] = pd.to_numeric(amartsum['REAL_SAL_TTM'])
print(amartsum)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "07:11:38"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-9a9c6b040e3d> in <module>
# ----> 1 amartsum['REAL_SAL_TTM'] = pd.to_numeric(amartsum['REAL_SAL_TTM'])
#       2 print(amartsum)
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "07:11:38" at position 0
