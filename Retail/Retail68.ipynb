# %% [markdown]
# ## 요일

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
base_path = ''

# %%
df = pd.read_csv(base_path + 'foruntitled65_1.csv')
df
# Out:
#              SAL_DT         PLU_CD    GDS_NM  GDS_CLSS_CD  SALE_QTY  SALE_PRC  \
# 0        2021-09-04       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# 1        2021-09-07       93682091  스니커즈피넛싱글        11509       2.0    1100.0
# 2        2021-09-10       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# 3        2021-09-10       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# 4        2021-09-10       93682091  스니커즈피넛싱글        11509       1.0    1100.0
# ...             ...            ...       ...          ...       ...       ...
# 2196143  2021-10-07  9803340000003       갈대비       999999       1.0    4200.0
# 2196144  2021-11-02  9803340000003       갈대비       999999       1.0    4200.0
# 2196145  2022-01-18  9803340000003       갈대비       999999       1.0    4200.0
# 2196146  2022-01-18  9803340000003       갈대비       999999       1.0    4200.0
# 2196147  2022-03-16  9803340000003       갈대비       999999       1.0    4200.0
#
# ...

# %%
dfw = df[['PLU_CD', 'GDS_NM', 'weekday', 'SALE_QTY', 'SALE_AMT']]
dfw
# Out:
#                 PLU_CD    GDS_NM  weekday  SALE_QTY  SALE_AMT
# 0             93682091  스니커즈피넛싱글        5       1.0    1100.0
# 1             93682091  스니커즈피넛싱글        1       2.0    2200.0
# 2             93682091  스니커즈피넛싱글        4       1.0    1100.0
# 3             93682091  스니커즈피넛싱글        4       1.0    1100.0
# 4             93682091  스니커즈피넛싱글        4       1.0    1100.0
# ...                ...       ...      ...       ...       ...
# 2196143  9803340000003       갈대비        3       1.0    4200.0
# 2196144  9803340000003       갈대비        1       1.0    4200.0
# 2196145  9803340000003       갈대비        1       1.0    4200.0
# 2196146  9803340000003       갈대비        1       1.0    4200.0
# 2196147  9803340000003       갈대비        2       1.0    4200.0
#
# [2196148 rows x 5 columns]

# %%
dfw1  = dfw.query('weekday == 1')
dfw2  = dfw.query('weekday == 2')
dfw3  = dfw.query('weekday == 3')
dfw4  = dfw.query('weekday == 4')
dfw5  = dfw.query('weekday == 5')
dfw6  = dfw.query('weekday == 6')
dfw0  = dfw.query('weekday == 0')

# %%
dfw1_1 = dfw1.groupby(['GDS_NM', 'weekday']).sum()
dfw2_1 = dfw2.groupby(['GDS_NM', 'weekday']).sum()
dfw3_1 = dfw3.groupby(['GDS_NM', 'weekday']).sum()
dfw4_1 = dfw4.groupby(['GDS_NM', 'weekday']).sum()
dfw5_1 = dfw5.groupby(['GDS_NM', 'weekday']).sum()
dfw6_1 = dfw6.groupby(['GDS_NM', 'weekday']).sum()
dfw0_1 = dfw0.groupby(['GDS_NM', 'weekday']).sum()

# %%
dfw1_2 = dfw1_1.reset_index()
dfw2_2 = dfw2_1.reset_index()
dfw3_2 = dfw3_1.reset_index()
dfw4_2 = dfw4_1.reset_index()
dfw5_2 = dfw5_1.reset_index()
dfw6_2 = dfw6_1.reset_index()
dfw0_2 = dfw0_1.reset_index()

# %%
dfw0_2 = dfw0_1.reset_index()
dfw0_2
# Out:
#              GDS_NM  weekday            PLU_CD  SALE_QTY   SALE_AMT
# 0              0000        0    17382432191114       2.0     3600.0
# 1     0241405572666        0      241405572666       1.0      900.0
# 2       10001200청량초        0    26680550130104      15.0    15000.0
# 3         12곡플러스그레인        0   117785921001050      41.0    61500.0
# 4          1300오이고추        0     4104100024010       2.0     2600.0
# ...             ...      ...               ...       ...        ...
# 2687        흙당근1봉비닐        0  2822059000406512    1016.0  2135300.0
# 2688            흙대파        0   166755200043161      66.0   175500.0
# 2689            흙생강        0            201021       1.0     1470.0
# 2690      히말라야암염88g        0     9001414088494       1.0    11900.0
# 2691       히츨러수수깡캔디        0    12300750019530       3.0    10500.0
#
# [2692 rows x 5 columns]

# %%
dfw1_2.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  weekday             PLU_CD  SALE_QT
2.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  weekday             PLU_CD  SALE_QTY      SALE_AMT
# 515            대파1단        5  30323311826001672   12207.0  1.942899e+07
# 1464      아이스크림바10개        5   1453394410052546   12200.0  1.427908e+07
# 1463         아이스콘1개        5     54599790002100   12022.0  1.092070e+07
# 1820             잡화        5    808596890036387   10389.0  4.001107e+09
# 268          깻잎4묶음봉        5  22431221923252928    9639.0  1.282098e+07
# 1045          백오이1개        5  20278806748392520    8612.0  2.176332e+07
# 357         느타리버섯1팩        5  14102062598055242    6720.0  6.317780e+06
# 2298         팽이버섯1봉        5  10684720282205956    6177.0  3.217040e+06
# 1831        적상추1봉비닐        5  16403794634453800    6128.0  1.095347e+07
# 1787      인큐애호박2개행사        5  12533873676218160    6023.0  9.278340e+06
# 2022          청양고추소        5  15647457237429804    5710.0  1.163648e+07
# 2741            흙당근        5         1122875376    5593.0  8.315930e+06
# ...

# %%
dfw6_2.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  weekday             PLU_CD  SALE_QTY     SALE_AMT
# 491            대파1단        6  32987946671801784   13341.0   20361910.0
# 1233         소금20kg        6      5101120001162   10000.0  270005000.0
# 260          깻잎4묶음봉        6  19615319599078912    8321.0   11087220.0
# 1011          백오이1개        6  17779596562328076    7283.0   19457280.0
# 1748      인큐애호박2개행사        6  14040964336450520    6528.0   10038120.0
# 344         느타리버섯1팩        6  13383430565515600    6253.0    5948450.0
# 1469             야채        6   5795142526120253    6227.0   15788750.0
# 2226         파프리카1개        6   8814239831680770    5753.0    8127280.0
# 2250         팽이버섯1봉        6  10527634822026460    5737.0    3033960.0
# 2678            흙당근        6         1128704840    5620.0    8786400.0
# 1975          청양고추소        6  15231471666700504    5486.0   11218720.0
# 1790        적상추1봉비닐        6  14722398411947592    5448.0    9719160.0
# ...

# %%
dfw0_2.sort_values('SALE_QTY', ascending=False).head(30)
# Out:
#              GDS_NM  weekday             PLU_CD  SALE_QTY     SALE_AMT
# 506            대파1단        0  23190468330475608    9151.0   15209990.0
# 1024          백오이1개        0  18469134180601968    7755.0   19453120.0
# 270          깻잎4묶음봉        0  14137691420959416    6374.0    8442000.0
# 361         느타리버섯1팩        0  11195530612196528    5126.0    4745380.0
# 1026          백오이3개        0   8687592107441900    4841.0    7735120.0
# 2252         팽이버섯1봉        0   8927690320198287    4774.0    2519940.0
# 2685            흙당근        0          952614824    4742.0    7612830.0
# 1766      인큐애호박2개행사        0  10418709757320620    4596.0    7752230.0
# 2228         파프리카1개        0   6527773657521996    4432.0    6087690.0
# 1985          청양고추소        0  11752319620600904    4247.0    8426160.0
# 1809        적상추1봉비닐        0  10958165346336808    4188.0    7910280.0
# 1765        인큐애호박1개        0   8932115571932887    4059.0    5165580.0
# ...

# %%
test1 = dfw1_2[dfw1_2.SALE_QTY > 2104.0]
test2 = dfw2_2[dfw2_2.SALE_QTY > 2071.0]
test3 = dfw3_2[dfw3_2.SALE_QTY > 2237.0]
test4 = dfw4_2[dfw4_2.SALE_QTY > 2428.0]
test5 = dfw5_2[dfw5_2.SALE_QTY > 2104.0]
test6 = dfw6_2[dfw6_2.SALE_QTY > 3229.0]
test0 = dfw0_2[dfw0_2.SALE_QTY > 2525.0]

# %%
test1.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test2.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test3.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test4.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test5.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test6.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test0.plot.bar(x='GDS_NM', y = 'SALE_QTY')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %% [markdown]
# ---

# %%
test1.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test2.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test3.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test4.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test5.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test6.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>

# %%
test0.plot.bar(x='GDS_NM', y = 'SALE_AMT')
# Out:
# <AxesSubplot:xlabel='GDS_NM'>
